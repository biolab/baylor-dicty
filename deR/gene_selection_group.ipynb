# %%
import os
import sys
from importlib import reload

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.insert(0,module_path)

import matplotlib.pyplot as plt
import pandas as pd
import deR.enrichment_library
reload(deR.enrichment_library)
from deR.enrichment_library import *

# %%
pathSelected = '/home/karin/Documents/timeTrajectories/data/regulons/selected_genes/'
pathDE = '/home/karin/Documents/timeTrajectories/data/deTime/de_time_impulse/'

# %%
selected_genes=pd.read_table(pathSelected+'newGenes_noAll-removeSelf_selectedGenesByGroup_scalemean0std1_logTrue_kN6_splitStrain.tsv',
                             index_col=0).T.rename(
    {'1Ag-':'Ag','2LAg':'LAg','3TA':'TA','4CD':'CD','5WT':'WT','6SFB':'SFB','7PD':'PD'},axis=1)

# %%
selected_genes.query('Ag<=1 & LAg<=1 & TA>=1 & CD>=4 & WT>=1 & SFB >=1 & PD >=1')
# Out:
#                Ag  LAg   TA   CD   WT  SFB   PD
# DDB_G0267544  1.0  1.0  2.0  5.0  2.0  2.0  2.0
# DDB_G0267550  0.0  1.0  2.0  5.0  2.0  2.0  2.0
# DDB_G0267566  0.0  0.0  2.0  5.0  2.0  1.0  2.0
# DDB_G0267620  0.0  0.0  2.0  4.0  2.0  2.0  2.0
# DDB_G0268148  0.0  0.0  1.0  4.0  1.0  2.0  1.0
# ...           ...  ...  ...  ...  ...  ...  ...
# DDB_G0293522  1.0  1.0  1.0  5.0  2.0  1.0  2.0
# DDB_G0293676  1.0  1.0  2.0  5.0  2.0  2.0  1.0
# DDB_G0293864  0.0  1.0  2.0  4.0  2.0  2.0  1.0
# DDB_G0295713  1.0  1.0  1.0  5.0  2.0  1.0  2.0
# DDB_G0295747  0.0  1.0  2.0  5.0  2.0  2.0  2.0
#
# [138 rows x 7 columns]
