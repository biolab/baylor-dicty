# %%
import os
import sys
from importlib import reload

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.insert(0,module_path)

import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display

from orangecontrib.bioinformatics.geneset.__init__ import (list_all, load_gene_sets)

import deR.enrichment_library as enr
reload(enr)
# Out:
# <module 'deR.enrichment_library' from '/home/karin/Documents/git/baylor-dicty/deR/enrichment_library.py'>

# %%
pathSelected = '/home/karin/Documents/timeTrajectories/data/regulons/selected_genes/'
pathDE = '/home/karin/Documents/timeTrajectories/data/deTime/de_time_impulse/'
dataPath='/home/karin/Documents/timeTrajectories/data/RPKUM/combined/'

# %%
# Get all ene sets
gene_sets=list(list_all(organism='44689'))
GENE_SETS_ONTOLOGY=enr.get_gene_sets(gene_set_names=gene_sets, go_slims=True)

# %%
# For conversion of gene names to EID
genes = pd.read_csv(dataPath + 'mergedGenes_RPKUM.tsv', sep='\t', index_col=0)
all_gene_names= genes[(genes != 0).any(axis=1)].index
NAME_EID=enr.name_genes_entrez(gene_names=all_gene_names, key_entrez=False)
ALL_GENE_NAMES_EID=enr.convert_EID(genes=all_gene_names, name_EID=NAME_EID)

# %%
# Rename strain groups to work with pd query
selected_genes=pd.read_table(pathSelected+'newGenes_noAll-removeSelf_selectedGenesByGroup_scalemean0std1_logTrue_kN6_splitStrain.tsv',
                             index_col=0).T.rename(
    {'1Ag-':'Ag','2LAg':'LAg','3TA':'TA','4CD':'CD','5WT':'WT','6SFB':'SFB','7PD':'PD'},axis=1)

# Genes that were never expressed were never selected - thus they are not used in enrichment
# selected_genes.loc[genes[(genes == 0).all(axis=1)].index,:].max().max()
selected_genes=selected_genes.loc[all_gene_names,:]

# %%
# Rename strain groups to work with pd query
selected_genes1000=pd.read_table(pathSelected+'newGenes_noAll-removeSelf_selectedGenes1000ByGroup_scalemean0std1_logTrue_kN6_splitStrain.tsv',
                             index_col=0).T.rename(
    {'1Ag-':'Ag','2LAg':'LAg','3TA':'TA','4CD':'CD','5WT':'WT','6SFB':'SFB','7PD':'PD'},axis=1)


selected_genes1000=selected_genes1000.loc[all_gene_names,:]

# %%
# Rename strain groups to work with pd query
selected_genes_DE=pd.read_table(pathDE+'DE_FDRe-11group.tsv',
                             index_col=0).T.rename(
    {'1Ag-_DE':'Ag','2LAg_DE':'LAg','3TA_DE':'TA','4CD_DE':'CD','5WT_DE':'WT','6SFB_DE':'SFB','7PD_DE':'PD'},axis=1)

selected_genes_DE=selected_genes_DE.loc[all_gene_names,:]

# %%
def group_diff_enrichment(selected_genes:pd.DataFrame, condition:str,padj:float=0.25):
    selected=selected_genes.query(condition).index
    query_EID=enr.convert_EID(genes=selected, name_EID=NAME_EID)
    print('*** Condition:',condition, ' selected:',len(selected),'with EID:',len(query_EID))
    result=None
    if len(query_EID) > 0:
        enrichment=enr.gene_set_enrichment(query_EID, reference_EID=ALL_GENE_NAMES_EID, 
                                                padj_threshold=padj,
                                                gene_sets_ontology=GENE_SETS_ONTOLOGY)
        if len(enrichment)>0:
            enrichment_display=list()
            enrichment= sorted(enrichment, key=lambda data: data.padj)
            for enriched in enrichment:
                enrichment_display.append({'Gene set':enriched.gene_set.name,'Ontology':enriched.ontology,
                                           'FDR':"{:.2e}".format(enriched.padj),'N in query':enriched.in_query})
            result=pd.DataFrame(enrichment_display)
    print('Enrichment:')
    display(result)

# %%
for condition in ['Ag<=1 & LAg>=3 & TA>=1 & CD>=4 & WT>=1 & PD >=1',
                 'Ag<=1 & LAg<=1 & TA>=1 & CD>=4 & WT>=1 & PD >=1',
                 'Ag<=1 & LAg<=1 & TA<=1 & CD>=4 & WT>=1 & PD >=1',
                 'Ag<=1 & LAg<=1 & TA<=1 & CD<=1 & WT>=1 & PD >=1']:
    group_diff_enrichment(selected_genes,condition)
# Out:
# *** Condition: Ag<=1 & LAg>=3 & TA>=1 & CD>=4 & WT>=1 & PD >=1  selected: 739 with EID: 735
# Enrichment:
#                                Gene set                  Ontology       FDR  \
# 0  cell wall organization or biogenesis  (GO, biological_process)  1.76e-04
# 1                  extracellular region  (GO, cellular_component)  1.80e-04
# 2        aberrant spore coat morphology   (Dictybase, Phenotypes)  1.80e-04
# 3      external encapsulating structure  (GO, cellular_component)  3.33e-02
# 4                             cell wall  (GO, cellular_component)  3.33e-02
# 5      anatomical structure development  (GO, biological_process)  1.02e-01
#
#    N in query
# 0           8
# 1          26
# 2           7
# 3           5
# 4           5
# 5          41
# *** Condition: Ag<=1 & LAg<=1 & TA>=1 & CD>=4 & WT>=1 & PD >=1  selected: 157 with EID: 154
# Enrichment:
# None
# *** Condition: Ag<=1 & LAg<=1 & TA<=1 & CD>=4 & WT>=1 & PD >=1  selected: 87 with EID: 86
# Enrichment:
#                                          Gene set                 Ontology  \
# 0                          precocious aggregation  (Dictybase, Phenotypes)
# 1  decreased actin nucleation on plasma membranes  (Dictybase, Phenotypes)
# 2            decreased lateral pseudopod traction  (Dictybase, Phenotypes)
# 3                   increased endocytic recycling  (Dictybase, Phenotypes)
#
#         FDR  N in query
# 0  1.60e-01           2
# 1  1.60e-01           1
# 2  1.60e-01           1
# 3  1.60e-01           1
# *** Condition: Ag<=1 & LAg<=1 & TA<=1 & CD<=1 & WT>=1 & PD >=1  selected: 256 with EID: 250
# Enrichment:
# None

# %%
for condition in ['Ag==4',
                 'LAg==4',
                 'TA==2',
                  # Use 4 instead of 5 (all strains) for CD as gtaG has almost no DE genes
                 'CD>=4',
                 'PD==2']:
    group_diff_enrichment(selected_genes_DE,condition)
# Out:
# *** Condition: Ag==4  selected: 834 with EID: 827
# Enrichment:
#                                              Gene set  \
# 0                                extracellular region
# 1                    anatomical structure development
# 2                                cell differentiation
# 3   anatomical structure formation involved in mor...
# 4                               delayed tip formation
# 5                           decreased spore viability
# 6                abolished stalk cell differentiation
# 7                      aberrant spore coat morphology
# 8                       Starch and sucrose metabolism
# 9                               abolished sporulation
# 10                                    plasma membrane
# 11                  aberrant fruiting body morphology
# 12               cell wall organization or biogenesis
# 13          increased prestalk 0 cell differentiation
# 14                       decreased catalytic activity
# 15                        abolished cellulose binding
# 16             aberrant defense response to bacterium
# 17                               aberrant development
# 18                                          wild type
# 19                   external encapsulating structure
# 20                                          cell wall
# 21                           abolished SDF production
# 22           development arrests at loose mound stage
# 23                                cell-cell signaling
# 24                                 thin standing slug
# 25                  increased cell-substrate adhesion
# 26                           abolished DIF production
# 27                        aberrant chemotaxis to cAMP
# 28                                 biological_process
# 29                                       reproduction
# 30                               aberrant aggregation
# 31  AGE-RAGE signaling pathway in diabetic complic...
# 32                                 cellular_component
#
#                     Ontology       FDR  N in query
# 0   (GO, cellular_component)  2.46e-06          32
# 1   (GO, biological_process)  2.46e-06          62
# 2   (GO, biological_process)  2.80e-06          30
# 3   (GO, biological_process)  2.25e-03          16
# 4    (Dictybase, Phenotypes)  6.99e-03           6
# 5    (Dictybase, Phenotypes)  6.99e-03          13
# 6    (Dictybase, Phenotypes)  3.15e-02           4
# 7    (Dictybase, Phenotypes)  3.20e-02           5
# 8           (KEGG, Pathways)  3.20e-02           8
# 9    (Dictybase, Phenotypes)  3.62e-02           7
# 10  (GO, cellular_component)  4.79e-02          31
# 11   (Dictybase, Phenotypes)  6.48e-02          15
# 12  (GO, biological_process)  6.48e-02           5
# 13   (Dictybase, Phenotypes)  7.16e-02           3
# 14   (Dictybase, Phenotypes)  1.03e-01           5
# 15   (Dictybase, Phenotypes)  1.04e-01           2
# 16   (Dictybase, Phenotypes)  1.12e-01           3
# 17   (Dictybase, Phenotypes)  1.28e-01           9
# 18   (Dictybase, Phenotypes)  1.31e-01          35
# 19  (GO, cellular_component)  1.37e-01           4
# 20  (GO, cellular_component)  1.37e-01           4
# 21   (Dictybase, Phenotypes)  1.37e-01           4
# 22   (Dictybase, Phenotypes)  1.37e-01           5
# 23  (GO, biological_process)  1.37e-01           4
# 24   (Dictybase, Phenotypes)  1.81e-01           2
# 25   (Dictybase, Phenotypes)  1.81e-01           6
# 26   (Dictybase, Phenotypes)  1.81e-01           2
# 27   (Dictybase, Phenotypes)  1.98e-01           6
# 28  (GO, biological_process)  1.98e-01         265
# 29  (GO, biological_process)  1.99e-01          14
# 30   (Dictybase, Phenotypes)  2.27e-01           9
# 31          (KEGG, Pathways)  2.27e-01           5
# 32  (GO, cellular_component)  2.29e-01         268
# *** Condition: LAg==4  selected: 1888 with EID: 1884
# Enrichment:
#                                              Gene set  \
# 0                                extracellular region
# 1                    external encapsulating structure
# 2                                           cell wall
# 3                           decreased spore viability
# 4   anatomical structure formation involved in mor...
# 5                                cell differentiation
# 6                    anatomical structure development
# 7                   extracellular matrix organization
# 8                                 ribosome biogenesis
# 9                      aberrant spore coat morphology
# 10                      Starch and sucrose metabolism
# 11                                 biological_process
# 12               cell wall organization or biogenesis
# 13                                 molecular_function
#
#                     Ontology       FDR  N in query
# 0   (GO, cellular_component)  5.24e-04          48
# 1   (GO, cellular_component)  1.58e-03           9
# 2   (GO, cellular_component)  1.58e-03           9
# 3    (Dictybase, Phenotypes)  1.58e-03          23
# 4   (GO, biological_process)  1.58e-03          26
# 5   (GO, biological_process)  1.58e-03          42
# 6   (GO, biological_process)  5.83e-03          96
# 7   (GO, biological_process)  3.00e-02           4
# 8   (GO, biological_process)  3.00e-02          20
# 9    (Dictybase, Phenotypes)  3.71e-02           7
# 10          (KEGG, Pathways)  5.81e-02          12
# 11  (GO, biological_process)  7.23e-02         594
# 12  (GO, biological_process)  1.52e-01           7
# 13  (GO, molecular_function)  1.73e-01         598
# *** Condition: TA==2  selected: 444 with EID: 442
# Enrichment:
#                                              Gene set  \
# 0                                  Metabolic pathways
# 1                       Starch and sucrose metabolism
# 2         Amino sugar and nucleotide sugar metabolism
# 3                                Galactose metabolism
# 4   anatomical structure formation involved in mor...
# 5                                cell differentiation
# 6                      carbohydrate metabolic process
# 7                    anatomical structure development
# 8               Biosynthesis of secondary metabolites
# 9                                           Phagosome
# 10              aberrant response to abiotic stimulus
# 11                                            Alanine
# 12                  Pantothenate and CoA biosynthesis
# 13                                 hydrolase activity
# 14                               extracellular region
# 15  aberrant positive regulation of chemorepellant...
# 16            Glyoxylate and dicarboxylate metabolism
# 17                         Cyanoamino acid metabolism
# 18                           aberrant cell morphology
# 19                      decreased rate of endocytosis
# 20               decreased sorting to prestalk region
# 21                          decreased spore viability
# 22                                Pyruvate metabolism
# 23           Pentose and glucuronate interconversions
# 24                                 molecular_function
# 25  aberrant plasma membrane organization and biog...
# 26                   abolished small molecule binding
# 27          increased prestalk B cell differentiation
# 28              increased protein kinase B activation
# 29                            delayed gene expression
# 30   increased spore sensitivity to hydrogen peroxide
# 31                            decreased lipid binding
# 32        decreased protein localization to cytoplasm
# 33                        abolished response to SDF-1
# 34                 decreased phosphorylation of actin
# 35                        decreased catalase activity
# 36                                          transport
# 37                                 biological_process
# 38                   small molecule metabolic process
# 39                                Nitrogen metabolism
# 40                            Sphingolipid metabolism
# 41                                  Carbon metabolism
# 42                        Biosynthesis of antibiotics
#
#                     Ontology       FDR  N in query
# 0           (KEGG, Pathways)  4.99e-04          48
# 1           (KEGG, Pathways)  1.41e-03           8
# 2           (KEGG, Pathways)  3.32e-03           7
# 3           (KEGG, Pathways)  6.40e-03           5
# 4   (GO, biological_process)  1.68e-02          10
# 5   (GO, biological_process)  3.39e-02          14
# 6   (GO, biological_process)  4.04e-02          10
# 7   (GO, biological_process)  7.22e-02          28
# 8           (KEGG, Pathways)  8.65e-02          18
# 9           (KEGG, Pathways)  8.65e-02           7
# 10   (Dictybase, Phenotypes)  1.87e-01           2
# 11          (KEGG, Pathways)  1.87e-01           4
# 12          (KEGG, Pathways)  1.87e-01           3
# 13  (GO, molecular_function)  1.92e-01           4
# 14  (GO, cellular_component)  1.92e-01          12
# 15   (Dictybase, Phenotypes)  1.92e-01           2
# 16          (KEGG, Pathways)  1.92e-01           5
# 17          (KEGG, Pathways)  1.92e-01           2
# 18   (Dictybase, Phenotypes)  2.28e-01           5
# 19   (Dictybase, Phenotypes)  2.29e-01           2
# 20   (Dictybase, Phenotypes)  2.29e-01           2
# 21   (Dictybase, Phenotypes)  2.29e-01           6
# 22          (KEGG, Pathways)  2.29e-01           4
# 23          (KEGG, Pathways)  2.29e-01           2
# 24  (GO, molecular_function)  2.42e-01         148
# 25   (Dictybase, Phenotypes)  2.42e-01           1
# 26   (Dictybase, Phenotypes)  2.42e-01           1
# 27   (Dictybase, Phenotypes)  2.42e-01           1
# 28   (Dictybase, Phenotypes)  2.42e-01           1
# 29   (Dictybase, Phenotypes)  2.42e-01           3
# 30   (Dictybase, Phenotypes)  2.42e-01           1
# 31   (Dictybase, Phenotypes)  2.42e-01           1
# 32   (Dictybase, Phenotypes)  2.42e-01           1
# 33   (Dictybase, Phenotypes)  2.42e-01           1
# 34   (Dictybase, Phenotypes)  2.42e-01           1
# 35   (Dictybase, Phenotypes)  2.42e-01           1
# 36  (GO, biological_process)  2.42e-01          28
# 37  (GO, biological_process)  2.42e-01         146
# 38  (GO, biological_process)  2.42e-01          20
# 39          (KEGG, Pathways)  2.42e-01           2
# 40          (KEGG, Pathways)  2.42e-01           3
# 41          (KEGG, Pathways)  2.42e-01           8
# 42          (KEGG, Pathways)  2.42e-01          12
# *** Condition: CD>=4  selected: 27 with EID: 27
# Enrichment:
# None
# *** Condition: PD==2  selected: 2055 with EID: 2045
# Enrichment:
#                                              Gene set  \
# 0                                extracellular region
# 1   anatomical structure formation involved in mor...
# 2                       Starch and sucrose metabolism
# 3                                  hydrolase activity
# 4                                cell differentiation
# 5                                  Metabolic pathways
# 6                           One carbon pool by folate
# 7                    anatomical structure development
# 8         Amino sugar and nucleotide sugar metabolism
# 9                                Galactose metabolism
# 10                                             Valine
# 11                   small molecule metabolic process
# 12                        secondary metabolic process
# 13                                 hydrolase activity
# 14                                Nitrogen metabolism
#
#                     Ontology       FDR  N in query
# 0   (GO, cellular_component)  9.77e-10          63
# 1   (GO, biological_process)  6.68e-03          27
# 2           (KEGG, Pathways)  6.68e-03          15
# 3   (GO, molecular_function)  2.34e-02          17
# 4   (GO, biological_process)  2.34e-02          41
# 5           (KEGG, Pathways)  2.34e-02         143
# 6           (KEGG, Pathways)  2.41e-02           8
# 7   (GO, biological_process)  2.70e-02          99
# 8           (KEGG, Pathways)  3.36e-02          12
# 9           (KEGG, Pathways)  3.36e-02           8
# 10          (KEGG, Pathways)  9.46e-02          13
# 11  (GO, biological_process)  1.28e-01          78
# 12  (GO, biological_process)  1.29e-01           4
# 13  (GO, molecular_function)  1.54e-01          10
# 14          (KEGG, Pathways)  1.54e-01           5
