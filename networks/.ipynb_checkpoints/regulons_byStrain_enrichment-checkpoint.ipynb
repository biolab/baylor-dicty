# %% [markdown]
# # Enrichment of regulons from Regulons_by_strain

# %%
import os
import sys
from importlib import reload

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.insert(0,module_path)

import pandas as pd
from IPython.display import display
pd.set_option('max_colwidth', 70)
pd.set_option('display.max_rows', 500)
import string
import numpy as np

from orangecontrib.bioinformatics.geneset.__init__ import list_all

import jupyter_functions as jf
reload(jf)
import jupyter_functions as jf
from functionsDENet import loadPickle, savePickle
import stages_DE.enrichment_library as enr
reload(enr)
import stages_DE.enrichment_library as enr

# %%
#Path for expression data (mergedGenes_RPKUM.tsv)
dataPath='/home/karin/Documents/timeTrajectories/data/RPKUM/combined/'
#Path for regulons
pathRegulons='/home/karin/Documents/timeTrajectories/data/regulons/by_strain/kN300_mean0std1_log/'

# %% [markdown]
# ## Used gene sets
# Use gene sets that do not have less than 5 or more than 500 genes. Use all ontologies.

# %%
# Get all gene sets
gene_sets=list(list_all(organism='44689'))
GENE_SETS_ONTOLOGY=enr.get_gene_sets(gene_set_names=gene_sets, go_slims=True,set_sizes=(5,500))

# %%
# Find out max/min gene set sizes and N sets
max_n=0
min_n=np.inf
for k,v in GENE_SETS_ONTOLOGY.items():
    for s in v:
        n=len(s.genes)
        if n<min_n:
            min_n=n
        if n>max_n:
            max_n=n
print('Min size',min_n,'Max size',max_n)  
print('N sets',{k:len(v) for k,v in GENE_SETS_ONTOLOGY.items()})
# Out:
# Min size 5 Max size 440
# N sets {('GO', 'molecular_function'): 35, ('GO', 'biological_process'): 52, ('GO', 'cellular_component'): 24, ('Dictybase', 'Phenotypes'): 209, ('KEGG', 'Pathways'): 96}

# %%
# For conversion of gene names to EID
genes = pd.read_csv(dataPath + 'mergedGenes_RPKUM.tsv', sep='\t', index_col=0)
all_gene_names= genes[(genes != 0).any(axis=1)].index
NAME_EID=enr.name_genes_entrez(gene_names=all_gene_names, key_entrez=False)
ALL_GENE_NAMES_EID=enr.convert_EID(genes=all_gene_names, name_EID=NAME_EID)

# %%
def group_diff_enrichment(data:pd.DataFrame,group:str,padj:float=0.25,min_overlap:int=None,
                          use_annotated_genes:bool=False):
    #Displays only gene sets that have overlap with query greater or equal to min_overlap 
    #For p value and padj calculation uses alll that have overlap >=1 } from gene_set_enrichment
    """
    :param use_annotated_genes: if True use for reference and query  only genes that have at 
    least one gene set annotation
    """
    selected=list(data[data['Cluster']==group].index)
    query_EID=enr.convert_EID(genes=selected, name_EID=NAME_EID)
    print('***  '+group+' selected:',len(selected),'with EID:',len(query_EID))
    
    reference_gene_eids=ALL_GENE_NAMES_EID.copy()
    query_eids=query_EID.copy()
    
    if use_annotated_genes:
        gene_sets_genes=set()
        for gene_set_name, gene_sets in GENE_SETS_ONTOLOGY.items():
            for gene_set in gene_sets:
                gene_sets_genes.update(gene_set.genes)
        reference_gene_eids=set(reference_gene_eids) & gene_sets_genes
        query_eids=set(query_eids) & gene_sets_genes
        print('Ratio of genes annotated with a gene set in reference',
              round(len(reference_gene_eids)/len(ALL_GENE_NAMES_EID),2),
             'and query',round(len(query_eids)/len(query_EID),2))
    
    query_in_enriched=set()
    result=None
    if len(query_eids) > 0:
        enrichment=enr.gene_set_enrichment(query_eids, reference_EID=reference_gene_eids, 
                                                padj_threshold=padj,min_overlap=min_overlap,
                                                gene_sets_ontology=GENE_SETS_ONTOLOGY)
        if len(enrichment)>0:
            enrichment_display=list()
            enrichment= sorted(enrichment, key=lambda data: data.padj)
            for enriched in enrichment:
                query_in_enriched.update(enriched.gene_set.genes & query_eids)
                enrichment_display.append({'Gene set':enriched.gene_set.name,
                                           'Ontology':enriched.ontology[0]+': '+enriched.ontology[1],
                                           'FDR':"{:.2e}".format(enriched.padj),'N in query':enriched.in_query,
                                           'Set size':len(enriched.gene_set.genes),
                                                          'N in ref.':enriched.in_reference})
            result=pd.DataFrame(enrichment_display)
    print('Enrichment at FDR: '+str(padj)+' and min query - gene set overlap',str(min_overlap))
    print('N query genes in displayed gene sets:',len(query_in_enriched),'out of', len(query_eids),
          'query genes used for enrichment calculation.')
    display(result)
    print('\n')
    return result

# %% [markdown]
# ## Enrichment reports

# %%
save_enrichment=False

# %% [markdown]
# ### Enrichment for expression_minExpressed0.990.1Strains1Min1Max18_clustersLouvain0.4minmaxNologPCA30kN30.pdf

# %%
regulons=pd.read_table(pathRegulons+'mergedGenes_minExpressed0.990.1Strains1Min1Max18_clustersLouvain0.4minmaxNologPCA30kN30.tab',index_col=0)
for group in range(1,len(regulons['Cluster'].unique())+1):
    enriched=group_diff_enrichment(data=regulons,group='C'+str(group),min_overlap=2)
    if save_enrichment and enriched is not None:
        enriched.to_csv(pathRegulons+'enrichment/minExpressed0.990.1Strains1Min1Max18_clustersLouvain0.4minmaxNologPCA30kN30_enrichment_cluster'+str(group)+'.tsv', sep='\t',index=False)
# Out:
# ***  C1 selected: 30 with EID: 30
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 20 out of 30 query genes used for enrichment calculation.
#                                Gene set                Ontology       FDR  \
# 0     Ribosome biogenesis in eukaryotes          KEGG: Pathways  3.61e-19
# 1                             nucleolus  GO: cellular_component  4.81e-17
# 2                   ribosome biogenesis  GO: biological_process  5.97e-16
# 3    ribonucleoprotein complex assembly  GO: biological_process  3.39e-07
# 4                           RNA binding  GO: molecular_function  8.74e-06
# 5   protein-containing complex assembly  GO: biological_process  7.59e-04
# 6                          rRNA binding  GO: molecular_function  1.00e-03
# 7           cellular component assembly  GO: biological_process  2.69e-03
# 8                     helicase activity  GO: molecular_function  1.20e-02
# 9            methyltransferase activity  GO: molecular_function  1.30e-02
# 10                      ATPase activity  GO: molecular_function  7.70e-02
#
#     N in query  Set size  N in ref.
# 0           12        72         68
# 1           11        72         72
# 2           10        61         61
# 3            4        18         18
# 4            6       169        169
# 5            4       134        133
# 6            2        13         13
# 7            4       202        201
# 8            2        51         51
# 9            2        58         56
# 10           2       169        168
# ***  C2 selected: 66 with EID: 65
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 34 out of 65 query genes used for enrichment calculation.
#                                           Gene set                Ontology  \
# 0                        Oxidative phosphorylation          KEGG: Pathways
# 1                                    mitochondrion  GO: cellular_component
# 2                        Citrate cycle (TCA cycle)          KEGG: Pathways
# 3                                        Phagosome          KEGG: Pathways
# 4                                  protein folding  GO: biological_process
# 5   generation of precursor metabolites and energy  GO: biological_process
# 6                              cytoplasmic vesicle  GO: cellular_component
# 7             aberrant cellular response to stress   Dictybase: Phenotypes
# 8                                         Ribosome          KEGG: Pathways
# 9            Biosynthesis of secondary metabolites          KEGG: Pathways
# 10          Various types of N-glycan biosynthesis          KEGG: Pathways
# 11                              cell morphogenesis  GO: biological_process
# 12              transmembrane transporter activity  GO: molecular_function
# 13                        unfolded protein binding  GO: molecular_function
# 14                         transmembrane transport  GO: biological_process
# 15                           N-Glycan biosynthesis          KEGG: Pathways
# 16                           Propanoate metabolism          KEGG: Pathways
# 17                               Carbon metabolism          KEGG: Pathways
# 18                        aberrant cell morphology   Dictybase: Phenotypes
# 19                                         cytosol  GO: cellular_component
# 20                         oxidoreductase activity  GO: molecular_function
# 21                                         vacuole  GO: cellular_component
# 22                              aberrant streaming   Dictybase: Phenotypes
# 23                                 ligase activity  GO: molecular_function
# 24     Protein processing in endoplasmic reticulum          KEGG: Pathways
# 25                            aberrant cytokinesis   Dictybase: Phenotypes
# 26                              mitotic cell cycle  GO: biological_process
#
#          FDR  N in query  Set size  N in ref.
# 0   6.60e-10           9        71         54
# 1   1.23e-04           9       229        229
# 2   4.91e-04           4        30         30
# 3   3.34e-03           4        53         52
# 4   1.16e-02           3        37         37
# 5   1.16e-02           4        77         77
# 6   1.16e-02           6       211        211
# 7   1.55e-02           2        11         11
# 8   1.59e-02           4       105         97
# 9   3.01e-02           6       289        281
# 10  4.56e-02           2        22         22
# 11  4.56e-02           2        23         23
# 12  5.11e-02           4       150        149
# 13  5.35e-02           2        27         27
# 14  5.77e-02           4       165        164
# 15  5.77e-02           2        31         30
# 16  6.12e-02           2        32         32
# 17  7.81e-02           3       104        102
# 18  8.78e-02           2        42         41
# 19  9.38e-02           4       203        203
# 20  9.52e-02           4       210        207
# 21  1.13e-01           3       127        127
# 22  1.68e-01           2        72         72
# 23  1.76e-01           2        80         80
# 24  2.02e-01           2        91         88
# 25  2.22e-01           2        98         98
# 26  2.24e-01           2       100        100
# ***  C3 selected: 68 with EID: 68
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 62 out of 68 query genes used for enrichment calculation.
#                              Gene set                Ontology        FDR  \
# 0                            Ribosome          KEGG: Pathways  6.41e-126
# 1                            ribosome  GO: cellular_component  1.47e-124
# 2  structural constituent of ribosome  GO: molecular_function  8.17e-109
# 3        structural molecule activity  GO: molecular_function   1.72e-98
# 4                         translation  GO: biological_process   1.79e-85
# 5                         RNA binding  GO: molecular_function   3.26e-15
# 6                        rRNA binding  GO: molecular_function   8.86e-13
# 7                             cytosol  GO: cellular_component   6.12e-05
# 8                 ribosome biogenesis  GO: biological_process   1.68e-02
# 9                 delayed development   Dictybase: Phenotypes   1.83e-01
#
#    N in query  Set size  N in ref.
# 0          60       105         97
# 1          59        93         93
# 2          53        85         85
# 3          53       117        117
# 4          52       169        169
# 5          16       169        169
# 6           7        13         13
# 7           8       203        203
# 8           3        61         61
# 9           2        69         69
# ***  C4 selected: 55 with EID: 55
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 21 out of 55 query genes used for enrichment calculation.
#                                Gene set                Ontology       FDR  \
# 0          cytoskeletal protein binding  GO: molecular_function  6.19e-08
# 1                           Endocytosis          KEGG: Pathways  3.88e-04
# 2   protein-containing complex assembly  GO: biological_process  1.98e-03
# 3           cellular component assembly  GO: biological_process  1.98e-03
# 4             cytoskeleton organization  GO: biological_process  1.98e-03
# 5                       plasma membrane  GO: cellular_component  1.98e-03
# 6                    response to stress  GO: biological_process  5.56e-03
# 7                          cytoskeleton  GO: cellular_component  6.63e-03
# 8                               cytosol  GO: cellular_component  5.47e-02
# 9                   cytoplasmic vesicle  GO: cellular_component  5.60e-02
# 10              decreased cell motility   Dictybase: Phenotypes  1.56e-01
# 11                            wild type   Dictybase: Phenotypes  1.68e-01
# 12           vesicle-mediated transport  GO: biological_process  1.85e-01
#
#     N in query  Set size  N in ref.
# 0           10       158        158
# 1            5        77         75
# 2            5       134        133
# 3            6       202        201
# 4            6       197        196
# 5            7       268        268
# 6            7       360        358
# 7            5       185        185
# 8            4       203        203
# 9            4       211        211
# 10           2        76         76
# 11           4       341        338
# 12           3       233        233
# ***  C5 selected: 41 with EID: 41
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 38 out of 41 query genes used for enrichment calculation.
#                                       Gene set                Ontology  \
# 0                                   Proteasome          KEGG: Pathways
# 1                           peptidase activity  GO: molecular_function
# 2                            catabolic process  GO: biological_process
# 3                    enzyme regulator activity  GO: molecular_function
# 4                           response to stress  GO: biological_process
# 5                              ATPase activity  GO: molecular_function
# 6  Protein processing in endoplasmic reticulum          KEGG: Pathways
#
#         FDR  N in query  Set size  N in ref.
# 0  2.56e-69          29        39         37
# 1  6.88e-34          21        91         91
# 2  1.46e-31          25       250        250
# 3  5.17e-02           3       105        105
# 4  5.21e-02           5       360        358
# 5  1.06e-01           3       169        168
# 6  1.64e-01           2        91         88
# ***  C6 selected: 74 with EID: 74
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 24 out of 74 query genes used for enrichment calculation.
#                                     Gene set                Ontology  \
# 0           anatomical structure development  GO: biological_process
# 1                              cell adhesion  GO: biological_process
# 2   development arrests at loose mound stage   Dictybase: Phenotypes
# 3                       extracellular region  GO: cellular_component
# 4              Glycosaminoglycan degradation          KEGG: Pathways
# 5               decreased fruiting body size   Dictybase: Phenotypes
# 6                   decreased aggregate size   Dictybase: Phenotypes
# 7                   increased slug migration   Dictybase: Phenotypes
# 8                        signal transduction  GO: biological_process
# 9                         response to stress  GO: biological_process
# 10                    multiple tips in mound   Dictybase: Phenotypes
# 11                      aberrant aggregation   Dictybase: Phenotypes
# 12                                locomotion  GO: biological_process
# 13                           plasma membrane  GO: cellular_component
# 14                 abolished gene expression   Dictybase: Phenotypes
# 15                      cell differentiation  GO: biological_process
# 16                    precocious development   Dictybase: Phenotypes
# 17                 decreased gene expression   Dictybase: Phenotypes
# 18                 decreased chemotaxis rate   Dictybase: Phenotypes
# 19         aberrant fruiting body morphology   Dictybase: Phenotypes
# 20             aberrant F-actin organization   Dictybase: Phenotypes
# 21                             cell motility  GO: biological_process
# 22                   decreased cell motility   Dictybase: Phenotypes
# 23                     abolished aggregation   Dictybase: Phenotypes
# 24                              cytoskeleton  GO: cellular_component
# 25                 cytoskeleton organization  GO: biological_process
#
#          FDR  N in query  Set size  N in ref.
# 0   3.88e-06          15       440        438
# 1   7.03e-03           5        84         83
# 2   7.53e-03           3        20         20
# 3   9.01e-03           6       157        157
# 4   1.08e-02           2         6          6
# 5   1.31e-02           4        76         75
# 6   1.31e-02           3        32         32
# 7   1.31e-02           2         8          8
# 8   1.31e-02           8       352        350
# 9   1.36e-02           8       360        358
# 10  4.27e-02           2        18         18
# 11  4.27e-02           3        61         61
# 12  4.27e-02           5       191        189
# 13  4.27e-02           6       268        268
# 14  6.69e-02           2        25         25
# 15  7.18e-02           4       145        145
# 16  7.86e-02           2        30         29
# 17  8.50e-02           3        95         86
# 18  1.03e-01           2        36         36
# 19  1.03e-01           3       101         98
# 20  1.03e-01           2        37         37
# 21  1.83e-01           2        67         66
# 22  1.87e-01           2        76         76
# 23  1.95e-01           2        82         80
# 24  2.14e-01           3       185        185
# 25  2.25e-01           3       197        196
# ***  C7 selected: 40 with EID: 40
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 13 out of 40 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0          aberrant CRAC localization to the plasma membrane
# 1                  development arrests at tipped mound stage
# 2                                          translucent sorus
# 3                         decreased intracellular cAMP level
# 4   anatomical structure formation involved in morphogenesis
# 5                                                 cell death
# 6                           anatomical structure development
# 7                                            kinase activity
# 8                                       aberrant aggregation
# 9                               decreased chemotaxis to cAMP
# 10                                      cell differentiation
# 11                                           RNA degradation
# 12                              decreased fruiting body size
# 13                                                locomotion
# 14                         aberrant fruiting body morphology
# 15                                                 wild type
# 16                                              cytoskeleton
# 17                                               DNA binding
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0    Dictybase: Phenotypes  1.28e-02           2         6          6
# 1    Dictybase: Phenotypes  1.39e-02           2        12         12
# 2    Dictybase: Phenotypes  1.39e-02           2         9          9
# 3    Dictybase: Phenotypes  1.39e-02           2        12         12
# 4   GO: biological_process  2.93e-02           3        74         74
# 5   GO: biological_process  3.52e-02           2        25         25
# 6   GO: biological_process  3.52e-02           6       440        438
# 7   GO: molecular_function  4.09e-02           5       328        327
# 8    Dictybase: Phenotypes  6.48e-02           2        61         61
# 9    Dictybase: Phenotypes  6.48e-02           2        63         63
# 10  GO: biological_process  6.48e-02           3       145        145
# 11          KEGG: Pathways  6.48e-02           2        48         48
# 12   Dictybase: Phenotypes  7.43e-02           2        76         75
# 13  GO: biological_process  7.43e-02           3       191        189
# 14   Dictybase: Phenotypes  9.58e-02           2       101         98
# 15   Dictybase: Phenotypes  1.61e-01           3       341        338
# 16  GO: cellular_component  1.88e-01           2       185        185
# 17  GO: molecular_function  2.26e-01           2       221        221
# ***  C8 selected: 23 with EID: 23
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 3 out of 23 query genes used for enrichment calculation.
#           Gene set                Ontology       FDR  N in query  Set size  \
# 0  kinase activity  GO: molecular_function  1.10e-01           3       328
#
#    N in ref.
# 0        327
# ***  C9 selected: 20 with EID: 20
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 0 out of 20 query genes used for enrichment calculation.
# None
# ***  C10 selected: 36 with EID: 36
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 18 out of 36 query genes used for enrichment calculation.
#                          Gene set                Ontology       FDR  \
# 0                      cell cycle  GO: biological_process  1.86e-14
# 1          chromosome segregation  GO: biological_process  1.19e-10
# 2        mitotic nuclear division  GO: biological_process  5.12e-09
# 3              mitotic cell cycle  GO: biological_process  1.05e-07
# 4                   cell division  GO: biological_process  1.95e-07
# 5                 DNA replication          KEGG: Pathways  1.95e-07
# 6                      chromosome  GO: cellular_component  2.15e-07
# 7         chromosome organization  GO: biological_process  2.64e-07
# 8                    cytoskeleton  GO: cellular_component  3.22e-06
# 9       cytoskeleton organization  GO: biological_process  8.01e-04
# 10  microtubule organizing center  GO: cellular_component  1.22e-03
# 11   cytoskeletal protein binding  GO: molecular_function  3.05e-03
# 12          DNA metabolic process  GO: biological_process  7.73e-02
# 13                ATPase activity  GO: molecular_function  1.47e-01
# 14                plasma membrane  GO: cellular_component  2.43e-01
#
#     N in query  Set size  N in ref.
# 0           13       167        167
# 1            6        18         18
# 2            5        15         15
# 3            7       100        100
# 4            7       115        115
# 5            5        34         33
# 6            6        70         70
# 7            6        74         74
# 8            7       185        185
# 9            5       197        196
# 10           3        50         50
# 11           4       158        158
# 12           2       105        105
# 13           2       169        168
# 14           2       268        268
# ***  C11 selected: 77 with EID: 77
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 10 out of 77 query genes used for enrichment calculation.
#                              Gene set                Ontology       FDR  \
# 0                cell differentiation  GO: biological_process  2.43e-03
# 1               decreased sporulation   Dictybase: Phenotypes  2.39e-01
# 2  development arrests at mound stage   Dictybase: Phenotypes  2.39e-01
# 3    anatomical structure development  GO: biological_process  2.39e-01
# 4                       cell adhesion  GO: biological_process  2.39e-01
# 5       Starch and sucrose metabolism          KEGG: Pathways  2.39e-01
#
#    N in query  Set size  N in ref.
# 0           7       145        145
# 1           2        53         53
# 2           2        56         54
# 3           7       440        438
# 4           3        84         83
# 5           2        31         31
# ***  C12 selected: 57 with EID: 57
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 9 out of 57 query genes used for enrichment calculation.
#                     Gene set                Ontology       FDR  N in query  \
# 0       extracellular region  GO: cellular_component  3.15e-04           7
# 1        cell-cell signaling  GO: biological_process  5.19e-02           2
# 2  decreased spore viability   Dictybase: Phenotypes  2.28e-01           2
# 3         peptidase activity  GO: molecular_function  2.37e-01           2
#
#    Set size  N in ref.
# 0       157        157
# 1        16         16
# 2        60         59
# 3        91         91
# ***  C13 selected: 64 with EID: 64
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 2 out of 64 query genes used for enrichment calculation.
#                       Gene set               Ontology       FDR  N in query  \
# 0  aberrant cell-cell adhesion  Dictybase: Phenotypes  3.67e-03           2
#
#    Set size  N in ref.
# 0         5          5
# ***  C14 selected: 19 with EID: 19
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 0 out of 19 query genes used for enrichment calculation.
# None
# ***  C15 selected: 91 with EID: 91
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 30 out of 91 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                           external encapsulating structure
# 1                                                  cell wall
# 2                             aberrant spore coat morphology
# 3   anatomical structure formation involved in morphogenesis
# 4                       cell wall organization or biogenesis
# 5                                       cell differentiation
# 6                           anatomical structure development
# 7                              Starch and sucrose metabolism
# 8                       abolished stalk cell differentiation
# 9                                       extracellular region
# 10                               cellular component assembly
# 11                            carbohydrate metabolic process
# 12                                               DNA binding
# 13                                 decreased spore viability
# 14                                     abolished sporulation
# 15                                    Glutathione metabolism
# 16                                      aberrant culmination
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: cellular_component  7.69e-11           7        13         13
# 1   GO: cellular_component  7.69e-11           7        13         13
# 2    Dictybase: Phenotypes  4.01e-09           6        12         12
# 3   GO: biological_process  7.97e-08           9        74         74
# 4   GO: biological_process  1.10e-06           5        15         15
# 5   GO: biological_process  1.73e-06          10       145        145
# 6   GO: biological_process  2.59e-04          13       440        438
# 7           KEGG: Pathways  9.26e-04           4        31         31
# 8    Dictybase: Phenotypes  1.09e-02           2         7          7
# 9   GO: cellular_component  1.09e-02           6       157        157
# 10  GO: biological_process  3.30e-02           6       202        201
# 11  GO: biological_process  3.32e-02           4        89         88
# 12  GO: molecular_function  4.42e-02           6       221        221
# 13   Dictybase: Phenotypes  6.62e-02           3        60         59
# 14   Dictybase: Phenotypes  8.94e-02           2        25         25
# 15          KEGG: Pathways  8.94e-02           2        28         25
# 16   Dictybase: Phenotypes  1.58e-01           3        88         88
# ***  C16 selected: 74 with EID: 74
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 8 out of 74 query genes used for enrichment calculation.
#                Gene set                Ontology       FDR  N in query  \
# 0  extracellular region  GO: cellular_component  1.40e-04           8
#
#    Set size  N in ref.
# 0       157        157
# ***  C17 selected: 61 with EID: 59
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 0 out of 59 query genes used for enrichment calculation.
# None
# ***  C18 selected: 46 with EID: 45
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 10 out of 45 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0                                      extracellular region
# 1  anatomical structure formation involved in morphogenesis
# 2                                      cell differentiation
# 3                                   oxidoreductase activity
#
#                  Ontology       FDR  N in query  Set size  N in ref.
# 0  GO: cellular_component  4.59e-04           6       157        157
# 1  GO: biological_process  2.70e-02           3        74         74
# 2  GO: biological_process  1.15e-01           3       145        145
# 3  GO: molecular_function  1.46e-01           3       210        207
# ***  C19 selected: 58 with EID: 58
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 9 out of 58 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0                                             cell adhesion
# 1                                      extracellular region
# 2                                        hydrolase activity
# 3                                      cell differentiation
# 4  anatomical structure formation involved in morphogenesis
#
#                  Ontology       FDR  N in query  Set size  N in ref.
# 0  GO: biological_process  8.68e-02           3        84         83
# 1  GO: cellular_component  8.68e-02           4       157        157
# 2  GO: molecular_function  1.57e-01           2        46         45
# 3  GO: biological_process  1.92e-01           3       145        145
# 4  GO: biological_process  1.96e-01           2        74         74
# ***  C20 selected: 54 with EID: 54
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 4 out of 54 query genes used for enrichment calculation.
#                     Gene set               Ontology       FDR  N in query  \
# 0  decreased spore viability  Dictybase: Phenotypes  2.34e-01           2
# 1                  Phagosome         KEGG: Pathways  2.34e-01           2
#
#    Set size  N in ref.
# 0        60         59
# 1        53         52
# ***  C21 selected: 45 with EID: 45
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 0 out of 45 query genes used for enrichment calculation.
# None

# %% [markdown]
# #### Using only genes annotated with at least one gene set
# To find genes that have gene set annotations only gene sets used in enrichment are used (see above). Genes that are in at least one of these gene sets are used for enrichment calculation, both for reference and gene group of interest (query).

# %%
regulons=pd.read_table(pathRegulons+'mergedGenes_minExpressed0.990.1Strains1Min1Max18_clustersLouvain0.4minmaxNologPCA30kN30.tab',index_col=0)
for group in range(1,len(regulons['Cluster'].unique())+1):
    enriched=group_diff_enrichment(data=regulons,group='C'+str(group),min_overlap=2,use_annotated_genes=True)
    if  save_enrichment and enriched is not None:
        enriched.to_csv(pathRegulons+'enrichment/minExpressed0.990.1Strains1Min1Max18_clustersLouvain0.4minmaxNologPCA30kN30_annotatedOnly_enrichment_cluster'+str(group)+'.tsv', sep='\t',index=False)
# Out:
# ***  C1 selected: 30 with EID: 30
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.7
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 20 out of 21 query genes used for enrichment calculation.
#                               Gene set                Ontology       FDR  \
# 0    Ribosome biogenesis in eukaryotes          KEGG: Pathways  1.09e-15
# 1                            nucleolus  GO: cellular_component  8.66e-14
# 2                  ribosome biogenesis  GO: biological_process  6.22e-13
# 3   ribonucleoprotein complex assembly  GO: biological_process  7.03e-06
# 4                          RNA binding  GO: molecular_function  5.86e-04
# 5                         rRNA binding  GO: molecular_function  5.46e-03
# 6  protein-containing complex assembly  GO: biological_process  1.10e-02
# 7          cellular component assembly  GO: biological_process  4.00e-02
# 8                    helicase activity  GO: molecular_function  5.27e-02
# 9           methyltransferase activity  GO: molecular_function  5.64e-02
#
#    N in query  Set size  N in ref.
# 0          12        72         68
# 1          11        72         72
# 2          10        61         61
# 3           4        18         18
# 4           6       169        169
# 5           2        13         13
# 6           4       134        133
# 7           4       202        201
# 8           2        51         51
# 9           2        58         56
# ***  C2 selected: 66 with EID: 65
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.58
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 33 out of 38 query genes used for enrichment calculation.
#                                           Gene set                Ontology  \
# 0                        Oxidative phosphorylation          KEGG: Pathways
# 1                                    mitochondrion  GO: cellular_component
# 2                        Citrate cycle (TCA cycle)          KEGG: Pathways
# 3                                        Phagosome          KEGG: Pathways
# 4             aberrant cellular response to stress   Dictybase: Phenotypes
# 5                                  protein folding  GO: biological_process
# 6   generation of precursor metabolites and energy  GO: biological_process
# 7                              cytoplasmic vesicle  GO: cellular_component
# 8                                         Ribosome          KEGG: Pathways
# 9                               cell morphogenesis  GO: biological_process
# 10          Various types of N-glycan biosynthesis          KEGG: Pathways
# 11                        unfolded protein binding  GO: molecular_function
# 12                           N-Glycan biosynthesis          KEGG: Pathways
# 13                           Propanoate metabolism          KEGG: Pathways
#
#          FDR  N in query  Set size  N in ref.
# 0   8.92e-08           9        71         54
# 1   6.90e-03           9       229        229
# 2   6.90e-03           4        30         30
# 3   3.07e-02           4        53         52
# 4   7.32e-02           2        11         11
# 5   7.32e-02           3        37         37
# 6   7.37e-02           4        77         77
# 7   1.37e-01           6       211        211
# 8   1.37e-01           4       105         97
# 9   1.57e-01           2        23         23
# 10  1.57e-01           2        22         22
# 11  1.94e-01           2        27         27
# 12  2.18e-01           2        31         30
# 13  2.29e-01           2        32         32
# ***  C3 selected: 68 with EID: 68
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.97
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 62 out of 66 query genes used for enrichment calculation.
#                              Gene set                Ontology       FDR  \
# 0                            Ribosome          KEGG: Pathways  6.76e-98
# 1                            ribosome  GO: cellular_component  6.26e-97
# 2  structural constituent of ribosome  GO: molecular_function  9.68e-84
# 3        structural molecule activity  GO: molecular_function  1.91e-73
# 4                         translation  GO: biological_process  6.25e-61
# 5                        rRNA binding  GO: molecular_function  2.38e-09
# 6                         RNA binding  GO: molecular_function  4.17e-08
# 7                             cytosol  GO: cellular_component  7.91e-02
#
#    N in query  Set size  N in ref.
# 0          60       105         97
# 1          59        93         93
# 2          53        85         85
# 3          53       117        117
# 4          52       169        169
# 5           7        13         13
# 6          16       169        169
# 7           8       203        203
# ***  C4 selected: 55 with EID: 55
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.44
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 18 out of 24 query genes used for enrichment calculation.
#                                Gene set                Ontology       FDR  \
# 0          cytoskeletal protein binding  GO: molecular_function  3.91e-07
# 1                           Endocytosis          KEGG: Pathways  1.38e-03
# 2   protein-containing complex assembly  GO: biological_process  6.77e-03
# 3           cellular component assembly  GO: biological_process  6.77e-03
# 4             cytoskeleton organization  GO: biological_process  6.77e-03
# 5                       plasma membrane  GO: cellular_component  6.77e-03
# 6                    response to stress  GO: biological_process  2.18e-02
# 7                          cytoskeleton  GO: cellular_component  2.18e-02
# 8                               cytosol  GO: cellular_component  1.41e-01
# 9                   cytoplasmic vesicle  GO: cellular_component  1.44e-01
# 10              decreased cell motility   Dictybase: Phenotypes  2.42e-01
#
#     N in query  Set size  N in ref.
# 0           10       158        158
# 1            5        77         75
# 2            5       134        133
# 3            6       202        201
# 4            6       197        196
# 5            7       268        268
# 6            7       360        358
# 7            5       185        185
# 8            4       203        203
# 9            4       211        211
# 10           2        76         76
# ***  C5 selected: 41 with EID: 41
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.98
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 35 out of 40 query genes used for enrichment calculation.
#              Gene set                Ontology       FDR  N in query  Set size  \
# 0          Proteasome          KEGG: Pathways  2.03e-55          29        39
# 1  peptidase activity  GO: molecular_function  7.60e-24          21        91
# 2   catabolic process  GO: biological_process  8.94e-20          25       250
#
#    N in ref.
# 0         37
# 1         91
# 2        250
# ***  C6 selected: 74 with EID: 74
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.42
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 24 out of 31 query genes used for enrichment calculation.
#                                     Gene set                Ontology  \
# 0           anatomical structure development  GO: biological_process
# 1   development arrests at loose mound stage   Dictybase: Phenotypes
# 2                              cell adhesion  GO: biological_process
# 3              Glycosaminoglycan degradation          KEGG: Pathways
# 4                       extracellular region  GO: cellular_component
# 5                   decreased aggregate size   Dictybase: Phenotypes
# 6                   increased slug migration   Dictybase: Phenotypes
# 7               decreased fruiting body size   Dictybase: Phenotypes
# 8                        signal transduction  GO: biological_process
# 9                         response to stress  GO: biological_process
# 10                    multiple tips in mound   Dictybase: Phenotypes
# 11                      aberrant aggregation   Dictybase: Phenotypes
# 12                 abolished gene expression   Dictybase: Phenotypes
# 13                                locomotion  GO: biological_process
# 14                           plasma membrane  GO: cellular_component
# 15                    precocious development   Dictybase: Phenotypes
# 16                      cell differentiation  GO: biological_process
# 17                 decreased chemotaxis rate   Dictybase: Phenotypes
# 18                 decreased gene expression   Dictybase: Phenotypes
# 19             aberrant F-actin organization   Dictybase: Phenotypes
# 20         aberrant fruiting body morphology   Dictybase: Phenotypes
# 21                             cell motility  GO: biological_process
#
#          FDR  N in query  Set size  N in ref.
# 0   2.30e-05          15       440        438
# 1   1.59e-02           3        20         20
# 2   1.59e-02           5        84         83
# 3   2.28e-02           2         6          6
# 4   2.44e-02           6       157        157
# 5   2.78e-02           3        32         32
# 6   2.78e-02           2         8          8
# 7   3.35e-02           4        76         75
# 8   5.29e-02           8       352        350
# 9   5.47e-02           8       360        358
# 10  7.98e-02           2        18         18
# 11  1.01e-01           3        61         61
# 12  1.13e-01           2        25         25
# 13  1.13e-01           5       191        189
# 14  1.13e-01           6       268        268
# 15  1.38e-01           2        30         29
# 16  1.56e-01           4       145        145
# 17  1.65e-01           2        36         36
# 18  1.65e-01           3        95         86
# 19  1.66e-01           2        37         37
# 20  1.75e-01           3       101         98
# 21  2.46e-01           2        67         66
# ***  C7 selected: 40 with EID: 40
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.38
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 12 out of 15 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0          aberrant CRAC localization to the plasma membrane
# 1                  development arrests at tipped mound stage
# 2                                          translucent sorus
# 3                         decreased intracellular cAMP level
# 4   anatomical structure formation involved in morphogenesis
# 5                                                 cell death
# 6                           anatomical structure development
# 7                                            kinase activity
# 8                                       aberrant aggregation
# 9                               decreased chemotaxis to cAMP
# 10                                      cell differentiation
# 11                                           RNA degradation
# 12                              decreased fruiting body size
# 13                                                locomotion
# 14                         aberrant fruiting body morphology
# 15                                                 wild type
# 16                                              cytoskeleton
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0    Dictybase: Phenotypes  1.70e-02           2         6          6
# 1    Dictybase: Phenotypes  1.84e-02           2        12         12
# 2    Dictybase: Phenotypes  1.84e-02           2         9          9
# 3    Dictybase: Phenotypes  1.84e-02           2        12         12
# 4   GO: biological_process  4.16e-02           3        74         74
# 5   GO: biological_process  4.65e-02           2        25         25
# 6   GO: biological_process  4.65e-02           6       440        438
# 7   GO: molecular_function  6.06e-02           5       328        327
# 8    Dictybase: Phenotypes  7.80e-02           2        61         61
# 9    Dictybase: Phenotypes  7.80e-02           2        63         63
# 10  GO: biological_process  7.80e-02           3       145        145
# 11          KEGG: Pathways  7.80e-02           2        48         48
# 12   Dictybase: Phenotypes  9.41e-02           2        76         75
# 13  GO: biological_process  9.41e-02           3       191        189
# 14   Dictybase: Phenotypes  1.13e-01           2       101         98
# 15   Dictybase: Phenotypes  2.10e-01           3       341        338
# 16  GO: cellular_component  2.37e-01           2       185        185
# ***  C8 selected: 23 with EID: 23
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.26
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 3 out of 6 query genes used for enrichment calculation.
#           Gene set                Ontology       FDR  N in query  Set size  \
# 0  kinase activity  GO: molecular_function  4.72e-02           3       328
#
#    N in ref.
# 0        327
# ***  C9 selected: 20 with EID: 20
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.0
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 0 out of 0 query genes used for enrichment calculation.
# None
# ***  C10 selected: 36 with EID: 36
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.53
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 18 out of 19 query genes used for enrichment calculation.
#                          Gene set                Ontology       FDR  \
# 0                      cell cycle  GO: biological_process  6.67e-13
# 1          chromosome segregation  GO: biological_process  1.58e-09
# 2        mitotic nuclear division  GO: biological_process  4.78e-08
# 3              mitotic cell cycle  GO: biological_process  1.81e-06
# 4                 DNA replication          KEGG: Pathways  2.15e-06
# 5                   cell division  GO: biological_process  2.74e-06
# 6                      chromosome  GO: cellular_component  2.74e-06
# 7         chromosome organization  GO: biological_process  3.35e-06
# 8                    cytoskeleton  GO: cellular_component  5.22e-05
# 9   microtubule organizing center  GO: cellular_component  5.37e-03
# 10      cytoskeleton organization  GO: biological_process  5.76e-03
# 11   cytoskeletal protein binding  GO: molecular_function  1.67e-02
# 12          DNA metabolic process  GO: biological_process  1.86e-01
#
#     N in query  Set size  N in ref.
# 0           13       167        167
# 1            6        18         18
# 2            5        15         15
# 3            7       100        100
# 4            5        34         33
# 5            7       115        115
# 6            6        70         70
# 7            6        74         74
# 8            7       185        185
# 9            3        50         50
# 10           5       197        196
# 11           4       158        158
# 12           2       105        105
# ***  C11 selected: 77 with EID: 77
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.29
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 12 out of 22 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0                                      cell differentiation
# 1                                     decreased sporulation
# 2                        development arrests at mound stage
# 3                          anatomical structure development
# 4                                             cell adhesion
# 5                             Starch and sucrose metabolism
# 6                                     abolished culmination
# 7                                       delayed aggregation
# 8  anatomical structure formation involved in morphogenesis
#
#                  Ontology       FDR  N in query  Set size  N in ref.
# 0  GO: biological_process  6.47e-04           7       145        145
# 1   Dictybase: Phenotypes  2.07e-01           2        53         53
# 2   Dictybase: Phenotypes  2.07e-01           2        56         54
# 3  GO: biological_process  2.07e-01           7       440        438
# 4  GO: biological_process  2.07e-01           3        84         83
# 5          KEGG: Pathways  2.07e-01           2        31         31
# 6   Dictybase: Phenotypes  2.17e-01           2        62         62
# 7   Dictybase: Phenotypes  2.45e-01           2        72         72
# 8  GO: biological_process  2.45e-01           2        74         74
# ***  C12 selected: 57 with EID: 57
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.25
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 11 out of 14 query genes used for enrichment calculation.
#                            Gene set                Ontology       FDR  \
# 0              extracellular region  GO: cellular_component  1.66e-05
# 1               cell-cell signaling  GO: biological_process  2.96e-02
# 2         decreased spore viability   Dictybase: Phenotypes  1.63e-01
# 3                peptidase activity  GO: molecular_function  1.63e-01
# 4  anatomical structure development  GO: biological_process  1.88e-01
# 5                   plasma membrane  GO: cellular_component  1.88e-01
#
#    N in query  Set size  N in ref.
# 0           7       157        157
# 1           2        16         16
# 2           2        60         59
# 3           2        91         91
# 4           4       440        438
# 5           3       268        268
# ***  C13 selected: 64 with EID: 64
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.16
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 6 out of 10 query genes used for enrichment calculation.
#                             Gene set                Ontology       FDR  \
# 0        aberrant cell-cell adhesion   Dictybase: Phenotypes  8.13e-04
# 1  aberrant fruiting body morphology   Dictybase: Phenotypes  7.61e-02
# 2   anatomical structure development  GO: biological_process  7.61e-02
# 3               extracellular region  GO: cellular_component  1.16e-01
#
#    N in query  Set size  N in ref.
# 0           2         5          5
# 1           2       101         98
# 2           4       440        438
# 3           2       157        157
# ***  C14 selected: 19 with EID: 19
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.05
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 0 out of 1 query genes used for enrichment calculation.
# None
# ***  C15 selected: 91 with EID: 91
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.45
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 28 out of 41 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                           external encapsulating structure
# 1                                                  cell wall
# 2                             aberrant spore coat morphology
# 3   anatomical structure formation involved in morphogenesis
# 4                       cell wall organization or biogenesis
# 5                                       cell differentiation
# 6                              Starch and sucrose metabolism
# 7                           anatomical structure development
# 8                       abolished stalk cell differentiation
# 9                                       extracellular region
# 10                            carbohydrate metabolic process
# 11                               cellular component assembly
# 12                                     abolished sporulation
# 13                                 decreased spore viability
# 14                                               DNA binding
# 15                                    Glutathione metabolism
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: cellular_component  6.38e-10           7        13         13
# 1   GO: cellular_component  6.38e-10           7        13         13
# 2    Dictybase: Phenotypes  2.57e-08           6        12         12
# 3   GO: biological_process  9.70e-07           9        74         74
# 4   GO: biological_process  5.30e-06           5        15         15
# 5   GO: biological_process  2.38e-05          10       145        145
# 6           KEGG: Pathways  3.70e-03           4        31         31
# 7   GO: biological_process  3.96e-03          13       440        438
# 8    Dictybase: Phenotypes  2.37e-02           2         7          7
# 9   GO: cellular_component  5.16e-02           6       157        157
# 10  GO: biological_process  1.14e-01           4        89         88
# 11  GO: biological_process  1.38e-01           6       202        201
# 12   Dictybase: Phenotypes  1.69e-01           2        25         25
# 13   Dictybase: Phenotypes  1.69e-01           3        60         59
# 14  GO: molecular_function  1.69e-01           6       221        221
# 15          KEGG: Pathways  1.69e-01           2        28         25
# ***  C16 selected: 74 with EID: 74
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.23
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 15 out of 17 query genes used for enrichment calculation.
#                     Gene set                Ontology       FDR  N in query  \
# 0       extracellular region  GO: cellular_component  3.21e-06           8
# 1                  wild type   Dictybase: Phenotypes  1.96e-01           5
# 2  decreased gene expression   Dictybase: Phenotypes  2.15e-01           2
# 3  decreased spore viability   Dictybase: Phenotypes  2.15e-01           2
# 4                DNA binding  GO: molecular_function  2.20e-01           3
#
#    Set size  N in ref.
# 0       157        157
# 1       341        338
# 2        95         86
# 3        60         59
# 4       221        221
# ***  C17 selected: 61 with EID: 59
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.2
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 4 out of 12 query genes used for enrichment calculation.
#                            Gene set                Ontology       FDR  \
# 0  anatomical structure development  GO: biological_process  2.34e-01
#
#    N in query  Set size  N in ref.
# 0           4       440        438
# ***  C18 selected: 46 with EID: 45
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.33
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 10 out of 15 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0                                      extracellular region
# 1  anatomical structure formation involved in morphogenesis
# 2                                      cell differentiation
# 3                                   oxidoreductase activity
#
#                  Ontology       FDR  N in query  Set size  N in ref.
# 0  GO: cellular_component  3.02e-04           6       157        157
# 1  GO: biological_process  2.73e-02           3        74         74
# 2  GO: biological_process  1.18e-01           3       145        145
# 3  GO: molecular_function  1.53e-01           3       210        207
# ***  C19 selected: 58 with EID: 58
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.21
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 9 out of 12 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0                                             cell adhesion
# 1                                      extracellular region
# 2                                      cell differentiation
# 3                                        hydrolase activity
# 4  anatomical structure formation involved in morphogenesis
#
#                  Ontology       FDR  N in query  Set size  N in ref.
# 0  GO: biological_process  2.18e-02           3        84         83
# 1  GO: cellular_component  2.18e-02           4       157        157
# 2  GO: biological_process  5.29e-02           3       145        145
# 3  GO: molecular_function  5.29e-02           2        46         45
# 4  GO: biological_process  1.02e-01           2        74         74
# ***  C20 selected: 54 with EID: 54
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.2
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 6 out of 11 query genes used for enrichment calculation.
#                     Gene set                Ontology       FDR  N in query  \
# 0  decreased spore viability   Dictybase: Phenotypes  1.51e-01           2
# 1                  Phagosome          KEGG: Pathways  1.51e-01           2
# 2       extracellular region  GO: cellular_component  2.37e-01           2
#
#    Set size  N in ref.
# 0        60         59
# 1        53         52
# 2       157        157
# ***  C21 selected: 45 with EID: 45
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.13
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 3 out of 6 query genes used for enrichment calculation.
#              Gene set                Ontology       FDR  N in query  Set size  \
# 0  response to stress  GO: biological_process  2.25e-01           2       360
# 1             cytosol  GO: cellular_component  2.25e-01           2       203
#
#    N in ref.
# 0        358
# 1        203

# %% [markdown]
# ### Enrichment for mergedGenes_minExpressed0.990.1Strains1Min1Max18_clustersAX4Louvain0.4m0s1log.tab

# %%
regulons=pd.read_table(pathRegulons+'mergedGenes_minExpressed0.990.1Strains1Min1Max18_clustersAX4Louvain0.4m0s1log.tab',index_col=0)
for group in range(1,len(regulons['Cluster'].unique())+1):
    cluster='C'+str(group)
    print('*** Cluster %s (%s)' %(cluster,string.ascii_uppercase[group-1]))
    
    enriched=group_diff_enrichment(data=regulons,group=cluster,min_overlap=2)
    if  save_enrichment and enriched is not None:
        enriched.to_csv(pathRegulons+'enrichment/minExpressed0.990.1Strains1Min1Max18_clustersAX4Louvain0.4m0s1log_enrichment_cluster'+str(group)+'.tsv', sep='\t',index=False)
# Out:
# *** Cluster C1 (A)
# ***  C1 selected: 31 with EID: 31
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 20 out of 31 query genes used for enrichment calculation.
#                                Gene set                Ontology       FDR  \
# 0     Ribosome biogenesis in eukaryotes          KEGG: Pathways  7.70e-19
# 1                             nucleolus  GO: cellular_component  9.74e-17
# 2                   ribosome biogenesis  GO: biological_process  1.15e-15
# 3    ribonucleoprotein complex assembly  GO: biological_process  5.11e-07
# 4                           RNA binding  GO: molecular_function  1.41e-05
# 5   protein-containing complex assembly  GO: biological_process  1.13e-03
# 6                          rRNA binding  GO: molecular_function  1.41e-03
# 7           cellular component assembly  GO: biological_process  4.00e-03
# 8                     helicase activity  GO: molecular_function  1.68e-02
# 9            methyltransferase activity  GO: molecular_function  1.82e-02
# 10                      ATPase activity  GO: molecular_function  9.28e-02
#
#     N in query  Set size  N in ref.
# 0           12        72         68
# 1           11        72         72
# 2           10        61         61
# 3            4        18         18
# 4            6       169        169
# 5            4       134        133
# 6            2        13         13
# 7            4       202        201
# 8            2        51         51
# 9            2        58         56
# 10           2       169        168
# *** Cluster C2 (B)
# ***  C2 selected: 54 with EID: 54
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 25 out of 54 query genes used for enrichment calculation.
#                                           Gene set                Ontology  \
# 0                                    mitochondrion  GO: cellular_component
# 1                        Oxidative phosphorylation          KEGG: Pathways
# 2   generation of precursor metabolites and energy  GO: biological_process
# 3                                  protein folding  GO: biological_process
# 4                         unfolded protein binding  GO: molecular_function
# 5                          oxidoreductase activity  GO: molecular_function
# 6                                        Phagosome          KEGG: Pathways
# 7                            Propanoate metabolism          KEGG: Pathways
# 8                        Citrate cycle (TCA cycle)          KEGG: Pathways
# 9                                         Ribosome          KEGG: Pathways
# 10                               Carbon metabolism          KEGG: Pathways
# 11                                         cytosol  GO: cellular_component
# 12              transmembrane transporter activity  GO: molecular_function
# 13                         transmembrane transport  GO: biological_process
# 14           Biosynthesis of secondary metabolites          KEGG: Pathways
# 15                                 ligase activity  GO: molecular_function
# 16                small molecule metabolic process  GO: biological_process
# 17                                         vacuole  GO: cellular_component
#
#          FDR  N in query  Set size  N in ref.
# 0   7.89e-08          11       229        229
# 1   7.89e-08           7        71         54
# 2   1.55e-05           6        77         77
# 3   2.28e-04           4        37         37
# 4   2.02e-03           3        27         27
# 5   2.14e-03           6       210        207
# 6   1.01e-02           3        53         52
# 7   4.11e-02           2        32         32
# 8   4.11e-02           2        30         30
# 9   4.11e-02           3       105         97
# 10  4.28e-02           3       104        102
# 11  4.64e-02           4       203        203
# 12  9.88e-02           3       150        149
# 13  1.03e-01           3       165        164
# 14  1.03e-01           4       289        281
# 15  1.25e-01           2        80         80
# 16  1.46e-01           4       354        353
# 17  2.00e-01           2       127        127
# *** Cluster C3 (C)
# ***  C3 selected: 54 with EID: 54
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 44 out of 54 query genes used for enrichment calculation.
#                              Gene set                Ontology       FDR  \
# 0                            Ribosome          KEGG: Pathways  1.07e-86
# 1                            ribosome  GO: cellular_component  4.46e-85
# 2  structural constituent of ribosome  GO: molecular_function  8.18e-76
# 3        structural molecule activity  GO: molecular_function  4.04e-69
# 4                         translation  GO: biological_process  5.72e-62
# 5                         RNA binding  GO: molecular_function  4.40e-10
# 6                        rRNA binding  GO: molecular_function  6.50e-07
#
#    N in query  Set size  N in ref.
# 0          44       105         97
# 1          43        93         93
# 2          39        85         85
# 3          39       117        117
# 4          39       169        169
# 5          11       169        169
# 6           4        13         13
# *** Cluster C4 (D)
# ***  C4 selected: 43 with EID: 43
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 21 out of 43 query genes used for enrichment calculation.
#                                Gene set                Ontology       FDR  \
# 0          cytoskeletal protein binding  GO: molecular_function  2.38e-10
# 1   protein-containing complex assembly  GO: biological_process  5.27e-06
# 2           cellular component assembly  GO: biological_process  5.27e-06
# 3             cytoskeleton organization  GO: biological_process  5.27e-06
# 4                          cytoskeleton  GO: cellular_component  3.07e-05
# 5                       plasma membrane  GO: cellular_component  3.07e-05
# 6                           Endocytosis          KEGG: Pathways  4.58e-05
# 7                    response to stress  GO: biological_process  1.47e-03
# 8                               cytosol  GO: cellular_component  4.06e-03
# 9               decreased cell motility   Dictybase: Phenotypes  1.28e-02
# 10                   cell morphogenesis  GO: biological_process  1.43e-02
# 11                  cytoplasmic vesicle  GO: cellular_component  2.79e-02
# 12             aberrant cell morphology   Dictybase: Phenotypes  3.78e-02
# 13     anatomical structure development  GO: biological_process  6.87e-02
# 14                            wild type   Dictybase: Phenotypes  8.27e-02
# 15                abolished aggregation   Dictybase: Phenotypes  8.27e-02
# 16                   aberrant streaming   Dictybase: Phenotypes  8.27e-02
# 17                         reproduction  GO: biological_process  8.27e-02
# 18                 aberrant cytokinesis   Dictybase: Phenotypes  9.65e-02
# 19                   mitotic cell cycle  GO: biological_process  9.65e-02
# 20           vesicle-mediated transport  GO: biological_process  9.65e-02
# 21                        cell division  GO: biological_process  1.11e-01
# 22                decreased growth rate   Dictybase: Phenotypes  1.41e-01
# 23                           cell cycle  GO: biological_process  1.55e-01
# 24              transmembrane transport  GO: biological_process  1.55e-01
# 25                      ATPase activity  GO: molecular_function  1.55e-01
# 26   transmembrane transporter activity  GO: molecular_function  1.55e-01
# 27                           locomotion  GO: biological_process  1.80e-01
#
#     N in query  Set size  N in ref.
# 0           11       158        158
# 1            7       134        133
# 2            8       202        201
# 3            8       197        196
# 4            7       185        185
# 5            8       268        268
# 6            5        77         75
# 7            7       360        358
# 8            5       203        203
# 9            3        76         76
# 10           2        23         23
# 11           4       211        211
# 12           2        42         41
# 13           5       440        438
# 14           4       341        338
# 15           2        82         80
# 16           2        72         72
# 17           2        79         79
# 18           2        98         98
# 19           2       100        100
# 20           3       233        233
# 21           2       115        115
# 22           2       146        137
# 23           2       167        167
# 24           2       165        164
# 25           2       169        168
# 26           2       150        149
# 27           2       191        189
# *** Cluster C5 (E)
# ***  C5 selected: 20 with EID: 20
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 18 out of 20 query genes used for enrichment calculation.
#                               Gene set                Ontology       FDR  \
# 0                             ribosome  GO: cellular_component  4.29e-33
# 1                             Ribosome          KEGG: Pathways  4.70e-33
# 2   structural constituent of ribosome  GO: molecular_function  1.12e-28
# 3         structural molecule activity  GO: molecular_function  1.46e-26
# 4                          translation  GO: biological_process  7.52e-22
# 5                         rRNA binding  GO: molecular_function  3.78e-06
# 6                          RNA binding  GO: molecular_function  1.87e-05
# 7                              cytosol  GO: cellular_component  4.00e-05
# 8                  ribosome biogenesis  GO: biological_process  3.02e-04
# 9                  delayed development   Dictybase: Phenotypes  1.21e-02
# 10    anatomical structure development  GO: biological_process  2.16e-01
#
#     N in query  Set size  N in ref.
# 0           17        93         93
# 1           17       105         97
# 2           15        85         85
# 3           15       117        117
# 4           14       169        169
# 5            3        13         13
# 6            5       169        169
# 7            5       203        203
# 8            3        61         61
# 9            2        69         69
# 10           2       440        438
# *** Cluster C6 (F)
# ***  C6 selected: 49 with EID: 49
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 42 out of 49 query genes used for enrichment calculation.
#                                       Gene set                Ontology  \
# 0                                   Proteasome          KEGG: Pathways
# 1                           peptidase activity  GO: molecular_function
# 2                            catabolic process  GO: biological_process
# 3  Protein processing in endoplasmic reticulum          KEGG: Pathways
# 4                    enzyme regulator activity  GO: molecular_function
# 5                           response to stress  GO: biological_process
# 6                              ATPase activity  GO: molecular_function
# 7                          cytoplasmic vesicle  GO: cellular_component
# 8                        endoplasmic reticulum  GO: cellular_component
#
#         FDR  N in query  Set size  N in ref.
# 0  1.09e-65          29        39         37
# 1  1.14e-31          21        91         91
# 2  9.27e-29          25       250        250
# 3  6.24e-02           3        91         88
# 4  8.14e-02           3       105        105
# 5  1.09e-01           5       360        358
# 6  1.77e-01           3       169        168
# 7  2.28e-01           3       211        211
# 8  2.41e-01           2       117        117
# *** Cluster C7 (G)
# ***  C7 selected: 96 with EID: 96
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 30 out of 96 query genes used for enrichment calculation.
#                                      Gene set                Ontology  \
# 0            anatomical structure development  GO: biological_process
# 1                        cell differentiation  GO: biological_process
# 2    development arrests at loose mound stage   Dictybase: Phenotypes
# 3                         signal transduction  GO: biological_process
# 4               Glycosaminoglycan degradation          KEGG: Pathways
# 5                        aberrant aggregation   Dictybase: Phenotypes
# 6                        extracellular region  GO: cellular_component
# 7                    increased slug migration   Dictybase: Phenotypes
# 8                    decreased aggregate size   Dictybase: Phenotypes
# 9                decreased fruiting body size   Dictybase: Phenotypes
# 10  development arrests at tipped mound stage   Dictybase: Phenotypes
# 11                                 locomotion  GO: biological_process
# 12                              cell adhesion  GO: biological_process
# 13                            plasma membrane  GO: cellular_component
# 14          aberrant fruiting body morphology   Dictybase: Phenotypes
# 15         development arrests at mound stage   Dictybase: Phenotypes
# 16                     multiple tips in mound   Dictybase: Phenotypes
# 17                    delayed gene expression   Dictybase: Phenotypes
# 18                        cell-cell signaling  GO: biological_process
# 19                       phosphatase activity  GO: molecular_function
# 20                      abolished sporulation   Dictybase: Phenotypes
# 21                  abolished gene expression   Dictybase: Phenotypes
# 22                  cytoskeleton organization  GO: biological_process
# 23                     precocious development   Dictybase: Phenotypes
# 24                         response to stress  GO: biological_process
# 25                  decreased gene expression   Dictybase: Phenotypes
# 26                  decreased chemotaxis rate   Dictybase: Phenotypes
# 27              aberrant F-actin organization   Dictybase: Phenotypes
# 28                         peptidase activity  GO: molecular_function
# 29                   abolished slug migration   Dictybase: Phenotypes
# 30                                  wild type   Dictybase: Phenotypes
# 31                       aberrant development   Dictybase: Phenotypes
# 32                               cytoskeleton  GO: cellular_component
# 33                      decreased sporulation   Dictybase: Phenotypes
# 34                cellular component assembly  GO: biological_process
# 35                              cell motility  GO: biological_process
# 36                        delayed aggregation   Dictybase: Phenotypes
# 37                    decreased cell motility   Dictybase: Phenotypes
# 38                      abolished aggregation   Dictybase: Phenotypes
# 39                                   endosome  GO: cellular_component
#
#          FDR  N in query  Set size  N in ref.
# 0   2.54e-05          16       440        438
# 1   7.20e-03           7       145        145
# 2   1.28e-02           3        20         20
# 3   1.28e-02          10       352        350
# 4   1.90e-02           2         6          6
# 5   2.15e-02           4        61         61
# 6   2.15e-02           6       157        157
# 7   2.20e-02           2         8          8
# 8   2.31e-02           3        32         32
# 9   2.96e-02           4        76         75
# 10  3.29e-02           2        12         12
# 11  3.29e-02           6       191        189
# 12  3.29e-02           4        84         83
# 13  3.75e-02           7       268        268
# 14  4.59e-02           4       101         98
# 15  4.59e-02           3        56         54
# 16  4.59e-02           2        18         18
# 17  4.59e-02           2        19         18
# 18  4.59e-02           2        16         16
# 19  4.59e-02           3        51         51
# 20  7.85e-02           2        25         25
# 21  7.85e-02           2        25         25
# 22  8.62e-02           5       197        196
# 23  9.28e-02           2        30         29
# 24  9.28e-02           7       360        358
# 25  1.22e-01           3        95         86
# 26  1.22e-01           2        36         36
# 27  1.22e-01           2        37         37
# 28  1.22e-01           3        91         91
# 29  1.40e-01           2        43         43
# 30  1.48e-01           6       341        338
# 31  1.64e-01           2        51         51
# 32  1.64e-01           4       185        185
# 33  1.68e-01           2        53         53
# 34  1.80e-01           4       202        201
# 35  1.97e-01           2        67         66
# 36  2.12e-01           2        72         72
# 37  2.24e-01           2        76         76
# 38  2.39e-01           2        82         80
# 39  2.48e-01           2        83         83
# *** Cluster C8 (H)
# ***  C8 selected: 35 with EID: 35
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 12 out of 35 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0          aberrant CRAC localization to the plasma membrane
# 1                  development arrests at tipped mound stage
# 2   anatomical structure formation involved in morphogenesis
# 3                                                 cell death
# 4                                       aberrant aggregation
# 5                               decreased chemotaxis to cAMP
# 6                                       cell differentiation
# 7                           anatomical structure development
# 8                                                 locomotion
# 9                                            kinase activity
# 10                                           RNA degradation
# 11                              decreased fruiting body size
# 12                         aberrant fruiting body morphology
# 13                                                 wild type
# 14                                              cytoskeleton
# 15                                               DNA binding
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0    Dictybase: Phenotypes  9.78e-03           2         6          6
# 1    Dictybase: Phenotypes  2.13e-02           2        12         12
# 2   GO: biological_process  3.31e-02           3        74         74
# 3   GO: biological_process  4.73e-02           2        25         25
# 4    Dictybase: Phenotypes  5.92e-02           2        61         61
# 5    Dictybase: Phenotypes  5.92e-02           2        63         63
# 6   GO: biological_process  5.92e-02           3       145        145
# 7   GO: biological_process  5.92e-02           5       440        438
# 8   GO: biological_process  5.92e-02           3       191        189
# 9   GO: molecular_function  5.92e-02           4       328        327
# 10          KEGG: Pathways  5.92e-02           2        48         48
# 11   Dictybase: Phenotypes  6.40e-02           2        76         75
# 12   Dictybase: Phenotypes  8.05e-02           2       101         98
# 13   Dictybase: Phenotypes  1.23e-01           3       341        338
# 14  GO: cellular_component  1.55e-01           2       185        185
# 15  GO: molecular_function  1.91e-01           2       221        221
# *** Cluster C9 (I)
# ***  C9 selected: 38 with EID: 38
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 18 out of 38 query genes used for enrichment calculation.
#                          Gene set                Ontology       FDR  \
# 0                      cell cycle  GO: biological_process  4.25e-14
# 1          chromosome segregation  GO: biological_process  1.68e-10
# 2        mitotic nuclear division  GO: biological_process  6.81e-09
# 3              mitotic cell cycle  GO: biological_process  1.57e-07
# 4                   cell division  GO: biological_process  2.78e-07
# 5                 DNA replication          KEGG: Pathways  2.78e-07
# 6                      chromosome  GO: cellular_component  3.02e-07
# 7         chromosome organization  GO: biological_process  3.70e-07
# 8                    cytoskeleton  GO: cellular_component  4.75e-06
# 9       cytoskeleton organization  GO: biological_process  1.04e-03
# 10  microtubule organizing center  GO: cellular_component  1.43e-03
# 11   cytoskeletal protein binding  GO: molecular_function  3.74e-03
# 12          DNA metabolic process  GO: biological_process  8.53e-02
# 13                ATPase activity  GO: molecular_function  1.56e-01
#
#     N in query  Set size  N in ref.
# 0           13       167        167
# 1            6        18         18
# 2            5        15         15
# 3            7       100        100
# 4            7       115        115
# 5            5        34         33
# 6            6        70         70
# 7            6        74         74
# 8            7       185        185
# 9            5       197        196
# 10           3        50         50
# 11           4       158        158
# 12           2       105        105
# 13           2       169        168
# *** Cluster C10 (J)
# ***  C10 selected: 70 with EID: 70
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 12 out of 70 query genes used for enrichment calculation.
#                Gene set                Ontology       FDR  N in query  \
# 0       kinase activity  GO: molecular_function  1.45e-01           6
# 1  extracellular region  GO: cellular_component  1.45e-01           4
# 2         cell adhesion  GO: biological_process  2.18e-01           2
#
#    Set size  N in ref.
# 0       328        327
# 1       157        157
# 2        84         83
# *** Cluster C11 (K)
# ***  C11 selected: 85 with EID: 85
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 7 out of 85 query genes used for enrichment calculation.
#                Gene set                Ontology       FDR  N in query  \
# 0  extracellular region  GO: cellular_component  6.09e-03           7
#
#    Set size  N in ref.
# 0       157        157
# *** Cluster C12 (L)
# ***  C12 selected: 73 with EID: 73
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 2 out of 73 query genes used for enrichment calculation.
#               Gene set                Ontology       FDR  N in query  \
# 0  cell-cell signaling  GO: biological_process  5.50e-02           2
#
#    Set size  N in ref.
# 0        16         16
# *** Cluster C13 (M)
# ***  C13 selected: 49 with EID: 49
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 13 out of 49 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                       cell differentiation
# 1   anatomical structure formation involved in morphogenesis
# 2                  DNA-binding transcription factor activity
# 3                           anatomical structure development
# 4                                  decreased gene expression
# 5                              Starch and sucrose metabolism
# 6                                  decreased spore viability
# 7                                                DNA binding
# 8                                        signal transduction
# 9                                               reproduction
# 10                            carbohydrate metabolic process
# 11                                 cytoskeleton organization
# 12                                             cell adhesion
# 13            generation of precursor metabolites and energy
# 14                                           kinase activity
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: biological_process  1.62e-03           6       145        145
# 1   GO: biological_process  7.62e-03           4        74         74
# 2   GO: molecular_function  1.03e-02           3        37         37
# 3   GO: biological_process  2.96e-02           7       440        438
# 4    Dictybase: Phenotypes  7.07e-02           3        95         86
# 5           KEGG: Pathways  8.23e-02           2        31         31
# 6    Dictybase: Phenotypes  1.09e-01           2        60         59
# 7   GO: molecular_function  1.09e-01           4       221        221
# 8   GO: biological_process  1.13e-01           4       352        350
# 9   GO: biological_process  1.13e-01           2        79         79
# 10  GO: biological_process  1.13e-01           2        89         88
# 11  GO: biological_process  1.13e-01           3       197        196
# 12  GO: biological_process  1.13e-01           2        84         83
# 13  GO: biological_process  1.13e-01           2        77         77
# 14  GO: molecular_function  2.25e-01           3       328        327
# *** Cluster C14 (N)
# ***  C14 selected: 87 with EID: 87
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 34 out of 87 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                           external encapsulating structure
# 1                                                  cell wall
# 2                             aberrant spore coat morphology
# 3                       cell wall organization or biogenesis
# 4   anatomical structure formation involved in morphogenesis
# 5                           anatomical structure development
# 6                                       extracellular region
# 7                                       cell differentiation
# 8                                aberrant cell-cell adhesion
# 9                                  decreased spore viability
# 10                                      extracellular matrix
# 11                               cellular component assembly
# 12                                        hydrolase activity
# 13                     Biosynthesis of secondary metabolites
# 14                                    Glutathione metabolism
# 15                                 Citrate cycle (TCA cycle)
# 16                             Starch and sucrose metabolism
# 17                              cytoskeletal protein binding
# 18                   Glyoxylate and dicarboxylate metabolism
# 19                                         catabolic process
# 20                                         Carbon metabolism
# 21                                           plasma membrane
# 22                              structural molecule activity
# 23                                                   cytosol
# 24                                     abolished culmination
# 25                                               DNA binding
# 26                                            lyase activity
# 27                        transmembrane transporter activity
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: cellular_component  6.64e-09           6        13         13
# 1   GO: cellular_component  6.64e-09           6        13         13
# 2    Dictybase: Phenotypes  3.07e-07           5        12         12
# 3   GO: biological_process  8.59e-07           5        15         15
# 4   GO: biological_process  1.30e-05           7        74         74
# 5   GO: biological_process  1.44e-04          13       440        438
# 6   GO: cellular_component  1.60e-04           8       157        157
# 7   GO: biological_process  6.96e-04           7       145        145
# 8    Dictybase: Phenotypes  4.20e-03           2         5          5
# 9    Dictybase: Phenotypes  6.09e-03           4        60         59
# 10  GO: cellular_component  9.49e-03           2         8          8
# 11  GO: biological_process  7.46e-02           5       202        201
# 12  GO: molecular_function  7.46e-02           2        25         25
# 13          KEGG: Pathways  7.46e-02           6       289        281
# 14          KEGG: Pathways  7.46e-02           2        28         25
# 15          KEGG: Pathways  9.17e-02           2        30         30
# 16          KEGG: Pathways  9.18e-02           2        31         31
# 17  GO: molecular_function  1.10e-01           4       158        158
# 18          KEGG: Pathways  1.15e-01           2        37         37
# 19  GO: biological_process  1.15e-01           5       250        250
# 20          KEGG: Pathways  1.15e-01           3       104        102
# 21  GO: cellular_component  1.27e-01           5       268        268
# 22  GO: molecular_function  1.43e-01           3       117        117
# 23  GO: cellular_component  1.54e-01           4       203        203
# 24   Dictybase: Phenotypes  1.84e-01           2        62         62
# 25  GO: molecular_function  1.84e-01           4       221        221
# 26  GO: molecular_function  1.96e-01           2        66         66
# 27  GO: molecular_function  1.96e-01           3       150        149
# *** Cluster C15 (O)
# ***  C15 selected: 31 with EID: 31
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 0 out of 31 query genes used for enrichment calculation.
# None
# *** Cluster C16 (P)
# ***  C16 selected: 72 with EID: 72
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 10 out of 72 query genes used for enrichment calculation.
#                Gene set                Ontology       FDR  N in query  \
# 0  extracellular region  GO: cellular_component  5.91e-07          10
#
#    Set size  N in ref.
# 0       157        157
# *** Cluster C17 (Q)
# ***  C17 selected: 57 with EID: 56
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 6 out of 56 query genes used for enrichment calculation.
#                     Gene set                Ontology       FDR  N in query  \
# 0              cell adhesion  GO: biological_process  1.23e-02           4
# 1  decreased spore viability   Dictybase: Phenotypes  1.80e-01           2
#
#    Set size  N in ref.
# 0        84         83
# 1        60         59
# *** Cluster C18 (R)
# ***  C18 selected: 65 with EID: 63
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 8 out of 63 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0                          external encapsulating structure
# 1                                                 cell wall
# 2  anatomical structure formation involved in morphogenesis
# 3                                        hydrolase activity
# 4                                      cell differentiation
# 5                                             lipid binding
# 6                                      extracellular region
#
#                  Ontology       FDR  N in query  Set size  N in ref.
# 0  GO: cellular_component  1.83e-02           2        13         13
# 1  GO: cellular_component  1.83e-02           2        13         13
# 2  GO: biological_process  4.02e-02           3        74         74
# 3  GO: molecular_function  1.05e-01           2        46         45
# 4  GO: biological_process  1.20e-01           3       145        145
# 5  GO: molecular_function  1.20e-01           2        59         59
# 6  GO: cellular_component  1.25e-01           3       157        157
# *** Cluster C19 (S)
# ***  C19 selected: 89 with EID: 88
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 10 out of 88 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0                                      extracellular region
# 1  anatomical structure formation involved in morphogenesis
# 2                                      cell differentiation
# 3                             Starch and sucrose metabolism
#
#                  Ontology       FDR  N in query  Set size  N in ref.
# 0  GO: cellular_component  2.40e-03           7       157        157
# 1  GO: biological_process  1.81e-02           4        74         74
# 2  GO: biological_process  9.71e-02           4       145        145
# 3          KEGG: Pathways  9.71e-02           2        31         31
# *** Cluster C20 (T)
# ***  C20 selected: 1 with EID: 1
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 0 out of 1 query genes used for enrichment calculation.
# None

# %% [markdown]
# #### Using only genes annotated with at least one gene set

# %%
regulons=pd.read_table(pathRegulons+'mergedGenes_minExpressed0.990.1Strains1Min1Max18_clustersAX4Louvain0.4m0s1log.tab',index_col=0)
for group in range(1,len(regulons['Cluster'].unique())+1):
    cluster='C'+str(group)
    print('*** Cluster %s (%s)' %(cluster,string.ascii_uppercase[group-1]))

    enriched=group_diff_enrichment(data=regulons,group=cluster,min_overlap=2,use_annotated_genes=True)
    if save_enrichment and enriched is not None:
        enriched.to_csv(pathRegulons+'enrichment/mergedGenes_minExpressed0.990.1Strains1Min1Max18_clustersAX4Louvain0.4m0s1log.tab'+str(group)+'.tsv', sep='\t',index=False)
# Out:
# *** Cluster C1 (A)
# ***  C1 selected: 31 with EID: 31
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.71
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 20 out of 22 query genes used for enrichment calculation.
#                               Gene set                Ontology       FDR  \
# 0    Ribosome biogenesis in eukaryotes          KEGG: Pathways  3.11e-15
# 1                            nucleolus  GO: cellular_component  2.24e-13
# 2                  ribosome biogenesis  GO: biological_process  1.48e-12
# 3   ribonucleoprotein complex assembly  GO: biological_process  1.12e-05
# 4                          RNA binding  GO: molecular_function  1.02e-03
# 5                         rRNA binding  GO: molecular_function  7.87e-03
# 6  protein-containing complex assembly  GO: biological_process  1.71e-02
# 7          cellular component assembly  GO: biological_process  6.17e-02
# 8                    helicase activity  GO: molecular_function  7.54e-02
# 9           methyltransferase activity  GO: molecular_function  8.06e-02
#
#    N in query  Set size  N in ref.
# 0          12        72         68
# 1          11        72         72
# 2          10        61         61
# 3           4        18         18
# 4           6       169        169
# 5           2        13         13
# 6           4       134        133
# 7           4       202        201
# 8           2        51         51
# 9           2        58         56
# *** Cluster C2 (B)
# ***  C2 selected: 54 with EID: 54
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.57
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 24 out of 31 query genes used for enrichment calculation.
#                                           Gene set                Ontology  \
# 0                        Oxidative phosphorylation          KEGG: Pathways
# 1                                    mitochondrion  GO: cellular_component
# 2   generation of precursor metabolites and energy  GO: biological_process
# 3                                  protein folding  GO: biological_process
# 4                         unfolded protein binding  GO: molecular_function
# 5                          oxidoreductase activity  GO: molecular_function
# 6                                        Phagosome          KEGG: Pathways
# 7                        Citrate cycle (TCA cycle)          KEGG: Pathways
# 8                            Propanoate metabolism          KEGG: Pathways
# 9                                         Ribosome          KEGG: Pathways
# 10                               Carbon metabolism          KEGG: Pathways
#
#          FDR  N in query  Set size  N in ref.
# 0   5.95e-06           7        71         54
# 1   1.46e-05          11       229        229
# 2   3.63e-04           6        77         77
# 3   2.05e-03           4        37         37
# 4   1.08e-02           3        27         27
# 5   3.78e-02           6       210        207
# 6   5.08e-02           3        53         52
# 7   1.34e-01           2        30         30
# 8   1.35e-01           2        32         32
# 9   1.87e-01           3       105         97
# 10  1.93e-01           3       104        102
# *** Cluster C3 (C)
# ***  C3 selected: 54 with EID: 54
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.89
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 44 out of 48 query genes used for enrichment calculation.
#                              Gene set                Ontology       FDR  \
# 0                            Ribosome          KEGG: Pathways  7.42e-70
# 1                            ribosome  GO: cellular_component  2.13e-68
# 2  structural constituent of ribosome  GO: molecular_function  4.10e-60
# 3        structural molecule activity  GO: molecular_function  1.96e-53
# 4                         translation  GO: biological_process  2.62e-46
# 5                         RNA binding  GO: molecular_function  1.27e-05
# 6                        rRNA binding  GO: molecular_function  3.69e-05
#
#    N in query  Set size  N in ref.
# 0          44       105         97
# 1          43        93         93
# 2          39        85         85
# 3          39       117        117
# 4          39       169        169
# 5          11       169        169
# 6           4        13         13
# *** Cluster C4 (D)
# ***  C4 selected: 43 with EID: 43
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.51
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 20 out of 22 query genes used for enrichment calculation.
#                                Gene set                Ontology       FDR  \
# 0          cytoskeletal protein binding  GO: molecular_function  8.32e-09
# 1   protein-containing complex assembly  GO: biological_process  9.64e-05
# 2           cellular component assembly  GO: biological_process  9.64e-05
# 3             cytoskeleton organization  GO: biological_process  9.64e-05
# 4                          cytoskeleton  GO: cellular_component  4.15e-04
# 5                           Endocytosis          KEGG: Pathways  4.15e-04
# 6                       plasma membrane  GO: cellular_component  4.57e-04
# 7                    response to stress  GO: biological_process  1.72e-02
# 8                               cytosol  GO: cellular_component  2.74e-02
# 9                    cell morphogenesis  GO: biological_process  3.88e-02
# 10              decreased cell motility   Dictybase: Phenotypes  4.11e-02
# 11             aberrant cell morphology   Dictybase: Phenotypes  9.85e-02
# 12                  cytoplasmic vesicle  GO: cellular_component  1.17e-01
# 13                   aberrant streaming   Dictybase: Phenotypes  1.75e-01
# 14                abolished aggregation   Dictybase: Phenotypes  1.82e-01
# 15                         reproduction  GO: biological_process  1.82e-01
# 16     anatomical structure development  GO: biological_process  2.01e-01
# 17                 aberrant cytokinesis   Dictybase: Phenotypes  2.17e-01
# 18                   mitotic cell cycle  GO: biological_process  2.17e-01
# 19                            wild type   Dictybase: Phenotypes  2.21e-01
# 20                        cell division  GO: biological_process  2.45e-01
# 21           vesicle-mediated transport  GO: biological_process  2.45e-01
#
#     N in query  Set size  N in ref.
# 0           11       158        158
# 1            7       134        133
# 2            8       202        201
# 3            8       197        196
# 4            7       185        185
# 5            5        77         75
# 6            8       268        268
# 7            7       360        358
# 8            5       203        203
# 9            2        23         23
# 10           3        76         76
# 11           2        42         41
# 12           4       211        211
# 13           2        72         72
# 14           2        82         80
# 15           2        79         79
# 16           5       440        438
# 17           2        98         98
# 18           2       100        100
# 19           4       341        338
# 20           2       115        115
# 21           3       233        233
# *** Cluster C5 (E)
# ***  C5 selected: 20 with EID: 20
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.9
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 18 out of 18 query genes used for enrichment calculation.
#                              Gene set                Ontology       FDR  \
# 0                            ribosome  GO: cellular_component  1.94e-26
# 1                            Ribosome          KEGG: Pathways  2.12e-26
# 2  structural constituent of ribosome  GO: molecular_function  1.67e-22
# 3        structural molecule activity  GO: molecular_function  2.14e-20
# 4                         translation  GO: biological_process  5.04e-16
# 5                        rRNA binding  GO: molecular_function  8.23e-05
# 6                         RNA binding  GO: molecular_function  2.36e-03
# 7                             cytosol  GO: cellular_component  4.75e-03
# 8                 ribosome biogenesis  GO: biological_process  6.01e-03
# 9                 delayed development   Dictybase: Phenotypes  8.53e-02
#
#    N in query  Set size  N in ref.
# 0          17        93         93
# 1          17       105         97
# 2          15        85         85
# 3          15       117        117
# 4          14       169        169
# 5           3        13         13
# 6           5       169        169
# 7           5       203        203
# 8           3        61         61
# 9           2        69         69
# *** Cluster C6 (F)
# ***  C6 selected: 49 with EID: 49
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.94
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 35 out of 46 query genes used for enrichment calculation.
#              Gene set                Ontology       FDR  N in query  Set size  \
# 0          Proteasome          KEGG: Pathways  1.82e-52          29        39
# 1  peptidase activity  GO: molecular_function  4.33e-22          21        91
# 2   catabolic process  GO: biological_process  1.31e-17          25       250
#
#    N in ref.
# 0         37
# 1         91
# 2        250
# *** Cluster C7 (G)
# ***  C7 selected: 96 with EID: 96
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.39
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 30 out of 37 query genes used for enrichment calculation.
#                                      Gene set                Ontology  \
# 0            anatomical structure development  GO: biological_process
# 1                        cell differentiation  GO: biological_process
# 2    development arrests at loose mound stage   Dictybase: Phenotypes
# 3                         signal transduction  GO: biological_process
# 4               Glycosaminoglycan degradation          KEGG: Pathways
# 5                    increased slug migration   Dictybase: Phenotypes
# 6                        aberrant aggregation   Dictybase: Phenotypes
# 7                    decreased aggregate size   Dictybase: Phenotypes
# 8                        extracellular region  GO: cellular_component
# 9                decreased fruiting body size   Dictybase: Phenotypes
# 10  development arrests at tipped mound stage   Dictybase: Phenotypes
# 11                                 locomotion  GO: biological_process
# 12                              cell adhesion  GO: biological_process
# 13                     multiple tips in mound   Dictybase: Phenotypes
# 14                    delayed gene expression   Dictybase: Phenotypes
# 15                        cell-cell signaling  GO: biological_process
# 16                       phosphatase activity  GO: molecular_function
# 17                            plasma membrane  GO: cellular_component
# 18          aberrant fruiting body morphology   Dictybase: Phenotypes
# 19         development arrests at mound stage   Dictybase: Phenotypes
# 20                      abolished sporulation   Dictybase: Phenotypes
# 21                  abolished gene expression   Dictybase: Phenotypes
# 22                     precocious development   Dictybase: Phenotypes
# 23                  cytoskeleton organization  GO: biological_process
# 24                  decreased chemotaxis rate   Dictybase: Phenotypes
# 25                  decreased gene expression   Dictybase: Phenotypes
# 26              aberrant F-actin organization   Dictybase: Phenotypes
# 27                         response to stress  GO: biological_process
# 28                         peptidase activity  GO: molecular_function
# 29                   abolished slug migration   Dictybase: Phenotypes
# 30                       aberrant development   Dictybase: Phenotypes
# 31                      decreased sporulation   Dictybase: Phenotypes
# 32                                  wild type   Dictybase: Phenotypes
# 33                               cytoskeleton  GO: cellular_component
# 34                cellular component assembly  GO: biological_process
#
#          FDR  N in query  Set size  N in ref.
# 0   6.54e-05          16       440        438
# 1   1.77e-02           7       145        145
# 2   2.73e-02           3        20         20
# 3   2.73e-02          10       352        350
# 4   2.73e-02           2         6          6
# 5   3.65e-02           2         8          8
# 6   3.65e-02           4        61         61
# 7   3.79e-02           3        32         32
# 8   3.79e-02           6       157        157
# 9   5.27e-02           4        76         75
# 10  5.27e-02           2        12         12
# 11  6.34e-02           6       191        189
# 12  6.34e-02           4        84         83
# 13  7.20e-02           2        18         18
# 14  7.20e-02           2        19         18
# 15  7.20e-02           2        16         16
# 16  7.20e-02           3        51         51
# 17  7.20e-02           7       268        268
# 18  7.27e-02           4       101         98
# 19  7.40e-02           3        56         54
# 20  1.11e-01           2        25         25
# 21  1.11e-01           2        25         25
# 22  1.40e-01           2        30         29
# 23  1.57e-01           5       197        196
# 24  1.58e-01           2        36         36
# 25  1.58e-01           3        95         86
# 26  1.58e-01           2        37         37
# 27  1.58e-01           7       360        358
# 28  1.73e-01           3        91         91
# 29  1.94e-01           2        43         43
# 30  2.27e-01           2        51         51
# 31  2.27e-01           2        53         53
# 32  2.27e-01           6       341        338
# 33  2.27e-01           4       185        185
# 34  2.45e-01           4       202        201
# *** Cluster C8 (H)
# ***  C8 selected: 35 with EID: 35
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.4
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 11 out of 14 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0          aberrant CRAC localization to the plasma membrane
# 1                  development arrests at tipped mound stage
# 2   anatomical structure formation involved in morphogenesis
# 3                                                 cell death
# 4                                       aberrant aggregation
# 5                               decreased chemotaxis to cAMP
# 6                                       cell differentiation
# 7                           anatomical structure development
# 8                                            RNA degradation
# 9                               decreased fruiting body size
# 10                                                locomotion
# 11                                           kinase activity
# 12                         aberrant fruiting body morphology
# 13                                                 wild type
# 14                                              cytoskeleton
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0    Dictybase: Phenotypes  1.47e-02           2         6          6
# 1    Dictybase: Phenotypes  3.20e-02           2        12         12
# 2   GO: biological_process  5.63e-02           3        74         74
# 3   GO: biological_process  7.09e-02           2        25         25
# 4    Dictybase: Phenotypes  8.09e-02           2        61         61
# 5    Dictybase: Phenotypes  8.09e-02           2        63         63
# 6   GO: biological_process  8.09e-02           3       145        145
# 7   GO: biological_process  8.09e-02           5       440        438
# 8           KEGG: Pathways  8.09e-02           2        48         48
# 9    Dictybase: Phenotypes  8.77e-02           2        76         75
# 10  GO: biological_process  8.77e-02           3       191        189
# 11  GO: molecular_function  8.77e-02           4       328        327
# 12   Dictybase: Phenotypes  1.05e-01           2       101         98
# 13   Dictybase: Phenotypes  1.86e-01           3       341        338
# 14  GO: cellular_component  2.14e-01           2       185        185
# *** Cluster C9 (I)
# ***  C9 selected: 38 with EID: 38
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.5
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 18 out of 19 query genes used for enrichment calculation.
#                          Gene set                Ontology       FDR  \
# 0                      cell cycle  GO: biological_process  6.67e-13
# 1          chromosome segregation  GO: biological_process  1.58e-09
# 2        mitotic nuclear division  GO: biological_process  4.78e-08
# 3              mitotic cell cycle  GO: biological_process  1.81e-06
# 4                 DNA replication          KEGG: Pathways  2.15e-06
# 5                   cell division  GO: biological_process  2.74e-06
# 6                      chromosome  GO: cellular_component  2.74e-06
# 7         chromosome organization  GO: biological_process  3.35e-06
# 8                    cytoskeleton  GO: cellular_component  5.22e-05
# 9   microtubule organizing center  GO: cellular_component  5.37e-03
# 10      cytoskeleton organization  GO: biological_process  5.76e-03
# 11   cytoskeletal protein binding  GO: molecular_function  1.67e-02
# 12          DNA metabolic process  GO: biological_process  1.86e-01
#
#     N in query  Set size  N in ref.
# 0           13       167        167
# 1            6        18         18
# 2            5        15         15
# 3            7       100        100
# 4            5        34         33
# 5            7       115        115
# 6            6        70         70
# 7            6        74         74
# 8            7       185        185
# 9            3        50         50
# 10           5       197        196
# 11           4       158        158
# 12           2       105        105
# *** Cluster C10 (J)
# ***  C10 selected: 70 with EID: 70
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.26
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 12 out of 18 query genes used for enrichment calculation.
#                Gene set                Ontology       FDR  N in query  \
# 0       kinase activity  GO: molecular_function  5.80e-02           6
# 1  extracellular region  GO: cellular_component  5.80e-02           4
# 2         cell adhesion  GO: biological_process  1.74e-01           2
#
#    Set size  N in ref.
# 0       328        327
# 1       157        157
# 2        84         83
# *** Cluster C11 (K)
# ***  C11 selected: 85 with EID: 85
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.24
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 7 out of 20 query genes used for enrichment calculation.
#                Gene set                Ontology       FDR  N in query  \
# 0  extracellular region  GO: cellular_component  4.26e-04           7
#
#    Set size  N in ref.
# 0       157        157
# *** Cluster C12 (L)
# ***  C12 selected: 73 with EID: 73
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.11
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 5 out of 8 query genes used for enrichment calculation.
#                            Gene set                Ontology       FDR  \
# 0               cell-cell signaling  GO: biological_process  6.01e-03
# 1  anatomical structure development  GO: biological_process  5.17e-02
# 2              extracellular region  GO: cellular_component  1.33e-01
# 3                         wild type   Dictybase: Phenotypes  2.33e-01
# 4               signal transduction  GO: biological_process  2.33e-01
#
#    N in query  Set size  N in ref.
# 0           2        16         16
# 1           4       440        438
# 2           2       157        157
# 3           2       341        338
# 4           2       352        350
# *** Cluster C13 (M)
# ***  C13 selected: 49 with EID: 49
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.31
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 13 out of 15 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                       cell differentiation
# 1   anatomical structure formation involved in morphogenesis
# 2                  DNA-binding transcription factor activity
# 3                           anatomical structure development
# 4                                  decreased gene expression
# 5                              Starch and sucrose metabolism
# 6                                                DNA binding
# 7                                  decreased spore viability
# 8                                        signal transduction
# 9                                               reproduction
# 10                            carbohydrate metabolic process
# 11                                 cytoskeleton organization
# 12                                             cell adhesion
# 13            generation of precursor metabolites and energy
# 14                                           kinase activity
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: biological_process  6.40e-04           6       145        145
# 1   GO: biological_process  5.00e-03           4        74         74
# 2   GO: molecular_function  7.98e-03           3        37         37
# 3   GO: biological_process  1.09e-02           7       440        438
# 4    Dictybase: Phenotypes  5.63e-02           3        95         86
# 5           KEGG: Pathways  7.32e-02           2        31         31
# 6   GO: molecular_function  8.59e-02           4       221        221
# 7    Dictybase: Phenotypes  1.04e-01           2        60         59
# 8   GO: biological_process  1.04e-01           4       352        350
# 9   GO: biological_process  1.04e-01           2        79         79
# 10  GO: biological_process  1.04e-01           2        89         88
# 11  GO: biological_process  1.04e-01           3       197        196
# 12  GO: biological_process  1.04e-01           2        84         83
# 13  GO: biological_process  1.04e-01           2        77         77
# 14  GO: molecular_function  1.98e-01           3       328        327
# *** Cluster C14 (N)
# ***  C14 selected: 87 with EID: 87
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.45
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 33 out of 39 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                           external encapsulating structure
# 1                                                  cell wall
# 2                             aberrant spore coat morphology
# 3                       cell wall organization or biogenesis
# 4   anatomical structure formation involved in morphogenesis
# 5                                       extracellular region
# 6                           anatomical structure development
# 7                                       cell differentiation
# 8                                aberrant cell-cell adhesion
# 9                                  decreased spore viability
# 10                                      extracellular matrix
# 11                                        hydrolase activity
# 12                                    Glutathione metabolism
# 13                                 Citrate cycle (TCA cycle)
# 14                             Starch and sucrose metabolism
# 15                               cellular component assembly
# 16                   Glyoxylate and dicarboxylate metabolism
# 17                     Biosynthesis of secondary metabolites
# 18                              cytoskeletal protein binding
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: cellular_component  4.07e-08           6        13         13
# 1   GO: cellular_component  4.07e-08           6        13         13
# 2    Dictybase: Phenotypes  1.45e-06           5        12         12
# 3   GO: biological_process  4.02e-06           5        15         15
# 4   GO: biological_process  9.33e-05           7        74         74
# 5   GO: cellular_component  1.51e-03           8       157        157
# 6   GO: biological_process  2.03e-03          13       440        438
# 7   GO: biological_process  4.48e-03           7       145        145
# 8    Dictybase: Phenotypes  8.16e-03           2         5          5
# 9    Dictybase: Phenotypes  1.84e-02           4        60         59
# 10  GO: cellular_component  1.84e-02           2         8          8
# 11  GO: molecular_function  1.50e-01           2        25         25
# 12          KEGG: Pathways  1.50e-01           2        28         25
# 13          KEGG: Pathways  1.94e-01           2        30         30
# 14          KEGG: Pathways  1.94e-01           2        31         31
# 15  GO: biological_process  2.00e-01           5       202        201
# 16          KEGG: Pathways  2.00e-01           2        37         37
# 17          KEGG: Pathways  2.08e-01           6       289        281
# 18  GO: molecular_function  2.36e-01           4       158        158
# *** Cluster C15 (O)
# ***  C15 selected: 31 with EID: 31
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.26
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 2 out of 8 query genes used for enrichment calculation.
#                   Gene set                Ontology       FDR  N in query  \
# 0  oxidoreductase activity  GO: molecular_function  2.39e-01           2
#
#    Set size  N in ref.
# 0       210        207
# *** Cluster C16 (P)
# ***  C16 selected: 72 with EID: 72
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.25
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 12 out of 18 query genes used for enrichment calculation.
#                Gene set                Ontology       FDR  N in query  \
# 0  extracellular region  GO: cellular_component  6.74e-09          10
# 1             wild type   Dictybase: Phenotypes  1.99e-01           5
#
#    Set size  N in ref.
# 0       157        157
# 1       341        338
# *** Cluster C17 (Q)
# ***  C17 selected: 57 with EID: 56
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.2
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 6 out of 11 query genes used for enrichment calculation.
#                     Gene set                Ontology       FDR  N in query  \
# 0              cell adhesion  GO: biological_process  1.25e-03           4
# 1  decreased spore viability   Dictybase: Phenotypes  1.12e-01           2
#
#    Set size  N in ref.
# 0        84         83
# 1        60         59
# *** Cluster C18 (R)
# ***  C18 selected: 65 with EID: 63
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.14
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 8 out of 9 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0  anatomical structure formation involved in morphogenesis
# 1                          external encapsulating structure
# 2                                                 cell wall
# 3                                      cell differentiation
# 4                                        hydrolase activity
# 5                                      extracellular region
# 6                                             lipid binding
# 7                          anatomical structure development
# 8                                         protein transport
#
#                  Ontology       FDR  N in query  Set size  N in ref.
# 0  GO: biological_process  3.14e-03           3        74         74
# 1  GO: cellular_component  3.14e-03           2        13         13
# 2  GO: cellular_component  3.14e-03           2        13         13
# 3  GO: biological_process  1.39e-02           3       145        145
# 4  GO: molecular_function  1.39e-02           2        46         45
# 5  GO: cellular_component  1.39e-02           3       157        157
# 6  GO: molecular_function  2.02e-02           2        59         59
# 7  GO: biological_process  2.88e-02           4       440        438
# 8  GO: biological_process  1.23e-01           2       197        197
# *** Cluster C19 (S)
# ***  C19 selected: 89 with EID: 88
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.2
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 10 out of 18 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0                                      extracellular region
# 1  anatomical structure formation involved in morphogenesis
# 2                                      cell differentiation
# 3                             Starch and sucrose metabolism
#
#                  Ontology       FDR  N in query  Set size  N in ref.
# 0  GO: cellular_component  5.93e-05           7       157        157
# 1  GO: biological_process  2.76e-03           4        74         74
# 2  GO: biological_process  2.30e-02           4       145        145
# 3          KEGG: Pathways  4.05e-02           2        31         31
# *** Cluster C20 (T)
# ***  C20 selected: 1 with EID: 1
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.0
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 0 out of 0 query genes used for enrichment calculation.
# None

# %% [markdown]
# #### Use all GO gene sets (not only slims), no lower bound on gene set size

# %%
# Get all gene sets
gene_sets=list(list_all(organism='44689'))
GENE_SETS_ONTOLOGY=enr.get_gene_sets(gene_set_names=gene_sets, go_slims=False,set_sizes=(1,500))
# Find out max/min gene set sizes and N sets
max_n=0
min_n=np.inf
for k,v in GENE_SETS_ONTOLOGY.items():
    for s in v:
        n=len(s.genes)
        if n<min_n:
            min_n=n
        if n>max_n:
            max_n=n
print('Min size',min_n,'Max size',max_n)  
print('N sets',{k:len(v) for k,v in GENE_SETS_ONTOLOGY.items()})
regulons=pd.read_table(pathRegulons+'mergedGenes_minExpressed0.990.1Strains1Min1Max18_clustersAX4Louvain0.4m0s1log.tab',index_col=0)
for group in range(1,len(regulons['Cluster'].unique())+1):
    cluster='C'+str(group)
    print('*** Cluster %s (%s)' %(cluster,string.ascii_uppercase[group-1]))

    enriched=group_diff_enrichment(data=regulons,group=cluster,min_overlap=2,use_annotated_genes=True)
    if save_enrichment and enriched is not None:
        enriched.to_csv(pathRegulons+'enrichment/mergedGenes_minExpressed0.990.1Strains1Min1Max18_clustersAX4Louvain0.4m0s1log.tab'+str(group)+'.tsv', sep='\t',index=False)
# Out:
# Min size 1 Max size 481
# N sets {('GO', 'molecular_function'): 1523, ('GO', 'biological_process'): 3089, ('GO', 'cellular_component'): 652, ('Dictybase', 'Phenotypes'): 631, ('KEGG', 'Pathways'): 105}
# *** Cluster C1 (A)
# ***  C1 selected: 31 with EID: 31
# Ratio of genes annotated with a gene set in reference 0.33 and query 0.71
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 20 out of 22 query genes used for enrichment calculation.
#                                            Gene set                Ontology  \
# 0                 Ribosome biogenesis in eukaryotes          KEGG: Pathways
# 1                                         nucleolus  GO: cellular_component
# 2                               ribosome biogenesis  GO: biological_process
# 3              ribonucleoprotein complex biogenesis  GO: biological_process
# 4                                     nuclear lumen  GO: cellular_component
# 5                  ribosomal large subunit assembly  GO: biological_process
# 6                           membrane-enclosed lumen  GO: cellular_component
# 7                                   organelle lumen  GO: cellular_component
# 8                     intracellular organelle lumen  GO: cellular_component
# 9                            rRNA metabolic process  GO: biological_process
# 10                                  rRNA processing  GO: biological_process
# 11                                ribosome assembly  GO: biological_process
# 12                    cellular component biogenesis  GO: biological_process
# 13               ribosomal large subunit biogenesis  GO: biological_process
# 14                                 ncRNA processing  GO: biological_process
# 15   ribonucleoprotein complex subunit organization  GO: biological_process
# 16               ribonucleoprotein complex assembly  GO: biological_process
# 17                   non-membrane-bounded organelle  GO: cellular_component
# 18     intracellular non-membrane-bounded organelle  GO: cellular_component
# 19                               organelle assembly  GO: biological_process
# 20                                   RNA processing  GO: biological_process
# 21                          ncRNA metabolic process  GO: biological_process
# 22                                      RNA binding  GO: molecular_function
# 23                                     rRNA binding  GO: molecular_function
# 24                            RNA metabolic process  GO: biological_process
# 25     cellular protein-containing complex assembly  GO: biological_process
# 26              protein-containing complex assembly  GO: biological_process
# 27                            RNA helicase activity  GO: molecular_function
# 28  protein-containing complex subunit organization  GO: biological_process
# 29                   nucleic acid metabolic process  GO: biological_process
# 30                               catalytic activity  GO: molecular_function
# 31                      cellular component assembly  GO: biological_process
# 32                             nucleic acid binding  GO: molecular_function
# 33                                helicase activity  GO: molecular_function
# 34                       methyltransferase activity  GO: molecular_function
# 35                                      methylation  GO: biological_process
# 36                             transferase activity  GO: molecular_function
# 37                           organelle organization  GO: biological_process
#
#          FDR  N in query  Set size  N in ref.
# 0   1.16e-14          12        72         68
# 1   8.77e-13          11        72         72
# 2   6.05e-12          10        61         61
# 3   2.62e-11          10        72         72
# 4   4.60e-09          11       167        167
# 5   6.85e-08           4         5          5
# 6   9.71e-08          11       234        234
# 7   9.71e-08          11       234        234
# 8   9.71e-08          11       234        234
# 9   5.44e-07           6        41         41
# 10  5.44e-07           6        41         41
# 11  8.51e-07           4         9          9
# 12  2.26e-06          10       254        253
# 13  1.03e-05           4        16         16
# 14  1.36e-05           6        73         73
# 15  1.41e-05           4        18         18
# 16  1.41e-05           4        18         18
# 17  4.62e-05          11       458        458
# 18  4.62e-05          11       458        458
# 19  4.85e-05           4        25         25
# 20  7.89e-05           7       161        160
# 21  1.26e-04           6       114        114
# 22  1.11e-03           6       169        169
# 23  1.15e-02           2        13         13
# 24  1.44e-02           7       380        379
# 25  1.84e-02           4       123        122
# 26  2.31e-02           4       134        133
# 27  2.86e-02           2        27         27
# 28  2.86e-02           4       158        157
# 29  2.86e-02           7       472        471
# 30  4.95e-02           3       111        111
# 31  4.95e-02           4       202        201
# 32  5.52e-02           6       438        438
# 33  6.54e-02           2        51         51
# 34  7.61e-02           2        58         56
# 35  7.61e-02           2        59         57
# 36  8.52e-02           2        64         62
# 37  1.95e-01           4       369        368
# *** Cluster C2 (B)
# ***  C2 selected: 54 with EID: 54
# Ratio of genes annotated with a gene set in reference 0.33 and query 0.59
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 24 out of 32 query genes used for enrichment calculation.
#                                                           Gene set  \
# 0                                        Oxidative phosphorylation
# 1                                                    mitochondrion
# 2                                            ATP metabolic process
# 3                   generation of precursor metabolites and energy
# 4                                                chaperone complex
# 5                                  chaperonin-containing T-complex
# 6                                        oxidative phosphorylation
# 7                                             cellular respiration
# 8                    proton-transporting two-sector ATPase complex
# 9                      succinate-CoA ligase (ADP-forming) activity
# 10                                   succinate-CoA ligase activity
# 11                       proton transmembrane transporter activity
# 12                                  proton transmembrane transport
# 13                                                 protein folding
# 14                                          mitochondrial envelope
# 15             energy derivation by oxidation of organic compounds
# 16                                                     respirasome
# 17                                mitochondrial electron transport
# 18                                    mitochondrial inner membrane
# 19                                        organelle inner membrane
# 20                                     oxidation-reduction process
# 21                                              organelle envelope
# 22                                                        envelope
# 23  monovalent inorganic cation transmembrane transporter activity
# 24                               proton-transporting V-type ATPase
# 25                        ATP synthesis coupled electron transport
# 26                                             aerobic respiration
# 27          mitochondrial ATP synthesis coupled electron transport
# 28                                          mitochondrial membrane
# 29                           monovalent inorganic cation transport
# 30                                        unfolded protein binding
# 31                                                          2 iron
# 32                   proton-transporting two-sector ATPase complex
# 33                            respiratory electron transport chain
# 34                       proton-transporting V-type ATPase complex
# 35                                      acid-thiol ligase activity
# 36                        inorganic cation transmembrane transport
# 37             inorganic cation transmembrane transporter activity
# 38                                  cation transmembrane transport
# 39                       cation transmembrane transporter activity
# 40                                         oxidoreductase activity
# 41                    inner mitochondrial membrane protein complex
# 42                           inorganic ion transmembrane transport
# 43                                      electron transfer activity
# 44                                                 ligase activity
# 45   inorganic molecular entity transmembrane transporter activity
# 46                                                       Phagosome
# 47                                                cation transport
# 48                                                    heme binding
# 49                         purine ribonucleotide metabolic process
# 50                                            tetrapyrrole binding
# 51                                        electron transport chain
# 52                                     iron-sulfur cluster binding
# 53                                           metal cluster binding
# 54                             purine nucleotide metabolic process
# 55                              ribose phosphate metabolic process
# 56                                        tricarboxylic acid cycle
# 57                                ribonucleotide metabolic process
# 58                                        membrane protein complex
# 59                                     ion transmembrane transport
# 60                                   mitochondrial protein complex
# 61                                              organelle membrane
# 62                                           magnesium ion binding
# 63                    purine-containing compound metabolic process
# 64                                                cofactor binding
# 65                          ion transmembrane transporter activity
# 66                                       Citrate cycle (TCA cycle)
# 67                                   contractile vacuolar membrane
# 68                                           Propanoate metabolism
# 69                                            transporter activity
# 70                                                        Ribosome
# 71                                    nucleotide metabolic process
# 72                          nucleoside phosphate metabolic process
# 73                                               Carbon metabolism
# 74                                                   ion transport
# 75                                             contractile vacuole
# 76                                     contractile vacuole complex
# 77          nucleobase-containing small molecule metabolic process
# 78                                                         cytosol
# 79                                               vacuolar membrane
# 80                           monocarboxylic acid metabolic process
# 81                              transmembrane transporter activity
# 82                       carbohydrate derivative metabolic process
# 83                                                 ligase activity
# 84                                         transmembrane transport
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0           KEGG: Pathways  3.52e-05           7        71         54
# 1   GO: cellular_component  8.58e-05          11       229        229
# 2   GO: biological_process  4.17e-04           5        33         33
# 3   GO: biological_process  1.16e-03           6        77         77
# 4   GO: cellular_component  1.16e-03           3         8          8
# 5   GO: cellular_component  1.16e-03           3         8          8
# 6   GO: biological_process  1.48e-03           3         9          9
# 7   GO: biological_process  2.98e-03           4        31         31
# 8   GO: cellular_component  2.98e-03           3        12         12
# 9   GO: molecular_function  3.64e-03           2         3          3
# 10  GO: molecular_function  3.64e-03           2         3          3
# 11  GO: molecular_function  3.64e-03           3        14         14
# 12  GO: biological_process  3.64e-03           3        15         15
# 13  GO: biological_process  3.64e-03           4        37         37
# 14  GO: cellular_component  3.64e-03           6       107        107
# 15  GO: biological_process  3.83e-03           4        39         39
# 16  GO: cellular_component  4.74e-03           3        17         17
# 17  GO: biological_process  5.47e-03           2         4          4
# 18  GO: cellular_component  5.47e-03           5        81         81
# 19  GO: cellular_component  5.81e-03           5        83         83
# 20  GO: biological_process  6.78e-03           8       254        251
# 21  GO: cellular_component  6.78e-03           6       136        136
# 22  GO: cellular_component  6.78e-03           6       136        136
# 23  GO: molecular_function  7.11e-03           3        22         22
# 24  GO: cellular_component  7.11e-03           2         5          5
# 25  GO: biological_process  9.02e-03           2         6          6
# 26  GO: biological_process  9.02e-03           3        25         25
# 27  GO: biological_process  9.02e-03           2         6          6
# 28  GO: cellular_component  9.02e-03           5        98         98
# 29  GO: biological_process  9.80e-03           3        26         26
# 30  GO: molecular_function  1.06e-02           3        27         27
# 31  GO: molecular_function  1.09e-02           2         7          7
# 32  GO: cellular_component  1.09e-02           2         7          7
# 33  GO: biological_process  1.40e-02           2         8          8
# 34  GO: cellular_component  1.74e-02           2         9          9
# 35  GO: molecular_function  2.07e-02           2        10         10
# 36  GO: biological_process  2.07e-02           3        36         36
# 37  GO: molecular_function  2.66e-02           3        40         40
# 38  GO: biological_process  2.66e-02           3        40         40
# 39  GO: molecular_function  3.19e-02           3        43         43
# 40  GO: molecular_function  3.32e-02           6       210        207
# 41  GO: cellular_component  3.58e-02           2        14         14
# 42  GO: biological_process  3.82e-02           3        48         47
# 43  GO: molecular_function  3.92e-02           2        15         15
# 44  GO: molecular_function  3.93e-02           2        16         16
# 45  GO: molecular_function  3.93e-02           3        54         53
# 46          KEGG: Pathways  3.93e-02           3        53         52
# 47  GO: biological_process  4.03e-02           3        54         54
# 48  GO: molecular_function  4.06e-02           2        18         18
# 49  GO: biological_process  4.11e-02           3        55         55
# 50  GO: molecular_function  4.30e-02           2        19         19
# 51  GO: biological_process  4.30e-02           2        19         19
# 52  GO: molecular_function  4.72e-02           2        22         22
# 53  GO: molecular_function  4.72e-02           2        22         22
# 54  GO: biological_process  4.72e-02           3        62         62
# 55  GO: biological_process  4.72e-02           3        68         68
# 56  GO: biological_process  4.72e-02           2        21         21
# 57  GO: biological_process  4.72e-02           3        65         65
# 58  GO: cellular_component  4.72e-02           4       113        112
# 59  GO: biological_process  4.72e-02           3        70         69
# 60  GO: cellular_component  4.72e-02           2        25         25
# 61  GO: cellular_component  4.90e-02           7       354        353
# 62  GO: molecular_function  4.95e-02           2        26         26
# 63  GO: biological_process  4.95e-02           3        71         71
# 64  GO: molecular_function  5.21e-02           4       133        132
# 65  GO: molecular_function  5.62e-02           3        76         75
# 66          KEGG: Pathways  6.27e-02           2        30         30
# 67  GO: cellular_component  6.37e-02           2        31         31
# 68          KEGG: Pathways  6.70e-02           2        32         32
# 69  GO: molecular_function  9.11e-02           4       163        162
# 70          KEGG: Pathways  9.11e-02           3       105         97
# 71  GO: biological_process  9.28e-02           3        98         98
# 72  GO: biological_process  9.44e-02           3        99         99
# 73          KEGG: Pathways  1.01e-01           3       104        102
# 74  GO: biological_process  1.07e-01           3       106        105
# 75  GO: cellular_component  1.29e-01           2        51         51
# 76  GO: cellular_component  1.29e-01           2        51         51
# 77  GO: biological_process  1.43e-01           3       122        122
# 78  GO: cellular_component  1.47e-01           4       203        203
# 79  GO: cellular_component  1.49e-01           2        57         57
# 80  GO: biological_process  1.79e-01           2        71         71
# 81  GO: molecular_function  1.84e-01           3       150        149
# 82  GO: biological_process  1.91e-01           3       152        152
# 83  GO: molecular_function  2.08e-01           2        80         80
# 84  GO: biological_process  2.11e-01           3       165        164
# *** Cluster C3 (C)
# ***  C3 selected: 54 with EID: 54
# Ratio of genes annotated with a gene set in reference 0.33 and query 0.89
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 45 out of 48 query genes used for enrichment calculation.
#                                            Gene set                Ontology  \
# 0                                          Ribosome          KEGG: Pathways
# 1                                          ribosome  GO: cellular_component
# 2                structural constituent of ribosome  GO: molecular_function
# 3                      structural molecule activity  GO: molecular_function
# 4                                       translation  GO: biological_process
# 5                      peptide biosynthetic process  GO: biological_process
# 6                         peptide metabolic process  GO: biological_process
# 7                        amide biosynthetic process  GO: biological_process
# 8                  cellular amide metabolic process  GO: biological_process
# 9                    non-membrane-bounded organelle  GO: cellular_component
# 10     intracellular non-membrane-bounded organelle  GO: cellular_component
# 11     organonitrogen compound biosynthetic process  GO: biological_process
# 12      cellular macromolecule biosynthetic process  GO: biological_process
# 13               macromolecule biosynthetic process  GO: biological_process
# 14  cellular nitrogen compound biosynthetic process  GO: biological_process
# 15                                ribosomal subunit  GO: cellular_component
# 16                          large ribosomal subunit  GO: cellular_component
# 17                        ribonucleoprotein complex  GO: cellular_component
# 18                                      RNA binding  GO: molecular_function
# 19                                     rRNA binding  GO: molecular_function
# 20                          small ribosomal subunit  GO: cellular_component
# 21                cytosolic large ribosomal subunit  GO: cellular_component
# 22                               cytosolic ribosome  GO: cellular_component
# 23                             nucleic acid binding  GO: molecular_function
#
#          FDR  N in query  Set size  N in ref.
# 0   5.89e-70          44       105         97
# 1   1.77e-68          43        93         93
# 2   4.10e-60          39        85         85
# 3   1.96e-53          39       117        117
# 4   2.63e-46          39       169        169
# 5   3.67e-46          39       171        171
# 6   1.42e-45          39       177        177
# 7   1.69e-44          39       188        188
# 8   5.71e-42          39       216        216
# 9   2.33e-37          44       458        458
# 10  2.33e-37          44       458        458
# 11  2.37e-34          39       332        332
# 12  3.11e-30          39       421        421
# 13  5.57e-30          39       428        428
# 14  8.36e-29          39       459        459
# 15  5.90e-12           9        22         22
# 16  2.54e-09           6        10         10
# 17  7.21e-06           9        96         96
# 18  1.50e-05          11       169        169
# 19  6.28e-05           4        13         13
# 20  1.69e-03           3        12         12
# 21  4.16e-03           2         4          4
# 22  1.80e-02           2         8          8
# 23  5.01e-02          11       438        438
# *** Cluster C4 (D)
# ***  C4 selected: 43 with EID: 43
# Ratio of genes annotated with a gene set in reference 0.33 and query 0.56
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 23 out of 24 query genes used for enrichment calculation.
#                                                           Gene set  \
# 0                                           actin filament binding
# 1                                                    actin binding
# 2                               protein-containing complex binding
# 3                                     cytoskeletal protein binding
# 4                                                      cell cortex
# 5                regulation of protein-containing complex assembly
# 6                  regulation of supramolecular fiber organization
# 7                    regulation of actin cytoskeleton organization
# 8                       regulation of actin filament-based process
# 9                                        response to cation stress
# 10                                         response to salt stress
# 11                         regulation of cytoskeleton organization
# 12                     regulation of cellular component biogenesis
# 13                                                  cell periphery
# 14                            regulation of organelle organization
# 15                               supramolecular fiber organization
# 16                                              actin cytoskeleton
# 17                                 actin cytoskeleton organization
# 18                                    actin filament-based process
# 19                                     actin filament organization
# 20                                          plasma membrane region
# 21                                               cell leading edge
# 22                   regulation of cellular component organization
# 23                    cellular protein-containing complex assembly
# 24                                          Arp2/3 protein complex
# 25                     regulation of actin filament polymerization
# 26                             protein-containing complex assembly
# 27                            regulation of protein polymerization
# 28                                       cytoskeleton organization
# 29                                     cellular component assembly
# 30                             regulation of actin filament length
# 31                       regulation of actin filament organization
# 32          regulation of actin polymerization or depolymerization
# 33                                     cortical actin cytoskeleton
# 34                        Arp2/3 complex-mediated actin nucleation
# 35                                            carbohydrate binding
# 36                 protein-containing complex subunit organization
# 37                                           cortical cytoskeleton
# 38                         regulation of anatomical structure size
# 39                           regulation of cellular component size
# 40                                   actin filament polymerization
# 41                                 F-actin capping protein complex
# 42                         plasma membrane bounded cell projection
# 43                                          protein polymerization
# 44                                                 cell projection
# 45                                   cellular component biogenesis
# 46                positive regulation of cytoskeleton organization
# 47                                                     Endocytosis
# 48                                                    cytoskeleton
# 49                        actin polymerization or depolymerization
# 50                   positive regulation of organelle organization
# 51                                                 plasma membrane
# 52                               barbed-end actin filament capping
# 53                                                    pseudopodium
# 54                                 actin filament depolymerization
# 55                                             clathrin-coated pit
# 56                                                actin nucleation
# 57                                        protein depolymerization
# 58                                          actin filament capping
# 59          positive regulation of cellular component organization
# 60                                              phagocytic vesicle
# 61                                regulation of biological quality
# 62                                     phagocytic vesicle membrane
# 63                            cellular protein complex disassembly
# 64                                     actin-based cell projection
# 65                                                      filopodium
# 66            positive regulation of actin filament polymerization
# 67                   positive regulation of protein polymerization
# 68                                    response to abiotic stimulus
# 69                          protein-containing complex disassembly
# 70                                  cellular component disassembly
# 71                                               endocytic vesicle
# 72                                          organelle organization
# 73      positive regulation of protein-containing complex assembly
# 74            positive regulation of cellular component biogenesis
# 75        positive regulation of supramolecular fiber organization
# 76          negative regulation of actin filament depolymerization
# 77   negative regulation of protein-containing complex disassembly
# 78                 negative regulation of protein depolymerization
# 79                                      endocytic vesicle membrane
# 80                                      response to osmotic stress
# 81                   regulation of actin filament depolymerization
# 82                          regulation of protein depolymerization
# 83                                                      exocytosis
# 84                         positive regulation of cellular process
# 85            regulation of protein-containing complex disassembly
# 86                                               secretion by cell
# 87                                                       secretion
# 88                       regulation of myosin II filament assembly
# 89                                                export from cell
# 90                                  actin filament bundle assembly
# 91                   regulation of myosin II filament organization
# 92                              actin filament bundle organization
# 93                                              cell trailing edge
# 94                                  non-membrane-bounded organelle
# 95                    intracellular non-membrane-bounded organelle
# 96                                 cellular component organization
# 97                                              response to stress
# 98            negative regulation of actin filament polymerization
# 99                                     myosin II filament assembly
# 100                      positive regulation of biological process
# 101     negative regulation of protein-containing complex assembly
# 102                  negative regulation of protein polymerization
# 103                                       myosin filament assembly
# 104                                                cleavage furrow
# 105                                                        cytosol
# 106                                             cell division site
# 107                       cortical actin cytoskeleton organization
# 108       negative regulation of supramolecular fiber organization
# 109               negative regulation of cytoskeleton organization
# 110                                   cytoplasmic vesicle membrane
# 111                                             cell morphogenesis
# 112                                myosin II filament organization
# 113                                 anchored component of membrane
# 114                                               vesicle membrane
# 115                             cortical cytoskeleton organization
# 116                  negative regulation of organelle organization
# 117                                            sexual reproduction
# 118                                   myosin filament organization
# 119                            multi-organism reproductive process
# 120                                                        vesicle
# 121                                        decreased cell motility
# 122                 positive regulation of protein phosphorylation
# 123                                         multi-organism process
# 124                         positive regulation of phosphorylation
# 125            positive regulation of protein modification process
# 126             positive regulation of phosphate metabolic process
# 127            positive regulation of phosphorus metabolic process
# 128                                           reproductive process
# 129               positive regulation of protein metabolic process
# 130      positive regulation of cellular protein metabolic process
# 131                                                   phagocytosis
# 132         negative regulation of cellular component organization
# 133                                       aberrant cell morphology
# 134                          regulation of protein phosphorylation
# 135                                            cytoplasmic vesicle
# 136                                          intracellular vesicle
# 137                   aggregation involved in sorocarp development
# 138                                  regulation of phosphorylation
# 139                                         response to starvation
# 140                                cellular response to starvation
# 141                         positive regulation of gene expression
# 142                     regulation of protein modification process
# 143                    cellular response to extracellular stimulus
# 144                         cellular response to external stimulus
# 145                           cellular response to nutrient levels
# 146     positive regulation of nitrogen compound metabolic process
# 147              positive regulation of cellular metabolic process
# 148                      regulation of phosphate metabolic process
# 149                     regulation of phosphorus metabolic process
# 150                             anatomical structure morphogenesis
# 151              ATPase-coupled transmembrane transporter activity
# 152                             response to extracellular stimulus
# 153                                    response to nutrient levels
# 154                                         sorocarp morphogenesis
# 155              primary active transmembrane transporter activity
# 156                                             aberrant streaming
# 157                      active transmembrane transporter activity
# 158                                            mitotic cytokinesis
# 159                                                 whole membrane
# 160                                                    cytokinesis
# 161                             cytoskeleton-dependent cytokinesis
# 162                                             chemotaxis to cAMP
# 163                                                   reproduction
# 164                                          abolished aggregation
# 165                                 bounding membrane of organelle
# 166                                  regulation of GTPase activity
# 167         positive regulation of macromolecule metabolic process
# 168               regulation of cellular protein metabolic process
# 169                               anatomical structure development
# 170                                     mitotic cell cycle process
# 171                        regulation of protein metabolic process
# 172                       positive regulation of metabolic process
# 173                                           aberrant cytokinesis
# 174                                          developmental process
# 175                                             mitotic cell cycle
# 176                                             cell cycle process
# 177                                                      wild type
# 178                                                  cell division
# 179                               regulation of hydrolase activity
# 180                                     vesicle-mediated transport
# 181                     non-reproductive fruiting body development
# 182                               socially cooperative development
# 183                                           sorocarp development
# 184                     intraspecies interaction between organisms
# 185                                                     chemotaxis
# 186                                    cellular response to stress
# 187                        negative regulation of cellular process
# 188                                          decreased growth rate
#
#                    Ontology       FDR  N in query  Set size  N in ref.
# 0    GO: molecular_function  1.85e-10          10        63         63
# 1    GO: molecular_function  1.14e-09          11       112        112
# 2    GO: molecular_function  8.22e-09          10       101        101
# 3    GO: molecular_function  2.54e-08          11       158        158
# 4    GO: cellular_component  3.64e-07           9       112        112
# 5    GO: biological_process  1.06e-06           7        58         57
# 6    GO: biological_process  2.33e-06           7        66         65
# 7    GO: biological_process  2.49e-06           7        69         68
# 8    GO: biological_process  2.49e-06           7        69         68
# 9    GO: biological_process  2.91e-06           4         9          9
# 10   GO: biological_process  2.91e-06           4         9          9
# 11   GO: biological_process  2.91e-06           7        75         74
# 12   GO: biological_process  2.91e-06           7        75         74
# 13   GO: cellular_component  2.91e-06          12       340        340
# 14   GO: biological_process  7.75e-06           7        87         86
# 15   GO: biological_process  7.92e-06           8       131        130
# 16   GO: cellular_component  1.57e-05           7        97         97
# 17   GO: biological_process  2.02e-05           8       150        149
# 18   GO: biological_process  2.11e-05           8       152        151
# 19   GO: biological_process  2.15e-05           7       105        104
# 20   GO: cellular_component  3.00e-05           5        38         38
# 21   GO: cellular_component  3.35e-05           6        71         71
# 22   GO: biological_process  4.67e-05           7       120        119
# 23   GO: biological_process  5.29e-05           7       123        122
# 24   GO: cellular_component  7.89e-05           3         7          7
# 25   GO: biological_process  8.48e-05           5        50         49
# 26   GO: biological_process  8.48e-05           7       134        133
# 27   GO: biological_process  9.05e-05           5        51         50
# 28   GO: biological_process  9.93e-05           8       197        196
# 29   GO: biological_process  1.16e-04           8       202        201
# 30   GO: biological_process  1.20e-04           5        56         55
# 31   GO: biological_process  1.20e-04           5        56         55
# 32   GO: biological_process  1.20e-04           5        56         55
# 33   GO: cellular_component  1.20e-04           4        26         26
# 34   GO: biological_process  1.34e-04           3         9          9
# 35   GO: molecular_function  1.48e-04           5        58         58
# 36   GO: biological_process  1.83e-04           7       158        157
# 37   GO: cellular_component  1.91e-04           4        30         30
# 38   GO: biological_process  2.11e-04           5        65         64
# 39   GO: biological_process  2.11e-04           5        65         64
# 40   GO: biological_process  2.11e-04           5        65         64
# 41   GO: cellular_component  2.54e-04           2         2          2
# 42   GO: cellular_component  2.90e-04           5        69         69
# 43   GO: biological_process  3.04e-04           5        71         70
# 44   GO: cellular_component  3.65e-04           5        73         73
# 45   GO: biological_process  3.94e-04           8       254        253
# 46   GO: biological_process  3.94e-04           4        38         38
# 47           KEGG: Pathways  3.94e-04           5        77         75
# 48   GO: cellular_component  4.02e-04           7       185        185
# 49   GO: biological_process  4.26e-04           5        78         77
# 50   GO: biological_process  4.55e-04           4        40         40
# 51   GO: cellular_component  5.43e-04           8       268        268
# 52   GO: biological_process  6.03e-04           2         3          3
# 53   GO: cellular_component  6.29e-04           4        44         44
# 54   GO: biological_process  6.58e-04           3        17         17
# 55   GO: cellular_component  6.58e-04           3        17         17
# 56   GO: biological_process  7.73e-04           3        18         18
# 57   GO: biological_process  8.99e-04           3        19         19
# 58   GO: biological_process  1.08e-03           2         4          4
# 59   GO: biological_process  1.18e-03           4        53         53
# 60   GO: cellular_component  1.65e-03           4        58         58
# 61   GO: biological_process  2.16e-03           6       179        177
# 62   GO: cellular_component  2.16e-03           3        26         26
# 63   GO: biological_process  2.31e-03           3        27         27
# 64   GO: cellular_component  2.31e-03           3        27         27
# 65   GO: cellular_component  2.31e-03           3        27         27
# 66   GO: biological_process  3.08e-03           3        30         30
# 67   GO: biological_process  3.08e-03           3        30         30
# 68   GO: biological_process  3.15e-03           5       126        126
# 69   GO: biological_process  3.21e-03           3        31         31
# 70   GO: biological_process  3.21e-03           3        31         31
# 71   GO: cellular_component  3.21e-03           4        72         72
# 72   GO: biological_process  3.44e-03           8       369        368
# 73   GO: biological_process  3.44e-03           3        32         32
# 74   GO: biological_process  3.66e-03           3        33         33
# 75   GO: biological_process  3.66e-03           3        33         33
# 76   GO: biological_process  3.71e-03           2         8          8
# 77   GO: biological_process  3.71e-03           2         8          8
# 78   GO: biological_process  3.71e-03           2         8          8
# 79   GO: cellular_component  4.14e-03           3        35         35
# 80   GO: biological_process  4.24e-03           4        80         80
# 81   GO: biological_process  4.57e-03           2         9          9
# 82   GO: biological_process  5.63e-03           2        10         10
# 83   GO: biological_process  6.27e-03           3        41         41
# 84   GO: biological_process  6.53e-03           5       155        155
# 85   GO: biological_process  7.91e-03           2        12         12
# 86   GO: biological_process  9.46e-03           3        48         48
# 87   GO: biological_process  9.46e-03           3        48         48
# 88   GO: biological_process  1.03e-02           2        14         14
# 89   GO: biological_process  1.03e-02           3        50         50
# 90   GO: biological_process  1.03e-02           2        14         14
# 91   GO: biological_process  1.12e-02           2        15         15
# 92   GO: biological_process  1.12e-02           2        15         15
# 93   GO: cellular_component  1.12e-02           2        15         15
# 94   GO: cellular_component  1.12e-02           8       458        458
# 95   GO: cellular_component  1.12e-02           8       458        458
# 96   GO: biological_process  1.13e-02           8       462        461
# 97   GO: biological_process  1.13e-02           7       360        358
# 98   GO: biological_process  1.22e-02           2        16         16
# 99   GO: biological_process  1.22e-02           2        16         16
# 100  GO: biological_process  1.22e-02           5       186        186
# 101  GO: biological_process  1.34e-02           2        17         17
# 102  GO: biological_process  1.34e-02           2        17         17
# 103  GO: biological_process  1.48e-02           2        18         18
# 104  GO: cellular_component  1.64e-02           2        19         19
# 105  GO: cellular_component  1.70e-02           5       203        203
# 106  GO: cellular_component  1.75e-02           2        20         20
# 107  GO: biological_process  2.05e-02           2        22         22
# 108  GO: biological_process  2.05e-02           2        22         22
# 109  GO: biological_process  2.05e-02           2        22         22
# 110  GO: cellular_component  2.06e-02           3        69         69
# 111  GO: biological_process  2.16e-02           2        23         23
# 112  GO: biological_process  2.16e-02           2        23         23
# 113  GO: cellular_component  2.16e-02           2        23         23
# 114  GO: cellular_component  2.24e-02           3        72         72
# 115  GO: biological_process  2.29e-02           2        24         24
# 116  GO: biological_process  2.29e-02           2        24         24
# 117  GO: biological_process  2.42e-02           2        25         25
# 118  GO: biological_process  2.42e-02           2        25         25
# 119  GO: biological_process  2.42e-02           2        25         25
# 120  GO: cellular_component  2.43e-02           5       230        229
# 121   Dictybase: Phenotypes  2.45e-02           3        76         76
# 122  GO: biological_process  3.05e-02           2        29         29
# 123  GO: biological_process  3.05e-02           2        29         29
# 124  GO: biological_process  3.24e-02           2        30         30
# 125  GO: biological_process  3.63e-02           2        32         32
# 126  GO: biological_process  3.80e-02           2        33         33
# 127  GO: biological_process  3.80e-02           2        33         33
# 128  GO: biological_process  3.85e-02           2        35         35
# 129  GO: biological_process  4.19e-02           2        37         37
# 130  GO: biological_process  4.19e-02           2        37         37
# 131  GO: biological_process  4.77e-02           3       107        107
# 132  GO: biological_process  4.77e-02           2        40         40
# 133   Dictybase: Phenotypes  4.77e-02           2        42         41
# 134  GO: biological_process  6.28e-02           2        48         48
# 135  GO: cellular_component  6.37e-02           4       211        211
# 136  GO: cellular_component  6.52e-02           4       213        213
# 137  GO: biological_process  6.94e-02           3       129        127
# 138  GO: biological_process  7.14e-02           2        53         53
# 139  GO: biological_process  8.06e-02           3       138        136
# 140  GO: biological_process  8.06e-02           3       138        136
# 141  GO: biological_process  8.14e-02           2        58         58
# 142  GO: biological_process  8.14e-02           2        59         59
# 143  GO: biological_process  8.14e-02           3       140        138
# 144  GO: biological_process  8.14e-02           3       141        139
# 145  GO: biological_process  8.14e-02           3       140        138
# 146  GO: biological_process  8.32e-02           2        60         60
# 147  GO: biological_process  8.78e-02           2        62         62
# 148  GO: biological_process  9.10e-02           2        64         64
# 149  GO: biological_process  9.10e-02           2        64         64
# 150  GO: biological_process  9.26e-02           3       149        149
# 151  GO: molecular_function  9.50e-02           2        66         66
# 152  GO: biological_process  9.50e-02           3       154        152
# 153  GO: biological_process  9.50e-02           3       154        152
# 154  GO: biological_process  9.78e-02           2        68         68
# 155  GO: molecular_function  9.98e-02           2        69         69
# 156   Dictybase: Phenotypes  1.07e-01           2        72         72
# 157  GO: molecular_function  1.10e-01           2        74         74
# 158  GO: biological_process  1.10e-01           2        74         74
# 159  GO: cellular_component  1.10e-01           3       165        164
# 160  GO: biological_process  1.14e-01           2        76         76
# 161  GO: biological_process  1.14e-01           2        76         76
# 162  GO: biological_process  1.15e-01           2        78         77
# 163  GO: biological_process  1.20e-01           2        79         79
# 164   Dictybase: Phenotypes  1.22e-01           2        82         80
# 165  GO: cellular_component  1.39e-01           3       186        185
# 166  GO: biological_process  1.48e-01           2        91         91
# 167  GO: biological_process  1.50e-01           2        92         92
# 168  GO: biological_process  1.51e-01           2        93         93
# 169  GO: biological_process  1.55e-01           5       440        438
# 170  GO: biological_process  1.55e-01           2        95         95
# 171  GO: biological_process  1.56e-01           2        96         96
# 172  GO: biological_process  1.56e-01           2        96         96
# 173   Dictybase: Phenotypes  1.60e-01           2        98         98
# 174  GO: biological_process  1.60e-01           5       449        447
# 175  GO: biological_process  1.63e-01           2       100        100
# 176  GO: biological_process  1.75e-01           2       105        105
# ...
# 67                            organic acid catabolic process
# 68                                         Carbon metabolism
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: cellular_component  1.09e-07           6        11         11
# 1   GO: cellular_component  1.33e-07           6        13         13
# 2   GO: cellular_component  1.33e-07           6        13         13
# 3   GO: biological_process  1.39e-07           5         8          8
# 4   GO: biological_process  1.39e-07           5         8          8
# 5   GO: biological_process  1.39e-07           5         8          8
# 6   GO: biological_process  1.39e-07           5         8          8
# 7   GO: biological_process  1.39e-07           5         8          8
# 8   GO: biological_process  1.39e-07           5         8          8
# 9   GO: biological_process  1.39e-07           5         8          8
# 10  GO: biological_process  1.39e-07           5         8          8
# 11  GO: cellular_component  2.58e-07           4         4          4
# 12   Dictybase: Phenotypes  1.62e-06           5        12         12
# 13  GO: biological_process  5.57e-06           5        15         15
# 14  GO: molecular_function  7.51e-06           5        16         16
# 15  GO: molecular_function  6.46e-05           5        24         24
# 16  GO: biological_process  1.28e-04           7        74         74
# 17  GO: biological_process  1.28e-04           7        74         74
# 18  GO: biological_process  1.33e-04           7        75         75
# 19  GO: biological_process  1.61e-03           2         2          2
# 20  GO: biological_process  1.61e-03           2         2          2
# 21   Dictybase: Phenotypes  1.61e-03           2         2          2
# 22  GO: cellular_component  1.95e-03           8       157        157
# 23  GO: biological_process  3.09e-03          13       440        438
# 24  GO: molecular_function  3.47e-03           5        58         58
# 25  GO: biological_process  3.51e-03          13       449        447
# 26  GO: cellular_component  4.65e-03          11       340        340
# 27  GO: biological_process  6.05e-03           7       145        145
# 28  GO: biological_process  6.05e-03           7       145        145
# 29  GO: biological_process  6.54e-03           7       149        149
# 30  GO: biological_process  6.54e-03           2         4          4
# 31  GO: biological_process  6.54e-03           2         4          4
# 32   Dictybase: Phenotypes  1.05e-02           2         5          5
# 33  GO: biological_process  1.95e-02           3        25         25
# 34  GO: biological_process  2.44e-02           2         8          8
# 35  GO: biological_process  2.44e-02           2         8          8
# 36  GO: biological_process  2.44e-02           2         8          8
# 37  GO: cellular_component  2.44e-02           2         8          8
# 38   Dictybase: Phenotypes  2.44e-02           4        60         59
# 39  GO: molecular_function  4.48e-02           2        11         11
# 40  GO: biological_process  4.48e-02           2        11         11
# 41  GO: biological_process  4.66e-02           4        72         72
# 42  GO: biological_process  5.51e-02           4        76         76
# 43  GO: molecular_function  8.09e-02           2        18         17
# 44  GO: molecular_function  8.09e-02           2        18         17
# 45  GO: cellular_component  1.13e-01           2        23         23
# 46  GO: cellular_component  1.13e-01           2        23         23
# 47  GO: molecular_function  1.19e-01           2        25         25
# 48  GO: molecular_function  1.19e-01           4       112        112
# 49  GO: biological_process  1.19e-01           8       365        363
# 50  GO: biological_process  1.19e-01           3        64         64
# 51  GO: biological_process  1.19e-01           8       365        363
# 52  GO: biological_process  1.19e-01           8       365        363
# 53  GO: biological_process  1.19e-01           8       365        363
# 54          KEGG: Pathways  1.19e-01           2        28         25
# 55          KEGG: Pathways  1.46e-01           2        30         30
# 56  GO: biological_process  1.50e-01           3        75         74
# 57          KEGG: Pathways  1.52e-01           2        31         31
# 58  GO: biological_process  1.54e-01           4       132        131
# 59  GO: biological_process  1.71e-01           5       202        201
# 60          KEGG: Pathways  1.80e-01           2        37         37
# 61  GO: biological_process  1.87e-01           2        38         38
# 62          KEGG: Pathways  1.88e-01           6       289        281
# 63  GO: biological_process  1.99e-01           2        41         41
# 64  GO: molecular_function  2.18e-01           4       158        158
# 65  GO: biological_process  2.44e-01           8       462        461
# 66  GO: biological_process  2.44e-01           2        49         49
# 67  GO: biological_process  2.44e-01           2        49         49
# 68          KEGG: Pathways  2.44e-01           3       104        102
# *** Cluster C15 (O)
# ***  C15 selected: 31 with EID: 31
# Ratio of genes annotated with a gene set in reference 0.33 and query 0.29
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 0 out of 9 query genes used for enrichment calculation.
# None
# *** Cluster C16 (P)
# ***  C16 selected: 72 with EID: 72
# Ratio of genes annotated with a gene set in reference 0.33 and query 0.25
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 14 out of 18 query genes used for enrichment calculation.
#                                        Gene set                Ontology  \
# 0                             cellulose binding  GO: molecular_function
# 1                          extracellular region  GO: cellular_component
# 2                        polysaccharide binding  GO: molecular_function
# 3                          carbohydrate binding  GO: molecular_function
# 4                anchored component of membrane  GO: cellular_component
# 5                                     wild type   Dictybase: Phenotypes
# 6  culmination involved in sorocarp development  GO: biological_process
#
#         FDR  N in query  Set size  N in ref.
# 0  2.93e-09           6        16         16
# 1  1.13e-08          10       157        157
# 2  1.61e-08           6        24         24
# 3  3.33e-06           6        58         58
# 4  5.91e-02           2        23         23
# 5  1.18e-01           5       341        338
# 6  1.23e-01           3       132        131
# *** Cluster C17 (Q)
# ***  C17 selected: 57 with EID: 56
# Ratio of genes annotated with a gene set in reference 0.33 and query 0.23
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 12 out of 13 query genes used for enrichment calculation.
#                                                           Gene set  \
# 0                                              biological adhesion
# 1                                                    cell adhesion
# 2                                    sequence-specific DNA binding
# 3                                             carbohydrate binding
# 4                                        decreased spore viability
# 5                                           sorocarp morphogenesis
# 6                           regulation of RNA biosynthetic process
# 7                              regulation of RNA metabolic process
# 8                      regulation of cellular biosynthetic process
# 9                               anatomical structure morphogenesis
# 10                                                   transcription
# 11                regulation of macromolecule biosynthetic process
# 12                            nucleic acid-templated transcription
# 13                                     regulation of transcription
# 14       regulation of cellular macromolecule biosynthetic process
# 15                                        RNA biosynthetic process
# 16                              regulation of biosynthetic process
# 17  regulation of nucleobase-containing compound metabolic process
# 18              regulation of nucleic acid-templated transcription
# 19                                                       wild type
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: biological_process  5.82e-03           4        84         83
# 1   GO: biological_process  5.82e-03           4        84         83
# 2   GO: molecular_function  1.34e-01           2        49         49
# 3   GO: molecular_function  1.44e-01           2        58         58
# 4    Dictybase: Phenotypes  1.44e-01           2        60         59
# 5   GO: biological_process  1.51e-01           2        68         68
# 6   GO: biological_process  2.32e-01           2       138        138
# 7   GO: biological_process  2.32e-01           2       140        140
# 8   GO: biological_process  2.32e-01           2       170        170
# 9   GO: biological_process  2.32e-01           2       149        149
# 10  GO: biological_process  2.32e-01           2       167        167
# 11  GO: biological_process  2.32e-01           2       163        163
# 12  GO: biological_process  2.32e-01           2       174        174
# 13  GO: biological_process  2.32e-01           2       131        131
# 14  GO: biological_process  2.32e-01           2       156        156
# 15  GO: biological_process  2.32e-01           2       177        177
# 16  GO: biological_process  2.32e-01           2       170        170
# 17  GO: biological_process  2.32e-01           2       148        148
# 18  GO: biological_process  2.32e-01           2       138        138
# 19   Dictybase: Phenotypes  2.32e-01           3       341        338
# *** Cluster C18 (R)
# ***  C18 selected: 65 with EID: 63
# Ratio of genes annotated with a gene set in reference 0.33 and query 0.14
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 8 out of 9 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0   anatomical structure formation involved in morphogenesis
# 1                                                sporulation
# 2     sporulation resulting in formation of a cellular spore
# 3                           external encapsulating structure
# 4                                                 spore wall
# 5                                                  cell wall
# 6                                     polysaccharide binding
# 7                                         hydrolase activity
# 8                                         hydrolase activity
# 9                         anatomical structure morphogenesis
# 10                                      cell differentiation
# 11                            cellular developmental process
# 12                                      extracellular region
# 13                                             lipid binding
# 14                                      carbohydrate binding
# 15                               organic substance transport
# 16                          anatomical structure development
# 17                                     developmental process
# 18                                macromolecule localization
# 19                                         protein transport
# 20                                         peptide transport
# 21                                           amide transport
# 22                     establishment of protein localization
# 23                               nitrogen compound transport
# 24                                      protein localization
# 25                                            cell periphery
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: biological_process  6.11e-03           3        74         74
# 1   GO: biological_process  6.11e-03           3        75         75
# 2   GO: biological_process  6.11e-03           3        74         74
# 3   GO: cellular_component  6.11e-03           2        13         13
# 4   GO: cellular_component  6.11e-03           2        11         11
# 5   GO: cellular_component  6.11e-03           2        13         13
# 6   GO: molecular_function  1.33e-02           2        24         24
# 7   GO: molecular_function  1.82e-02           2        31         30
# 8   GO: molecular_function  2.36e-02           2        46         45
# 9   GO: biological_process  2.36e-02           3       149        149
# 10  GO: biological_process  2.36e-02           3       145        145
# 11  GO: biological_process  2.36e-02           3       145        145
# 12  GO: cellular_component  2.36e-02           3       157        157
# 13  GO: molecular_function  3.26e-02           2        59         59
# 14  GO: molecular_function  3.26e-02           2        58         58
# 15  GO: biological_process  4.03e-02           3       265        265
# 16  GO: biological_process  4.03e-02           4       440        438
# 17  GO: biological_process  4.03e-02           4       449        447
# 18  GO: biological_process  4.14e-02           3       275        275
# 19  GO: biological_process  1.16e-01           2       197        197
# 20  GO: biological_process  1.16e-01           2       197        197
# 21  GO: biological_process  1.17e-01           2       200        200
# 22  GO: biological_process  1.17e-01           2       206        206
# 23  GO: biological_process  1.32e-01           2       232        232
# 24  GO: biological_process  1.38e-01           2       241        241
# 25  GO: cellular_component  2.18e-01           2       340        340
# *** Cluster C19 (S)
# ***  C19 selected: 89 with EID: 88
# Ratio of genes annotated with a gene set in reference 0.33 and query 0.2
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 10 out of 18 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0                                      extracellular region
# 1                                         spore germination
# 2  anatomical structure formation involved in morphogenesis
# 3                                               sporulation
# 4    sporulation resulting in formation of a cellular spore
# 5                        anatomical structure morphogenesis
# 6                                      cell differentiation
# 7                            cellular developmental process
# 8                             Starch and sucrose metabolism
# 9                          anatomical structure development
#
#                  Ontology       FDR  N in query  Set size  N in ref.
# 0  GO: cellular_component  1.99e-04           7       157        157
# 1  GO: biological_process  6.51e-04           3        12         12
# 2  GO: biological_process  4.43e-03           4        74         74
# 3  GO: biological_process  4.43e-03           4        75         75
# 4  GO: biological_process  4.43e-03           4        74         74
# 5  GO: biological_process  2.51e-02           4       149        149
# 6  GO: biological_process  2.51e-02           4       145        145
# 7  GO: biological_process  2.51e-02           4       145        145
# 8          KEGG: Pathways  4.20e-02           2        31         31
# 9  GO: biological_process  2.45e-01           4       440        438
# *** Cluster C20 (T)
# ***  C20 selected: 1 with EID: 1
# Ratio of genes annotated with a gene set in reference 0.33 and query 0.0
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 0 out of 0 query genes used for enrichment calculation.
# None
