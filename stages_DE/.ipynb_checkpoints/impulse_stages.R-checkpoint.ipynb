# %%
library("ImpulseDE2")
library('dplyr')
library(ggplot2)

# %%
pathSave='/home/khrovatin/timeTrajectoriesNet/data/stages/DE_across_stages/'

# %%
genes<-read.table('/home/khrovatin/timeTrajectoriesNet/data/counts/mergedGenes_counts.tsv', header=TRUE,row.names=1, sep="\t")
conditions<-read.table('/home/khrovatin/timeTrajectoriesNet/data/RPKUM/conditions_mergedGenes.tsv', header=TRUE,row.names='Measurment', sep="\t")
#R imported colnames of genes with changes but gene IDs remained ok
rownames(conditions)<-make.names(rownames(conditions))

# %%
PHENOTYPES_ORDERED=c('no_agg','disappear', 'stream', 'lag', 'tag', 'tip', 'slug', 'mhat', 'cul', 'tag_spore', 'FB')
PHENOTYPES_X=data.frame(Phenotype=PHENOTYPES_ORDERED,X=c(1:length(PHENOTYPES_ORDERED)))

# %%
conditions_annotated=conditions[rowSums(conditions[, PHENOTYPES_ORDERED])>0, ]
X=data.frame(row.names=rownames(genes))
Y=data.frame()
for (row_idx in 1:dim(conditions_annotated)[1]){
  y=conditions_annotated[row_idx,]
  x=genes[,rownames(y)]
  repeated_sample=0
  for (phenotype in PHENOTYPES_ORDERED){
    if (y[phenotype]==1){
      sample_name=paste(rownames(y),repeated_sample,sep='_')
      X[,sample_name]=x
      Y[sample_name,c('Sample','Condition','Batch','Time')]=c(sample_name,'case',y['Replicate'],PHENOTYPES_X[PHENOTYPES_X['Phenotype']==phenotype,'X'])
      repeated_sample=repeated_sample+1
    }
  }
}
Y<-Y[order(Y$Time),]

# %%
objectImpulseDE2 <- runImpulseDE2(matCountData = as.matrix(X), dfAnnotation = Y,boolCaseCtrl = FALSE,vecConfounders = c("Batch"),scaNProc = 20)
# Out:
# ImpulseDE2 for count data, v1.10.0
#
# # Process input
# Processing Details:
# ImpulseDE2 runs in case-only mode.
# Found time points: 1,4,5,6,7,8,9,11,3,2,10
# Case: Found the samples at time point 1: FDpool01_TCGCAGG_Hr00_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_TCGCAGG_Hr00_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_00h_9_S86_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_04h_10_S87_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_00h_9_S58_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_04h_10_S59_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr00_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr06_7_CTCGATG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr00_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr06_7_CTCGATG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_AX4_bio2_hr00_1_13_ACTATCA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_MybBGFP_bio1_hr00_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_MybBGFP_bio1_hr06_1_TCGCAGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr00_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_ecmARm_bio1_00h_1_TCGCAGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_ecmARm_bio1_08h_8_GCTCGAA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_ecmARm_bio1_12h_Inv_9_ACCAACT_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_ecmARm_bio1_16h_10_CCGGTAC_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,ecmARm_bio2_00h_1_S136_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,ecmARm_bio2_08h_8_S143_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,ecmARm_bio2_12h_9_S144_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,ecmARm_bio2_16h_10_S145_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaI_bio3_hr00_01_S51_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaI_bio4_hr00_02_S52_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_0h_7_S173_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_4h_8_S174_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_0h_16_S182_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_4h_17_S183_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_0h_r1_1_S52_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_4h_r1_2_S53_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_8h_r1_3_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_0h_r2_10_S61_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_4h_r2_11_S62_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_00hr_1_S79_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_04hr_2_S80_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_00h_8_S57_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_04h_24_S72_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_00h_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_00h_14_S149_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_00h_38_S111_L001_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_02h_39_S112_L001_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_04h_40_S113_L001_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_06h_41_S114_L001_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_00h_33_S153_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_02h_34_S154_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_04h_35_S155_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_06h_36_S156_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_0h_r1_28_S79_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_4h_r1_29_S80_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_6h_r1_30_S81_L0 ...
# Case: Found the samples at time point 4: FDpool01_TTGAAGT_Hr10_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_GATCTCG_Hr11_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_ACCAACT_Hr08_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool02_CCGGTAC_Hr09_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool02_AACTCCG_Hr10_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_TTGAAGT_Hr11_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_08h_11_S88_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,Ax4_r2_08h_11_S60_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool26_AX4_bio2_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_1,pool27_AX4_bio1_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool29_AX4_bio2_hr08_2_CTCTGCA_mappedGene_expressions_All_milestone_mRNA_gff_1,pool35_MybBGFP_bio1_hr08_2_CTCTGCA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_1,pool38_ecmARm_bio1_12h_Inv_9_ACCAACT_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1,pool38_ecmARm_bio1_16h_10_CCGGTAC_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1,pool38_ecmARm_bio1_28h_13_ACTATCA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,ecmARm_bio2_12h_9_S144_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,ecmARm_bio2_16h_10_S145_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,ecmARm_bio2_20h_11_S146_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,ecmARm_bio2_28h_13_S148_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_8h_9_S175_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_12h_10_S176_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_8h_18_S184_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_12h_19_S185_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_8h_r2_12_S63_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r1_08hr_8_S85_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r1_12hr_4_S81_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_08h_25_S73_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_tagB__bio1_08h_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_tagB__bio1_12h_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_tagB__bio1_16h_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_08h_21_S156_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tagB_bio2_12h_22_S157_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r1_08h_42_S115_L001_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r1_12h_28_S148_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_08h_37_S157_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r2_12h_38_S158_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r2_16h_39_S159_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r2_20h_40_S160_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_10h_r1_32_S83_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gbfA_12h_r1_33_S84_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_14h_r1_34_S85_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gbfA_r3_12h_6_S131_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,gbfA_r3_14h_10_S135_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r1_12h_26_S42_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrC1_r1_20h_29_S45_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r1_24h_30_S46_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r2_10h_15_S31_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r2_12h_16_S32_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_20h_19_S35_L002_R1_001_mappedGene_expr ...
# Case: Found the samples at time point 5: FDpool01_CAATATG_Hr12_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_TTGGATC_Hr14_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_TTGAAGT_Hr11_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool02_ACTATCA_Hr12_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_12h_12_S89_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_12h_12_S61_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_MybBGFP_bio1_hr08_2_CTCTGCA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1,pool30_MybBGFP_bio1_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_ecmARm_bio1_16h_10_CCGGTAC_mate1_mappedGene_expressions_All_milestone_mRNA_gff_2,ecmARm_bio2_16h_10_S145_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,cudA2_6_r2_12h_10_S176_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,cudA2_6_r3_12h_19_S185_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,dgcA_12h_r1_4_S55_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_14h_r1_5_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_12h_r2_13_S64_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_12hr_4_S81_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r2_12h_4_S53_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_16h_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_tagB__bio1_20h_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_24h_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_28h_13_ACTATCA_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_12h_22_S157_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tagB_bio2_16h_23_S158_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tagB_bio2_24h_25_S160_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_12h_28_S148_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r1_16h_29_S149_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_20h_30_S150_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_24h_31_S151_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_28h_32_S152_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_12h_38_S158_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,t345_r2_16h_39_S159_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,t345_r2_20h_40_S160_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r2_24h_41_S161_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_28h_42_S162_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_14h_17_S33_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r2_16h_18_S34_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_20h_19_S35_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1_r1_24h_20_S36_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1_r2_16h_28_S44_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1_r2_20h_29_S45_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1C1_r1_12h_6_S22_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1C1_r1_16h_8_S24_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1C1_r1_20h_9_S25_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1C1_r2_16h_8_S24_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1C1_r2_20h_9_S25_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,pool36_acaAKO_pkaC3_bio1_12h_22_GCATTGG_mappedGene_expressions_All_milestone_mRNA_gff_2,pool36_acaAKO_pkaC3_bio1_16h_23_GATCTCG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_acaAKO_pkaC3_bio1_20h_24_ ...
# Case: Found the samples at time point 6: FDpool01_TTGGATC_Hr14_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool01_CGACCTG_Hr16_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_TTGGATC_Hr14_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_14h_11_S177_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_14h_20_S186_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_14h_r1_5_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,dgcA_14h_r2_14_S65_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_28h_13_ACTATCA_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r1_24h_31_S151_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r1_28h_32_S152_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r2_24h_41_S161_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r2_28h_42_S162_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1C1_r1_24h_10_S26_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1C1_r2_24h_10_S26_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_acaAKO_pkaC3_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_3,pool36_acaAKO_pkaC3_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_2,pool36_acaAKO_pkaC3_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_1,pool37_acaA_pkaC1_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool37_acaA_pkaC1_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaCoe25_r2_12h_24_S100_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_12h_34_S50_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaC25_r3_14h_35_S51_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 7: FDpool01_TAATGCG_Hr18_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_CGACCTG_Hr16_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_16h_13_S90_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_16h_13_S62_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr16_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr16_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr12_3_CCTAGGT_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr16_4_GGATCAA_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr20_5_GCAAGAT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_MybBGFP_bio1_hr16_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_MybBGFP_bio1_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool28_MybBGFP_bio2_hr16_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_ecmARm_bio1_20h_11_AACTCCG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_ecmARm_bio1_24h_12_TTGAAGT_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_ecmARm_bio1_28h_13_ACTATCA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1,ecmARm_bio2_20h_11_S146_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,ecmARm_bio2_24h_12_S147_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,ecmARm_bio2_28h_13_S148_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,cudA2_6_r2_16h_12_S178_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_18h_13_S179_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_20h_14_S180_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_24h_15_S181_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_16h_22_S187_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_18h_23_S188_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_20h_24_S189_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_24h_25_S190_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_16h_r1_6_S57_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_18h_r1_7_S58_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_20h_r1_8_S59_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_24h_r1_9_S60_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_16h_r2_15_S66_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_18h_r2_16_S67_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_20h_r2_17_S68_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_24h_r2_18_S69_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_16hr_5_S82_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_20hr_6_S83_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_24hr_7_S84_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_16h_5_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_20h_6_S55_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_24h_7_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_24h_20_S36_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_3,tgrB1_r2_24h_30_S46_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1C1_r1_24h_10_S26_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1C1_r2_24h_10_S26_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,pool36_acaAKO_pkaC3_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_4,pool36_acaAKO_pkaC3_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone ...
# Case: Found the samples at time point 8: FDpool01_TAATGCG_Hr18_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool01_AGGTACC_Hr20_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_GAATCTC_Hr22_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_TAATGCG_Hr18_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_20h_14_S91_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_20h_14_S63_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool27_AX4_bio1_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr20_5_GCAAGAT_mappedGene_expressions_All_milestone_mRNA_gff_1,cudA2_6_r2_20h_14_S180_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,cudA2_6_r2_24h_15_S181_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,cudA2_6_r3_20h_24_S189_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,cudA2_6_r3_24h_25_S190_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Case: Found the samples at time point 9: FDpool01_GAATCTC_Hr22_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool01_CATGCTC_Hr24_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_GAATCTC_Hr20_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_CATGCTC_Hr22_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_ACGCAAC_Hr24_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_20h_14_S91_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,Ax4_r2_20h_14_S63_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool26_AX4_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_2,Pool26_AX4_bio2_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool27_AX4_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr20_5_GCAAGAT_mappedGene_expressions_All_milestone_mRNA_gff_2,Pool29_AX4_bio2_hr24_6_ATGGAGA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_MybBGFP_bio1_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool30_MybBGFP_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool28_MybBGFP_bio2_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_24hr_7_S84_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r2_24h_7_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_acaAKO_pkaC3_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_4,pool36_acaAKO_pkaC3_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_3,pool37_acaA_pkaC1_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_3,pool37_acaA_pkaC1_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_3,pool37_acaA_pkaC1_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaCoe25_r2_16h_26_S102_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_20h_28_S104_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_24h_29_S105_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_16h_36_S52_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaC25_r3_18h_37_S53_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_20h_38_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_24h_39_S55_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 11: FDpool01_CATGCTC_Hr24_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool02_ACGCAAC_Hr24_mappedGene_expressions_All_milestone_mRNA_gff_1,Ax4_r1_24h_15_S92_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_24h_15_S64_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_1,pool27_AX4_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool29_AX4_bio2_hr24_6_ATGGAGA_mappedGene_expressions_All_milestone_mRNA_gff_1,pool30_MybBGFP_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool28_MybBGFP_bio2_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r1_24hr_7_S84_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,gtaG_r2_24h_7_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1_r2_24h_30_S46_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,pool36_acaAKO_pkaC3_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_5,pool36_acaAKO_pkaC3_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_4,pool37_acaA_pkaC1_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_4,pool37_acaA_pkaC1_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_4,pool37_acaA_pkaC1_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_2,PkaCoe25_r2_16h_26_S102_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaCoe25_r2_20h_28_S104_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaCoe25_r2_24h_29_S105_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaC25_r3_20h_38_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaC25_r3_24h_39_S55_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Case: Found the samples at time point 3: FDpool02_ACCAACT_Hr08_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_CCGGTAC_Hr09_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_08h_11_S88_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_08h_11_S60_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr08_2_CTCTGCA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_MybBGFP_bio1_hr06_1_TCGCAGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool28_MybBGFP_bio2_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_8h_r1_3_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,dgcA_8h_r2_12_S63_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_08hr_8_S85_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_04h_24_S72_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r2_08h_25_S73_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_08h_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_12h_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_06h_20_S155_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_08h_21_S156_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_12h_22_S157_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_16h_23_S158_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_08h_42_S115_L001_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_08h_37_S157_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_12h_38_S158_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_16h_39_S159_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_10h_r1_32_S83_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_24h_r1_37_S88_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gbfA_r3_10h_5_S130_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gbfA_r3_12h_6_S131_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gbfA_r3_24h_13_S138_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r1_08h_24_S40_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_12h_26_S42_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r1_16h_28_S44_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r2_08h_14_S30_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_10h_15_S31_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_10h_15_S31_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_08h_24_S40_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_10h_25_S41_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_12h_26_S42_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_16h_28_S44_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r1_06h_3_S19_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r1_08h_4_S20_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r1_10h_5_S21_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r1_12h_6_S22_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1C1_r2_08h_4_S20_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_10h_5_S21_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_acaAKO_pkaC3_bio1_06h_20_CATGCTC_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_acaAKO_pkaC3_bio1_08h_21_ACGCAAC_mappedGene_expressions_All_milestone_mRNA_gff_1,pool37_acaA_pkaC1_bio1_06h_20_CATGCTC_mappedGene_expressions_All_milestone_mRNA_gff_1,pool37_acaA_pkaC1_bio1_08h_21_ACGCAAC_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaCoe25_r2_04h_22_S98_L ...
# Case: Found the samples at time point 2: gbfA_14h_r1_34_S85_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_16h_r1_35_S86_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_20h_r1_36_S87_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_16h_11_S136_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_20h_12_S137_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_10h_25_S41_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_14h_27_S43_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_16h_28_S44_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_14h_17_S33_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_20h_19_S35_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_24h_20_S36_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1_r1_16h_18_S34_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_20h_19_S35_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_14h_27_S43_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_20h_29_S45_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r1_12h_6_S22_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_14h_7_S23_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_16h_8_S24_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_20h_9_S25_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 10: pool35_pkaR_24h_bio1_7_CTCGATG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_pkaR_28h_bio1_8_GCTCGAA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_pkaR__24h_bio2_33_CATCCGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch AX4_FD_r1: FDpool01_TCGCAGG_Hr00_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_TTGAAGT_Hr10_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_GATCTCG_Hr11_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_CAATATG_Hr12_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_TTGGATC_Hr14_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_TTGGATC_Hr14_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool01_CGACCTG_Hr16_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_TAATGCG_Hr18_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_TAATGCG_Hr18_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool01_AGGTACC_Hr20_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_GAATCTC_Hr22_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_GAATCTC_Hr22_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool01_CATGCTC_Hr24_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_CATGCTC_Hr24_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch AX4_FD_r2: FDpool02_TCGCAGG_Hr00_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_ACCAACT_Hr08_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_ACCAACT_Hr08_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool02_CCGGTAC_Hr09_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_CCGGTAC_Hr09_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool02_AACTCCG_Hr10_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_TTGAAGT_Hr11_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_TTGAAGT_Hr11_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool02_ACTATCA_Hr12_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_TTGGATC_Hr14_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_CGACCTG_Hr16_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_TAATGCG_Hr18_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_GAATCTC_Hr20_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_CATGCTC_Hr22_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_ACGCAAC_Hr24_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_ACGCAAC_Hr24_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch AX4_PE_r3: Ax4_r1_00h_9_S86_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_04h_10_S87_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_08h_11_S88_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_08h_11_S88_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,Ax4_r1_12h_12_S89_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_16h_13_S90_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_20h_14_S91_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_20h_14_S91_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,Ax4_r1_24h_15_S92_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch AX4_PE_r4: Ax4_r2_00h_9_S58_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_04h_10_S59_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_08h_11_S60_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_08h_11_S60_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,Ax4_r2_12h_12_S61_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_16h_13_S62_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_20h_14_S63_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_20h_14_S63_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,Ax4_r2_24h_15_S64_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch AX4_SE_r5: Pool26_AX4_bio2_hr00_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr06_7_CTCGATG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool26_AX4_bio2_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr16_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool26_AX4_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_2,Pool26_AX4_bio2_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch AX4_SE_r6: pool27_AX4_bio1_hr00_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr06_7_CTCGATG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_1,pool27_AX4_bio1_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr16_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool27_AX4_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch AX4_SE_r7: Pool28_AX4_bio2_hr00_1_13_ACTATCA_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr08_2_CTCTGCA_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr08_2_CTCTGCA_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool29_AX4_bio2_hr12_3_CCTAGGT_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr16_4_GGATCAA_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr20_5_GCAAGAT_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr20_5_GCAAGAT_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool29_AX4_bio2_hr20_5_GCAAGAT_mappedGene_expressions_All_milestone_mRNA_gff_2,Pool29_AX4_bio2_hr24_6_ATGGAGA_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr24_6_ATGGAGA_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch MybBGFP_r1: pool30_MybBGFP_bio1_hr00_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_MybBGFP_bio1_hr06_1_TCGCAGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_MybBGFP_bio1_hr06_1_TCGCAGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1,pool35_MybBGFP_bio1_hr08_2_CTCTGCA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_MybBGFP_bio1_hr08_2_CTCTGCA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1,pool30_MybBGFP_bio1_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_MybBGFP_bio1_hr16_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_MybBGFP_bio1_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_MybBGFP_bio1_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool30_MybBGFP_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_MybBGFP_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch MybBGFP_r2: Pool28_MybBGFP_bio2_hr00_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool28_MybBGFP_bio2_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool28_MybBGFP_bio2_hr16_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool28_MybBGFP_bio2_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch ecmARm_r1: pool38_ecmARm_bio1_00h_1_TCGCAGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_ecmARm_bio1_08h_8_GCTCGAA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_ecmARm_bio1_12h_Inv_9_ACCAACT_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_ecmARm_bio1_12h_Inv_9_ACCAACT_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1,pool38_ecmARm_bio1_16h_10_CCGGTAC_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_ecmARm_bio1_16h_10_CCGGTAC_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1,pool38_ecmARm_bio1_16h_10_CCGGTAC_mate1_mappedGene_expressions_All_milestone_mRNA_gff_2,pool38_ecmARm_bio1_20h_11_AACTCCG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_ecmARm_bio1_24h_12_TTGAAGT_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_ecmARm_bio1_28h_13_ACTATCA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_ecmARm_bio1_28h_13_ACTATCA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch ecmARm_r2: ecmARm_bio2_00h_1_S136_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,ecmARm_bio2_08h_8_S143_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,ecmARm_bio2_12h_9_S144_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,ecmARm_bio2_12h_9_S144_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,ecmARm_bio2_16h_10_S145_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,ecmARm_bio2_16h_10_S145_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,ecmARm_bio2_16h_10_S145_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,ecmARm_bio2_20h_11_S146_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,ecmARm_bio2_20h_11_S146_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,ecmARm_bio2_24h_12_S147_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,ecmARm_bio2_28h_13_S148_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,ecmARm_bio2_28h_13_S148_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch gtaI_r1: gtaI_bio3_hr00_01_S51_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch gtaI_r2: gtaI_bio4_hr00_02_S52_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch cudA_r1: cudA2_6_r2_0h_7_S173_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_4h_8_S174_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_8h_9_S175_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_12h_10_S176_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_12h_10_S176_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,cudA2_6_r2_14h_11_S177_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_16h_12_S178_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_18h_13_S179_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_20h_14_S180_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_20h_14_S180_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,cudA2_6_r2_24h_15_S181_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_24h_15_S181_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch cudA_r2: cudA2_6_r3_0h_16_S182_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_4h_17_S183_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_8h_18_S184_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_12h_19_S185_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_12h_19_S185_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,cudA2_6_r3_14h_20_S186_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_16h_22_S187_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_18h_23_S188_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_20h_24_S189_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_20h_24_S189_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,cudA2_6_r3_24h_25_S190_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_24h_25_S190_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch dgcA_r1: dgcA_0h_r1_1_S52_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_4h_r1_2_S53_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_8h_r1_3_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_8h_r1_3_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,dgcA_12h_r1_4_S55_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_14h_r1_5_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_14h_r1_5_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,dgcA_16h_r1_6_S57_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_18h_r1_7_S58_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_20h_r1_8_S59_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_24h_r1_9_S60_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch dgcA_r2: dgcA_0h_r2_10_S61_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_4h_r2_11_S62_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_8h_r2_12_S63_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_8h_r2_12_S63_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,dgcA_12h_r2_13_S64_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_14h_r2_14_S65_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_16h_r2_15_S66_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_18h_r2_16_S67_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_20h_r2_17_S68_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_24h_r2_18_S69_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch gtaG_r1: gtaG_r1_00hr_1_S79_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_04hr_2_S80_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_08hr_8_S85_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_08hr_8_S85_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r1_12hr_4_S81_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_12hr_4_S81_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r1_16hr_5_S82_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_20hr_6_S83_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_24hr_7_S84_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_24hr_7_S84_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r1_24hr_7_S84_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2
# Found the following samples for confounder Batch and batch gtaG_r2: gtaG_r2_00h_8_S57_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_04h_24_S72_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_04h_24_S72_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r2_08h_25_S73_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_08h_25_S73_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r2_12h_4_S53_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_16h_5_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_20h_6_S55_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_24h_7_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_24h_7_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r2_24h_7_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2
# Found the following samples for confounder Batch and batch tagB_r1: pool36_tagB__bio1_00h_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_08h_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_08h_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_tagB__bio1_12h_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_12h_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_tagB__bio1_16h_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_16h_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_tagB__bio1_20h_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_24h_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_28h_13_ACTATCA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_28h_13_ACTATCA_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch tagB_r2: tagB_bio2_00h_14_S149_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_06h_20_S155_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_08h_21_S156_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_08h_21_S156_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tagB_bio2_12h_22_S157_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_12h_22_S157_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tagB_bio2_12h_22_S157_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tagB_bio2_16h_23_S158_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_16h_23_S158_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tagB_bio2_24h_25_S160_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# ...
# Found the following samples for confounder Batch and batch tgrB1C1_r2: tgrB1C1_r2_00h_1_S17_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_04h_2_S18_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_06h_3_S19_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_08h_4_S20_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_10h_5_S21_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_10h_5_S21_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1C1_r2_12h_6_S22_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_14h_7_S23_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_14h_7_S23_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1C1_r2_16h_8_S24_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_16h_8_S24_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1C1_r2_16h_8_S24_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1C1_r2_20h_9_S25_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_20h_9_S25_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1C1_r2_20h_9_S25_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1C1_r2_24h_10_S26_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_24h_10_S26_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1C1_r2_24h_10_S26_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2
# Found the following samples for confounder Batch and batch gtaC_r1: pool_19_ATGGAGA_06_gtaC__1A_0h_2_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch gtaC_r2: pool_21_TCGCAGG_01_gtaC__1A_0h_4_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch gtaC_r3: pool_19_TCGCAGG_01_gtaC__7B_0h_2_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch gtaC_r4: pool_21_ATGGAGA_06_gtaC__7B_0h_4_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch mybB_r1: pool27_mybB__bio1_hr00_13_ACTATCA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_mybB__bio1_hr06_19_GAATCTC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_mybB__bio1_hr08_20_CATGCTC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_mybB__bio1_hr12_21_ACGCAAC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_mybB__bio1_hr16_22_GCATTGG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_mybB__bio1_hr20_23_GATCTCG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_mybB__bio1_hr24_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch mybB_r2: Pool26_mybB__bio2_hr00_13_ACTATCA_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_mybB__bio2_hr06_19_GAATCTC_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_mybB__bio2_hr08_20_CATGCTC_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_mybB__bio2_hr12_21_ACGCAAC_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_mybB__bio2_hr16_22_GCATTGG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_mybB__bio2_hr20_23_GATCTCG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_mybB__bio2_hr24_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch amiB_r1: amiB_0h_r1_19_S70_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,amiB_2h_r1_20_S71_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,amiB_4h_r1_21_S72_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,amiB_6h_r1_22_S73_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,amiB_8h_r1_23_S74_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,amiB_12h_r1_24_S75_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,amiB_16h_r1_25_S76_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,amiB_20h_r1_26_S77_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,amiB_24h_r1_27_S78_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch amiB_r2: amiB_r2_00h_30_S106_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,amiB_r2_02h_31_S107_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,amiB_r2_04h_32_S108_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,amiB_r2_06h_34_S109_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,amiB_r2_08h_47_S122_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,amiB_r2_12h_35_S110_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,amiB_r2_16h_36_S111_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,amiB_r2_20h_37_S112_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,amiB_r2_24h_38_S113_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch acaA_r1: pool30_acaA__bio1_hr00_13_ACTATCA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_acaA__bio1_hr06_19_GAATCTC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_acaA__bio1_hr08_20_CATGCTC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_acaA__bio1_hr12_21_ACGCAAC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_acaA__bio1_hr16_22_GCATTGG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_acaA__bio1_hr20_23_GATCTCG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_acaA__bio1_hr24_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch acaA_r2: Pool29_acaA__bio2_hr00_7_CTCGATG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_acaA__bio2_hr08_14_TTGGATC_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_acaA__bio2_hr16_16_TAATGCG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_acaA__bio2_hr20_17_AGGTACC_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_acaA__bio2_hr24_18_TGCGTCC_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch acaAPkaCoe_r1: pool36_acaAKO_pkaC3_bio1_00h_14_TTGGATC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_acaAKO_pkaC3_bio1_06h_20_CATGCTC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_acaAKO_pkaC3_bio1_06h_20_CATGCTC_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_acaAKO_pkaC3_bio1_08h_21_ACGCAAC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_acaAKO_pkaC3_bio1_08h_21_ACGCAAC_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_acaAKO_pkaC3_bio1_12h_22_GCATTGG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_acaAKO_pkaC3_bio1_12h_22_GCATTGG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_acaAKO_pkaC3_bio1_12h_22_GCATTGG_mappedGene_expressions_All_milestone_mRNA_gff_2,pool36_acaAKO_pkaC3_bio1_16h_23_GATCTCG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_acaAKO_pkaC3_bio1_16h_23_GATCTCG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_acaAKO_pkaC3_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_acaAKO_pkaC3_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_acaAKO_pkaC3_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_2,pool36_acaAKO_pkaC3_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_3,pool36_acaAKO_pkaC3_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_4,pool36_acaAKO_pkaC3_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_acaAKO_pkaC3_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_acaAKO_pkaC3_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_2,pool36_acaAKO_pkaC3_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_3,pool36_acaAKO_pkaC3_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_4,pool36_acaAKO_pkaC3_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_5,pool36_acaAKO_pkaC3_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_acaAKO_pkaC3_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_acaAKO_pkaC3_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_2,pool36_acaAKO_pkaC3_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_3,pool36_acaAKO_pkaC3_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_4
# Found the following samples for confounder Batch and batch acaAPkaCoe_r2: pool37_acaA_pkaC1_bio1_00h_14_TTGGATC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool37_acaA_pkaC1_bio1_06h_20_CATGCTC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool37_acaA_pkaC1_bio1_06h_20_CATGCTC_mappedGene_expressions_All_milestone_mRNA_gff_1,pool37_acaA_pkaC1_bio1_08h_21_ACGCAAC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool37_acaA_pkaC1_bio1_08h_21_ACGCAAC_mappedGene_expressions_All_milestone_mRNA_gff_1,pool37_acaA_pkaC1_bio1_08h_21_ACGCAAC_mappedGene_expressions_All_milestone_mRNA_gff_2,pool37_acaA_pkaC1_bio1_12h_22_GCATTGG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool37_acaA_pkaC1_bio1_12h_22_GCATTGG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool37_acaA_pkaC1_bio1_12h_22_GCATTGG_mappedGene_expressions_All_milestone_mRNA_gff_2,pool37_acaA_pkaC1_bio1_16h_23_GATCTCG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool37_acaA_pkaC1_bio1_16h_23_GATCTCG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool37_acaA_pkaC1_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool37_acaA_pkaC1_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool37_acaA_pkaC1_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_2,pool37_acaA_pkaC1_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_3,pool37_acaA_pkaC1_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_4,pool37_acaA_pkaC1_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool37_acaA_pkaC1_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_1,pool37_acaA_pkaC1_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_2,pool37_acaA_pkaC1_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_3,pool37_acaA_pkaC1_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_4,pool37_acaA_pkaC1_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool37_acaA_pkaC1_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_1,pool37_acaA_pkaC1_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_2
# Found the following samples for confounder Batch and batch ac3PkaCoe_r1: ac3_PkaC_r1_00hr_17_S94_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch ac3PkaCoe_r2: ac3_PkaC_r2_00hr_16_S93_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch PkaCoe_r1: PkaCoe25_r2_00h_21_S97_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_04h_22_S98_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_04h_22_S98_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaCoe25_r2_08h_23_S99_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_08h_23_S99_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaCoe25_r2_12h_24_S100_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_12h_24_S100_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaCoe25_r2_14h_25_S101_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_16h_26_S102_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_16h_26_S102_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaCoe25_r2_20h_28_S104_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_20h_28_S104_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaCoe25_r2_24h_29_S105_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_24h_29_S105_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch PkaCoe_r2: PkaC25_r3_00h_31_S47_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_04h_32_S48_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_08h_33_S49_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_12h_34_S50_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_12h_34_S50_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaC25_r3_14h_35_S51_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_14h_35_S51_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaC25_r3_16h_36_S52_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_16h_36_S52_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaC25_r3_18h_37_S53_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_20h_38_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_20h_38_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaC25_r3_24h_39_S55_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_24h_39_S55_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch pkaR_r1: pool35_pkaR_00h_bio1_9_ACCAACT_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_pkaR_08h_bio1_16_TAATGCG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_pkaR_08h_bio1_16_TAATGCG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1,pool35_pkaR_12h_bio1_4_GGATCAA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_pkaR_16h_bio1_5_GCAAGAT_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_pkaR_20h_bio1_6_ATGGAGA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_pkaR_24h_bio1_7_CTCGATG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_pkaR_28h_bio1_8_GCTCGAA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch pkaR_r2: pool38_pkaR__00h_bio2_22_GCATTGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_pkaR__06h_bio2_28_AGATAGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_pkaR__08h_bio2_29_CCGATTG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_pkaR__08h_bio2_29_CCGATTG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1,pool38_pkaR__12h_bio2_30_ATGCCGC_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_pkaR__16h_bio2_31_CAGTACT_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_pkaR__24h_bio2_33_CATCCGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0
# Input contained 12828 genes/regions.
# WARNING: 378 out of 12828 genes do not have obserserved non-zero counts and are excluded.
# Selected 12450 genes/regions for analysis.
# # Run DESeq2: Using dispersion factorscomputed by DESeq2.
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
# [1] "Corrected 69 DESEq2 dispersion estimates which to avoid variance overestimation and loss of discriminatory power for model selection."
# Consumed time: 98.11 min.
#
# # Compute size factors
# [1] "WARNING: Found size factors==0, setting these to 1."
# # Fitting null and alternative model to the genes
#
# Consumed time: 237.94 min.
#
# # Differentially expression analysis based on model fits
#
# Finished running ImpulseDE2.
#
# TOTAL consumed time: 336.12 min.

# %%
saveRDS(object=objectImpulseDE2,file=paste(pathSave,'DEacrossStages.rds',sep=''))
saveRDS(object=PHENOTYPES_X,file=paste(pathSave,'DEacrossStages_phenotypesOrder.rds',sep=''))

# %%
fdr=0.05
result<-objectImpulseDE2$dfImpulseDE2Results
result<-result[result$padj<=fdr & ! is.na(result$padj),]
result<-result[order(result$padj),]
write.table(result,file=paste(pathSave,'DEacrossStages_padj',fdr,'.tsv',sep='') ,sep='\t',row.names = FALSE)

# %% [markdown]
# ## Individual strains

# %%
unique(conditions$Strain)[4:length(unique(conditions$Strain))]
# Out:
#  [1] gtaI       cudA       dgcA       gtaG       tagB       comH
#  [7] gbfA       tgrC1      tgrB1      tgrB1C1    gtaC       mybB
# [13] amiB       acaA       acaAPkaCoe ac3PkaCoe  PkaCoe     pkaR
# 21 Levels: ac3PkaCoe acaA acaAPkaCoe amiB AX4 comH cudA dgcA ecmARm ... tgrC1

# %%
for (strain in unique(conditions$Strain)){
  conditions_annotated=conditions[rowSums(conditions[, PHENOTYPES_ORDERED])>0 &conditions$Strain==strain, ]
  #Drop phenotypes not annoated in this strain
  phenotypes_count<-colSums(conditions_annotated[, PHENOTYPES_ORDERED])
  phenotypes_present<-names(phenotypes_count[phenotypes_count>0])
  if (length(phenotypes_present)>1){
      phenotypes_x=data.frame(Phenotype=phenotypes_present,X=c(1:length(phenotypes_present)))
      drop<-names(phenotypes_count[phenotypes_count==0])
      drop<-which(colnames(conditions_annotated) %in% drop)
      conditions_annotated=conditions_annotated[,-drop]
      X=data.frame(row.names=rownames(genes))
      Y=data.frame()
      for (row_idx in 1:dim(conditions_annotated)[1]){
        y=conditions_annotated[row_idx,]
        x=genes[,rownames(y)]
        repeated_sample=0
        for (phenotype in phenotypes_present){
          if (y[phenotype]==1){
            sample_name=paste(rownames(y),repeated_sample,sep='_')
            X[,sample_name]=x
            Y[sample_name,c('Sample','Condition','Batch','Time')]=c(sample_name,'case',y['Replicate'],phenotypes_x[phenotypes_x['Phenotype']==phenotype,'X'])
            repeated_sample=repeated_sample+1
          }
        }
      } 

      Y<-Y[order(Y$Time),]
      print(strain)
      print(dim(conditions_annotated))
      print(paste(dim(X)[1],dim(X)[2],sum(conditions_annotated[,phenotypes_present])))
      objectImpulseDE2 <- runImpulseDE2(matCountData = as.matrix(X), dfAnnotation = Y,boolCaseCtrl = FALSE,vecConfounders = c("Batch"),
                                        boolIdentifyTransients = TRUE,scaNProc = 20 )
      saveRDS(object=objectImpulseDE2,file=paste(pathSave,'strain/',strain,'_DEacrossStages.rds',sep=''))
      write.table(phenotypes_x,file=paste(pathSave,'strain/',strain,'_DEacrossStages_phenotypesOrder.tsv',sep=''),sep='\t',row.names = FALSE)
    }
}
# Out:
# [1] "cudA"
# [1] 18 11
# [1] "12828 24 24"
# ImpulseDE2 for count data, v1.10.0
#
# # Process input
# Processing Details:
# ImpulseDE2 runs in case-only mode.
# Found time points: 1,2,3,4,5,6
# Case: Found the samples at time point 1: cudA2_6_r2_0h_7_S173_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_4h_8_S174_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_0h_16_S182_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_4h_17_S183_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 2: cudA2_6_r2_8h_9_S175_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_12h_10_S176_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_8h_18_S184_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_12h_19_S185_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 3: cudA2_6_r2_12h_10_S176_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,cudA2_6_r3_12h_19_S185_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Case: Found the samples at time point 4: cudA2_6_r2_14h_11_S177_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_14h_20_S186_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 5: cudA2_6_r2_16h_12_S178_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_18h_13_S179_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_20h_14_S180_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_24h_15_S181_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_16h_22_S187_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_18h_23_S188_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_20h_24_S189_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_24h_25_S190_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 6: cudA2_6_r2_20h_14_S180_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,cudA2_6_r2_24h_15_S181_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,cudA2_6_r3_20h_24_S189_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,cudA2_6_r3_24h_25_S190_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch cudA_r1: cudA2_6_r2_0h_7_S173_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_4h_8_S174_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_8h_9_S175_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_12h_10_S176_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_12h_10_S176_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,cudA2_6_r2_14h_11_S177_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_16h_12_S178_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_18h_13_S179_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_20h_14_S180_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_24h_15_S181_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r2_20h_14_S180_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,cudA2_6_r2_24h_15_S181_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch cudA_r2: cudA2_6_r3_0h_16_S182_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_4h_17_S183_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_8h_18_S184_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_12h_19_S185_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_12h_19_S185_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,cudA2_6_r3_14h_20_S186_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_16h_22_S187_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_18h_23_S188_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_20h_24_S189_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_24h_25_S190_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,cudA2_6_r3_20h_24_S189_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,cudA2_6_r3_24h_25_S190_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Input contained 12828 genes/regions.
# WARNING: 972 out of 12828 genes do not have obserserved non-zero counts and are excluded.
# Selected 11856 genes/regions for analysis.
# # Run DESeq2: Using dispersion factorscomputed by DESeq2.
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
# [1] "Corrected 13 DESEq2 dispersion estimates which to avoid variance overestimation and loss of discriminatory power for model selection."
# Consumed time: 0.11 min.
#
# # Compute size factors
#
# # Fitting null and alternative model to the genes
#
# Consumed time: 5.24 min.
#
# # Fitting sigmoid model to case condition
#
# Consumed time: 1.75 min.
#
# # Differentially expression analysis based on model fits
#
# Finished running ImpulseDE2.
#
# TOTAL consumed time: 7.14 min.
# [1] "dgcA"
# [1] 18 11
# [1] "12828 21 21"
# ImpulseDE2 for count data, v1.10.0
#
# # Process input
# Processing Details:
# ImpulseDE2 runs in case-only mode.
# Found time points: 1,2,3,4,5,6
# Case: Found the samples at time point 1: dgcA_0h_r1_1_S52_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_4h_r1_2_S53_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_8h_r1_3_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_0h_r2_10_S61_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_4h_r2_11_S62_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 2: dgcA_8h_r1_3_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,dgcA_8h_r2_12_S63_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 3: dgcA_8h_r2_12_S63_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Case: Found the samples at time point 4: dgcA_12h_r1_4_S55_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_14h_r1_5_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_12h_r2_13_S64_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 5: dgcA_14h_r1_5_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,dgcA_14h_r2_14_S65_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 6: dgcA_16h_r1_6_S57_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_18h_r1_7_S58_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_20h_r1_8_S59_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_24h_r1_9_S60_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_16h_r2_15_S66_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_18h_r2_16_S67_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_20h_r2_17_S68_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_24h_r2_18_S69_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch dgcA_r1: dgcA_0h_r1_1_S52_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_4h_r1_2_S53_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_8h_r1_3_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_8h_r1_3_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,dgcA_12h_r1_4_S55_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_14h_r1_5_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_14h_r1_5_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,dgcA_16h_r1_6_S57_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_18h_r1_7_S58_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_20h_r1_8_S59_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_24h_r1_9_S60_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch dgcA_r2: dgcA_0h_r2_10_S61_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_4h_r2_11_S62_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_8h_r2_12_S63_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_8h_r2_12_S63_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,dgcA_12h_r2_13_S64_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_14h_r2_14_S65_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_16h_r2_15_S66_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_18h_r2_16_S67_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_20h_r2_17_S68_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,dgcA_24h_r2_18_S69_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Input contained 12828 genes/regions.
# WARNING: 803 out of 12828 genes do not have obserserved non-zero counts and are excluded.
# Selected 12025 genes/regions for analysis.
# # Run DESeq2: Using dispersion factorscomputed by DESeq2.
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
# [1] "Corrected 10 DESEq2 dispersion estimates which to avoid variance overestimation and loss of discriminatory power for model selection."
# Consumed time: 0.11 min.
#
# # Compute size factors
#
# # Fitting null and alternative model to the genes
#
# Consumed time: 5.41 min.
#
# # Fitting sigmoid model to case condition
#
# Consumed time: 1.86 min.
#
# # Differentially expression analysis based on model fits
#
# Finished running ImpulseDE2.
#
# TOTAL consumed time: 7.42 min.
# [1] "gtaG"
# [1] 14 12
# [1] "12828 22 22"
# ImpulseDE2 for count data, v1.10.0
#
# # Process input
# Processing Details:
# ImpulseDE2 runs in case-only mode.
# Found time points: 1,2,3,4,5,6,7
# Case: Found the samples at time point 1: gtaG_r1_00hr_1_S79_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_04hr_2_S80_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_00h_8_S57_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_04h_24_S72_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 2: gtaG_r1_08hr_8_S85_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_04h_24_S72_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r2_08h_25_S73_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 3: gtaG_r1_08hr_8_S85_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r1_12hr_4_S81_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_08h_25_S73_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Case: Found the samples at time point 4: gtaG_r1_12hr_4_S81_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r2_12h_4_S53_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 5: gtaG_r1_16hr_5_S82_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_20hr_6_S83_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_24hr_7_S84_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_16h_5_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_20h_6_S55_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_24h_7_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 6: gtaG_r1_24hr_7_S84_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r2_24h_7_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Case: Found the samples at time point 7: gtaG_r1_24hr_7_S84_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,gtaG_r2_24h_7_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2
# Found the following samples for confounder Batch and batch gtaG_r1: gtaG_r1_00hr_1_S79_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_04hr_2_S80_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_08hr_8_S85_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_08hr_8_S85_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r1_12hr_4_S81_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_12hr_4_S81_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r1_16hr_5_S82_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_20hr_6_S83_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_24hr_7_S84_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r1_24hr_7_S84_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r1_24hr_7_S84_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2
# Found the following samples for confounder Batch and batch gtaG_r2: gtaG_r2_00h_8_S57_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_04h_24_S72_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_04h_24_S72_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r2_08h_25_S73_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_08h_25_S73_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r2_12h_4_S53_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_16h_5_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_20h_6_S55_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_24h_7_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gtaG_r2_24h_7_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gtaG_r2_24h_7_S56_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2
# Input contained 12828 genes/regions.
# WARNING: 649 out of 12828 genes do not have obserserved non-zero counts and are excluded.
# Selected 12179 genes/regions for analysis.
# # Run DESeq2: Using dispersion factorscomputed by DESeq2.
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
# [1] "Corrected 8 DESEq2 dispersion estimates which to avoid variance overestimation and loss of discriminatory power for model selection."
# Consumed time: 0.11 min.
#
# # Compute size factors
#
# # Fitting null and alternative model to the genes
#
# Consumed time: 5.56 min.
#
# # Fitting sigmoid model to case condition
#
# Consumed time: 1.67 min.
#
# # Differentially expression analysis based on model fits
#
# Finished running ImpulseDE2.
#
# TOTAL consumed time: 7.38 min.
# [1] "tagB"
# [1] 13 10
# [1] "12828 21 21"
# ImpulseDE2 for count data, v1.10.0
#
# # Process input
# Processing Details:
# ImpulseDE2 runs in case-only mode.
# Found time points: 1,2,3,4,5
# Case: Found the samples at time point 1: pool36_tagB__bio1_00h_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_00h_14_S149_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 2: pool36_tagB__bio1_08h_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_12h_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_06h_20_S155_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_08h_21_S156_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_12h_22_S157_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_16h_23_S158_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 3: pool36_tagB__bio1_08h_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_tagB__bio1_12h_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_tagB__bio1_16h_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_08h_21_S156_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tagB_bio2_12h_22_S157_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Case: Found the samples at time point 4: pool36_tagB__bio1_16h_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_tagB__bio1_20h_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_24h_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_28h_13_ACTATCA_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_12h_22_S157_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tagB_bio2_16h_23_S158_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tagB_bio2_24h_25_S160_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 5: pool36_tagB__bio1_28h_13_ACTATCA_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch tagB_r1: pool36_tagB__bio1_00h_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_08h_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_12h_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_08h_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_tagB__bio1_12h_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_tagB__bio1_16h_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_16h_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_tagB__bio1_20h_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_24h_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_28h_13_ACTATCA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_tagB__bio1_28h_13_ACTATCA_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch tagB_r2: tagB_bio2_00h_14_S149_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_06h_20_S155_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_08h_21_S156_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_12h_22_S157_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_16h_23_S158_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tagB_bio2_08h_21_S156_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tagB_bio2_12h_22_S157_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tagB_bio2_12h_22_S157_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tagB_bio2_16h_23_S158_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tagB_bio2_24h_25_S160_L008_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Input contained 12828 genes/regions.
# WARNING: 585 out of 12828 genes do not have obserserved non-zero counts and are excluded.
# Selected 12243 genes/regions for analysis.
# # Run DESeq2: Using dispersion factorscomputed by DESeq2.
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# Consumed time: 0.11 min.
#
# # Compute size factors
#
# # Fitting null and alternative model to the genes
#
# Consumed time: 4.98 min.
#
# # Fitting sigmoid model to case condition
#
# Consumed time: 1.96 min.
#
# # Differentially expression analysis based on model fits
#
# Finished running ImpulseDE2.
#
# TOTAL consumed time: 7.09 min.
# [1] "comH"
# [1] 20 10
# [1] "12828 32 32"
# ImpulseDE2 for count data, v1.10.0
#
# # Process input
# Processing Details:
# ImpulseDE2 runs in case-only mode.
# Found time points: 1,2,3,4,5
# Case: Found the samples at time point 1: t345_r1_00h_38_S111_L001_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_02h_39_S112_L001_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_04h_40_S113_L001_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_06h_41_S114_L001_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_00h_33_S153_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_02h_34_S154_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_04h_35_S155_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_06h_36_S156_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 2: t345_r1_08h_42_S115_L001_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_08h_37_S157_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_12h_38_S158_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_16h_39_S159_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 3: t345_r1_08h_42_S115_L001_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r1_12h_28_S148_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_08h_37_S157_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r2_12h_38_S158_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r2_16h_39_S159_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r2_20h_40_S160_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 4: t345_r1_12h_28_S148_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r1_16h_29_S149_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_20h_30_S150_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_24h_31_S151_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_28h_32_S152_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_12h_38_S158_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,t345_r2_16h_39_S159_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,t345_r2_20h_40_S160_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r2_24h_41_S161_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_28h_42_S162_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 5: t345_r1_24h_31_S151_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r1_28h_32_S152_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r2_24h_41_S161_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r2_28h_42_S162_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch comH_r1: t345_r1_00h_38_S111_L001_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_02h_39_S112_L001_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_04h_40_S113_L001_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_06h_41_S114_L001_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_08h_42_S115_L001_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_08h_42_S115_L001_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r1_12h_28_S148_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_12h_28_S148_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r1_16h_29_S149_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_20h_30_S150_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_24h_31_S151_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_28h_32_S152_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r1_24h_31_S151_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r1_28h_32_S152_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch comH_r2: t345_r2_00h_33_S153_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_02h_34_S154_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_04h_35_S155_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_06h_36_S156_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_08h_37_S157_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_12h_38_S158_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_16h_39_S159_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_08h_37_S157_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r2_12h_38_S158_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r2_16h_39_S159_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r2_20h_40_S160_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_12h_38_S158_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,t345_r2_16h_39_S159_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,t345_r2_20h_40_S160_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r2_24h_41_S161_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_28h_42_S162_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,t345_r2_24h_41_S161_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,t345_r2_28h_42_S162_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Input contained 12828 genes/regions.
# WARNING: 439 out of 12828 genes do not have obserserved non-zero counts and are excluded.
# Selected 12389 genes/regions for analysis.
# # Run DESeq2: Using dispersion factorscomputed by DESeq2.
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
# [1] "Corrected 1 DESEq2 dispersion estimates which to avoid variance overestimation and loss of discriminatory power for model selection."
# Consumed time: 0.12 min.
#
# # Compute size factors
#
# # Fitting null and alternative model to the genes
#
# Consumed time: 4.28 min.
#
# # Fitting sigmoid model to case condition
#
# Consumed time: 1.92 min.
#
# # Differentially expression analysis based on model fits
#
# Finished running ImpulseDE2.
#
# TOTAL consumed time: 6.37 min.
# [1] "gbfA"
# [1] 20  9
# [1] "12828 28 28"
# ImpulseDE2 for count data, v1.10.0
#
# # Process input
# Processing Details:
# ImpulseDE2 runs in case-only mode.
# Found time points: 1,2,3,4
# Case: Found the samples at time point 1: gbfA_0h_r1_28_S79_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_4h_r1_29_S80_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_6h_r1_30_S81_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_8h_r1_31_S82_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_24h_r1_37_S88_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_00h_1_S126_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_04h_2_S127_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_06h_3_S128_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_08h_4_S129_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_10h_5_S130_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_12h_6_S131_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_14h_10_S135_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_24h_13_S138_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 2: gbfA_14h_r1_34_S85_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_16h_r1_35_S86_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_20h_r1_36_S87_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_16h_11_S136_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_20h_12_S137_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 3: gbfA_10h_r1_32_S83_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_24h_r1_37_S88_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gbfA_r3_10h_5_S130_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gbfA_r3_12h_6_S131_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gbfA_r3_24h_13_S138_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Case: Found the samples at time point 4: gbfA_10h_r1_32_S83_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gbfA_12h_r1_33_S84_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_14h_r1_34_S85_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gbfA_r3_12h_6_S131_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,gbfA_r3_14h_10_S135_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch gbfA_r1: gbfA_0h_r1_28_S79_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_4h_r1_29_S80_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_6h_r1_30_S81_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_8h_r1_31_S82_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_24h_r1_37_S88_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_14h_r1_34_S85_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_16h_r1_35_S86_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_20h_r1_36_S87_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_10h_r1_32_S83_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_24h_r1_37_S88_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gbfA_10h_r1_32_S83_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gbfA_12h_r1_33_S84_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_14h_r1_34_S85_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch gbfA_r2: gbfA_r3_00h_1_S126_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_04h_2_S127_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_06h_3_S128_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_08h_4_S129_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_10h_5_S130_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_12h_6_S131_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_14h_10_S135_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_24h_13_S138_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_16h_11_S136_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_20h_12_S137_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,gbfA_r3_10h_5_S130_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gbfA_r3_12h_6_S131_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gbfA_r3_24h_13_S138_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,gbfA_r3_12h_6_S131_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,gbfA_r3_14h_10_S135_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Input contained 12828 genes/regions.
# WARNING: 810 out of 12828 genes do not have obserserved non-zero counts and are excluded.
# Selected 12018 genes/regions for analysis.
# # Run DESeq2: Using dispersion factorscomputed by DESeq2.
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
# [1] "Corrected 4 DESEq2 dispersion estimates which to avoid variance overestimation and loss of discriminatory power for model selection."
# Consumed time: 0.11 min.
#
# # Compute size factors
#
# # Fitting null and alternative model to the genes
#
# Consumed time: 3.49 min.
#
# # Fitting sigmoid model to case condition
#
# Consumed time: 1.79 min.
#
# # Differentially expression analysis based on model fits
#
# Finished running ImpulseDE2.
#
# TOTAL consumed time: 5.43 min.
# [1] "tgrC1"
# [1] 20 10
# [1] "12828 30 30"
# ImpulseDE2 for count data, v1.10.0
#
# # Process input
# Processing Details:
# ImpulseDE2 runs in case-only mode.
# Found time points: 1,2,3,4,5
# Case: Found the samples at time point 1: tgrC1_r1_00h_21_S37_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_04h_22_S38_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_06h_23_S39_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_12h_26_S42_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_20h_29_S45_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_24h_30_S46_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_00h_11_S27_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_04h_12_S28_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_06h_13_S29_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_24h_20_S36_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 2: tgrC1_r1_10h_25_S41_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_14h_27_S43_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_16h_28_S44_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_14h_17_S33_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_20h_19_S35_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_24h_20_S36_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Case: Found the samples at time point 3: tgrC1_r1_08h_24_S40_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_12h_26_S42_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r1_16h_28_S44_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r2_08h_14_S30_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_10h_15_S31_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 4: tgrC1_r1_12h_26_S42_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrC1_r1_20h_29_S45_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r1_24h_30_S46_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r2_10h_15_S31_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r2_12h_16_S32_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_20h_19_S35_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r2_24h_20_S36_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2
# Case: Found the samples at time point 5: tgrC1_r2_14h_17_S33_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r2_16h_18_S34_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch tgrC1_r1: tgrC1_r1_00h_21_S37_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_04h_22_S38_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_06h_23_S39_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_12h_26_S42_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_20h_29_S45_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_24h_30_S46_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_10h_25_S41_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_14h_27_S43_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_16h_28_S44_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_08h_24_S40_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r1_12h_26_S42_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r1_16h_28_S44_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r1_12h_26_S42_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrC1_r1_20h_29_S45_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r1_24h_30_S46_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch tgrC1_r2: tgrC1_r2_00h_11_S27_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_04h_12_S28_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_06h_13_S29_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_24h_20_S36_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_14h_17_S33_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_20h_19_S35_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_24h_20_S36_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r2_08h_14_S30_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_10h_15_S31_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_10h_15_S31_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r2_12h_16_S32_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrC1_r2_20h_19_S35_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r2_24h_20_S36_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrC1_r2_14h_17_S33_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrC1_r2_16h_18_S34_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Input contained 12828 genes/regions.
# WARNING: 744 out of 12828 genes do not have obserserved non-zero counts and are excluded.
# Selected 12084 genes/regions for analysis.
# # Run DESeq2: Using dispersion factorscomputed by DESeq2.
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
# [1] "Corrected 8 DESEq2 dispersion estimates which to avoid variance overestimation and loss of discriminatory power for model selection."
# Consumed time: 0.12 min.
#
# # Compute size factors
#
# # Fitting null and alternative model to the genes
#
# Consumed time: 4.77 min.
#
# # Fitting sigmoid model to case condition
#
# Consumed time: 1.91 min.
#
# # Differentially expression analysis based on model fits
#
# Finished running ImpulseDE2.
#
# TOTAL consumed time: 6.85 min.
# [1] "tgrB1"
# [1] 20 12
# [1] "12828 36 36"
# ImpulseDE2 for count data, v1.10.0
#
# # Process input
# Processing Details:
# ImpulseDE2 runs in case-only mode.
# Found time points: 1,2,3,4,5,6,7
# Case: Found the samples at time point 1: tgrB1_r1_00h_11_S27_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_04h_12_S28_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_06h_13_S29_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_08h_14_S30_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_24h_20_S36_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_00h_21_S37_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_04h_22_S38_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_06h_23_S39_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_24h_30_S46_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 2: tgrB1_r1_16h_18_S34_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_20h_19_S35_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_14h_27_S43_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_20h_29_S45_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 3: tgrB1_r1_10h_15_S31_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_08h_24_S40_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_10h_25_S41_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_12h_26_S42_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_16h_28_S44_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 4: tgrB1_r1_10h_15_S31_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1_r1_12h_16_S32_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_14h_17_S33_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_16h_18_S34_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1_r1_20h_19_S35_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1_r1_24h_20_S36_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1_r2_10h_25_S41_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1_r2_12h_26_S42_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1_r2_14h_27_S43_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1_r2_16h_28_S44_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1_r2_20h_29_S45_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Case: Found the samples at time point 5: tgrB1_r1_20h_19_S35_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1_r1_24h_20_S36_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1_r2_16h_28_S44_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1_r2_20h_29_S45_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2
# Case: Found the samples at time point 6: tgrB1_r1_24h_20_S36_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_3,tgrB1_r2_24h_30_S46_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Case: Found the samples at time point 7: tgrB1_r2_24h_30_S46_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2
# Found the following samples for confounder Batch and batch tgrB1_r1: tgrB1_r1_00h_11_S27_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_04h_12_S28_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_06h_13_S29_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_08h_14_S30_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_24h_20_S36_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_16h_18_S34_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_20h_19_S35_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_10h_15_S31_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_10h_15_S31_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1_r1_12h_16_S32_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_14h_17_S33_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r1_16h_18_S34_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1_r1_20h_19_S35_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1_r1_24h_20_S36_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1_r1_20h_19_S35_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1_r1_24h_20_S36_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1_r1_24h_20_S36_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_3
# Found the following samples for confounder Batch and batch tgrB1_r2: tgrB1_r2_00h_21_S37_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_04h_22_S38_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_06h_23_S39_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_24h_30_S46_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_14h_27_S43_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_20h_29_S45_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_08h_24_S40_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_10h_25_S41_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_12h_26_S42_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_16h_28_S44_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1_r2_10h_25_S41_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1_r2_12h_26_S42_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1_r2_14h_27_S43_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1_r2_16h_28_S44_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1_r2_20h_29_S45_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1_r2_16h_28_S44_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1_r2_20h_29_S45_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1_r2_24h_30_S46_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1_r2_24h_30_S46_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2
# Input contained 12828 genes/regions.
# WARNING: 847 out of 12828 genes do not have obserserved non-zero counts and are excluded.
# Selected 11981 genes/regions for analysis.
# # Run DESeq2: Using dispersion factorscomputed by DESeq2.
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
# [1] "Corrected 14 DESEq2 dispersion estimates which to avoid variance overestimation and loss of discriminatory power for model selection."
# Consumed time: 0.19 min.
#
# # Compute size factors
#
# # Fitting null and alternative model to the genes
#
# Consumed time: 6.02 min.
#
# # Fitting sigmoid model to case condition
#
# Consumed time: 1.98 min.
#
# # Differentially expression analysis based on model fits
#
# Finished running ImpulseDE2.
#
# TOTAL consumed time: 8.23 min.
# [1] "tgrB1C1"
# [1] 20 12
# [1] "12828 35 35"
# ImpulseDE2 for count data, v1.10.0
#
# # Process input
# Processing Details:
# ImpulseDE2 runs in case-only mode.
# Found time points: 1,2,3,4,5,6,7
# Case: Found the samples at time point 1: tgrB1C1_r1_00h_1_S17_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r1_04h_2_S18_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r1_24h_10_S26_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_00h_1_S17_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_04h_2_S18_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_06h_3_S19_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_24h_10_S26_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 2: tgrB1C1_r1_12h_6_S22_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_14h_7_S23_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_16h_8_S24_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_20h_9_S25_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 3: tgrB1C1_r1_06h_3_S19_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r1_08h_4_S20_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r1_10h_5_S21_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r1_12h_6_S22_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1C1_r2_08h_4_S20_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_10h_5_S21_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 4: tgrB1C1_r1_10h_5_S21_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1C1_r1_14h_7_S23_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r1_16h_8_S24_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r1_20h_9_S25_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_10h_5_S21_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1C1_r2_12h_6_S22_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,tgrB1C1_r2_14h_7_S23_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1C1_r2_16h_8_S24_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1C1_r2_20h_9_S25_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Case: Found the samples at time point 5: tgrB1C1_r1_12h_6_S22_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1C1_r1_16h_8_S24_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1C1_r1_20h_9_S25_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1C1_r2_16h_8_S24_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1C1_r2_20h_9_S25_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2
# Case: Found the samples at time point 6: tgrB1C1_r1_24h_10_S26_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,tgrB1C1_r2_24h_10_S26_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Case: Found the samples at time point 7: tgrB1C1_r1_24h_10_S26_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2,tgrB1C1_r2_24h_10_S26_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_2
# ...
# Case: Found the samples at time point 7: pool36_acaAKO_pkaC3_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_4,pool36_acaAKO_pkaC3_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_3,pool37_acaA_pkaC1_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_3,pool37_acaA_pkaC1_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_3,pool37_acaA_pkaC1_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_1
# Case: Found the samples at time point 8: pool36_acaAKO_pkaC3_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_5,pool36_acaAKO_pkaC3_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_4,pool37_acaA_pkaC1_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_4,pool37_acaA_pkaC1_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_4,pool37_acaA_pkaC1_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_2
# Found the following samples for confounder Batch and batch acaAPkaCoe_r1: pool36_acaAKO_pkaC3_bio1_00h_14_TTGGATC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_acaAKO_pkaC3_bio1_06h_20_CATGCTC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_acaAKO_pkaC3_bio1_08h_21_ACGCAAC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_acaAKO_pkaC3_bio1_12h_22_GCATTGG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_acaAKO_pkaC3_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_acaAKO_pkaC3_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_acaAKO_pkaC3_bio1_06h_20_CATGCTC_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_acaAKO_pkaC3_bio1_08h_21_ACGCAAC_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_acaAKO_pkaC3_bio1_12h_22_GCATTGG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_acaAKO_pkaC3_bio1_16h_23_GATCTCG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_acaAKO_pkaC3_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_acaAKO_pkaC3_bio1_12h_22_GCATTGG_mappedGene_expressions_All_milestone_mRNA_gff_2,pool36_acaAKO_pkaC3_bio1_16h_23_GATCTCG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_acaAKO_pkaC3_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_2,pool36_acaAKO_pkaC3_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_acaAKO_pkaC3_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool36_acaAKO_pkaC3_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_3,pool36_acaAKO_pkaC3_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_2,pool36_acaAKO_pkaC3_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_1,pool36_acaAKO_pkaC3_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_4,pool36_acaAKO_pkaC3_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_3,pool36_acaAKO_pkaC3_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_2,pool36_acaAKO_pkaC3_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_4,pool36_acaAKO_pkaC3_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_3,pool36_acaAKO_pkaC3_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_5,pool36_acaAKO_pkaC3_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_4
# Found the following samples for confounder Batch and batch acaAPkaCoe_r2: pool37_acaA_pkaC1_bio1_00h_14_TTGGATC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool37_acaA_pkaC1_bio1_06h_20_CATGCTC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool37_acaA_pkaC1_bio1_08h_21_ACGCAAC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool37_acaA_pkaC1_bio1_12h_22_GCATTGG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool37_acaA_pkaC1_bio1_06h_20_CATGCTC_mappedGene_expressions_All_milestone_mRNA_gff_1,pool37_acaA_pkaC1_bio1_08h_21_ACGCAAC_mappedGene_expressions_All_milestone_mRNA_gff_1,pool37_acaA_pkaC1_bio1_08h_21_ACGCAAC_mappedGene_expressions_All_milestone_mRNA_gff_2,pool37_acaA_pkaC1_bio1_12h_22_GCATTGG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool37_acaA_pkaC1_bio1_16h_23_GATCTCG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool37_acaA_pkaC1_bio1_12h_22_GCATTGG_mappedGene_expressions_All_milestone_mRNA_gff_2,pool37_acaA_pkaC1_bio1_16h_23_GATCTCG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool37_acaA_pkaC1_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool37_acaA_pkaC1_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool37_acaA_pkaC1_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool37_acaA_pkaC1_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool37_acaA_pkaC1_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_1,pool37_acaA_pkaC1_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_2,pool37_acaA_pkaC1_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_2,pool37_acaA_pkaC1_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_3,pool37_acaA_pkaC1_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_3,pool37_acaA_pkaC1_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_1,pool37_acaA_pkaC1_bio1_20h_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_4,pool37_acaA_pkaC1_bio1_24h_25_TGACGTC_mappedGene_expressions_All_milestone_mRNA_gff_4,pool37_acaA_pkaC1_bio1_28h_26_GATGCCA_mappedGene_expressions_All_milestone_mRNA_gff_2
# Input contained 12828 genes/regions.
# WARNING: 623 out of 12828 genes do not have obserserved non-zero counts and are excluded.
# Selected 12205 genes/regions for analysis.
# # Run DESeq2: Using dispersion factorscomputed by DESeq2.
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
# [1] "Corrected 1 DESEq2 dispersion estimates which to avoid variance overestimation and loss of discriminatory power for model selection."
# Consumed time: 0.17 min.
#
# # Compute size factors
#
# # Fitting null and alternative model to the genes
#
# Consumed time: 5.62 min.
#
# # Fitting sigmoid model to case condition
#
# Consumed time: 1.52 min.
#
# # Differentially expression analysis based on model fits
#
# Finished running ImpulseDE2.
#
# TOTAL consumed time: 7.36 min.
# [1] "PkaCoe"
# [1] 17 13
# [1] "12828 28 28"
# ImpulseDE2 for count data, v1.10.0
#
# # Process input
# Processing Details:
# ImpulseDE2 runs in case-only mode.
# Found time points: 1,2,3,4,5,6,7,8
# Case: Found the samples at time point 1: PkaCoe25_r2_00h_21_S97_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_04h_22_S98_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_00h_31_S47_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_04h_32_S48_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 2: PkaCoe25_r2_04h_22_S98_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaCoe25_r2_08h_23_S99_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_08h_33_S49_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 3: PkaCoe25_r2_08h_23_S99_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Case: Found the samples at time point 4: PkaC25_r3_12h_34_S50_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 5: PkaCoe25_r2_12h_24_S100_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_12h_34_S50_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaC25_r3_14h_35_S51_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 6: PkaCoe25_r2_12h_24_S100_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaCoe25_r2_14h_25_S101_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_14h_35_S51_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaC25_r3_16h_36_S52_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 7: PkaCoe25_r2_16h_26_S102_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_20h_28_S104_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_24h_29_S105_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_16h_36_S52_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaC25_r3_18h_37_S53_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_20h_38_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_24h_39_S55_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 8: PkaCoe25_r2_16h_26_S102_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaCoe25_r2_20h_28_S104_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaCoe25_r2_24h_29_S105_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaC25_r3_20h_38_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaC25_r3_24h_39_S55_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch PkaCoe_r1: PkaCoe25_r2_00h_21_S97_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_04h_22_S98_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_04h_22_S98_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaCoe25_r2_08h_23_S99_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_08h_23_S99_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaCoe25_r2_12h_24_S100_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_12h_24_S100_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaCoe25_r2_14h_25_S101_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_16h_26_S102_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_20h_28_S104_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_24h_29_S105_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaCoe25_r2_16h_26_S102_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaCoe25_r2_20h_28_S104_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaCoe25_r2_24h_29_S105_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch PkaCoe_r2: PkaC25_r3_00h_31_S47_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_04h_32_S48_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_08h_33_S49_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_12h_34_S50_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_12h_34_S50_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaC25_r3_14h_35_S51_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_14h_35_S51_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaC25_r3_16h_36_S52_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_16h_36_S52_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaC25_r3_18h_37_S53_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_20h_38_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_24h_39_S55_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,PkaC25_r3_20h_38_S54_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,PkaC25_r3_24h_39_S55_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Input contained 12828 genes/regions.
# WARNING: 582 out of 12828 genes do not have obserserved non-zero counts and are excluded.
# Selected 12246 genes/regions for analysis.
# # Run DESeq2: Using dispersion factorscomputed by DESeq2.
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
# [1] "Corrected 6 DESEq2 dispersion estimates which to avoid variance overestimation and loss of discriminatory power for model selection."
# Consumed time: 0.13 min.
#
# # Compute size factors
#
# # Fitting null and alternative model to the genes
#
# Consumed time: 5.6 min.
#
# # Fitting sigmoid model to case condition
#
# Consumed time: 1.72 min.
#
# # Differentially expression analysis based on model fits
#
# Finished running ImpulseDE2.
#
# TOTAL consumed time: 7.5 min.
# [1] "pkaR"
# [1] 13 10
# [1] "12828 15 15"
# ImpulseDE2 for count data, v1.10.0
#
# # Process input
# Processing Details:
# ImpulseDE2 runs in case-only mode.
# Found time points: 1,2,3,4,5
# Case: Found the samples at time point 1: pool35_pkaR_00h_bio1_9_ACCAACT_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_pkaR__00h_bio2_22_GCATTGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_pkaR__06h_bio2_28_AGATAGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 2: pool35_pkaR_08h_bio1_16_TAATGCG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_pkaR__08h_bio2_29_CCGATTG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 3: pool35_pkaR_08h_bio1_16_TAATGCG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1,pool38_pkaR__08h_bio2_29_CCGATTG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1
# Case: Found the samples at time point 4: pool35_pkaR_12h_bio1_4_GGATCAA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_pkaR_16h_bio1_5_GCAAGAT_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_pkaR_20h_bio1_6_ATGGAGA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_pkaR__12h_bio2_30_ATGCCGC_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_pkaR__16h_bio2_31_CAGTACT_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 5: pool35_pkaR_24h_bio1_7_CTCGATG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_pkaR_28h_bio1_8_GCTCGAA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_pkaR__24h_bio2_33_CATCCGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch pkaR_r1: pool35_pkaR_00h_bio1_9_ACCAACT_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_pkaR_08h_bio1_16_TAATGCG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_pkaR_08h_bio1_16_TAATGCG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1,pool35_pkaR_12h_bio1_4_GGATCAA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_pkaR_16h_bio1_5_GCAAGAT_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_pkaR_20h_bio1_6_ATGGAGA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_pkaR_24h_bio1_7_CTCGATG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_pkaR_28h_bio1_8_GCTCGAA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch pkaR_r2: pool38_pkaR__00h_bio2_22_GCATTGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_pkaR__06h_bio2_28_AGATAGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_pkaR__08h_bio2_29_CCGATTG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_pkaR__08h_bio2_29_CCGATTG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1,pool38_pkaR__12h_bio2_30_ATGCCGC_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_pkaR__16h_bio2_31_CAGTACT_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool38_pkaR__24h_bio2_33_CATCCGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0
# Input contained 12828 genes/regions.
# WARNING: 518 out of 12828 genes do not have obserserved non-zero counts and are excluded.
# Selected 12310 genes/regions for analysis.
# # Run DESeq2: Using dispersion factorscomputed by DESeq2.
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# Consumed time: 0.1 min.
#
# # Compute size factors
#
# # Fitting null and alternative model to the genes
#
# Consumed time: 4.02 min.
#
# # Fitting sigmoid model to case condition
#
# Consumed time: 1.58 min.
#
# # Differentially expression analysis based on model fits
#
# Finished running ImpulseDE2.
#
# TOTAL consumed time: 5.74 min.

# %%
fdr=0.05
result<-objectImpulseDE2$dfImpulseDE2Results
result<-result[result$padj<=fdr & ! is.na(result$padj),]
result<-result[order(result$padj),]

# %%
result<-result[order(result$padj),]

# %%
top<-rownames(result[result$isMonotonous,])[1:20]

# %%
nrow(result)
# Out:
# [1] 6910

# %%
length(rownames(result))
# Out:
# [1] 7428

# %%
library(ggplot2)

# %%
gene_ids=c('DDB_G0295685')
lsgplotsGenes <- plotGenes(
vecGeneIDs = gene_ids,
scaNTopIDs = NULL,
objectImpulseDE2 = objectImpulseDE2,
boolCaseCtrl = FALSE,
dirOut = NULL,
strFileName = NULL,
vecRefPval = NULL,
strNameRefMethod = NULL)

# %%
i=1
print(lsgplotsGenes[[i]])
print(gene_ids[i])
print(objectImpulseDE2$dfImpulseDE2Results[gene_ids[i],])

print(objectImpulseDE2@lsModelFits$case[gene_ids[i]][[1]]$lsImpulseFit$vecImpulseParam)
print(objectImpulseDE2@lsModelFits$case[gene_ids[i]][[1]]$lsSigmoidFit$vecSigmoidParam)
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 7. Consider
# specifying shapes manually if you must have them.”
# Warning message:
# “Removed 10 rows containing missing values (geom_point).”
# [1] "DDB_G0295685"
#                      Gene            p         padj loglik_full loglik_red
# DDB_G0295685 DDB_G0295685 1.797494e-35 5.623399e-35    -285.752  -372.1776
#              df_full df_red     mean converge_impulse converge_const
# DDB_G0295685      13      8 39.14791                0              0
#              converge_sigmoid impulseTOsigmoid_p impulseTOsigmoid_padj
# DDB_G0295685                0       5.009211e-21          3.441524e-19
#              sigmoidTOconst_p sigmoidTOconst_padj isTransient isMonotonous
# DDB_G0295685     4.199354e-17         8.53191e-17        TRUE        FALSE
#              allZero
# DDB_G0295685   FALSE
#        beta          h0          h1          h2          t1          t2
# 3.559679203 0.980735090 0.003909485 6.120401023 4.388184711 4.387891903
#       beta         h0         h1          t
#  3.3043581  0.5680911 47.7174245  3.1444588
# plot without title

# %% [markdown]
# ## Parse the result - find stages where gene is up(down)regulated

# %%
objectImpulseDE2<-readRDS(paste(pathSave,'strain/','AX4','_DEacrossStages.rds',sep=''))

# %%
for (strain in unique(conditions$Strain)){
if (file.exists(paste(pathSave,'strain/',strain,'_DEacrossStages.rds',sep=''))){

objectImpulseDE2<-readRDS(paste(pathSave,'strain/',strain,'_DEacrossStages.rds',sep=''))
phenotypes_x<-read.table(paste(pathSave,'strain/',strain,'_DEacrossStages_phenotypesOrder.tsv',sep=''),header=TRUE)
min_x<-min(phenotypes_x$X)
max_x<-max(phenotypes_x$X)

#Default is 0.001, but they used 0.01 in the paper, but 0.001 seems to neglect many probably DE genes
objectImpulseDE2<-updateDEAnalysis(objectImpulseDE2,scaQThresTransients=0.01)

model<-objectImpulseDE2@lsModelFits$case
result<-objectImpulseDE2$dfImpulseDE2Results
result<-result[! is.na(result$padj),]
result<-result[result$isMonotonous |result$isTransient,]
if (nrow(result[result$isMonotonous & result$isTransient,])>0) stop('Asigned both transient and monotonous')
annotation<-objectImpulseDE2@dfAnnotationProc
print(paste(strain,nrow(result)))

parsed<-data.frame()

for(gene in rownames(result)){
    parsed[gene,c('impulse_padj','impulseTOsigmoid_padj','sigmoid_padj')]=result[gene,
                                c('padj','impulseTOsigmoid_padj','sigmoidTOconst_padj')]
    type=''
    # Was gene assigned to be transient or monotonous
    if (result[gene,'isTransient']) type='transient'
    if (result[gene,'isMonotonous']) type='monotonous'
    parsed[gene,'Type']=type
    
    if (type=='monotonous'){
        
        # If monotonous it can be sigmoid or impulse monotonous - if only sigmoid was used the split could be 
        # wrong (in the middle of relatively stable stage) - thus use as threshold the t from impulse 
        # that is closest to the sigmoid t
        if(result[gene,'padj']>result[gene,'sigmoidTOconst_padj']){
            model_data=as.list(model[gene][[1]]$lsSigmoidFit$vecSigmoidParam)
            t=model_data$t
        }else{
            model_data=as.list(model[gene][[1]]$lsSigmoidFit$vecSigmoidParam)
            model_impulse=as.list(model[gene][[1]]$lsImpulseFit$vecImpulseParam)
            diff_t1=abs(model_data$t-model_impulse$t1)
            diff_t2=abs(model_data$t-model_impulse$t2)
            if(diff_t1<diff_t2){t=model_impulse$t1
            } else {t=model_impulse$t2}
        }
        
        # If t in between stages assign impulse, else (t larger/smaller than last/first stage) assume 
        # that only the last/first stage is DE - assign impulse_manual as this is not directly based on the model
        assignment=NA
        if (min_x<t & t<max_x){
            assignment='impulse'
        #Assumes that stages/times are integers
        } else if (min_x>=t ){
            t=min_x+0.1
            assignment='impulse_manual_border'
        } else if (max_x <= t ){
            t=max_x-0.1
            assignment='impulse_manual_border'
        }
        parsed[gene,'Assignment']=assignment
        
        # Does gene change up or down through time and which stages are on each side of the tipping point
        phenotypes1=as.vector(phenotypes_x[phenotypes_x$X<t,'Phenotype'])
        phenotypes2=as.vector(phenotypes_x[phenotypes_x$X>t,'Phenotype'])
        if (model_data$h1>model_data$h0) {
            parsed[gene,'Direction']='up'
            parsed[gene,phenotypes1]='down'
            parsed[gene,phenotypes2]='up'
        }else{
            parsed[gene,'Direction']='down'
            parsed[gene,phenotypes1]='up'
            parsed[gene,phenotypes2]='down'
        }
        
    } else if (type=='transient') {
        model_data=as.list(model[gene][[1]]$lsImpulseFit$vecImpulseParam)
        t1=model_data$t1
        t2=model_data$t2
        proceed=TRUE
        # t1,t2 can be between different stages - assign phenotypes to up/down based on t1,t2 and 
        # assignments is based directly on the models ('impulse'). If t1/t2 is larger or smaller 
        # than first/last stage assume that only last/first stage is in this state (assignment is impulse_manual)
        # If t1,t2 are between the same two stages assume there is a peak - find stage with max expression and
        # set t based on it - check that only 1 t's floor changes for one stage (assignment is impulse_manual)
        assignment=NA
        if (min_x<t1 & t1<max_x & min_x<t2 & t2<max_x & floor(t1)!=floor(t2)){
            assignment='impulse'
        }
        #Assumes that stages/times are integers
        if(min_x>=t1 & t1<max_x){
            assignment='impulse_manual_border'
            t1=min_x+0.1
        }
        if(min_x<t2 & t2>=max_x){
            assignment='impulse_manual_border'
            t2=max_x-0.1
        }
        if(floor(t1)==floor(t2)){
            assignment='impulse_manual_peak'
            #Expression scaled by ImpulseDE2
            values=model[gene][[1]][[1]]$vecImpulseValue
            values=merge(values,annotation,by="row.names",all.x=TRUE)
            #Mean of each stage group
            values=aggregate(values$x, by=list(values$Time), FUN=mean)
            #Peak or valley
            peak=NULL
            if(model_data$h0<model_data$h1 & model_data$h2<model_data$h1) {
                peak=values[values$x==max(values$x),]$Group.1
            } else if (model_data$h0>model_data$h1 & model_data$h2>model_data$h1){
                peak=values[values$x==min(values$x),]$Group.1
            }
            #Peak identified in wrong place
            if (abs(peak-t1)>1) {
                print(paste('Peak identified at wrong place for gene ',gene))
                proceed=FALSE
                assignment=NA
            }
            t1=peak-0.1
            t2=peak+0.1
        }
        
        parsed[gene,'Assignment']=assignment
        
        if(proceed){
        phenotypes1=as.vector(phenotypes_x[phenotypes_x$X<t1 |phenotypes_x$X>t2,'Phenotype'])
        phenotypes2=as.vector(phenotypes_x[phenotypes_x$X>t1 & phenotypes_x$X<t2,'Phenotype'])
        if(model_data$h0<model_data$h1 & model_data$h2<model_data$h1){
            parsed[gene,'Direction']='up'
            parsed[gene,phenotypes1]='down'
            parsed[gene,phenotypes2]='up'

        } else if (model_data$h0>model_data$h1 & model_data$h2>model_data$h1) {
            parsed[gene,'Direction']='down'
            parsed[gene,phenotypes1]='up'
            parsed[gene,phenotypes2]='down'

        } else{
           stor(paste('Problem in stage annotation for',gene)) 
        }
        }
    }

}
parsed=parsed[,c(c('impulse_padj','impulseTOsigmoid_padj','sigmoid_padj','Type','Direction','Assignment')
                 ,as.vector(phenotypes_x$Phenotype))]
parsed2<-parsed[! is.na(parsed$'Assignment'),]
print(paste(sum(parsed$Assignment=='impulse'),sum(parsed$Assignment=='impulse_manual_border'),
            sum(parsed$Assignment=='impulse_manual_peak')))
write.table(parsed,paste(pathSave,'strain/',strain,'_DEacrossStages_summary.tsv',sep=''),sep='\t')
}
}
# Out:
# [1] "AX4 10611"
# [1] "Peak identified at wrong place for gene  DDB_G0275453"
# [1] "Peak identified at wrong place for gene  DDB_G0275853"
# [1] "Peak identified at wrong place for gene  DDB_G0283713"
# [1] "Peak identified at wrong place for gene  DDB_G0295685"
# [1] "NA NA"
# [1] "MybBGFP 6962"
# [1] "5576 1386"
# [1] "ecmARm 506"
# [1] "177 329"
# [1] "cudA 7211"
# [1] "NA NA"
# [1] "dgcA 3574"
# [1] "2266 1308"
# [1] "gtaG 7357"
# [1] "6015 1342"
# [1] "tagB 4321"
# [1] "2278 2043"
# [1] "comH 4339"
# [1] "2276 2063"
# [1] "gbfA 14"
# [1] "1 13"
# [1] "tgrC1 60"
# [1] "6 54"
# [1] "tgrB1 1547"
# [1] "NA NA"
# [1] "tgrB1C1 1456"
# [1] "Peak identified at wrong place for gene  DDB_G0286929"
# [1] "NA NA"
# [1] "acaAPkaCoe 4387"
# [1] "4259 128"
# [1] "PkaCoe 7813"
# [1] "Peak identified at wrong place for gene  DDB_G0280603"
# [1] "NA NA"
# [1] "pkaR 5374"
# [1] "4012 1362"

# %%
# Out:
# [1] "no_agg"    "stream"    "lag"       "tag"       "tag_spore"
