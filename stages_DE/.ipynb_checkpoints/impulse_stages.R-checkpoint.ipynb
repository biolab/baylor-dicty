# %%
library("ImpulseDE2")
library('dplyr')
library(ggplot2)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
pathSave='/home/khrovatin/timeTrajectoriesNet/data/stages/DE_across_stages/'

# %%
genes<-read.table('/home/khrovatin/timeTrajectoriesNet/data/counts/mergedGenes_counts.tsv', header=TRUE,row.names=1, sep="\t")
conditions<-read.table('/home/khrovatin/timeTrajectoriesNet/data/RPKUM/conditions_mergedGenes.tsv', header=TRUE,row.names='Measurment', sep="\t")
#R imported colnames of genes with changes but gene IDs remained ok
rownames(conditions)<-make.names(rownames(conditions))

# %%
#PHENOTYPES_ORDERED=c('no_agg', 'stream', 'lag', 'tag', 'tip', 'slug', 'mhat', 'cul', 'FB', 'yem')
PHENOTYPES_ORDERED=c('no_agg', 'stream', 'lag', 'tag', 'tip', 'slug', 'mhat', 'cul', 'FB')
PHENOTYPES_X=data.frame(Phenotype=PHENOTYPES_ORDERED,X=c(1:length(PHENOTYPES_ORDERED)))

# %% [markdown]
# Adjusting for replicates when using all data is incorrect as not all strains have all stages - imbalance between stages. If using only WT batch rep it sometimes gives too many genes that only in WT (and poorly) or missing. When using no batch it sometimes gives FP if one strain has very high samples in a stage.

# %%
conditions_annotated=conditions[rowSums(conditions[, PHENOTYPES_ORDERED])>0, ]
# Use only WT data
#conditions_annotated=conditions[rowSums(conditions[, PHENOTYPES_ORDERED])>0 & conditions$Group=='WT', ]
X=data.frame(row.names=rownames(genes))
Y=data.frame()
for (row_idx in 1:dim(conditions_annotated)[1]){
  y=conditions_annotated[row_idx,]
  x=genes[,rownames(y)]
  repeated_sample=0
  for (phenotype in PHENOTYPES_ORDERED){
    if (y[phenotype]==1){
      sample_name=paste(rownames(y),repeated_sample,sep='_')
      X[,sample_name]=x
        #Replicate/strain should not be  used as batch in ImpulseDE2 when using all strains
      Y[sample_name,c('Sample','Condition','Batch','Time')]=c(sample_name,'case',y['Replicate'],PHENOTYPES_X[PHENOTYPES_X['Phenotype']==phenotype,'X'])
      #Only for use in Orange
      #Y[sample_name,c('Measurment','Group','Strain')]=c(rownames(y),y['Group'],y['Strain'])
      repeated_sample=repeated_sample+1
    }
  }
}
Y<-Y[order(Y$Time),]

# %%
#For analysis in Orange
#Y_orange=Y[,c('Time','Measurment','Group','Strain')]
#colnames(Y_orange)=c('Stage','Measurment','Group','Strain')
#write.table(Y_orange,file=paste(pathSave,'impulseSamples.tsv',sep=''),sep='\t', col.names=NA)

# %%
#Do not use replicates/strains as confounders as they do not have same stages ('times')
objectImpulseDE2 <- runImpulseDE2(matCountData = as.matrix(X), dfAnnotation = Y,boolCaseCtrl = FALSE,
                                  vecConfounders = c("Batch"),
                                  #vecConfounders = NULL,
                                  boolIdentifyTransients = TRUE,scaNProc = 20)

saveRDS(object=objectImpulseDE2,file=paste(pathSave,'DEacrossStages_WT_noyem_batchrep.rds',sep=''))
write.table(PHENOTYPES_X,file=paste(pathSave,'DEacrossStages_phenotypesOrder_WT_noyem_batchrep.tsv',sep=''),sep='\t',row.names = FALSE)
# Out:
# ImpulseDE2 for count data, v1.10.0
#
# # Process input
# Processing Details:
# ImpulseDE2 runs in case-only mode.
# Found time points: 1,2,3,4,5,6,7,8,9
# Case: Found the samples at time point 1: FDpool01_TCGCAGG_Hr00_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_TCGCAGG_Hr00_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_00h_9_S86_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_04h_10_S87_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_00h_9_S58_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_04h_10_S59_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr00_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr06_7_CTCGATG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr00_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr06_7_CTCGATG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_AX4_bio2_hr00_1_13_ACTATCA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_MybBGFP_bio1_hr00_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_MybBGFP_bio1_hr06_1_TCGCAGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr00_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 2: FDpool02_ACCAACT_Hr08_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_CCGGTAC_Hr09_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_08h_11_S88_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_08h_11_S60_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr06_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr08_2_CTCTGCA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_MybBGFP_bio1_hr06_1_TCGCAGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool28_MybBGFP_bio2_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 3: FDpool01_TTGAAGT_Hr10_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_GATCTCG_Hr11_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_ACCAACT_Hr08_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool02_CCGGTAC_Hr09_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool02_AACTCCG_Hr10_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_TTGAAGT_Hr11_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_08h_11_S88_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,Ax4_r2_08h_11_S60_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool26_AX4_bio2_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_1,pool27_AX4_bio1_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool29_AX4_bio2_hr08_2_CTCTGCA_mappedGene_expressions_All_milestone_mRNA_gff_1,pool35_MybBGFP_bio1_hr08_2_CTCTGCA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_1
# Case: Found the samples at time point 4: FDpool01_CAATATG_Hr12_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_TTGGATC_Hr14_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_TTGAAGT_Hr11_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool02_ACTATCA_Hr12_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_12h_12_S89_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_12h_12_S61_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_MybBGFP_bio1_hr08_2_CTCTGCA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1,pool30_MybBGFP_bio1_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 5: FDpool01_TTGGATC_Hr14_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool01_CGACCTG_Hr16_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_TTGGATC_Hr14_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr12_3_CCTAGGT_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 6: FDpool01_TAATGCG_Hr18_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_CGACCTG_Hr16_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_16h_13_S90_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_16h_13_S62_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr16_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr16_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr12_3_CCTAGGT_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool29_AX4_bio2_hr16_4_GGATCAA_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr20_5_GCAAGAT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_MybBGFP_bio1_hr16_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_MybBGFP_bio1_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool28_MybBGFP_bio2_hr16_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 7: FDpool01_TAATGCG_Hr18_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool01_AGGTACC_Hr20_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_GAATCTC_Hr22_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_TAATGCG_Hr18_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_20h_14_S91_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_20h_14_S63_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool27_AX4_bio1_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr20_5_GCAAGAT_mappedGene_expressions_All_milestone_mRNA_gff_1,pool30_MybBGFP_bio1_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool30_MybBGFP_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool28_MybBGFP_bio2_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 8: FDpool01_GAATCTC_Hr22_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool01_CATGCTC_Hr24_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_GAATCTC_Hr20_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_CATGCTC_Hr22_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_ACGCAAC_Hr24_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_20h_14_S91_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,Ax4_r2_20h_14_S63_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,Ax4_r2_24h_15_S64_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_2,Pool26_AX4_bio2_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool27_AX4_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool29_AX4_bio2_hr20_5_GCAAGAT_mappedGene_expressions_All_milestone_mRNA_gff_2,Pool29_AX4_bio2_hr24_6_ATGGAGA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_MybBGFP_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool28_MybBGFP_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_2,Pool28_MybBGFP_bio2_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_1
# Case: Found the samples at time point 9: FDpool01_CATGCTC_Hr24_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool02_CATGCTC_Hr22_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool02_ACGCAAC_Hr24_mappedGene_expressions_All_milestone_mRNA_gff_1,Ax4_r1_24h_15_S92_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_24h_15_S64_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool26_AX4_bio2_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_1,pool27_AX4_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_2,Pool29_AX4_bio2_hr24_6_ATGGAGA_mappedGene_expressions_All_milestone_mRNA_gff_1,pool30_MybBGFP_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_2,Pool28_MybBGFP_bio2_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_2
# Found the following samples for confounder Batch and batch AX4_FD_r1: FDpool01_TCGCAGG_Hr00_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_TTGAAGT_Hr10_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_GATCTCG_Hr11_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_CAATATG_Hr12_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_TTGGATC_Hr14_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_TTGGATC_Hr14_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool01_CGACCTG_Hr16_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_TAATGCG_Hr18_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_TAATGCG_Hr18_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool01_AGGTACC_Hr20_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_GAATCTC_Hr22_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_GAATCTC_Hr22_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool01_CATGCTC_Hr24_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool01_CATGCTC_Hr24_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch AX4_FD_r2: FDpool02_TCGCAGG_Hr00_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_ACCAACT_Hr08_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_CCGGTAC_Hr09_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_ACCAACT_Hr08_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool02_CCGGTAC_Hr09_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool02_AACTCCG_Hr10_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_TTGAAGT_Hr11_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_TTGAAGT_Hr11_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool02_ACTATCA_Hr12_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_TTGGATC_Hr14_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_CGACCTG_Hr16_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_TAATGCG_Hr18_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_GAATCTC_Hr20_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_CATGCTC_Hr22_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_ACGCAAC_Hr24_mappedGene_expressions_All_milestone_mRNA_gff_0,FDpool02_CATGCTC_Hr22_mappedGene_expressions_All_milestone_mRNA_gff_1,FDpool02_ACGCAAC_Hr24_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch AX4_PE_r3: Ax4_r1_00h_9_S86_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_04h_10_S87_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_08h_11_S88_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_08h_11_S88_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,Ax4_r1_12h_12_S89_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_16h_13_S90_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_20h_14_S91_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r1_20h_14_S91_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,Ax4_r1_24h_15_S92_L002_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0
# Found the following samples for confounder Batch and batch AX4_PE_r4: Ax4_r2_00h_9_S58_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_04h_10_S59_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_08h_11_S60_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_08h_11_S60_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,Ax4_r2_12h_12_S61_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_16h_13_S62_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_20h_14_S63_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_20h_14_S63_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1,Ax4_r2_24h_15_S64_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_0,Ax4_r2_24h_15_S64_L003_R1_001_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch AX4_SE_r5: Pool26_AX4_bio2_hr00_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr06_7_CTCGATG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool26_AX4_bio2_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr16_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool26_AX4_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_2,Pool26_AX4_bio2_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool26_AX4_bio2_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch AX4_SE_r6: pool27_AX4_bio1_hr00_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr06_7_CTCGATG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_1,pool27_AX4_bio1_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr16_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool27_AX4_bio1_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool27_AX4_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_1,pool27_AX4_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_2
# Found the following samples for confounder Batch and batch AX4_SE_r7: Pool28_AX4_bio2_hr00_1_13_ACTATCA_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr06_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr08_2_CTCTGCA_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr08_2_CTCTGCA_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool29_AX4_bio2_hr12_3_CCTAGGT_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr12_3_CCTAGGT_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool29_AX4_bio2_hr16_4_GGATCAA_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr20_5_GCAAGAT_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr20_5_GCAAGAT_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool29_AX4_bio2_hr20_5_GCAAGAT_mappedGene_expressions_All_milestone_mRNA_gff_2,Pool29_AX4_bio2_hr24_6_ATGGAGA_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_AX4_bio2_hr24_6_ATGGAGA_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch MybBGFP_r1: pool30_MybBGFP_bio1_hr00_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_MybBGFP_bio1_hr06_1_TCGCAGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_MybBGFP_bio1_hr06_1_TCGCAGG_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1,pool35_MybBGFP_bio1_hr08_2_CTCTGCA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_0,pool35_MybBGFP_bio1_hr08_2_CTCTGCA_mate1_mappedGene_expressions_All_milestone_mRNA_gff_1,pool30_MybBGFP_bio1_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_MybBGFP_bio1_hr16_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_MybBGFP_bio1_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_MybBGFP_bio1_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_1,pool30_MybBGFP_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_MybBGFP_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_1,pool30_MybBGFP_bio1_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_2
# Found the following samples for confounder Batch and batch MybBGFP_r2: Pool28_MybBGFP_bio2_hr00_1_TCGCAGG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr08_8_GCTCGAA_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool28_MybBGFP_bio2_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr12_9_ACCAACT_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool28_MybBGFP_bio2_hr16_10_CCGGTAC_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool28_MybBGFP_bio2_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool28_MybBGFP_bio2_hr20_11_AACTCCG_mappedGene_expressions_All_milestone_mRNA_gff_2,Pool28_MybBGFP_bio2_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_1,Pool28_MybBGFP_bio2_hr24_12_TTGAAGT_mappedGene_expressions_All_milestone_mRNA_gff_2
# Input contained 12828 genes/regions.
# WARNING: 495 out of 12828 genes do not have obserserved non-zero counts and are excluded.
# Selected 12333 genes/regions for analysis.
# # Run DESeq2: Using dispersion factorscomputed by DESeq2.
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
# [1] "Corrected 42 DESEq2 dispersion estimates which to avoid variance overestimation and loss of discriminatory power for model selection."
# Consumed time: 1.16 min.
#
# # Compute size factors
#
# # Fitting null and alternative model to the genes
#
# Consumed time: 17.38 min.
#
# # Fitting sigmoid model to case condition
#
# Consumed time: 5.88 min.
#
# # Differentially expression analysis based on model fits
#
# Finished running ImpulseDE2.
#
# TOTAL consumed time: 24.49 min.

# %%
fdr=0.05
result<-objectImpulseDE2$dfImpulseDE2Results
result<-result[result$padj<=fdr & ! is.na(result$padj),]
result<-result[order(result$padj),]
write.table(result,file=paste(pathSave,'DEacrossStages_padj',fdr,'.tsv',sep='') ,sep='\t',row.names = FALSE)

# %% [markdown]
# ## Individual strains

# %%
unique(conditions$Strain)[17:length(unique(conditions$Strain))]
# Out:
# [1] acaA       acaAPkaCoe ac3PkaCoe  PkaCoe     pkaR
# 21 Levels: ac3PkaCoe acaA acaAPkaCoe amiB AX4 comH cudA dgcA ecmARm ... tgrC1

# %%
for (strain in unique(conditions$Strain)[17:length(unique(conditions$Strain))]){

  conditions_annotated=conditions[rowSums(conditions[, PHENOTYPES_ORDERED])>0 &conditions$Strain==strain, ]
  #Drop phenotypes not annoated in this strain
  phenotypes_count<-colSums(conditions_annotated[, PHENOTYPES_ORDERED])
  phenotypes_present<-names(phenotypes_count[phenotypes_count>0])
  if (length(phenotypes_present)>1){
      phenotypes_x=data.frame(Phenotype=phenotypes_present,X=c(1:length(phenotypes_present)))
      drop<-names(phenotypes_count[phenotypes_count==0])
      drop<-which(colnames(conditions_annotated) %in% drop)
      conditions_annotated=conditions_annotated[,-drop]
      X=data.frame(row.names=rownames(genes))
      Y=data.frame()
      for (row_idx in 1:dim(conditions_annotated)[1]){
        y=conditions_annotated[row_idx,]
        x=genes[,rownames(y)]
        repeated_sample=0
        for (phenotype in phenotypes_present){
          if (y[phenotype]==1){
            sample_name=paste(rownames(y),repeated_sample,sep='_')
            X[,sample_name]=x
            Y[sample_name,c('Sample','Condition','Batch','Time')]=c(sample_name,'case',y['Replicate'],phenotypes_x[phenotypes_x['Phenotype']==phenotype,'X'])
            repeated_sample=repeated_sample+1
          }
        }
      } 

      Y<-Y[order(Y$Time),]
      print(strain)
      print(dim(conditions_annotated))
      print(paste(dim(X)[1],dim(X)[2],sum(conditions_annotated[,phenotypes_present])))
      tryCatch({
          objectImpulseDE2 <- runImpulseDE2(matCountData = as.matrix(X), dfAnnotation = Y,boolCaseCtrl = FALSE,
                                        vecConfounders = c("Batch"), boolIdentifyTransients = TRUE,scaNProc = 20 )
          saveRDS(object=objectImpulseDE2,file=paste(pathSave,'strain/',strain,'_DEacrossStages.rds',sep=''))
          write.table(phenotypes_x,file=paste(pathSave,'strain/',strain,'_DEacrossStages_phenotypesOrder.tsv',sep=''),sep='\t',row.names = FALSE)

      }, error=function(cond) {
          print(paste('Error in strain ',strain,cond))
      }
      )

     }
}
# Out:
# [1] "acaA"
# [1] "acaA"
# [1] 12  7
# [1] "12828 13 13"
# ImpulseDE2 for count data, v1.10.0
#
# # Process input
# Processing Details:
# ImpulseDE2 runs in case-only mode.
# Found time points: 1,2
# Case: Found the samples at time point 1: pool30_acaA__bio1_hr00_13_ACTATCA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_acaA__bio1_hr06_19_GAATCTC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_acaA__bio1_hr08_20_CATGCTC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_acaA__bio1_hr12_21_ACGCAAC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_acaA__bio1_hr16_22_GCATTGG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_acaA__bio1_hr20_23_GATCTCG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_acaA__bio1_hr24_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_acaA__bio2_hr00_7_CTCGATG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_acaA__bio2_hr08_14_TTGGATC_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_acaA__bio2_hr16_16_TAATGCG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_acaA__bio2_hr20_17_AGGTACC_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_acaA__bio2_hr24_18_TGCGTCC_mappedGene_expressions_All_milestone_mRNA_gff_0
# Case: Found the samples at time point 2: pool30_acaA__bio1_hr08_20_CATGCTC_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch acaA_r1: pool30_acaA__bio1_hr00_13_ACTATCA_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_acaA__bio1_hr06_19_GAATCTC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_acaA__bio1_hr08_20_CATGCTC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_acaA__bio1_hr12_21_ACGCAAC_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_acaA__bio1_hr16_22_GCATTGG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_acaA__bio1_hr20_23_GATCTCG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_acaA__bio1_hr24_24_CAATATG_mappedGene_expressions_All_milestone_mRNA_gff_0,pool30_acaA__bio1_hr08_20_CATGCTC_mappedGene_expressions_All_milestone_mRNA_gff_1
# Found the following samples for confounder Batch and batch acaA_r2: Pool29_acaA__bio2_hr00_7_CTCGATG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_acaA__bio2_hr08_14_TTGGATC_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_acaA__bio2_hr16_16_TAATGCG_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_acaA__bio2_hr20_17_AGGTACC_mappedGene_expressions_All_milestone_mRNA_gff_0,Pool29_acaA__bio2_hr24_18_TGCGTCC_mappedGene_expressions_All_milestone_mRNA_gff_0
# Input contained 12828 genes/regions.
# WARNING: 943 out of 12828 genes do not have obserserved non-zero counts and are excluded.
# Selected 11885 genes/regions for analysis.
# # Run DESeq2: Using dispersion factorscomputed by DESeq2.
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# Consumed time: 0.05 min.
#
# # Compute size factors
#
# # Fitting null and alternative model to the genes
#
# Timing stopped at: 1.52 1.932 0.826
#
# Timing stopped at: 6.276 3.948 4.953
# [1] "Error in strain  acaA Error: BiocParallel errors\n  element index: 1, 2, 3, 4, 5, 6, ...\n  first error: wrong sign in 'by' argument\n"
# [1] "mybB"

# %%
fdr=0.05
result<-objectImpulseDE2$dfImpulseDE2Results
result<-result[result$padj<=fdr & ! is.na(result$padj),]
result<-result[order(result$padj),]

# %%
result<-result[order(result$padj),]

# %%
top<-rownames(result[result$isMonotonous,])[1:20]

# %%
nrow(result)
# Out:
# [1] 6910

# %%
length(rownames(result))
# Out:
# [1] 7428

# %%
colnames(parsed)
# Out:
#  [1] "impulse_padj"          "impulseTOsigmoid_padj" "sigmoid_padj"
#  [4] "Type"                  "Direction"             "Assignment"
#  [7] "no_agg"                "stream"                "lag"
# [10] "tag"                   "tip"                   "slug"
# [13] "mhat"                  "cul"                   "FB"
# [16] "yem"

# %%
parsed[order(parsed$impulse_padj),][1:100,]
# Out:
#              impulse_padj  impulseTOsigmoid_padj sigmoid_padj  Type
# DDB_G0269574  0.000000e+00 4.263958e-32           0.000000e+00 monotonous
# DDB_G0271850  0.000000e+00 1.063147e-37          3.507861e-307 monotonous
# DDB_G0272570  0.000000e+00 7.490363e-11           0.000000e+00 monotonous
# DDB_G0272835  0.000000e+00 9.372950e-07           0.000000e+00 monotonous
# DDB_G0273225  0.000000e+00 3.511376e-04           0.000000e+00 monotonous
# DDB_G0281091  0.000000e+00 1.003168e-08           0.000000e+00 monotonous
# DDB_G0281895  0.000000e+00 1.397528e-10           0.000000e+00 monotonous
# DDB_G0284677  0.000000e+00 6.709416e-08           0.000000e+00 monotonous
# DDB_G0286639  0.000000e+00 3.463591e-01           0.000000e+00 monotonous
# DDB_G0290695  0.000000e+00 2.145118e-03           0.000000e+00 monotonous
# DDB_G0293388  0.000000e+00 1.552003e-06           0.000000e+00 monotonous
# DDB_G0282995 3.588893e-320 8.564921e-14          5.544792e-309 monotonous
# DDB_G0288817 7.288456e-319 1.699912e-09          4.406983e-312 monotonous
# DDB_G0290023 1.559386e-310 1.040195e-10          1.242393e-302 monotonous
# DDB_G0292462 4.599286e-309 1.353822e-07          2.487658e-304 monotonous
# DDB_G0279983 1.991538e-307 2.221899e-07          6.433165e-303 monotonous
# DDB_G0290719 4.345903e-304 3.646671e-08          8.449387e-299 monotonous
# DDB_G0270980 5.593881e-304 1.917124e-01          9.878666e-306 monotonous
# DDB_G0272530 1.492983e-303 2.086620e-04          3.579063e-302 transient
# DDB_G0269442 5.246421e-303 4.170863e-68          3.185547e-236 monotonous
# DDB_G0291396 7.620692e-300 4.855183e-08          1.240819e-294 monotonous
# DDB_G0272468 5.637926e-298 1.783743e-05          1.984278e-295 transient
# DDB_G0268446 1.670811e-296 1.233125e-12          1.418412e-286 monotonous
# DDB_G0274433 2.989138e-294 2.618493e-10          1.071709e-286 monotonous
# DDB_G0278017 2.045561e-293 1.572319e-02          5.139861e-294 monotonous
# DDB_G0293286 6.556335e-293 2.675857e-06          1.809446e-289 transient
# DDB_G0272076 1.046218e-289 8.197725e-05          7.282915e-288 transient
# DDB_G0288331 5.026207e-289 5.648084e-03          4.000148e-289 monotonous
# DDB_G0282245 8.308298e-287 5.531201e-05          8.537164e-285 monotonous
# DDB_G0293262 3.791623e-285 1.166294e-03          1.494462e-284 monotonous
# ⋮            ⋮             ⋮                     ⋮             ⋮
# DDB_G0268784 1.267648e-236 3.609843e-07          3.179653e-232 monotonous
# DDB_G0287509 1.572290e-236 3.099937e-04          3.169315e-235 transient
# DDB_G0283283 2.272952e-236 5.499030e-04          2.550404e-235 monotonous
# DDB_G0282813 4.571772e-236 5.801798e-05          5.590271e-234 transient
# DDB_G0282193 8.170987e-236 9.868220e-07          7.337373e-232 monotonous
# DDB_G0275521 1.073614e-235 1.445099e-05          5.876607e-233 monotonous
# DDB_G0275145 3.225122e-233 2.840974e-11          1.389164e-224 monotonous
# DDB_G0274809 7.671180e-232 1.809888e-10          4.835915e-224 monotonous
# DDB_G0274385 1.549764e-231 3.036280e-03          2.709512e-231 monotonous
# DDB_G0286055 1.953038e-231 3.263797e-05          4.192848e-229 monotonous
# DDB_G0278355 2.693169e-231 2.759441e-02          4.597884e-232 monotonous
# DDB_G0292294 2.289051e-230 1.787059e-05          9.286451e-228 transient
# DDB_G0275687 6.868774e-230 1.037150e-03          3.850921e-229 monotonous
# DDB_G0286979 1.257047e-229 1.711611e-01          2.854308e-231 monotonous
# DDB_G0272220 2.728373e-229 1.893868e-27          4.849171e-204 monotonous
# DDB_G0275195 2.821026e-229 5.237637e-02          2.405758e-230 monotonous
# DDB_G0274309 5.669144e-228 5.197007e-05          7.521421e-226 transient
# DDB_G0285259 1.399019e-227 4.426289e-01          1.130227e-229 monotonous
# DDB_G0281361 2.269222e-227 6.830353e-03          1.690458e-227 monotonous
# DDB_G0270162 8.378932e-227 4.548773e-01          6.483173e-229 monotonous
# DDB_G0277883 9.283880e-227 2.444671e-08          3.913499e-221 monotonous
# DDB_G0268038 1.142628e-226 1.156931e-02          4.862499e-227 monotonous
# DDB_G0277723 1.275182e-226 1.015699e-41          8.185523e-187 monotonous
# DDB_G0267544 2.816695e-226 2.262069e-11          1.588153e-217 monotonous
# DDB_G0290531 2.917960e-226 9.721963e-06          2.476670e-223 monotonous
# DDB_G0288231 1.930655e-224 1.503575e-11          1.647380e-215 monotonous
# DDB_G0287549 2.437567e-224 6.570790e-09          3.934977e-218 monotonous
# DDB_G0267374 7.194193e-224 1.001327e-03          4.407989e-223 monotonous
# DDB_G0269530 4.537707e-223 3.406619e-17          2.413827e-208 monotonous
# DDB_G0282305 8.730621e-223 9.461098e-07          8.352119e-219 monotonous
#              Direction Assignment             no_agg stream lag  tag  tip  slug
# DDB_G0269574 up        impulse_manual_border  down   down   down down down down
# DDB_G0271850 up        impulse_manual_border  down   down   down down down down
# DDB_G0272570 up        impulse_manual_border  down   down   down down down down
# DDB_G0272835 up        impulse_manual_border  down   down   down down down down
# DDB_G0273225 up        impulse_manual_border  down   down   down down down down
# DDB_G0281091 up        impulse_manual_border  down   down   down down down down
# DDB_G0281895 up        impulse                down   down   down down up   up
# DDB_G0284677 down      impulse_manual_border  up     up     up   up   up   up
# DDB_G0286639 up        impulse_manual_border  down   down   down down down down
# DDB_G0290695 up        impulse_manual_border  down   down   down down down down
# DDB_G0293388 up        impulse_manual_border  down   down   down down down down
# DDB_G0282995 up        impulse_manual_border  down   down   down down down down
# DDB_G0288817 up        impulse_manual_border  down   down   down down down down
# DDB_G0290023 up        impulse_manual_border  down   down   down down down down
# DDB_G0292462 up        impulse_manual_border  down   down   down down down down
# DDB_G0279983 up        impulse                down   down   down down up   up
# DDB_G0290719 up        impulse                down   down   down up   up   up
# DDB_G0270980 up        impulse_manual_border  down   down   down down down down
# DDB_G0272530 up        impulse                down   down   down down up   up
# DDB_G0269442 up        impulse_manual_border  down   down   down down down down
# DDB_G0291396 up        impulse_manual_border  down   down   down down down down
# DDB_G0272468 up        impulse_manual_peak    down   down   down down down down
# DDB_G0268446 up        impulse_manual_border  down   down   down down down down
# DDB_G0274433 up        impulse_manual_border  down   down   down down down down
# DDB_G0278017 up        impulse                down   down   down down up   up
# DDB_G0293286 up        impulse                down   down   down down up   up
# DDB_G0272076 down      impulse_manual_border  up     up     up   up   down down
# DDB_G0288331 up        impulse                down   down   down down down down
# DDB_G0282245 up        impulse                down   down   down up   up   up
# DDB_G0293262 up        impulse_manual_border  down   down   down down down down
# ⋮            ⋮         ⋮                      ⋮      ⋮      ⋮    ⋮    ⋮    ⋮
# DDB_G0268784 up        impulse                down   down   down down up   up
# DDB_G0287509 down      impulse_manual_border  up     up     down down down down
# DDB_G0283283 down      impulse                up     up     up   down down down
# DDB_G0282813 down      impulse_manual_border  up     up     up   up   down down
# DDB_G0282193 up        impulse_manual_border  down   down   down down down down
# DDB_G0275521 up        impulse_manual_border  down   down   down down down down
# DDB_G0275145 up        impulse                down   down   down down down down
# DDB_G0274809 down      impulse                up     up     up   up   down down
# DDB_G0274385 up        impulse                down   down   down up   up   up
# DDB_G0286055 up        impulse                down   down   down down down down
# DDB_G0278355 down      impulse                up     up     up   down down down
# DDB_G0292294 down      impulse                up     up     up   down down down
# DDB_G0275687 up        impulse_manual_border  down   down   down down down down
# DDB_G0286979 up        impulse                down   down   down down down down
# DDB_G0272220 up        impulse_manual_border  down   down   down down down down
# DDB_G0275195 up        impulse                down   down   down up   up   up
# DDB_G0274309 up        impulse_manual_swapped down   down   down down up   up
# DDB_G0285259 up        impulse                down   down   down down down up
# DDB_G0281361 up        impulse                down   down   down down up   up
# DDB_G0270162 up        impulse                down   down   down down down up
# DDB_G0277883 up        impulse_manual_border  down   down   down down down down
# DDB_G0268038 down      impulse                up     up     down down down down
# DDB_G0277723 up        impulse_manual_border  down   down   down down down down
# DDB_G0267544 up        impulse                down   down   down up   up   up
# DDB_G0290531 up        impulse_manual_border  down   down   down down down down
# DDB_G0288231 up        impulse                down   down   down up   up   up
# DDB_G0287549 up        impulse_manual_border  down   down   down down down down
# DDB_G0267374 down      impulse                up     up     up   up   down down
# DDB_G0269530 up        impulse                down   down   down down down down
# DDB_G0282305 up        impulse                down   down   down down down down
#              mhat cul  FB   yem
# DDB_G0269574 down down down up
# DDB_G0271850 down down down up
# DDB_G0272570 down down down up
# DDB_G0272835 down down down up
# DDB_G0273225 down down down up
# DDB_G0281091 down down down up
# DDB_G0281895 up   up   up   up
# DDB_G0284677 up   up   up   down
# DDB_G0286639 down down down up
# DDB_G0290695 down down down up
# DDB_G0293388 down down down up
# DDB_G0282995 down down down up
# DDB_G0288817 down down down up
# DDB_G0290023 down down down up
# DDB_G0292462 down down down up
# DDB_G0279983 up   up   up   up
# DDB_G0290719 up   up   up   up
# DDB_G0270980 down down down up
# DDB_G0272530 up   up   up   down
# DDB_G0269442 down down down up
# DDB_G0291396 down down down up
# DDB_G0272468 up   up   down down
# DDB_G0268446 down down down up
# DDB_G0274433 down down down up
# DDB_G0278017 up   up   up   up
# DDB_G0293286 up   up   down down
# DDB_G0272076 down down down up
# DDB_G0288331 up   up   up   up
# DDB_G0282245 up   up   up   up
# DDB_G0293262 down down down up
# ⋮            ⋮    ⋮    ⋮    ⋮
# DDB_G0268784 up   up   up   up
# DDB_G0287509 down down down up
# DDB_G0283283 down down down down
# DDB_G0282813 down down down up
# DDB_G0282193 down down down up
# DDB_G0275521 down down down up
# DDB_G0275145 up   up   up   up
# DDB_G0274809 down down down down
# DDB_G0274385 up   up   up   up
# DDB_G0286055 up   up   up   up
# DDB_G0278355 down down down down
# DDB_G0292294 up   up   up   up
# DDB_G0275687 down down down up
# DDB_G0286979 down down up   up
# DDB_G0272220 down down down up
# DDB_G0275195 up   up   up   up
# DDB_G0274309 up   up   up   down
# DDB_G0285259 up   up   up   up
# DDB_G0281361 up   up   up   up
# DDB_G0270162 up   up   up   up
# DDB_G0277883 down down down up
# DDB_G0268038 down down down down
# DDB_G0277723 down down down up
# DDB_G0267544 up   up   up   up
# DDB_G0290531 down down down up
# DDB_G0288231 up   up   up   up
# DDB_G0287549 down down down up
# DDB_G0267374 down down down down
# DDB_G0269530 down down up   up
# DDB_G0282305 down down up   up

# %%
library(ggplot2)

# %%
gene_ids<-rownames(parsed[parsed$Assignment=='impulse' & parsed$Type=='transient',])[1:200]

# %%
#gene_ids=c('DDB_G0289979')
lsgplotsGenes <- plotGenes(
vecGeneIDs = gene_ids,
scaNTopIDs = NULL,
objectImpulseDE2 = objectImpulseDE2,
boolCaseCtrl = FALSE,
dirOut = NULL,
strFileName = NULL,
vecRefPval = NULL,
strNameRefMethod = NULL)
# Out:
# [1] "Setting boolSimplePlot=TRUE as no batch structure was found."

# %%
i=100
print(parsed[gene_ids[i],])
print(lsgplotsGenes[[i]])
print(gene_ids[i])
print(objectImpulseDE2$dfImpulseDE2Results[gene_ids[i],])

print(objectImpulseDE2@lsModelFits$case[gene_ids[i]][[1]]$lsImpulseFit$vecImpulseParam)
print(objectImpulseDE2@lsModelFits$case[gene_ids[i]][[1]]$lsSigmoidFit$vecSigmoidParam)
# Out:
#              impulse_padj impulseTOsigmoid_padj sigmoid_padj      Type
# DDB_G0268794 1.859901e-35          1.904966e-25  3.31135e-11 transient
#              Direction Assignment no_agg stream  lag  tag  tip slug mhat  cul
# DDB_G0268794        up    impulse   down     up down down down down down down
#                FB
# DDB_G0268794 down
# [1] "DDB_G0268794"
#                      Gene            p         padj loglik_full loglik_red
# DDB_G0268794 DDB_G0268794 8.731216e-36 1.859901e-35   -3387.722  -3474.882
#              df_full df_red     mean converge_impulse converge_const
# DDB_G0268794       7      2 201.5056                0              0
#              converge_sigmoid impulseTOsigmoid_p impulseTOsigmoid_padj
# DDB_G0268794                0       3.518367e-27          1.904966e-25
#              sigmoidTOconst_p sigmoidTOconst_padj isTransient isMonotonous
# DDB_G0268794     2.346902e-11         3.31135e-11        TRUE        FALSE
#              allZero
# DDB_G0268794   FALSE
#       beta         h0         h1         h2         t1         t2
#   1.384927   5.907700 436.838087 169.604070   1.247633   2.734576
#       beta         h0         h1          t
#  -3.775760 170.525399 215.463119   4.527996
# plot without title

# %% [markdown]
# ## Parse the result - find stages where gene is up(down)regulated

# %%
#For deseq object of all  strains combined
objectImpulseDE2<-readRDS(paste(pathSave,'DEacrossStages_WT_noyem_batchrep.rds',sep=''))

phenotypes_x<-read.table(paste(pathSave,'DEacrossStages_phenotypesOrder_WT_noyem_batchrep.tsv',sep=''),header=TRUE)
max_x<-min(phenotypes_x$X)
max_x<-max(phenotypes_x$X)
times_all=sort(phenotypes_x$X)

# Default is 0.001, but they used 0.01 in the paper; 0.001 seems to neglect many probably DE genes
# objectImpulseDE2<-updateDEAnalysis(objectImpulseDE2,scaQThresTransients=0.01)

model<-objectImpulseDE2@lsModelFits$case
result<-objectImpulseDE2$dfImpulseDE2Results
result<-result[! is.na(result$padj),]
result<-result[result$isMonotonous |result$isTransient,]
if (nrow(result[result$isMonotonous & result$isTransient,])>0) stop('Asigned both transient and monotonous')
annotation<-objectImpulseDE2@dfAnnotationProc
print(nrow(result))

parsed<-data.frame()

for(gene in rownames(result)){
    parsed[gene,c('impulse_padj','impulseTOsigmoid_padj','sigmoid_padj')]=result[gene,
                                c('padj','impulseTOsigmoid_padj','sigmoidTOconst_padj')]
    type=''
    # Was gene assigned to be transient or monotonous
    if (result[gene,'isTransient']) type='transient'
    if (result[gene,'isMonotonous']) type='monotonous'
    parsed[gene,'Type']=type
    
    if (type=='monotonous'){
        
        # If monotonous it can be sigmoid or impulse monotonous - if only sigmoid was used the split could be 
        # wrong (in the middle of relatively stable stage) - thus use as threshold the t from impulse 
        # that is closest to the sigmoid t
        if(result[gene,'padj']>result[gene,'sigmoidTOconst_padj']){
            model_data=as.list(model[gene][[1]]$lsSigmoidFit$vecSigmoidParam)
            t=model_data$t
        }else{
            model_data=as.list(model[gene][[1]]$lsSigmoidFit$vecSigmoidParam)
            model_impulse=as.list(model[gene][[1]]$lsImpulseFit$vecImpulseParam)
            diff_t1=abs(model_data$t-model_impulse$t1)
            diff_t2=abs(model_data$t-model_impulse$t2)
            if(diff_t1<diff_t2){t=model_impulse$t1
            } else {t=model_impulse$t2}
        }
        
        # If t in between stages assign impulse, else (t larger/smaller than last/first stage) assume 
        # that only the last/first stage is DE - assign impulse_manual as this is not directly based on the model
        assignment=NA
        if (min_x<t & t<max_x){
            assignment='impulse'
        #Assumes that stages/times are integers
        } else if (min_x>=t ){
            t=min_x+0.1
            assignment='impulse_manual_border'
        } else if (max_x <= t ){
            t=max_x-0.1
            assignment='impulse_manual_border'
        }
        parsed[gene,'Assignment']=assignment

        # Does gene change up or down through time and which stages are on each side of the tipping point
        phenotypes1=as.vector(phenotypes_x[phenotypes_x$X<t,'Phenotype'])
        phenotypes2=as.vector(phenotypes_x[phenotypes_x$X>t,'Phenotype'])
        if (model_data$h1>model_data$h0) {
            parsed[gene,'Direction']='up'
            parsed[gene,phenotypes1]='down'
            parsed[gene,phenotypes2]='up'
        }else{
            parsed[gene,'Direction']='down'
            parsed[gene,phenotypes1]='up'
            parsed[gene,phenotypes2]='down'
        }
        
    } else if (type=='transient') {
        model_data=as.list(model[gene][[1]]$lsImpulseFit$vecImpulseParam)
        t1=model_data$t1
        t2=model_data$t2
        proceed=TRUE
        # t1,t2 can be between different stages - assign phenotypes to up/down based on t1,t2 and 
        # assignments is based directly on the models ('impulse'). If t1/t2 is larger or smaller 
        # than first/last stage assume that only last/first stage is in this state (assignment is 
        # impulse_manual_border). If t1,t2 are between the same two stages assume there is a peak/vallley - 
        # set t1,t2 so that stages closest to original t1,t2 now represent peak/valley
        # (assignment is impulse_manual_peak). If t1>t2 (except if it was corrected before e.g.
        # in  impulse_manual_peak, which corrects t1,t2) switch t1 and t2 - impulse_manual_swap. 
        # If impulse_manual_peak or impulse_manual_swap find h0,1,2 as averages in stages between 
        # times with data defined by impulse model. Changed h is different from the impulse h - 
        # used only for deteriming up/down expression. This does not account for batches.
        assignment=NA
        #Assumes that stages/times are integers
        if (min_x<t1 & t1<max_x & min_x<t2 & t2<max_x & floor(t1)!=floor(t2)){
            assignment='impulse'
        }
        # Check this before reasigning border so that reasigned border does not cause this situation
        if(floor(t1)==floor(t2)){
            assignment='impulse_manual_peak'
            #Expression predicted by ImpulseDE2
            values=model[gene][[1]]$lsImpulseFit$vecImpulseValue
            values=merge(values,annotation,by="row.names",all.x=TRUE)
            
            #Find single peak/valley near the t1,t2
            ##Mean of each stage group
            #values_mean=aggregate(values$x, by=list(values$Time), FUN=mean)
            ##Peak or valley
            #peak_max=values_mean[values_mean$x==max(values_mean$x),]$Group.1 #Peak (max expression)
            #peak_min=values_mean[values_mean$x==min(values_mean$x),]$Group.1 #Valley (min expression)
            ##Peak (valley) identified in wrong place or correct - is it neighboursing to the wrongly assigned t?
            #if (abs(peak_max-t1)<=1) {
            #    peak=peak_max
            #}else if (abs(peak_min-t1)<=1){
            #    peak=peak_min
            #}else{
            #    print(paste('Peak identified at wrong place for gene ',gene))
            #    proceed=FALSE
            #    assignment=NA
            #}
            #t1=peak-0.1
            #t2=peak+0.1
            
            #Assign t1,t2 so that the two points closest to t1,t2 represent peak/valley, except if
            # t1,t2 thus get below/above min/max times - assign single point as peak/valley
            t1=max(times_all[times_all<t1])-0.1
            t2=min(times_all[times_all>t2])+0.1
            if(min_x>=t1 & t1<max_x){
                t1=min_x+0.1
            }
            if(min_x<t2 & t2>=max_x){
                t2=max_x-0.1
            }

            
            model_data$h0<-mean(values[values$Time<t1,'x'])
            model_data$h1<-mean(values[values$Time>t1 & values$Time<t2,'x'])
            model_data$h2<-mean(values[values$Time>t2,'x'])

        }
        if (t2<t1){
            # Swap t1,t2 - can also reasign border
            t_temp=t1
            t1=t2
            t2=t_temp
            #Reasign border if needed
            if(min_x>=t1 & t1<max_x){
                t1=min_x+0.1
            }
            if(min_x<t2 & t2>=max_x){
                t2=max_x-0.1
            }
            assignment='impulse_manual_swapped'
            # Expression predicted by ImpulseDE2
            values=model[gene][[1]]$lsImpulseFit$vecImpulseValue
            values=merge(values,annotation,by="row.names",all.x=TRUE)
            model_data$h0<-mean(values[values$Time<t1,'x'])
            model_data$h1<-mean(values[values$Time>t1 & values$Time<t2,'x'])
            model_data$h2<-mean(values[values$Time>t2,'x'])

        }
        #This may cause t1&t2 to be equal
        if(min_x>=t1 & t1<max_x){
            if (is.na(assignment)) assignment='impulse_manual_border'
            t1=min_x+0.1
        }
        if(min_x<t2 & t2>=max_x){
            if (is.na(assignment)) assignment='impulse_manual_border'
            t2=max_x-0.1
        }
        # Check again if t1==t2 - the case where this was so originally was already dealt with
        # Treat this as monotonous
        if (floor(t1)==floor(t2)){
            parsed[gene,'Type']='transient_monotonous'
            t2=NA
            # Expression predicted by ImpulseDE2
            values=model[gene][[1]]$lsImpulseFit$vecImpulseValue
            values=merge(values,annotation,by="row.names",all.x=TRUE)
            model_data$h0<-mean(values[values$Time<t1,'x'])
            model_data$h1<-mean(values[values$Time>t1,'x'])
            model_data$h2<-NA
        }
        
        parsed[gene,'Assignment']=assignment
        
        if(proceed & !is.na(assignment)){
        # Where in fact transient after parsing t1,t2
        if(is.na(t2)){
            phenotypes1=as.vector(phenotypes_x[phenotypes_x$X<t1,'Phenotype'])
            phenotypes2=as.vector(phenotypes_x[phenotypes_x$X>t1,'Phenotype'])

            if (model_data$h1>model_data$h0) {
                parsed[gene,'Direction']='up'
                parsed[gene,phenotypes1]='down'
                parsed[gene,phenotypes2]='up'
            }else{
                parsed[gene,'Direction']='down'
                parsed[gene,phenotypes1]='up'
                parsed[gene,phenotypes2]='down'
            }
        # Actual impulse
        } else{
            phenotypes1=as.vector(phenotypes_x[phenotypes_x$X<t1 |phenotypes_x$X>t2,'Phenotype'])
            phenotypes2=as.vector(phenotypes_x[phenotypes_x$X>t1 & phenotypes_x$X<t2,'Phenotype'])
            if(model_data$h0<model_data$h1 & model_data$h2<model_data$h1){
                parsed[gene,'Direction']='up'
                parsed[gene,phenotypes1]='down'
                parsed[gene,phenotypes2]='up'

            } else if (model_data$h0>model_data$h1 & model_data$h2>model_data$h1) {
                parsed[gene,'Direction']='down'
                parsed[gene,phenotypes1]='up'
                parsed[gene,phenotypes2]='down'

            } else{
               stop(paste('Problem in stage annotation for',gene)) 
            }
            
        }
        }
    }

}
parsed=parsed[,c(c('impulse_padj','impulseTOsigmoid_padj','sigmoid_padj','Type','Direction','Assignment')
                 ,as.vector(phenotypes_x$Phenotype))]
parsed2<-parsed[! is.na(parsed$Assignment),]
print(paste(sum(parsed2$Assignment=='impulse'),sum(parsed2$Assignment=='impulse_manual_border'),
            sum(parsed2$Assignment=='impulse_manual_peak'),sum(parsed2$Assignment=='impulse_manual_swapped')))

write.table(parsed,paste(pathSave,'DEacrossStages_summary_WT_noyem_batchrep.tsv',sep=''),sep='\t',col.names = NA)
# Out:
# [1] 10485
# [1] "7236 2869 327 53"

# %%
paste(pathSave,'DEacrossStages_summary_noyem_batchrep.tsv',sep='')
# Out:
# [1] "/home/khrovatin/timeTrajectoriesNet/data/stages/DE_across_stages/DEacrossStages_summary_noyem_batchrep.tsv"

# %%
#TODO!!!!!!!!!!!!!!!!!!!!!!!!
#Update with the all strains above!!!!



#For deseq objects of individual strains
strain='AX4' 
#for (strain in unique(conditions$Strain)){
if (file.exists(paste(pathSave,'strain/',strain,'_DEacrossStages.rds',sep=''))){

objectImpulseDE2<-readRDS(paste(pathSave,'strain/',strain,'_DEacrossStages.rds',sep=''))
phenotypes_x<-read.table(paste(pathSave,'strain/',strain,'_DEacrossStages_phenotypesOrder.tsv',sep=''),header=TRUE)
min_x<-min(phenotypes_x$X)
max_x<-max(phenotypes_x$X)
times_all=sort(phenotypes_x$X)

#Default is 0.001, but they used 0.01 in the paper, but 0.001 seems to neglect many probably DE genes
objectImpulseDE2<-updateDEAnalysis(objectImpulseDE2,scaQThresTransients=0.01)

model<-objectImpulseDE2@lsModelFits$case
result<-objectImpulseDE2$dfImpulseDE2Results
result<-result[! is.na(result$padj),]
result<-result[result$isMonotonous |result$isTransient,]
if (nrow(result[result$isMonotonous & result$isTransient,])>0) stop('Asigned both transient and monotonous')
annotation<-objectImpulseDE2@dfAnnotationProc
print(paste(strain,nrow(result)))

parsed<-data.frame()

for(gene in rownames(result)){
    parsed[gene,c('impulse_padj','impulseTOsigmoid_padj','sigmoid_padj')]=result[gene,
                                c('padj','impulseTOsigmoid_padj','sigmoidTOconst_padj')]
    type=''
    # Was gene assigned to be transient or monotonous
    if (result[gene,'isTransient']) type='transient'
    if (result[gene,'isMonotonous']) type='monotonous'
    parsed[gene,'Type']=type
    
    if (type=='monotonous'){
        
        # If monotonous it can be sigmoid or impulse monotonous - if only sigmoid was used the split could be 
        # wrong (in the middle of relatively stable stage) - thus use as threshold the t from impulse 
        # that is closest to the sigmoid t
        if(result[gene,'padj']>result[gene,'sigmoidTOconst_padj']){
            model_data=as.list(model[gene][[1]]$lsSigmoidFit$vecSigmoidParam)
            t=model_data$t
        }else{
            model_data=as.list(model[gene][[1]]$lsSigmoidFit$vecSigmoidParam)
            model_impulse=as.list(model[gene][[1]]$lsImpulseFit$vecImpulseParam)
            diff_t1=abs(model_data$t-model_impulse$t1)
            diff_t2=abs(model_data$t-model_impulse$t2)
            if(diff_t1<diff_t2){t=model_impulse$t1
            } else {t=model_impulse$t2}
        }
        
        # If t in between stages assign impulse, else (t larger/smaller than last/first stage) assume 
        # that only the last/first stage is DE - assign impulse_manual as this is not directly based on the model
        assignment=NA
        if (min_x<t & t<max_x){
            assignment='impulse'
        #Assumes that stages/times are integers
        } else if (min_x>=t ){
            t=min_x+0.1
            assignment='impulse_manual_border'
        } else if (max_x <= t ){
            t=max_x-0.1
            assignment='impulse_manual_border'
        }
        parsed[gene,'Assignment']=assignment

        # Does gene change up or down through time and which stages are on each side of the tipping point
        phenotypes1=as.vector(phenotypes_x[phenotypes_x$X<t,'Phenotype'])
        phenotypes2=as.vector(phenotypes_x[phenotypes_x$X>t,'Phenotype'])
        if (model_data$h1>model_data$h0) {
            parsed[gene,'Direction']='up'
            parsed[gene,phenotypes1]='down'
            parsed[gene,phenotypes2]='up'
        }else{
            parsed[gene,'Direction']='down'
            parsed[gene,phenotypes1]='up'
            parsed[gene,phenotypes2]='down'
        }
        
    } else if (type=='transient') {
        model_data=as.list(model[gene][[1]]$lsImpulseFit$vecImpulseParam)
        t1=model_data$t1
        t2=model_data$t2
        proceed=TRUE
        # t1,t2 can be between different stages - assign phenotypes to up/down based on t1,t2 and 
        # assignments is based directly on the models ('impulse'). If t1/t2 is larger or smaller 
        # than first/last stage assume that only last/first stage is in this state (assignment is 
        # impulse_manual_border). If t1,t2 are between the same two stages assume there is a peak/vallley - 
        # set t1,t2 so that stages closest to original t1,t2 now represent peak/valley
        # (assignment is impulse_manual_peak). If t1>t2 (except if it was corrected before e.g.
        # in  impulse_manual_peak, which corrects t1,t2) switch t1 and t2 - impulse_manual_swap. 
        # If impulse_manual_peak or impulse_manual_swap find h0,1,2 as averages in stages between 
        # times with data defined by impulse model. Changed h is different from the impulse h - 
        # used only for deteriming up/down expression. This does not account for batches.
        assignment=NA
        #Assumes that stages/times are integers
        if (min_x<t1 & t1<max_x & min_x<t2 & t2<max_x & floor(t1)!=floor(t2)){
            assignment='impulse'
        }
        # Check this before reasigning border so that reasigned border does not cause this situation
        if(floor(t1)==floor(t2)){
            assignment='impulse_manual_peak'
            #Expression predicted by ImpulseDE2
            values=model[gene][[1]]$lsImpulseFit$vecImpulseValue
            values=merge(values,annotation,by="row.names",all.x=TRUE)
            
            #Find single peak/valley near the t1,t2
            ##Mean of each stage group
            #values_mean=aggregate(values$x, by=list(values$Time), FUN=mean)
            ##Peak or valley
            #peak_max=values_mean[values_mean$x==max(values_mean$x),]$Group.1 #Peak (max expression)
            #peak_min=values_mean[values_mean$x==min(values_mean$x),]$Group.1 #Valley (min expression)
            ##Peak (valley) identified in wrong place or correct - is it neighboursing to the wrongly assigned t?
            #if (abs(peak_max-t1)<=1) {
            #    peak=peak_max
            #}else if (abs(peak_min-t1)<=1){
            #    peak=peak_min
            #}else{
            #    print(paste('Peak identified at wrong place for gene ',gene))
            #    proceed=FALSE
            #    assignment=NA
            #}
            #t1=peak-0.1
            #t2=peak+0.1
            
            #Assign t1,t2 so that the two points closest to t1,t2 represent peak/valley, except if
            # t1,t2 thus get below/above min/max times - assign single point as peak/valley
            t1=max(times_all[times_all<t1])-0.1
            t2=min(times_all[times_all>t2])+0.1
            if(min_x>=t1 & t1<max_x){
                t1=min_x+0.1
            }
            if(min_x<t2 & t2>=max_x){
                t2=max_x-0.1
            }

            
            model_data$h0<-mean(values[values$Time<t1,'x'])
            model_data$h1<-mean(values[values$Time>t1 & values$Time<t2,'x'])
            model_data$h2<-mean(values[values$Time>t2,'x'])

        }
        if (t2<t1){
            # Swap t1,t2 - can also reasign border
            t_temp=t1
            t1=t2
            t2=t_temp
            #Reasign border if needed
            if(min_x>=t1 & t1<max_x){
                t1=min_x+0.1
            }
            if(min_x<t2 & t2>=max_x){
                t2=max_x-0.1
            }
            assignment='impulse_manual_swapped'
            # Expression predicted by ImpulseDE2
            values=model[gene][[1]]$lsImpulseFit$vecImpulseValue
            values=merge(values,annotation,by="row.names",all.x=TRUE)
            model_data$h0<-mean(values[values$Time<t1,'x'])
            model_data$h1<-mean(values[values$Time>t1 & values$Time<t2,'x'])
            model_data$h2<-mean(values[values$Time>t2,'x'])

        }
        #This may cause t1&t2 to be equal
        if(min_x>=t1 & t1<max_x){
            if (is.na(assignment)) assignment='impulse_manual_border'
            t1=min_x+0.1
        }
        if(min_x<t2 & t2>=max_x){
            if (is.na(assignment)) assignment='impulse_manual_border'
            t2=max_x-0.1
        }
        # Check again if t1==t2 - the case where this was so originally was already dealt with
        # Treat this as monotonous
        if (floor(t1)==floor(t2)){
            parsed[gene,'Type']='transient_monotonous'
            t2=NA
            # Expression predicted by ImpulseDE2
            values=model[gene][[1]]$lsImpulseFit$vecImpulseValue
            values=merge(values,annotation,by="row.names",all.x=TRUE)
            model_data$h0<-mean(values[values$Time<t1,'x'])
            model_data$h1<-mean(values[values$Time>t1,'x'])
            model_data$h2<-NA
        }
        
        parsed[gene,'Assignment']=assignment
        
        if(proceed & !is.na(assignment)){
        # Where in fact transient after parsing t1,t2
        if(is.na(t2)){
            phenotypes1=as.vector(phenotypes_x[phenotypes_x$X<t1,'Phenotype'])
            phenotypes2=as.vector(phenotypes_x[phenotypes_x$X>t1,'Phenotype'])

            if (model_data$h1>model_data$h0) {
                parsed[gene,'Direction']='up'
                parsed[gene,phenotypes1]='down'
                parsed[gene,phenotypes2]='up'
            }else{
                parsed[gene,'Direction']='down'
                parsed[gene,phenotypes1]='up'
                parsed[gene,phenotypes2]='down'
            }
        # Actual impulse
        } else{
            phenotypes1=as.vector(phenotypes_x[phenotypes_x$X<t1 |phenotypes_x$X>t2,'Phenotype'])
            phenotypes2=as.vector(phenotypes_x[phenotypes_x$X>t1 & phenotypes_x$X<t2,'Phenotype'])
            if(model_data$h0<model_data$h1 & model_data$h2<model_data$h1){
                parsed[gene,'Direction']='up'
                parsed[gene,phenotypes1]='down'
                parsed[gene,phenotypes2]='up'

            } else if (model_data$h0>model_data$h1 & model_data$h2>model_data$h1) {
                parsed[gene,'Direction']='down'
                parsed[gene,phenotypes1]='up'
                parsed[gene,phenotypes2]='down'

            } else{
               stop(paste('Problem in stage annotation for',gene)) 
            }
            
        }
        }
    }

}
parsed=parsed[,c(c('impulse_padj','impulseTOsigmoid_padj','sigmoid_padj','Type','Direction','Assignment')
                 ,as.vector(phenotypes_x$Phenotype))]
parsed2<-parsed[! is.na(parsed$Assignment),]
print(paste(sum(parsed2$Assignment=='impulse'),sum(parsed2$Assignment=='impulse_manual_border'),
            sum(parsed2$Assignment=='impulse_manual_peak'),sum(parsed2$Assignment=='impulse_manual_swapped')))
#write.table(parsed,paste(pathSave,'strain/',strain,'_DEacrossStages_summary.tsv',sep=''),sep='\t',col.names = NA)
}
#}
# Out:
# [1] "AX4 10708"
# [1] "7189 3010 446 63"

# %%
gene_ids<-rownames(parsed[parsed$Assignment=='impulse' & parsed$Type=='transient',])

# %%
parsed['DDB_G0269770',]
# Out:
#              impulse_padj impulseTOsigmoid_padj sigmoid_padj Type
# DDB_G0269770 1.533452e-05 5.549121e-06          0.5627776    transient
#              Direction Assignment          no_agg stream lag  tag  tip  slug
# DDB_G0269770 up        impulse_manual_peak down   up     down down down down
#              mhat cul  FB
# DDB_G0269770 down down down

# %% [markdown]
# ## Genes related with development in AX4

# %%
objectImpulseDE2<-readRDS(paste(pathSave,'strain/','AX4','_DEacrossStages.rds',sep=''))

# %%
result<-objectImpulseDE2$dfImpulseDE2Results
result<-result[! is.na(result$padj),]
result<-result[order(result$padj),]

# %% [markdown]
# Select 2000 genes with lowest Impulse padj in AX4 to use in dimensionality reduction techniques.

# %%
top<-data.frame(Gene=rownames(result[1:2000,]))

# %%
write.table(top,paste(pathSave,'strain/AX4_bestImpulse2000.tsv',sep=''),sep='\t',row.names = FALSE)

# %% [markdown]
# Select all variable (impulse, sigmoid) genes.

# %%
top<-data.frame(Gene=rownames(result[result$isMonotonous |result$isTransient,]))
print(dim(top))
# Out:
# [1] 10121     1

# %%
write.table(top,paste(pathSave,'strain/AX4_variableImpulseSigmoid.tsv',sep=''),sep='\t',row.names = FALSE)
