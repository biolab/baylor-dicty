# %% [markdown]
# # Enrichment for milestone genes

# %%
import os
import sys
from importlib import reload

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.insert(0,module_path)

import pandas as pd
from IPython.display import display
pd.set_option('max_colwidth', 70)
pd.set_option('display.max_rows', 500)
import string
import numpy as np

from orangecontrib.bioinformatics.geneset.__init__ import list_all

import jupyter_functions as jf
reload(jf)
import jupyter_functions as jf
from networks.functionsDENet import loadPickle, savePickle
import enrichment_library as enr
reload(enr)
import enrichment_library as enr
from stages_DE.stages_library import PHENOTYPES

# %%
#Path for expression data (mergedGenes_RPKUM.tsv)
dataPath='/home/karin/Documents/timeTrajectories/data/RPKUM/combined/'
path_de='/home/karin/Documents/timeTrajectories/data/deTime/stage_vs_other/'
path_impulse='/home/karin/Documents/timeTrajectories/data/stages/DE_across_stages/'

# %% [markdown]
# ## Gene sets

# %% [markdown]
# Uses gene sets that do not have less than 5 or more than 500 genes. Use all ontologies.

# %%
# Get all gene sets
gene_sets=list(list_all(organism='44689'))
GENE_SETS_ONTOLOGY=enr.get_gene_sets(gene_set_names=gene_sets, go_slims=True,set_sizes=(5,500))

# %%
# For conversion of gene names to EID
genes = pd.read_csv(dataPath + 'mergedGenes_RPKUM.tsv', sep='\t', index_col=0)
all_gene_names= genes[(genes != 0).any(axis=1)].index
NAME_EID=enr.name_genes_entrez(gene_names=all_gene_names, key_entrez=False)
ALL_GENE_NAMES_EID=enr.convert_EID(genes=all_gene_names, name_EID=NAME_EID)

# %%
def group_diff_enrichment(query_names,group:str,padj:float=0.25,min_overlap:int=None,
                          use_annotated_genes:bool=False):
    #Displays only gene sets that have overlap with query greater or equal to min_overlap 
    #For p value and padj calculation uses alll that have overlap >=1 } from gene_set_enrichment
    """
    :param use_annotated_genes: if True use for reference and query  only genes that have at 
    least one gene set annotation
    """
    query_EID=enr.convert_EID(genes=query_names, name_EID=NAME_EID)
    print('***  '+group+' selected:',len(query_names),'with EID:',len(query_EID))
    
    reference_gene_eids=ALL_GENE_NAMES_EID.copy()
    query_eids=query_EID.copy()
    
    if use_annotated_genes:
        gene_sets_genes=set()
        for gene_set_name, gene_sets in GENE_SETS_ONTOLOGY.items():
            for gene_set in gene_sets:
                gene_sets_genes.update(gene_set.genes)
        reference_gene_eids=set(reference_gene_eids) & gene_sets_genes
        query_eids=set(query_eids) & gene_sets_genes
        
        query_annotated_reatio='NA'
        if len(query_EID)>0:
            query_annotated_reatio=round(len(query_eids)/len(query_EID),2)
        print('Ratio of genes annotated with a gene set in reference',
              round(len(reference_gene_eids)/len(ALL_GENE_NAMES_EID),2),
             'and query',query_annotated_reatio)
    
    query_in_enriched=set()
    result=None
    if len(query_eids) > 0:
        enrichment=enr.gene_set_enrichment(query_eids, reference_EID=reference_gene_eids, 
                                                padj_threshold=padj,min_overlap=min_overlap,
                                                gene_sets_ontology=GENE_SETS_ONTOLOGY)
        if len(enrichment)>0:
            enrichment_display=list()
            enrichment= sorted(enrichment, key=lambda data: data.padj)
            for enriched in enrichment:
                query_in_enriched.update(enriched.gene_set.genes & query_eids)
                enrichment_display.append({'Gene set':enriched.gene_set.name,'Ontology':enriched.ontology,
                                           'FDR':"{:.2e}".format(enriched.padj),'N in query':enriched.in_query})
            result=pd.DataFrame(enrichment_display)
    print('Enrichment at FDR: '+str(padj)+' and min query - gene set overlap',str(min_overlap))
    print('N query genes in displayed gene sets:',len(query_in_enriched),'out of', len(query_eids),
          'query genes used for enrichment calculation.')
    display(result)
    print('\n')
    return result

# %% [markdown]
# ## Enrichment report

# %% [markdown]
# ### DESeq2
# Only positive log2 fold changes (lFC) are used to select only overexpressed genes.

# %% [markdown]
# #### DESeq2 all strains

# %% [markdown]
# ##### DESeq2 all strains lFC >= 2 and padj <= 0.01

# %%
milestones=pd.read_table(path_de+'nobatchrep_combined.tsv',index_col=0,sep='\t')
for stage in [phenotype for phenotype in PHENOTYPES if phenotype in list(milestones['Stage'].unique())]:
    query_names=list(milestones.query('log2FoldChange>=2 & padj <= 0.01 & Stage=="'+stage+'"').index)
    enriched=group_diff_enrichment(query_names=query_names,group=stage,min_overlap=2,use_annotated_genes=True)
# Out:
# ***  no_agg selected: 216 with EID: 215
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.38
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 64 out of 82 query genes used for enrichment calculation.
#                                  Gene set                  Ontology       FDR  \
# 0                    extracellular region  (GO, cellular_component)  4.33e-04
# 1                 oxidoreductase activity  (GO, molecular_function)  1.22e-03
# 2                      hydrolase activity  (GO, molecular_function)  1.38e-02
# 3                     homeostatic process  (GO, biological_process)  1.96e-02
# 4                                lysosome  (GO, cellular_component)  6.83e-02
# 5                      response to stress  (GO, biological_process)  6.83e-02
# 6            cytoskeletal protein binding  (GO, molecular_function)  1.05e-01
# 7                     Lysine biosynthesis          (KEGG, Pathways)  1.09e-01
# 8                      peptidase activity  (GO, molecular_function)  1.76e-01
# 9    aberrant cellular response to stress   (Dictybase, Phenotypes)  1.84e-01
# 10                        plasma membrane  (GO, cellular_component)  1.84e-01
# 11                      catabolic process  (GO, biological_process)  1.84e-01
# 12               increased aggregate size   (Dictybase, Phenotypes)  1.86e-01
# 13    aberrant cellular metabolic process   (Dictybase, Phenotypes)  1.86e-01
# 14  Biosynthesis of secondary metabolites          (KEGG, Pathways)  2.14e-01
# 15                    increased cell size   (Dictybase, Phenotypes)  2.26e-01
# 16   Porphyrin and chlorophyll metabolism          (KEGG, Pathways)  2.26e-01
# 17            Biosynthesis of amino acids          (KEGG, Pathways)  2.26e-01
# 18   cell wall organization or biogenesis  (GO, biological_process)  2.26e-01
# 19                                vacuole  (GO, cellular_component)  2.35e-01
# 20                lipid metabolic process  (GO, biological_process)  2.35e-01
#
#     N in query
# 0           14
# 1           15
# 2            6
# 3            7
# 4            6
# 5           16
# 6            9
# 7            2
# 8            6
# 9            2
# 10          11
# 11          11
# 12           3
# 13           2
# 14          11
# 15           2
# 16           2
# 17           4
# 18           2
# 19           6
# 20           7
# ***  stream selected: 15 with EID: 15
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.13
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 0 out of 2 query genes used for enrichment calculation.
# None
# ***  lag selected: 17 with EID: 17
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.18
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 0 out of 3 query genes used for enrichment calculation.
# None
# ***  tag selected: 37 with EID: 37
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.11
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 2 out of 4 query genes used for enrichment calculation.
#           Gene set                  Ontology       FDR  N in query
# 0  kinase activity  (GO, molecular_function)  8.61e-02           2
# ***  tip selected: 48 with EID: 48
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.08
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 4 out of 4 query genes used for enrichment calculation.
#                            Gene set                  Ontology       FDR  \
# 0              extracellular region  (GO, cellular_component)  7.60e-02
# 1  small molecule metabolic process  (GO, biological_process)  1.07e-01
# 2                Metabolic pathways          (KEGG, Pathways)  2.26e-01
#
#    N in query
# 0           2
# 1           2
# 2           2
# ***  slug selected: 411 with EID: 410
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.18
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 43 out of 73 query genes used for enrichment calculation.
#                                 Gene set                  Ontology       FDR  \
# 0                   extracellular region  (GO, cellular_component)  1.15e-14
# 1       external encapsulating structure  (GO, cellular_component)  2.57e-03
# 2                              cell wall  (GO, cellular_component)  2.57e-03
# 3       anatomical structure development  (GO, biological_process)  7.48e-03
# 4   cell wall organization or biogenesis  (GO, biological_process)  5.32e-02
# 5            aberrant cell-cell adhesion   (Dictybase, Phenotypes)  6.11e-02
# 6                   extracellular matrix  (GO, cellular_component)  1.41e-01
# 7         aberrant spore coat morphology   (Dictybase, Phenotypes)  2.02e-01
# 8              decreased spore viability   (Dictybase, Phenotypes)  2.13e-01
# 9                        plasma membrane  (GO, cellular_component)  2.13e-01
# 10                   cell-cell signaling  (GO, biological_process)  2.42e-01
#
#     N in query
# 0           24
# 1            4
# 2            4
# 3           19
# 4            3
# 5            2
# 6            2
# 7            2
# 8            4
# 9           10
# 10           2
# ***  mhat selected: 527 with EID: 526
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.27
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 89 out of 144 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                       extracellular region
# 1                             aberrant spore coat morphology
# 2                       cell wall organization or biogenesis
# 3   anatomical structure formation involved in morphogenesis
# 4                           external encapsulating structure
# 5                                                  cell wall
# 6                                       cell differentiation
# 7                           anatomical structure development
# 8                              Starch and sucrose metabolism
# 9                                       extracellular matrix
# 10                          abolished cellulose biosynthesis
# 11                                 decreased spore viability
# 12                            carbohydrate metabolic process
# 13                                        hydrolase activity
# 14                               abolished cellulose binding
# 15                              precocious spore germination
# 16                                        thin standing slug
# 17                    decreased autophagic vacuole formation
# 18                                      aberrant culmination
# 19                                       cell-cell signaling
# 20                                                 wild type
# 21                                     abolished culmination
# 22                      abolished stalk cell differentiation
# 23                                 aberrant spore morphology
# 24                   increased prestalk cell differentiation
#
#                     Ontology       FDR  N in query
# 0   (GO, cellular_component)  1.45e-10          28
# 1    (Dictybase, Phenotypes)  1.24e-07           8
# 2   (GO, biological_process)  9.76e-07           8
# 3   (GO, biological_process)  2.07e-06          15
# 4   (GO, cellular_component)  3.85e-06           7
# 5   (GO, cellular_component)  3.85e-06           7
# 6   (GO, biological_process)  5.45e-06          20
# 7   (GO, biological_process)  3.81e-05          36
# 8           (KEGG, Pathways)  2.26e-03           7
# 9   (GO, cellular_component)  2.29e-03           4
# 10   (Dictybase, Phenotypes)  8.81e-03           3
# 11   (Dictybase, Phenotypes)  1.87e-02           8
# 12  (GO, biological_process)  1.87e-02          10
# 13  (GO, molecular_function)  1.87e-02           7
# 14   (Dictybase, Phenotypes)  1.89e-02           2
# 15   (Dictybase, Phenotypes)  4.61e-02           2
# 16   (Dictybase, Phenotypes)  4.61e-02           2
# 17   (Dictybase, Phenotypes)  4.61e-02           2
# 18   (Dictybase, Phenotypes)  4.99e-02           9
# 19  (GO, biological_process)  2.02e-01           3
# 20   (Dictybase, Phenotypes)  2.05e-01          20
# 21   (Dictybase, Phenotypes)  2.29e-01           6
# 22   (Dictybase, Phenotypes)  2.29e-01           2
# 23   (Dictybase, Phenotypes)  2.29e-01           2
# 24   (Dictybase, Phenotypes)  2.46e-01           2
# ***  cul selected: 933 with EID: 926
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.21
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 96 out of 192 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                       extracellular region
# 1                                       cell differentiation
# 2                             aberrant spore coat morphology
# 3   anatomical structure formation involved in morphogenesis
# 4                       cell wall organization or biogenesis
# 5                               precocious spore germination
# 6                           external encapsulating structure
# 7                                                  cell wall
# 8                           anatomical structure development
# 9                                       extracellular matrix
# 10                                 decreased spore viability
# 11                                   oxidoreductase activity
# 12                                        hydrolase activity
# 13                                 decreased gene expression
# 14                             Starch and sucrose metabolism
# 15                         development arrests at slug stage
# 16                                             cell adhesion
# 17                                  aberrant stalk formation
# 18                               secondary metabolic process
#
#                     Ontology       FDR  N in query
# 0   (GO, cellular_component)  9.44e-13          35
# 1   (GO, biological_process)  7.98e-06          24
# 2    (Dictybase, Phenotypes)  2.05e-05           7
# 3   (GO, biological_process)  2.05e-05          16
# 4   (GO, biological_process)  1.18e-04           7
# 5    (Dictybase, Phenotypes)  4.12e-03           3
# 6   (GO, cellular_component)  5.89e-03           5
# 7   (GO, cellular_component)  5.89e-03           5
# 8   (GO, biological_process)  5.89e-03          38
# 9   (GO, cellular_component)  7.12e-03           4
# 10   (Dictybase, Phenotypes)  3.84e-02           9
# 11  (GO, molecular_function)  9.17e-02          19
# 12  (GO, molecular_function)  9.17e-02           7
# 13   (Dictybase, Phenotypes)  1.30e-01          10
# 14          (KEGG, Pathways)  2.28e-01           5
# 15   (Dictybase, Phenotypes)  2.38e-01           3
# 16  (GO, biological_process)  2.38e-01           9
# 17   (Dictybase, Phenotypes)  2.44e-01           2
# 18  (GO, biological_process)  2.44e-01           2
# ***  yem selected: 1001 with EID: 995
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.32
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 149 out of 320 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                secondary metabolic process
# 1                                       cell differentiation
# 2                                         Metabolic pathways
# 3   anatomical structure formation involved in morphogenesis
# 4        Ubiquinone and other terpenoid-quinone biosynthesis
# 5                                  decreased gene expression
# 6                         Cysteine and methionine metabolism
# 7                                              Phenylalanine
# 8                                    Fatty acid biosynthesis
# 9                                    oxidoreductase activity
# 10                                  Phenylalanine metabolism
# 11                          anatomical structure development
# 12                 SNARE interactions in vesicular transport
#
#                     Ontology       FDR  N in query
# 0   (GO, biological_process)  1.16e-03           5
# 1   (GO, biological_process)  1.63e-03          28
# 2           (KEGG, Pathways)  6.85e-03          80
# 3   (GO, biological_process)  6.85e-03          17
# 4           (KEGG, Pathways)  4.15e-02           5
# 5    (Dictybase, Phenotypes)  6.15e-02          16
# 6           (KEGG, Pathways)  6.15e-02           8
# 7           (KEGG, Pathways)  7.76e-02           3
# 8           (KEGG, Pathways)  7.76e-02           4
# 9   (GO, molecular_function)  7.76e-02          29
# 10          (KEGG, Pathways)  1.85e-01           4
# 11  (GO, biological_process)  1.85e-01          50
# 12          (KEGG, Pathways)  2.19e-01           6
# ***  FB selected: 709 with EID: 705
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.22
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 65 out of 155 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0                                      extracellular region
# 1                                      cell differentiation
# 2                                   oxidoreductase activity
# 3  anatomical structure formation involved in morphogenesis
# 4                               secondary metabolic process
# 5                                             cell adhesion
#
#                    Ontology       FDR  N in query
# 0  (GO, cellular_component)  5.70e-09          27
# 1  (GO, biological_process)  4.12e-03          17
# 2  (GO, molecular_function)  9.29e-03          20
# 3  (GO, biological_process)  2.26e-02          10
# 4  (GO, biological_process)  2.26e-02           3
# 5  (GO, biological_process)  1.63e-01           9

# %% [markdown]
# ##### DESeq2 all strains lFC >= 1 and padj <= 0.05

# %%
milestones=pd.read_table(path_de+'nobatchrep_combined.tsv',index_col=0,sep='\t')
for stage in [phenotype for phenotype in PHENOTYPES if phenotype in list(milestones['Stage'].unique())]:
    query_names=list(milestones.query('log2FoldChange>=1 & padj <= 0.05 & Stage=="'+stage+'"').index)
    enriched=group_diff_enrichment(query_names=query_names,group=stage,min_overlap=2,use_annotated_genes=True)
# Out:
# ***  no_agg selected: 1652 with EID: 1643
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.37
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 389 out of 600 query genes used for enrichment calculation.
#                                    Gene set                  Ontology  \
# 0                                  Ribosome          (KEGG, Pathways)
# 1                                  ribosome  (GO, cellular_component)
# 2        structural constituent of ribosome  (GO, molecular_function)
# 3              structural molecule activity  (GO, molecular_function)
# 4                               translation  (GO, biological_process)
# 5                             mitochondrion  (GO, cellular_component)
# 6                      Steroid biosynthesis          (KEGG, Pathways)
# 7                              rRNA binding  (GO, molecular_function)
# 8                               RNA binding  (GO, molecular_function)
# 9     Biosynthesis of secondary metabolites          (KEGG, Pathways)
# 10                       Metabolic pathways          (KEGG, Pathways)
# 11                Oxidative phosphorylation          (KEGG, Pathways)
# 12                  oxidoreductase activity  (GO, molecular_function)
# 13              Aminoacyl-tRNA biosynthesis          (KEGG, Pathways)
# 14               mitochondrion organization  (GO, biological_process)
# 15               methyltransferase activity  (GO, molecular_function)
# 16                    Fatty acid elongation          (KEGG, Pathways)
# 17                     extracellular region  (GO, cellular_component)
# 18     Porphyrin and chlorophyll metabolism          (KEGG, Pathways)
# 19  Biosynthesis of unsaturated fatty acids          (KEGG, Pathways)
# 20                       hydrolase activity  (GO, molecular_function)
# 21                       isomerase activity  (GO, molecular_function)
#
#          FDR  N in query
# 0   1.24e-64          90
# 1   1.00e-59          85
# 2   6.37e-57          79
# 3   8.62e-44          85
# 4   1.33e-38          99
# 5   2.91e-09          73
# 6   2.64e-07          14
# 7   2.37e-06          11
# 8   2.16e-04          48
# 9   1.01e-03          68
# 10  3.69e-03         134
# 11  1.84e-02          18
# 12  1.84e-02          49
# 13  1.92e-02          16
# 14  2.35e-02          10
# 15  2.35e-02          18
# 16  2.75e-02           7
# 17  3.41e-02          38
# 18  4.28e-02           7
# 19  2.10e-01           6
# 20  2.25e-01          13
# 21  2.25e-01          14
# ***  stream selected: 170 with EID: 167
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.25
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 30 out of 41 query genes used for enrichment calculation.
#                                     Gene set                  Ontology  \
# 0                       extracellular region  (GO, cellular_component)
# 1   development arrests at loose mound stage   (Dictybase, Phenotypes)
# 2                              cell adhesion  (GO, biological_process)
# 3                         aberrant streaming   (Dictybase, Phenotypes)
# 4                       aberrant aggregation   (Dictybase, Phenotypes)
# 5                   abolished slug migration   (Dictybase, Phenotypes)
# 6                            plasma membrane  (GO, cellular_component)
# 7                        signal transduction  (GO, biological_process)
# 8                       aberrant culmination   (Dictybase, Phenotypes)
# 9                     precocious aggregation   (Dictybase, Phenotypes)
# 10              aberrant cAMP wave formation   (Dictybase, Phenotypes)
# 11                   aberrant slug migration   (Dictybase, Phenotypes)
# 12                 abolished gene expression   (Dictybase, Phenotypes)
# 13                     increased growth rate   (Dictybase, Phenotypes)
# 14              decreased fruiting body size   (Dictybase, Phenotypes)
# 15                  decreased aggregate size   (Dictybase, Phenotypes)
# 16                   decreased cell motility   (Dictybase, Phenotypes)
# 17             aberrant F-actin organization   (Dictybase, Phenotypes)
# 18                      cell differentiation  (GO, biological_process)
# 19          anatomical structure development  (GO, biological_process)
# 20                      aberrant development   (Dictybase, Phenotypes)
# 21                     decreased sporulation   (Dictybase, Phenotypes)
#
#          FDR  N in query
# 0   4.03e-05          11
# 1   2.72e-03           4
# 2   6.36e-02           5
# 3   8.68e-02           4
# 4   8.68e-02           4
# 5   8.68e-02           3
# 6   8.68e-02           8
# 7   8.68e-02           9
# 8   9.84e-02           4
# 9   1.08e-01           2
# 10  1.08e-01           4
# 11  1.09e-01           3
# 12  1.29e-01           2
# 13  1.48e-01           2
# 14  1.48e-01           3
# 15  1.48e-01           2
# 16  1.48e-01           3
# 17  1.80e-01           2
# 18  1.95e-01           4
# 19  2.14e-01           8
# 20  2.35e-01           2
# 21  2.39e-01           2
# ***  lag selected: 193 with EID: 190
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.3
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 44 out of 57 query genes used for enrichment calculation.
#                                                 Gene set  \
# 0                                   extracellular region
# 1                                        plasma membrane
# 2               development arrests at loose mound stage
# 3                               abolished slug migration
# 4                                    signal transduction
# 5                                   aberrant aggregation
# 6                             multiple tips in culminant
# 7                                     response to stress
# 8                                  decreased culmination
# 9                                    abolished streaming
# 10                                 delayed tip formation
# 11                         abolished cAMP wave formation
# 12                      anatomical structure development
# 13                                    aberrant streaming
# 14                                 abolished aggregation
# 15                                multiple tips in mound
# 16                                         cell adhesion
# 17                                precocious aggregation
# 18                    development arrests at mound stage
# 19                                  aberrant culmination
# 20                                  aberrant development
# 21                               aberrant slug migration
# 22                             abolished gene expression
# 23                                 abolished sporulation
# 24                          aberrant cAMP wave formation
# 25  AGE-RAGE signaling pathway in diabetic complications
# 26                                  cell differentiation
# 27                                       GTPase activity
# 28                                   delayed culmination
# 29                                 increased growth rate
# 30                              decreased aggregate size
# 31                          decreased fruiting body size
# 32                               decreased cell motility
# 33                         aberrant F-actin organization
#
#                     Ontology       FDR  N in query
# 0   (GO, cellular_component)  1.59e-03          11
# 1   (GO, cellular_component)  6.03e-03          13
# 2    (Dictybase, Phenotypes)  7.91e-03           4
# 3    (Dictybase, Phenotypes)  9.92e-03           5
# 4   (GO, biological_process)  9.92e-03          14
# 5    (Dictybase, Phenotypes)  4.19e-02           5
# 6    (Dictybase, Phenotypes)  4.21e-02           2
# 7   (GO, biological_process)  8.00e-02          12
# 8    (Dictybase, Phenotypes)  1.07e-01           2
# 9    (Dictybase, Phenotypes)  1.07e-01           3
# 10   (Dictybase, Phenotypes)  1.07e-01           2
# 11   (Dictybase, Phenotypes)  1.07e-01           2
# 12  (GO, biological_process)  1.07e-01          13
# 13   (Dictybase, Phenotypes)  1.37e-01           4
# 14   (Dictybase, Phenotypes)  1.46e-01           4
# 15   (Dictybase, Phenotypes)  1.46e-01           2
# 16  (GO, biological_process)  1.53e-01           4
# 17   (Dictybase, Phenotypes)  1.57e-01           2
# 18   (Dictybase, Phenotypes)  1.66e-01           3
# 19   (Dictybase, Phenotypes)  1.66e-01           4
# 20   (Dictybase, Phenotypes)  1.66e-01           3
# 21   (Dictybase, Phenotypes)  1.74e-01           3
# 22   (Dictybase, Phenotypes)  1.74e-01           2
# 23   (Dictybase, Phenotypes)  1.74e-01           2
# 24   (Dictybase, Phenotypes)  1.74e-01           4
# 25          (KEGG, Pathways)  1.74e-01           2
# 26  (GO, biological_process)  1.75e-01           5
# 27  (GO, molecular_function)  1.75e-01           5
# 28   (Dictybase, Phenotypes)  1.84e-01           2
# 29   (Dictybase, Phenotypes)  1.96e-01           2
# 30   (Dictybase, Phenotypes)  2.04e-01           2
# 31   (Dictybase, Phenotypes)  2.34e-01           3
# 32   (Dictybase, Phenotypes)  2.34e-01           3
# 33   (Dictybase, Phenotypes)  2.36e-01           2
# ***  tag selected: 384 with EID: 382
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.18
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 44 out of 70 query genes used for enrichment calculation.
#                              Gene set                  Ontology       FDR  \
# 0              chromosome segregation  (GO, biological_process)  1.50e-03
# 1                          cell cycle  (GO, biological_process)  1.94e-03
# 2            mitotic nuclear division  (GO, biological_process)  4.90e-03
# 3                     DNA replication          (KEGG, Pathways)  7.90e-03
# 4             chromosome organization  (GO, biological_process)  7.90e-03
# 5   increased cell-substrate adhesion   (Dictybase, Phenotypes)  3.04e-02
# 6                          chromosome  (GO, cellular_component)  3.04e-02
# 7                  mitotic cell cycle  (GO, biological_process)  3.04e-02
# 8                       cell division  (GO, biological_process)  6.00e-02
# 9                extracellular region  (GO, cellular_component)  8.40e-02
# 10          decreased spore viability   (Dictybase, Phenotypes)  1.33e-01
# 11              delayed tip formation   (Dictybase, Phenotypes)  1.33e-01
# 12   external encapsulating structure  (GO, cellular_component)  1.33e-01
# 13                          cell wall  (GO, cellular_component)  1.33e-01
# 14                    kinase activity  (GO, molecular_function)  1.65e-01
# 15                 nuclear chromosome  (GO, cellular_component)  1.87e-01
#
#     N in query
# 0            5
# 1           12
# 2            4
# 3            5
# 4            7
# 5            4
# 6            6
# 7            7
# 8            7
# 9            8
# 10           4
# 11           2
# 12           2
# 13           2
# 14          11
# 15           2
# ***  tip selected: 616 with EID: 613
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.26
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 93 out of 157 query genes used for enrichment calculation.
#                                               Gene set  \
# 0                                           chromosome
# 1                                      DNA replication
# 2                                           cell cycle
# 3                               chromosome segregation
# 4                              chromosome organization
# 5                             mitotic nuclear division
# 6                                        cell division
# 7                                   nuclear chromosome
# 8                                   mitotic cell cycle
# 9                                      Mismatch repair
# 10                                         DNA binding
# 11                          Nucleotide excision repair
# 12                                Base excision repair
# 13                               Pyrimidine metabolism
# 14                               DNA metabolic process
# 15                               delayed tip formation
# 16                                extracellular region
# 17                             abolished tip formation
# 18                       microtubule organizing center
# 19  abolished negative regulation of vegetative growth
# 20                      Ubiquitin mediated proteolysis
# 21                     aberrant myosin II organization
# 22                                   cell cycle arrest
# 23                      increased chemotaxis to folate
# 24                          increased macropinocytosis
# 25                              Glutathione metabolism
# 26                        decreased cell-cell adhesion
# 27             decreased prestalk cell differentiation
# 28                          precocious gene expression
# 29                                        cytoskeleton
# 30                       aberrant culminant morphology
#
#                     Ontology       FDR  N in query
# 0   (GO, cellular_component)  1.37e-12          22
# 1           (KEGG, Pathways)  1.37e-12          16
# 2   (GO, biological_process)  1.25e-08          27
# 3   (GO, biological_process)  3.99e-07           9
# 4   (GO, biological_process)  7.65e-07          16
# 5   (GO, biological_process)  2.53e-05           7
# 6   (GO, biological_process)  6.42e-05          17
# 7   (GO, cellular_component)  7.92e-04           6
# 8   (GO, biological_process)  7.92e-04          14
# 9           (KEGG, Pathways)  1.42e-03           6
# 10  (GO, molecular_function)  8.03e-03          20
# 11          (KEGG, Pathways)  9.63e-03           7
# 12          (KEGG, Pathways)  1.12e-02           6
# 13          (KEGG, Pathways)  1.22e-02           6
# 14  (GO, biological_process)  1.22e-02          12
# 15   (Dictybase, Phenotypes)  1.69e-02           4
# 16  (GO, cellular_component)  1.69e-02          15
# 17   (Dictybase, Phenotypes)  1.92e-02           2
# 18  (GO, cellular_component)  3.82e-02           7
# 19   (Dictybase, Phenotypes)  9.86e-02           2
# 20          (KEGG, Pathways)  1.05e-01           7
# 21   (Dictybase, Phenotypes)  1.28e-01           2
# 22   (Dictybase, Phenotypes)  1.28e-01           2
# 23   (Dictybase, Phenotypes)  1.28e-01           2
# 24   (Dictybase, Phenotypes)  1.28e-01           2
# 25          (KEGG, Pathways)  1.35e-01           4
# 26   (Dictybase, Phenotypes)  1.62e-01           3
# 27   (Dictybase, Phenotypes)  1.67e-01           2
# 28   (Dictybase, Phenotypes)  1.86e-01           3
# 29  (GO, cellular_component)  1.86e-01          13
# 30   (Dictybase, Phenotypes)  2.16e-01           2
# ***  slug selected: 1373 with EID: 1367
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.21
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 166 out of 292 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                       extracellular region
# 1                           anatomical structure development
# 2                             aberrant spore coat morphology
# 3                           external encapsulating structure
# 4                                                  cell wall
# 5                                       cell differentiation
# 6                              Starch and sucrose metabolism
# 7   anatomical structure formation involved in morphogenesis
# 8                       cell wall organization or biogenesis
# 9                                        signal transduction
# 10                                      aberrant culmination
# 11                                 decreased spore viability
# 12                 DNA-binding transcription factor activity
# 13                                      aberrant thermotaxis
# 14                          abolished cellulose biosynthesis
# 15                                           spores inviable
# 16                                               DNA binding
# 17                               abolished cellulose binding
# 18                 decreased prestalk A cell differentiation
# 19                   increased prespore cell differentiation
# 20                                       aberrant phototaxis
# 21                                    Glutathione metabolism
# 22                         development arrests at slug stage
# 23                         aberrant fruiting body morphology
# 24                                     abolished culmination
# 25                                  abolished DIF production
# 26                                        thin standing slug
# 27                    decreased autophagic vacuole formation
# 28                                    increased stalk length
# 29                                      extracellular matrix
# 30                              aberrant cAMP wave formation
#
#                     Ontology       FDR  N in query
# 0   (GO, cellular_component)  5.18e-09          38
# 1   (GO, biological_process)  2.12e-05          62
# 2    (Dictybase, Phenotypes)  3.22e-05           8
# 3   (GO, cellular_component)  4.70e-05           8
# 4   (GO, cellular_component)  4.70e-05           8
# 5   (GO, biological_process)  2.57e-04          27
# 6           (KEGG, Pathways)  2.98e-04          11
# 7   (GO, biological_process)  7.05e-04          17
# 8   (GO, biological_process)  1.49e-03           7
# 9   (GO, biological_process)  7.22e-03          44
# 10   (Dictybase, Phenotypes)  1.66e-02          16
# 11   (Dictybase, Phenotypes)  2.64e-02          12
# 12  (GO, molecular_function)  2.73e-02           9
# 13   (Dictybase, Phenotypes)  6.44e-02           3
# 14   (Dictybase, Phenotypes)  6.44e-02           3
# 15   (Dictybase, Phenotypes)  6.44e-02           3
# 16  (GO, molecular_function)  6.44e-02          28
# 17   (Dictybase, Phenotypes)  8.75e-02           2
# 18   (Dictybase, Phenotypes)  8.75e-02           2
# 19   (Dictybase, Phenotypes)  9.86e-02           3
# 20   (Dictybase, Phenotypes)  9.86e-02           3
# 21          (KEGG, Pathways)  1.16e-01           6
# 22   (Dictybase, Phenotypes)  1.20e-01           4
# 23   (Dictybase, Phenotypes)  1.57e-01          14
# 24   (Dictybase, Phenotypes)  1.69e-01          10
# 25   (Dictybase, Phenotypes)  1.69e-01           2
# 26   (Dictybase, Phenotypes)  1.69e-01           2
# 27   (Dictybase, Phenotypes)  1.69e-01           2
# 28   (Dictybase, Phenotypes)  1.73e-01           3
# 29  (GO, cellular_component)  1.73e-01           3
# 30   (Dictybase, Phenotypes)  2.31e-01          13
# ***  mhat selected: 1871 with EID: 1864
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.3
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 337 out of 567 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                           anatomical structure development
# 1   anatomical structure formation involved in morphogenesis
# 2                             aberrant spore coat morphology
# 3                                       cell differentiation
# 4                                       extracellular region
# 5                           external encapsulating structure
# 6                                                  cell wall
# 7                              Starch and sucrose metabolism
# 8                                  decreased spore viability
# 9                                        signal transduction
# 10                                           kinase activity
# 11                   increased prespore cell differentiation
# 12                 DNA-binding transcription factor activity
# 13                                      aberrant culmination
# 14                      cell wall organization or biogenesis
# 15                 development arrests at tipped mound stage
# 16                          abolished cellulose biosynthesis
# 17                                           spores inviable
# 18                                   aberrant slug migration
# 19                         aberrant fruiting body morphology
# 20                                 aberrant spore morphology
# 21                                        thin standing slug
# 22                    decreased autophagic vacuole formation
# 23                                       aberrant phototaxis
# 24                                     abolished culmination
# 25                                                 wild type
# 26                                               DNA binding
# 27                     aberrant response to abiotic stimulus
# 28                                      increased sorus size
# 29                 decreased prestalk 0 cell differentiation
# 30                                 increased gene expression
# 31                                      Galactose metabolism
# 32                            carbohydrate metabolic process
# 33                                          ABC transporters
# 34                                     decreased sporulation
# 35                                  abolished slug migration
# 36                               abolished cellulose binding
# 37                                 abolished gene expression
# 38                          aberrant protein phosphorylation
# 39                                    increased stalk length
# 40                            increased standing slug length
# 41                 decreased prestalk A cell differentiation
# 42                        decreased intracellular cAMP level
# 43                                 abolished response to DIF
# 44                                 decreased gene expression
# 45                                   abolished tip formation
# 46                                      extracellular matrix
# 47                                       cell-cell signaling
# 48                                      aberrant thermotaxis
# 49                                    precocious sporulation
# 50                 abolished protein localization to nucleus
# 51                                increased macropinocytosis
# 52                            aberrant autophagic cell death
# 53                                      Histidine metabolism
# 54                                         translucent sorus
#
#                     Ontology       FDR  N in query
# 0   (GO, biological_process)  9.79e-07         107
# 1   (GO, biological_process)  2.46e-05          29
# 2    (Dictybase, Phenotypes)  2.77e-05          10
# 3   (GO, biological_process)  4.76e-05          44
# 4   (GO, cellular_component)  1.66e-04          45
# 5   (GO, cellular_component)  6.91e-04           9
# 6   (GO, cellular_component)  6.91e-04           9
# 7           (KEGG, Pathways)  2.03e-03          14
# 8    (Dictybase, Phenotypes)  6.20e-03          20
# 9   (GO, biological_process)  9.28e-03          74
# 10  (GO, molecular_function)  9.28e-03          70
# 11   (Dictybase, Phenotypes)  1.24e-02           5
# 12  (GO, molecular_function)  1.25e-02          14
# 13   (Dictybase, Phenotypes)  1.37e-02          25
# 14  (GO, biological_process)  1.37e-02           8
# 15   (Dictybase, Phenotypes)  1.47e-02           7
# 16   (Dictybase, Phenotypes)  4.84e-02           4
# 17   (Dictybase, Phenotypes)  4.84e-02           4
# 18   (Dictybase, Phenotypes)  5.37e-02          17
# 19   (Dictybase, Phenotypes)  5.37e-02          25
# 20   (Dictybase, Phenotypes)  5.37e-02           5
# 21   (Dictybase, Phenotypes)  5.97e-02           3
# 22   (Dictybase, Phenotypes)  5.97e-02           3
# 23   (Dictybase, Phenotypes)  9.66e-02           4
# 24   (Dictybase, Phenotypes)  9.68e-02          17
# 25   (Dictybase, Phenotypes)  1.16e-01          65
# 26  (GO, molecular_function)  1.38e-01          45
# 27   (Dictybase, Phenotypes)  1.54e-01           3
# 28   (Dictybase, Phenotypes)  1.54e-01           3
# 29   (Dictybase, Phenotypes)  1.54e-01           3
# 30   (Dictybase, Phenotypes)  1.54e-01          13
# 31          (KEGG, Pathways)  1.54e-01           6
# 32  (GO, biological_process)  1.61e-01          21
# 33          (KEGG, Pathways)  1.86e-01           6
# 34   (Dictybase, Phenotypes)  1.97e-01          14
# 35   (Dictybase, Phenotypes)  1.97e-01          12
# 36   (Dictybase, Phenotypes)  1.99e-01           2
# 37   (Dictybase, Phenotypes)  1.99e-01           8
# 38   (Dictybase, Phenotypes)  1.99e-01           2
# 39   (Dictybase, Phenotypes)  1.99e-01           4
# 40   (Dictybase, Phenotypes)  1.99e-01           2
# 41   (Dictybase, Phenotypes)  1.99e-01           2
# 42   (Dictybase, Phenotypes)  1.99e-01           5
# 43   (Dictybase, Phenotypes)  1.99e-01           2
# 44   (Dictybase, Phenotypes)  1.99e-01          20
# 45   (Dictybase, Phenotypes)  1.99e-01           2
# 46  (GO, cellular_component)  1.99e-01           4
# 47  (GO, biological_process)  1.99e-01           6
# 48   (Dictybase, Phenotypes)  2.06e-01           3
# 49   (Dictybase, Phenotypes)  2.06e-01           3
# 50   (Dictybase, Phenotypes)  2.06e-01           3
# 51   (Dictybase, Phenotypes)  2.06e-01           3
# 52   (Dictybase, Phenotypes)  2.06e-01           3
# 53          (KEGG, Pathways)  2.47e-01           5
# 54   (Dictybase, Phenotypes)  2.47e-01           4
# ***  cul selected: 2344 with EID: 2328
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.27
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 315 out of 629 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0   anatomical structure formation involved in morphogenesis
# 1                                       cell differentiation
# 2                                       extracellular region
# 3                           anatomical structure development
# 4                             aberrant spore coat morphology
# 5                           external encapsulating structure
# 6                                                  cell wall
# 7                              Starch and sucrose metabolism
# 8                                  decreased spore viability
# 9                                       aberrant culmination
# 10                   increased prespore cell differentiation
# 11                 decreased prestalk 0 cell differentiation
# 12                 development arrests at tipped mound stage
# 13                      cell wall organization or biogenesis
# 14                                   aberrant slug migration
# 15                                           spores inviable
# 16                               secondary metabolic process
# 17                                  abolished DIF production
# 18                              precocious spore germination
# 19                                        thin standing slug
# 20                                 aberrant spore morphology
# 21                 DNA-binding transcription factor activity
# 22                                     abolished culmination
# 23                 SNARE interactions in vesicular transport
# 24                                           kinase activity
# 25                           abolished autophagic cell death
# 26                    abolished autophagic vacuole formation
# 27                                 increased gene expression
# 28                                           Golgi apparatus
# 29       Ubiquinone and other terpenoid-quinone biosynthesis
# 30                                      increased sorus size
# 31                                 decreased gene expression
# 32                    aberrant prestalk cell differentiation
# 33                                     decreased sporulation
# 34                                      Galactose metabolism
# 35                         aberrant fruiting body morphology
# 36                                               DNA binding
#
#                     Ontology       FDR  N in query
# 0   (GO, biological_process)  1.33e-11          40
# 1   (GO, biological_process)  7.01e-11          59
# 2   (GO, cellular_component)  8.78e-09          58
# 3   (GO, biological_process)  2.45e-05         109
# 4    (Dictybase, Phenotypes)  4.60e-05          10
# 5   (GO, cellular_component)  1.46e-03           9
# 6   (GO, cellular_component)  1.46e-03           9
# 7           (KEGG, Pathways)  1.46e-03          15
# 8    (Dictybase, Phenotypes)  8.76e-03          21
# 9    (Dictybase, Phenotypes)  1.70e-02          27
# 10   (Dictybase, Phenotypes)  2.26e-02           5
# 11   (Dictybase, Phenotypes)  2.50e-02           4
# 12   (Dictybase, Phenotypes)  3.23e-02           7
# 13  (GO, biological_process)  3.23e-02           8
# 14   (Dictybase, Phenotypes)  8.11e-02          18
# 15   (Dictybase, Phenotypes)  8.11e-02           4
# 16  (GO, biological_process)  8.11e-02           4
# 17   (Dictybase, Phenotypes)  8.56e-02           3
# 18   (Dictybase, Phenotypes)  8.56e-02           3
# 19   (Dictybase, Phenotypes)  8.56e-02           3
# 20   (Dictybase, Phenotypes)  8.56e-02           5
# 21  (GO, molecular_function)  8.56e-02          13
# 22   (Dictybase, Phenotypes)  1.21e-01          18
# 23          (KEGG, Pathways)  1.21e-01           9
# 24  (GO, molecular_function)  1.21e-01          69
# 25   (Dictybase, Phenotypes)  1.27e-01           4
# 26   (Dictybase, Phenotypes)  1.27e-01           4
# 27   (Dictybase, Phenotypes)  1.67e-01          14
# 28  (GO, cellular_component)  1.94e-01          22
# 29          (KEGG, Pathways)  1.98e-01           5
# 30   (Dictybase, Phenotypes)  2.07e-01           3
# 31   (Dictybase, Phenotypes)  2.07e-01          22
# 32   (Dictybase, Phenotypes)  2.11e-01           4
# 33   (Dictybase, Phenotypes)  2.11e-01          15
# 34          (KEGG, Pathways)  2.11e-01           6
# 35   (Dictybase, Phenotypes)  2.32e-01          24
# 36  (GO, molecular_function)  2.50e-01          47
# ***  yem selected: 2231 with EID: 2218
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.34
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 56 out of 760 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0                               secondary metabolic process
# 1                                   Glycerolipid metabolism
# 2  anatomical structure formation involved in morphogenesis
# 3                 DNA-binding transcription factor activity
#
#                    Ontology       FDR  N in query
# 0  (GO, biological_process)  1.34e-01           5
# 1          (KEGG, Pathways)  1.45e-01          10
# 2  (GO, biological_process)  1.45e-01          26
# 3  (GO, molecular_function)  1.45e-01          16
# ***  FB selected: 1970 with EID: 1958
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.25
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 277 out of 494 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                       extracellular region
# 1                                       cell differentiation
# 2   anatomical structure formation involved in morphogenesis
# 3                           anatomical structure development
# 4                              Starch and sucrose metabolism
# 5                                       aberrant culmination
# 6                                                  wild type
# 7                                            spores inviable
# 8                  SNARE interactions in vesicular transport
# 9                                secondary metabolic process
# 10                 development arrests at tipped mound stage
# 11                                 decreased spore viability
# 12                                  abolished DIF production
# 13                            aberrant spore coat morphology
# 14                   increased prespore cell differentiation
# 15                   decreased prestalk cell differentiation
# 16                                     abolished culmination
# 17       Ubiquinone and other terpenoid-quinone biosynthesis
# 18                                      increased sorus size
# 19                 decreased prestalk 0 cell differentiation
# 20                                           Golgi apparatus
# 21                                           kinase activity
# 22                                 decreased gene expression
# 23                                      extracellular matrix
# 24                        development arrests at mound stage
# 25                 decreased prestalk A cell differentiation
# 26                          abolished cellulose biosynthesis
# 27                      abolished outer basal disc formation
# 28                                   abolished tip formation
# 29                            aberrant autophagic cell death
# 30                                       signal transduction
# 31                 DNA-binding transcription factor activity
# 32                                   delayed gene expression
# 33                                       delayed culmination
#
#                     Ontology       FDR  N in query
# 0   (GO, cellular_component)  1.97e-06          46
# 1   (GO, biological_process)  1.97e-06          44
# 2   (GO, biological_process)  2.88e-06          28
# 3   (GO, biological_process)  5.12e-04          86
# 4           (KEGG, Pathways)  5.81e-04          14
# 5    (Dictybase, Phenotypes)  2.51e-02          23
# 6    (Dictybase, Phenotypes)  4.82e-02          62
# 7    (Dictybase, Phenotypes)  4.82e-02           4
# 8           (KEGG, Pathways)  4.82e-02           9
# 9   (GO, biological_process)  4.82e-02           4
# 10   (Dictybase, Phenotypes)  5.86e-02           6
# 11   (Dictybase, Phenotypes)  5.86e-02          16
# 12   (Dictybase, Phenotypes)  5.86e-02           3
# 13   (Dictybase, Phenotypes)  5.86e-02           6
# 14   (Dictybase, Phenotypes)  7.79e-02           4
# 15   (Dictybase, Phenotypes)  7.79e-02           4
# 16   (Dictybase, Phenotypes)  7.88e-02          16
# 17          (KEGG, Pathways)  1.04e-01           5
# 18   (Dictybase, Phenotypes)  1.46e-01           3
# 19   (Dictybase, Phenotypes)  1.46e-01           3
# 20  (GO, cellular_component)  1.46e-01          19
# 21  (GO, molecular_function)  1.46e-01          56
# 22   (Dictybase, Phenotypes)  1.59e-01          19
# 23  (GO, cellular_component)  1.97e-01           4
# 24   (Dictybase, Phenotypes)  2.11e-01          13
# 25   (Dictybase, Phenotypes)  2.11e-01           2
# 26   (Dictybase, Phenotypes)  2.11e-01           3
# 27   (Dictybase, Phenotypes)  2.11e-01           2
# 28   (Dictybase, Phenotypes)  2.11e-01           2
# 29   (Dictybase, Phenotypes)  2.11e-01           3
# 30  (GO, biological_process)  2.11e-01          58
# 31  (GO, molecular_function)  2.11e-01          10
# 32   (Dictybase, Phenotypes)  2.29e-01           6
# 33   (Dictybase, Phenotypes)  2.29e-01           8

# %% [markdown]
# #### DESeq2 WT

# %% [markdown]
# ##### DESeq2 WT lFC >= 2 and padj <= 0.01

# %%
milestones=pd.read_table(path_de+'WT_batchrep_combined.tsv',index_col=0,sep='\t')
for stage in [phenotype for phenotype in PHENOTYPES if phenotype in list(milestones['Stage'].unique())]:
    query_names=list(milestones.query('log2FoldChange>=2 & padj <= 0.01 & Stage=="'+stage+'"').index)
    enriched=group_diff_enrichment(query_names=query_names,group=stage,min_overlap=2,use_annotated_genes=True)
# Out:
# ***  no_agg selected: 878 with EID: 873
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.39
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 260 out of 337 query genes used for enrichment calculation.
#                                   Gene set                  Ontology  \
# 0                                 Ribosome          (KEGG, Pathways)
# 1       structural constituent of ribosome  (GO, molecular_function)
# 2                                 ribosome  (GO, cellular_component)
# 3                              translation  (GO, biological_process)
# 4             structural molecule activity  (GO, molecular_function)
# 5                            mitochondrion  (GO, cellular_component)
# 6                     Steroid biosynthesis          (KEGG, Pathways)
# 7        Ribosome biogenesis in eukaryotes          (KEGG, Pathways)
# 8                  oxidoreductase activity  (GO, molecular_function)
# 9    Biosynthesis of secondary metabolites          (KEGG, Pathways)
# 10                 lipid metabolic process  (GO, biological_process)
# 11                               nucleolus  (GO, cellular_component)
# 12    Porphyrin and chlorophyll metabolism          (KEGG, Pathways)
# 13                      hydrolase activity  (GO, molecular_function)
# 14             Aminoacyl-tRNA biosynthesis          (KEGG, Pathways)
# 15              methyltransferase activity  (GO, molecular_function)
# 16                      Metabolic pathways          (KEGG, Pathways)
# 17                   Fatty acid elongation          (KEGG, Pathways)
# 18                                 Glycine          (KEGG, Pathways)
# 19   cellular amino acid metabolic process  (GO, biological_process)
# 20                             RNA binding  (GO, molecular_function)
# 21                  tRNA metabolic process  (GO, biological_process)
# 22                     ribosome biogenesis  (GO, biological_process)
# 23                   Vitamin B6 metabolism          (KEGG, Pathways)
# 24                     Lysine biosynthesis          (KEGG, Pathways)
# 25                    extracellular region  (GO, cellular_component)
# 26             Biosynthesis of amino acids          (KEGG, Pathways)
# 27                         ligase activity  (GO, molecular_function)
# 28                    Butanoate metabolism          (KEGG, Pathways)
# 29                      isomerase activity  (GO, molecular_function)
# 30  protein-macromolecule adaptor activity  (GO, molecular_function)
# 31                                lysosome  (GO, cellular_component)
#
#          FDR  N in query
# 0   2.61e-19          43
# 1   2.12e-15          36
# 2   4.53e-15          37
# 3   4.53e-15          51
# 4   1.00e-10          36
# 5   1.79e-06          45
# 6   1.93e-04           9
# 7   1.16e-03          17
# 8   1.40e-03          35
# 9   2.05e-03          43
# 10  3.27e-03          28
# 11  5.85e-03          16
# 12  1.20e-02           6
# 13  1.96e-02          11
# 14  2.22e-02          11
# 15  3.51e-02          12
# 16  4.26e-02          76
# 17  4.26e-02           5
# 18  4.26e-02           7
# 19  4.78e-02          20
# 20  5.10e-02          25
# 21  5.37e-02          13
# 22  5.37e-02          12
# 23  5.69e-02           3
# 24  1.02e-01           3
# 25  1.29e-01          22
# 26  1.36e-01          11
# 27  1.53e-01          13
# 28  1.75e-01           4
# 29  2.00e-01           9
# 30  2.03e-01           3
# 31  2.41e-01          11
# ***  stream selected: 87 with EID: 86
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.17
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 9 out of 15 query genes used for enrichment calculation.
#                                    Gene set                  Ontology  \
# 0                    precocious aggregation   (Dictybase, Phenotypes)
# 1  development arrests at loose mound stage   (Dictybase, Phenotypes)
# 2                             cell adhesion  (GO, biological_process)
# 3                     decreased sporulation   (Dictybase, Phenotypes)
# 4                           plasma membrane  (GO, cellular_component)
# 5              decreased fruiting body size   (Dictybase, Phenotypes)
# 6                   decreased cell motility   (Dictybase, Phenotypes)
# 7                      extracellular region  (GO, cellular_component)
# 8                           GTPase activity  (GO, molecular_function)
#
#         FDR  N in query
# 0  4.38e-02           2
# 1  4.38e-02           2
# 2  4.38e-02           3
# 3  8.23e-02           2
# 4  8.23e-02           4
# 5  1.06e-01           2
# 6  1.06e-01           2
# 7  2.21e-01           2
# 8  2.21e-01           2
# ***  lag selected: 70 with EID: 69
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.22
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 9 out of 15 query genes used for enrichment calculation.
#                         Gene set                  Ontology       FDR  \
# 0       abolished slug migration   (Dictybase, Phenotypes)  2.98e-02
# 1             aberrant streaming   (Dictybase, Phenotypes)  3.41e-02
# 2           aberrant culmination   (Dictybase, Phenotypes)  3.41e-02
# 3           aberrant aggregation   (Dictybase, Phenotypes)  3.41e-02
# 4                plasma membrane  (GO, cellular_component)  3.41e-02
# 5   aberrant cAMP wave formation   (Dictybase, Phenotypes)  3.82e-02
# 6                GTPase activity  (GO, molecular_function)  7.31e-02
# 7        aberrant slug migration   (Dictybase, Phenotypes)  7.80e-02
# 8                   reproduction  (GO, biological_process)  1.04e-01
# 9                  cell adhesion  (GO, biological_process)  1.09e-01
# 10           signal transduction  (GO, biological_process)  2.34e-01
#
#     N in query
# 0            3
# 1            3
# 2            3
# 3            3
# 4            5
# 5            3
# 6            3
# 7            2
# 8            2
# 9            2
# 10           3
# ***  tag selected: 24 with EID: 24
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.17
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 4 out of 4 query genes used for enrichment calculation.
#                                 Gene set                  Ontology       FDR  \
# 0  Biosynthesis of secondary metabolites          (KEGG, Pathways)  9.74e-02
# 1       small molecule metabolic process  (GO, biological_process)  9.74e-02
# 2                        kinase activity  (GO, molecular_function)  9.74e-02
# 3                     Metabolic pathways          (KEGG, Pathways)  1.97e-01
#
#    N in query
# 0           2
# 1           2
# 2           2
# 3           2
# ***  tip selected: 60 with EID: 60
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.37
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 21 out of 22 query genes used for enrichment calculation.
#                             Gene set                  Ontology       FDR  \
# 0                         cell cycle  (GO, biological_process)  1.39e-08
# 1                         chromosome  (GO, cellular_component)  4.46e-08
# 2            chromosome organization  (GO, biological_process)  4.69e-08
# 3           mitotic nuclear division  (GO, biological_process)  1.24e-07
# 4             chromosome segregation  (GO, biological_process)  2.66e-07
# 5                 mitotic cell cycle  (GO, biological_process)  2.66e-07
# 6                    DNA replication          (KEGG, Pathways)  5.25e-06
# 7                  cell cycle arrest   (Dictybase, Phenotypes)  1.88e-03
# 8                      cell division  (GO, biological_process)  1.96e-03
# 9              Pyrimidine metabolism          (KEGG, Pathways)  2.57e-03
# 10                   ATPase activity  (GO, molecular_function)  9.03e-03
# 11     microtubule organizing center  (GO, cellular_component)  1.07e-02
# 12                   Mismatch repair          (KEGG, Pathways)  1.89e-02
# 13                      cytoskeleton  (GO, cellular_component)  5.67e-02
# 14        Nucleotide excision repair          (KEGG, Pathways)  5.67e-02
# 15             DNA metabolic process  (GO, biological_process)  5.90e-02
# 16                 helicase activity  (GO, molecular_function)  7.48e-02
# 17                       DNA binding  (GO, molecular_function)  7.48e-02
# 18  small molecule metabolic process  (GO, biological_process)  2.48e-01
#
#     N in query
# 0           11
# 1            8
# 2            8
# 3            5
# 4            5
# 5            8
# 6            5
# 7            2
# 8            5
# 9            3
# 10           5
# 11           3
# 12           2
# 13           4
# 14           2
# 15           3
# 16           2
# 17           4
# 18           4
# ***  slug selected: 148 with EID: 148
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.14
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 11 out of 21 query genes used for enrichment calculation.
#                            Gene set                  Ontology       FDR  \
# 0              extracellular region  (GO, cellular_component)  4.01e-05
# 1  external encapsulating structure  (GO, cellular_component)  3.88e-02
# 2                         cell wall  (GO, cellular_component)  3.88e-02
# 3            Glutathione metabolism          (KEGG, Pathways)  1.08e-01
#
#    N in query
# 0           8
# 1           2
# 2           2
# 3           2
# ***  mhat selected: 545 with EID: 544
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.24
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 63 out of 132 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                       extracellular region
# 1                             aberrant spore coat morphology
# 2                           external encapsulating structure
# 3                                                  cell wall
# 4                       cell wall organization or biogenesis
# 5                                       extracellular matrix
# 6   anatomical structure formation involved in morphogenesis
# 7                           anatomical structure development
# 8                                  decreased spore viability
# 9                                       cell differentiation
# 10                               abolished cellulose binding
# 11                              precocious spore germination
# 12                                        thin standing slug
# 13                             Starch and sucrose metabolism
# 14                                                 wild type
#
#                     Ontology       FDR  N in query
# 0   (GO, cellular_component)  1.72e-07          23
# 1    (Dictybase, Phenotypes)  2.45e-06           7
# 2   (GO, cellular_component)  7.83e-05           6
# 3   (GO, cellular_component)  7.83e-05           6
# 4   (GO, biological_process)  1.73e-04           6
# 5   (GO, cellular_component)  2.21e-03           4
# 6   (GO, biological_process)  3.68e-03          10
# 7   (GO, biological_process)  1.02e-02          28
# 8    (Dictybase, Phenotypes)  1.31e-02           8
# 9   (GO, biological_process)  1.72e-02          13
# 10   (Dictybase, Phenotypes)  1.77e-02           2
# 11   (Dictybase, Phenotypes)  4.12e-02           2
# 12   (Dictybase, Phenotypes)  4.12e-02           2
# 13          (KEGG, Pathways)  4.12e-02           5
# 14   (Dictybase, Phenotypes)  9.37e-02          20
# ***  cul selected: 944 with EID: 936
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.23
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 94 out of 211 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                       extracellular region
# 1   anatomical structure formation involved in morphogenesis
# 2                                       cell differentiation
# 3                             aberrant spore coat morphology
# 4                       cell wall organization or biogenesis
# 5                               precocious spore germination
# 6                                       extracellular matrix
# 7                           anatomical structure development
# 8                              Starch and sucrose metabolism
# 9                                secondary metabolic process
# 10                                                 wild type
# 11                                        hydrolase activity
# 12                                 decreased spore viability
# 13       Ubiquinone and other terpenoid-quinone biosynthesis
#
#                     Ontology       FDR  N in query
# 0   (GO, cellular_component)  7.27e-10          33
# 1   (GO, biological_process)  1.40e-04          16
# 2   (GO, biological_process)  1.46e-04          23
# 3    (Dictybase, Phenotypes)  9.79e-04           6
# 4   (GO, biological_process)  3.70e-03           6
# 5    (Dictybase, Phenotypes)  6.36e-03           3
# 6   (GO, cellular_component)  1.70e-02           4
# 7   (GO, biological_process)  2.42e-02          39
# 8           (KEGG, Pathways)  2.80e-02           7
# 9   (GO, biological_process)  3.52e-02           3
# 10   (Dictybase, Phenotypes)  4.05e-02          31
# 11  (GO, molecular_function)  4.83e-02           8
# 12   (Dictybase, Phenotypes)  2.41e-01           8
# 13          (KEGG, Pathways)  2.47e-01           3
# ***  FB selected: 307 with EID: 303
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.23
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 21 out of 69 query genes used for enrichment calculation.
#                                    Gene set                  Ontology  \
# 0                      extracellular region  (GO, cellular_component)
# 1                   oxidoreductase activity  (GO, molecular_function)
# 2           Fructose and mannose metabolism          (KEGG, Pathways)
# 3  Pentose and glucuronate interconversions          (KEGG, Pathways)
#
#         FDR  N in query
# 0  9.90e-02           9
# 1  9.90e-02          11
# 2  1.46e-01           3
# 3  1.46e-01           2

# %% [markdown]
# ##### DESeq2 WT lFC >= 1 and padj <= 0.05

# %%
milestones=pd.read_table(path_de+'WT_batchrep_combined.tsv',index_col=0,sep='\t')
for stage in [phenotype for phenotype in PHENOTYPES if phenotype in list(milestones['Stage'].unique())]:
    query_names=list(milestones.query('log2FoldChange>=1 & padj <= 0.05 & Stage=="'+stage+'"').index)
    enriched=group_diff_enrichment(query_names=query_names,group=stage,min_overlap=2,use_annotated_genes=True)
# Out:
# ***  no_agg selected: 2578 with EID: 2560
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.38
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 640 out of 968 query genes used for enrichment calculation.
#                                           Gene set                  Ontology  \
# 0                                         Ribosome          (KEGG, Pathways)
# 1                                         ribosome  (GO, cellular_component)
# 2               structural constituent of ribosome  (GO, molecular_function)
# 3                                      translation  (GO, biological_process)
# 4                     structural molecule activity  (GO, molecular_function)
# 5                                    mitochondrion  (GO, cellular_component)
# 6                              ribosome biogenesis  (GO, biological_process)
# 7                                        nucleolus  (GO, cellular_component)
# 8                Ribosome biogenesis in eukaryotes          (KEGG, Pathways)
# 9                                      RNA binding  (GO, molecular_function)
# 10                          tRNA metabolic process  (GO, biological_process)
# 11                     Aminoacyl-tRNA biosynthesis          (KEGG, Pathways)
# 12                              Metabolic pathways          (KEGG, Pathways)
# 13                       Oxidative phosphorylation          (KEGG, Pathways)
# 14                                    rRNA binding  (GO, molecular_function)
# 15                      methyltransferase activity  (GO, molecular_function)
# 16                            Steroid biosynthesis          (KEGG, Pathways)
# 17                                 ligase activity  (GO, molecular_function)
# 18           cellular amino acid metabolic process  (GO, biological_process)
# 19                small molecule metabolic process  (GO, biological_process)
# 20           Biosynthesis of secondary metabolites          (KEGG, Pathways)
# 21  generation of precursor metabolites and energy  (GO, biological_process)
# 22                         oxidoreductase activity  (GO, molecular_function)
# 23                      cofactor metabolic process  (GO, biological_process)
# 24                      mitochondrion organization  (GO, biological_process)
# 25            Porphyrin and chlorophyll metabolism          (KEGG, Pathways)
# 26                        unfolded protein binding  (GO, molecular_function)
# 27                           Fatty acid elongation          (KEGG, Pathways)
# 28                           Pyrimidine metabolism          (KEGG, Pathways)
# 29                              isomerase activity  (GO, molecular_function)
# 30                             Sulfur relay system          (KEGG, Pathways)
# 31                                 protein folding  (GO, biological_process)
# 32                               Purine metabolism          (KEGG, Pathways)
# 33              transmembrane transporter activity  (GO, molecular_function)
#
#          FDR  N in query
# 0   4.37e-52          94
# 1   3.25e-46          88
# 2   4.69e-45          82
# 3   1.11e-36         120
# 4   1.22e-30          89
# 5   6.34e-22         125
# 6   1.73e-19          50
# 7   1.65e-12          48
# 8   1.43e-11          45
# 9   5.13e-09          79
# 10  2.03e-08          41
# 11  2.91e-08          31
# 12  2.56e-07         223
# 13  2.98e-07          33
# 14  1.24e-05          12
# 15  6.50e-05          30
# 16  7.05e-05          14
# 17  1.31e-04          38
# 18  2.42e-04          52
# 19  2.42e-04         121
# 20  4.25e-04          99
# 21  1.27e-02          32
# 22  1.42e-02          71
# 23  1.61e-02          30
# 24  1.62e-02          13
# 25  2.85e-02           9
# 26  2.94e-02          14
# 27  6.61e-02           8
# 28  6.61e-02          14
# 29  6.61e-02          21
# 30  1.16e-01           6
# 31  1.19e-01          16
# 32  1.34e-01          20
# 33  2.30e-01          48
# ***  stream selected: 557 with EID: 553
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.35
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 88 out of 194 query genes used for enrichment calculation.
#                                        Gene set                  Ontology  \
# 0                                    Proteasome          (KEGG, Pathways)
# 1                            peptidase activity  (GO, molecular_function)
# 2                             catabolic process  (GO, biological_process)
# 3   Protein processing in endoplasmic reticulum          (KEGG, Pathways)
# 4                         endoplasmic reticulum  (GO, cellular_component)
# 5        Various types of N-glycan biosynthesis          (KEGG, Pathways)
# 6                                Protein export          (KEGG, Pathways)
# 7                            aberrant streaming   (Dictybase, Phenotypes)
# 8                                 curly fingers   (Dictybase, Phenotypes)
# 9       decreased contractile vacuole discharge   (Dictybase, Phenotypes)
# 10     development arrests at loose mound stage   (Dictybase, Phenotypes)
# 11                        N-Glycan biosynthesis          (KEGG, Pathways)
#
#          FDR  N in query
# 0   3.43e-40          34
# 1   3.46e-09          23
# 2   6.26e-07          35
# 3   1.01e-05          18
# 4   3.53e-05          20
# 5   2.21e-02           6
# 6   5.18e-02           5
# 7   5.85e-02          10
# 8   5.85e-02           2
# 9   5.85e-02           2
# 10  5.85e-02           5
# 11  6.31e-02           6
# ***  lag selected: 509 with EID: 505
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.36
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 136 out of 183 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0                                                Proteasome
# 1                                           plasma membrane
# 2                                        peptidase activity
# 3                                        aberrant streaming
# 4                                  decreased aggregate size
# 5                                  aberrant cell morphology
# 6                                      aberrant cytokinesis
# 7                                             curly fingers
# 8                   decreased contractile vacuole discharge
# 9                  development arrests at loose mound stage
# 10                                    endoplasmic reticulum
# 11                   Various types of N-glycan biosynthesis
# 12                                               locomotion
# 13                                      signal transduction
# 14                                        catabolic process
# 15                                cytoskeleton organization
# 16                             cytoskeletal protein binding
# 17                                       cell morphogenesis
# 18                             aberrant cAMP wave formation
# 19                  aberrant contractile vacuole morphology
# 20                                             cytoskeleton
# 21                                     extracellular region
# 22                         anatomical structure development
# 23                                                wild type
# 24                                    decreased culmination
# 25                            increased basal F-actin level
# 26                                         aberrant binding
# 27                                            cell motility
# 28                                    decreased pinocytosis
# 29                                   precocious culmination
# 30                                 Other glycan degradation
# 31                                      delayed development
# 32                                            cell adhesion
# 33                               multiple tips in culminant
# 34                                     aberrant culmination
# 35  aberrant positive regulation of chemorepellant activity
# 36              Protein processing in endoplasmic reticulum
# 37                                     aberrant aggregation
# 38                             decreased fruiting body size
# 39                                    decreased growth rate
# 40                                   decreased phagocytosis
# 41                            aberrant F-actin organization
# 42                                         ABC transporters
# 43                abolished activation of adenylate cyclase
# 44                       development arrests at mound stage
# 45                                  increased protein level
# 46                                 increased slug migration
# 47                                 abolished slug migration
# 48                                    N-Glycan biosynthesis
# 49                                       mitotic cell cycle
# 50                                    increased growth rate
# 51                                enzyme regulator activity
# 52                                  decreased cell motility
# 53                                   precocious aggregation
#
#                     Ontology       FDR  N in query
# 0           (KEGG, Pathways)  1.39e-21          24
# 1   (GO, cellular_component)  7.82e-03          27
# 2   (GO, molecular_function)  7.82e-03          14
# 3    (Dictybase, Phenotypes)  2.90e-02          11
# 4    (Dictybase, Phenotypes)  2.97e-02           7
# 5    (Dictybase, Phenotypes)  4.73e-02           7
# 6    (Dictybase, Phenotypes)  4.73e-02          12
# 7    (Dictybase, Phenotypes)  4.73e-02           2
# 8    (Dictybase, Phenotypes)  4.73e-02           2
# 9    (Dictybase, Phenotypes)  4.73e-02           5
# 10  (GO, cellular_component)  4.73e-02          13
# 11          (KEGG, Pathways)  4.73e-02           5
# 12  (GO, biological_process)  4.73e-02          18
# 13  (GO, biological_process)  4.73e-02          28
# 14  (GO, biological_process)  4.73e-02          23
# 15  (GO, biological_process)  4.73e-02          19
# 16  (GO, molecular_function)  4.73e-02          16
# 17  (GO, biological_process)  5.49e-02           5
# 18   (Dictybase, Phenotypes)  6.59e-02          11
# 19   (Dictybase, Phenotypes)  6.59e-02           3
# 20  (GO, cellular_component)  6.67e-02          17
# 21  (GO, cellular_component)  7.03e-02          15
# 22  (GO, biological_process)  7.03e-02          32
# 23   (Dictybase, Phenotypes)  7.08e-02          26
# 24   (Dictybase, Phenotypes)  7.08e-02           3
# 25   (Dictybase, Phenotypes)  7.08e-02           4
# 26   (Dictybase, Phenotypes)  7.08e-02           2
# 27  (GO, biological_process)  1.08e-01           8
# 28   (Dictybase, Phenotypes)  1.11e-01           5
# 29   (Dictybase, Phenotypes)  1.13e-01           2
# 30          (KEGG, Pathways)  1.13e-01           3
# 31   (Dictybase, Phenotypes)  1.20e-01           8
# 32  (GO, biological_process)  1.20e-01           9
# 33   (Dictybase, Phenotypes)  1.53e-01           2
# 34   (Dictybase, Phenotypes)  1.53e-01           9
# 35   (Dictybase, Phenotypes)  1.53e-01           2
# 36          (KEGG, Pathways)  1.53e-01           9
# 37   (Dictybase, Phenotypes)  1.60e-01           7
# 38   (Dictybase, Phenotypes)  1.60e-01           8
# 39   (Dictybase, Phenotypes)  1.72e-01          12
# 40   (Dictybase, Phenotypes)  1.77e-01           7
# 41   (Dictybase, Phenotypes)  1.80e-01           5
# 42          (KEGG, Pathways)  1.96e-01           3
# 43   (Dictybase, Phenotypes)  2.08e-01           2
# 44   (Dictybase, Phenotypes)  2.08e-01           6
# 45   (Dictybase, Phenotypes)  2.08e-01           2
# 46   (Dictybase, Phenotypes)  2.08e-01           2
# 47   (Dictybase, Phenotypes)  2.08e-01           5
# 48          (KEGG, Pathways)  2.08e-01           4
# 49  (GO, biological_process)  2.08e-01           9
# 50   (Dictybase, Phenotypes)  2.17e-01           4
# 51  (GO, molecular_function)  2.17e-01           9
# 52   (Dictybase, Phenotypes)  2.45e-01           7
# 53   (Dictybase, Phenotypes)  2.48e-01           3
# ***  tag selected: 305 with EID: 305
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.36
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 93 out of 109 query genes used for enrichment calculation.
#                           Gene set                  Ontology       FDR  \
# 0                  DNA replication          (KEGG, Pathways)  1.25e-29
# 1                       chromosome  (GO, cellular_component)  1.50e-26
# 2                       cell cycle  (GO, biological_process)  5.93e-19
# 3          chromosome organization  (GO, biological_process)  2.37e-16
# 4            DNA metabolic process  (GO, biological_process)  3.07e-16
# 5                  Mismatch repair          (KEGG, Pathways)  1.46e-15
# 6           chromosome segregation  (GO, biological_process)  3.45e-14
# 7       Nucleotide excision repair          (KEGG, Pathways)  9.47e-11
# 8                    cell division  (GO, biological_process)  2.48e-10
# 9         mitotic nuclear division  (GO, biological_process)  4.06e-10
# 10            Base excision repair          (KEGG, Pathways)  7.88e-10
# 11                     DNA binding  (GO, molecular_function)  6.95e-09
# 12              mitotic cell cycle  (GO, biological_process)  6.11e-07
# 13              nuclear chromosome  (GO, cellular_component)  1.54e-06
# 14                 ATPase activity  (GO, molecular_function)  4.19e-04
# 15   microtubule organizing center  (GO, cellular_component)  4.61e-04
# 16  Ubiquitin mediated proteolysis          (KEGG, Pathways)  1.85e-03
# 17        Homologous recombination          (KEGG, Pathways)  3.81e-03
# 18              response to stress  (GO, biological_process)  4.54e-03
# 19                    cytoskeleton  (GO, cellular_component)  1.06e-02
# 20               cell cycle arrest   (Dictybase, Phenotypes)  4.63e-02
# 21           Pyrimidine metabolism          (KEGG, Pathways)  4.76e-02
# 22               helicase activity  (GO, molecular_function)  7.45e-02
# 23      Non-homologous end-joining          (KEGG, Pathways)  7.87e-02
# 24                 histone binding  (GO, molecular_function)  7.87e-02
# 25    increased cell-cell adhesion   (Dictybase, Phenotypes)  2.24e-01
#
#     N in query
# 0           24
# 1           29
# 2           33
# 3           22
# 4           25
# 5           13
# 6           12
# 7           13
# 8           20
# 9            9
# 10          11
# 11          25
# 12          15
# 13           7
# 14          15
# 15           8
# 16           8
# 17           5
# 18          21
# 19          13
# 20           2
# 21           4
# 22           5
# 23           2
# 24           2
# 25           2
# ***  tip selected: 309 with EID: 308
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.39
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 103 out of 119 query genes used for enrichment calculation.
#                           Gene set                  Ontology       FDR  \
# 0                       chromosome  (GO, cellular_component)  8.09e-33
# 1                  DNA replication          (KEGG, Pathways)  5.65e-29
# 2          chromosome organization  (GO, biological_process)  2.72e-23
# 3                       cell cycle  (GO, biological_process)  5.55e-21
# 4            DNA metabolic process  (GO, biological_process)  9.91e-19
# 5           chromosome segregation  (GO, biological_process)  1.36e-17
# 6                  Mismatch repair          (KEGG, Pathways)  3.62e-15
# 7         mitotic nuclear division  (GO, biological_process)  2.23e-13
# 8                      DNA binding  (GO, molecular_function)  1.40e-12
# 9                    cell division  (GO, biological_process)  1.47e-12
# 10      Nucleotide excision repair          (KEGG, Pathways)  9.12e-12
# 11            Base excision repair          (KEGG, Pathways)  6.73e-11
# 12              mitotic cell cycle  (GO, biological_process)  3.51e-08
# 13              nuclear chromosome  (GO, cellular_component)  9.11e-08
# 14   microtubule organizing center  (GO, cellular_component)  1.29e-05
# 15  Ubiquitin mediated proteolysis          (KEGG, Pathways)  5.36e-04
# 16                 ATPase activity  (GO, molecular_function)  9.13e-04
# 17           Pyrimidine metabolism          (KEGG, Pathways)  1.20e-03
# 18                    cytoskeleton  (GO, cellular_component)  2.38e-03
# 19        Homologous recombination          (KEGG, Pathways)  4.52e-03
# 20                 histone binding  (GO, molecular_function)  4.89e-03
# 21                     nucleoplasm  (GO, cellular_component)  3.12e-02
# 22               cell cycle arrest   (Dictybase, Phenotypes)  4.24e-02
# 23     aberrant nucleus morphology   (Dictybase, Phenotypes)  4.24e-02
# 24      Non-homologous end-joining          (KEGG, Pathways)  8.21e-02
# 25               helicase activity  (GO, molecular_function)  8.24e-02
# 26              response to stress  (GO, biological_process)  9.05e-02
# 27                nuclear envelope  (GO, cellular_component)  1.77e-01
# 28      methyltransferase activity  (GO, molecular_function)  2.38e-01
#
#     N in query
# 0           34
# 1           24
# 2           28
# 3           36
# 4           28
# 5           14
# 6           13
# 7           11
# 8           31
# 9           23
# 10          14
# 11          12
# 12          17
# 13           8
# 14          10
# 15           9
# 16          15
# 17           6
# 18          15
# 19           5
# 20           3
# 21           8
# 22           2
# 23           2
# 24           2
# 25           5
# 26          18
# 27           3
# 28           4
# ***  slug selected: 757 with EID: 753
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.24
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 107 out of 182 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                     chromosome segregation
# 1                                                 chromosome
# 2                           external encapsulating structure
# 3                                                  cell wall
# 4                                            DNA replication
# 5                                    chromosome organization
# 6                                                 cell cycle
# 7                                   mitotic nuclear division
# 8                                         nuclear chromosome
# 9                                     Glutathione metabolism
# 10                                 decreased spore viability
# 11                            aberrant spore coat morphology
# 12                                          ABC transporters
# 13                                           ATPase activity
# 14                                      extracellular region
# 15  anatomical structure formation involved in morphogenesis
# 16                                             cell division
# 17                                        mitotic cell cycle
# 18                                               DNA binding
# 19                 DNA-binding transcription factor activity
# 20                                      Base excision repair
# 21                        transmembrane transporter activity
# 22                                     Pyrimidine metabolism
# 23        abolished negative regulation of vegetative growth
# 24                                      cell differentiation
# 25                           aberrant myosin II organization
# 26                      increased sorting to prestalk region
# 27                                         cell cycle arrest
# 28                 increased prestalk 0 cell differentiation
# 29                                increased macropinocytosis
# 30                                   transmembrane transport
# 31                             microtubule organizing center
# 32                                Nucleotide excision repair
# 33                   increased prespore cell differentiation
# 34                      cell wall organization or biogenesis
# 35                                       extracellular space
# 36                          anatomical structure development
# 37                                           histone binding
#
#                     Ontology       FDR  N in query
# 0   (GO, biological_process)  1.32e-04           8
# 1   (GO, cellular_component)  6.75e-04          13
# 2   (GO, cellular_component)  6.75e-04           6
# 3   (GO, cellular_component)  6.75e-04           6
# 4           (KEGG, Pathways)  6.75e-04           9
# 5   (GO, biological_process)  1.05e-03          13
# 6   (GO, biological_process)  2.33e-03          20
# 7   (GO, biological_process)  1.29e-02           5
# 8   (GO, cellular_component)  1.97e-02           5
# 9           (KEGG, Pathways)  1.97e-02           6
# 10   (Dictybase, Phenotypes)  3.06e-02           9
# 11   (Dictybase, Phenotypes)  3.41e-02           4
# 12          (KEGG, Pathways)  7.59e-02           4
# 13  (GO, molecular_function)  7.59e-02          16
# 14  (GO, cellular_component)  8.14e-02          15
# 15  (GO, biological_process)  8.14e-02           9
# 16  (GO, biological_process)  8.14e-02          12
# 17  (GO, biological_process)  8.14e-02          11
# 18  (GO, molecular_function)  8.14e-02          19
# 19  (GO, molecular_function)  8.14e-02           6
# 20          (KEGG, Pathways)  9.40e-02           5
# 21  (GO, molecular_function)  9.40e-02          14
# 22          (KEGG, Pathways)  1.05e-01           5
# 23   (Dictybase, Phenotypes)  1.25e-01           2
# 24  (GO, biological_process)  1.56e-01          13
# 25   (Dictybase, Phenotypes)  1.56e-01           2
# 26   (Dictybase, Phenotypes)  1.56e-01           2
# 27   (Dictybase, Phenotypes)  1.56e-01           2
# 28   (Dictybase, Phenotypes)  1.56e-01           2
# 29   (Dictybase, Phenotypes)  1.56e-01           2
# 30  (GO, biological_process)  1.56e-01          14
# 31  (GO, cellular_component)  2.00e-01           6
# 32          (KEGG, Pathways)  2.00e-01           5
# 33   (Dictybase, Phenotypes)  2.07e-01           2
# 34  (GO, biological_process)  2.10e-01           3
# 35  (GO, cellular_component)  2.14e-01           2
# 36  (GO, biological_process)  2.14e-01          28
# 37  (GO, molecular_function)  2.14e-01           2
# ***  mhat selected: 1615 with EID: 1609
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.29
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 219 out of 468 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                             aberrant spore coat morphology
# 1   anatomical structure formation involved in morphogenesis
# 2                                       cell differentiation
# 3                                       extracellular region
# 4                           anatomical structure development
# 5                                  decreased spore viability
# 6                              Starch and sucrose metabolism
# 7                                            Golgi apparatus
# 8                           abolished cellulose biosynthesis
# 9                       cell wall organization or biogenesis
# 10                    decreased autophagic vacuole formation
# 11                          external encapsulating structure
# 12                                                 cell wall
# 13                   increased prespore cell differentiation
# 14                                                   Alanine
# 15                                      Galactose metabolism
# 16                                  Phenylalanine metabolism
# 17                              increased catalytic activity
# 18                            carbohydrate metabolic process
# 19                               abolished cellulose binding
# 20                                                 wild type
# 21                                      aberrant thermotaxis
# 22                                       delayed culmination
# 23                 decreased prestalk A cell differentiation
# 24                                      aberrant culmination
# 25                                  aberrant stalk formation
# 26                                           spores inviable
# 27                                   abolished tip formation
# 28                                 aberrant spore morphology
# 29                                      extracellular matrix
# 30                                       Tyrosine metabolism
# 31                        Taurine and hypotaurine metabolism
# 32                                       signal transduction
# 33                                   aberrant slug migration
# 34                              abolished catalytic activity
#
#                     Ontology       FDR  N in query
# 0    (Dictybase, Phenotypes)  3.04e-04           9
# 1   (GO, biological_process)  3.82e-03          22
# 2   (GO, biological_process)  3.82e-03          35
# 3   (GO, cellular_component)  5.80e-03          36
# 4   (GO, biological_process)  6.52e-03          78
# 5    (Dictybase, Phenotypes)  7.15e-03          18
# 6           (KEGG, Pathways)  7.24e-03          12
# 7   (GO, cellular_component)  1.40e-02          22
# 8    (Dictybase, Phenotypes)  3.89e-02           4
# 9   (GO, biological_process)  3.89e-02           7
# 10   (Dictybase, Phenotypes)  6.60e-02           3
# 11  (GO, cellular_component)  7.53e-02           6
# 12  (GO, cellular_component)  7.53e-02           6
# 13   (Dictybase, Phenotypes)  7.55e-02           4
# 14          (KEGG, Pathways)  9.29e-02           8
# 15          (KEGG, Pathways)  9.29e-02           6
# 16          (KEGG, Pathways)  9.29e-02           5
# 17   (Dictybase, Phenotypes)  1.45e-01           3
# 18  (GO, biological_process)  1.45e-01          19
# 19   (Dictybase, Phenotypes)  1.86e-01           2
# 20   (Dictybase, Phenotypes)  1.86e-01          54
# 21   (Dictybase, Phenotypes)  1.86e-01           3
# 22   (Dictybase, Phenotypes)  1.86e-01           8
# 23   (Dictybase, Phenotypes)  1.86e-01           2
# 24   (Dictybase, Phenotypes)  1.86e-01          18
# 25   (Dictybase, Phenotypes)  1.86e-01           3
# 26   (Dictybase, Phenotypes)  1.86e-01           3
# 27   (Dictybase, Phenotypes)  1.86e-01           2
# 28   (Dictybase, Phenotypes)  1.86e-01           4
# 29  (GO, cellular_component)  1.86e-01           4
# 30          (KEGG, Pathways)  1.86e-01           5
# 31          (KEGG, Pathways)  1.86e-01           3
# 32  (GO, biological_process)  1.86e-01          56
# 33   (Dictybase, Phenotypes)  2.09e-01          13
# 34   (Dictybase, Phenotypes)  2.31e-01           5
# ***  cul selected: 2289 with EID: 2274
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.28
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 373 out of 631 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0   anatomical structure formation involved in morphogenesis
# 1                                       cell differentiation
# 2                              Starch and sucrose metabolism
# 3                           anatomical structure development
# 4                             aberrant spore coat morphology
# 5                                       extracellular region
# 6                  DNA-binding transcription factor activity
# 7                                       aberrant culmination
# 8                    increased prespore cell differentiation
# 9                  decreased prestalk 0 cell differentiation
# 10                                 decreased gene expression
# 11                      cell wall organization or biogenesis
# 12                                           kinase activity
# 13                 SNARE interactions in vesicular transport
# 14                                       signal transduction
# 15                                   aberrant slug migration
# 16                                 decreased spore viability
# 17                                  abolished DIF production
# 18                              precocious spore germination
# 19                                        thin standing slug
# 20                                 increased gene expression
# 21                    decreased autophagic vacuole formation
# 22                          abolished cellulose biosynthesis
# 23                                 aberrant spore morphology
# 24                                           Golgi apparatus
# 25                                      Galactose metabolism
# 26                               secondary metabolic process
# 27                 development arrests at tipped mound stage
# 28                           abolished autophagic cell death
# 29                    abolished autophagic vacuole formation
# 30                                       aberrant phototaxis
# 31                  Pentose and glucuronate interconversions
# 32                                       delayed culmination
# 33                                                 wild type
# 34                          external encapsulating structure
# 35                                                 cell wall
# 36       Ubiquinone and other terpenoid-quinone biosynthesis
# 37                                  Phenylalanine metabolism
# 38                              increased catalytic activity
# 39                                      increased sorus size
# 40                                                 autophagy
# 41                                     abolished culmination
# 42                    aberrant prestalk cell differentiation
# 43                                   delayed gene expression
# 44                         aberrant fruiting body morphology
# 45                               abolished cellulose binding
# 46                        aberrant response to valproic acid
# 47                          aberrant protein phosphorylation
# 48                decreased protein tyrosine phosphorylation
# 49                            decreased pseudopod retraction
# 50                            increased standing slug length
# 51                 decreased prestalk A cell differentiation
# 52                             aberrant protein localization
# 53                      abolished outer basal disc formation
# 54                              aberrant response to lithium
# 55                                   abolished tip formation
# 56                              aberrant negative chemotaxis
# 57                                      extracellular matrix
# 58                                       Nitrogen metabolism
# 59                                  aberrant gene expression
# 60                                      aberrant thermotaxis
# 61                                    precocious sporulation
# 62                                  aberrant stalk formation
# 63                                           spores inviable
# 64                            aberrant autophagic cell death
# 65                           Arginine and proline metabolism
# 66                                       cell-cell signaling
# 67                                               DNA binding
# 68                                  abolished slug migration
#
#                     Ontology       FDR  N in query
# 0   (GO, biological_process)  5.55e-08          35
# 1   (GO, biological_process)  5.55e-08          54
# 2           (KEGG, Pathways)  1.66e-05          18
# 3   (GO, biological_process)  1.66e-05         110
# 4    (Dictybase, Phenotypes)  5.21e-05          10
# 5   (GO, cellular_component)  1.22e-03          46
# 6   (GO, molecular_function)  2.16e-02          15
# 7    (Dictybase, Phenotypes)  2.47e-02          27
# 8    (Dictybase, Phenotypes)  3.04e-02           5
# 9    (Dictybase, Phenotypes)  3.04e-02           4
# 10   (Dictybase, Phenotypes)  3.04e-02          26
# 11  (GO, biological_process)  3.99e-02           8
# 12  (GO, molecular_function)  4.55e-02          73
# 13          (KEGG, Pathways)  5.95e-02          10
# 14  (GO, biological_process)  7.13e-02          76
# 15   (Dictybase, Phenotypes)  7.74e-02          18
# 16   (Dictybase, Phenotypes)  7.74e-02          18
# 17   (Dictybase, Phenotypes)  7.74e-02           3
# 18   (Dictybase, Phenotypes)  7.74e-02           3
# 19   (Dictybase, Phenotypes)  7.74e-02           3
# 20   (Dictybase, Phenotypes)  7.74e-02          15
# 21   (Dictybase, Phenotypes)  7.74e-02           3
# 22   (Dictybase, Phenotypes)  7.74e-02           4
# 23   (Dictybase, Phenotypes)  7.74e-02           5
# 24  (GO, cellular_component)  7.74e-02          24
# 25          (KEGG, Pathways)  7.74e-02           7
# 26  (GO, biological_process)  7.74e-02           4
# 27   (Dictybase, Phenotypes)  1.17e-01           6
# 28   (Dictybase, Phenotypes)  1.19e-01           4
# 29   (Dictybase, Phenotypes)  1.19e-01           4
# 30   (Dictybase, Phenotypes)  1.19e-01           4
# 31          (KEGG, Pathways)  1.19e-01           4
# 32   (Dictybase, Phenotypes)  1.36e-01          10
# 33   (Dictybase, Phenotypes)  1.46e-01          70
# 34  (GO, cellular_component)  1.46e-01           6
# 35  (GO, cellular_component)  1.46e-01           6
# 36          (KEGG, Pathways)  1.74e-01           5
# 37          (KEGG, Pathways)  1.74e-01           5
# 38   (Dictybase, Phenotypes)  1.80e-01           3
# 39   (Dictybase, Phenotypes)  1.80e-01           3
# 40  (GO, biological_process)  1.80e-01          11
# 41   (Dictybase, Phenotypes)  1.81e-01          17
# 42   (Dictybase, Phenotypes)  1.81e-01           4
# 43   (Dictybase, Phenotypes)  1.92e-01           7
# 44   (Dictybase, Phenotypes)  2.12e-01          24
# 45   (Dictybase, Phenotypes)  2.29e-01           2
# 46   (Dictybase, Phenotypes)  2.29e-01           2
# 47   (Dictybase, Phenotypes)  2.29e-01           2
# 48   (Dictybase, Phenotypes)  2.29e-01           2
# 49   (Dictybase, Phenotypes)  2.29e-01           2
# 50   (Dictybase, Phenotypes)  2.29e-01           2
# 51   (Dictybase, Phenotypes)  2.29e-01           2
# 52   (Dictybase, Phenotypes)  2.29e-01          10
# 53   (Dictybase, Phenotypes)  2.29e-01           2
# 54   (Dictybase, Phenotypes)  2.29e-01           2
# 55   (Dictybase, Phenotypes)  2.29e-01           2
# 56   (Dictybase, Phenotypes)  2.29e-01           2
# 57  (GO, cellular_component)  2.31e-01           4
# 58          (KEGG, Pathways)  2.31e-01           4
# 59   (Dictybase, Phenotypes)  2.38e-01           8
# 60   (Dictybase, Phenotypes)  2.38e-01           3
# 61   (Dictybase, Phenotypes)  2.38e-01           3
# 62   (Dictybase, Phenotypes)  2.38e-01           3
# 63   (Dictybase, Phenotypes)  2.38e-01           3
# 64   (Dictybase, Phenotypes)  2.38e-01           3
# 65          (KEGG, Pathways)  2.38e-01           7
# 66  (GO, biological_process)  2.38e-01           6
# 67  (GO, molecular_function)  2.38e-01          46
# 68   (Dictybase, Phenotypes)  2.47e-01          12
# ***  FB selected: 1096 with EID: 1085
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.28
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 148 out of 304 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                       cell differentiation
# 1                           anatomical structure development
# 2                  DNA-binding transcription factor activity
# 3                                   aberrant gene expression
# 4                  decreased prestalk 0 cell differentiation
# 5                  SNARE interactions in vesicular transport
# 6   anatomical structure formation involved in morphogenesis
# 7                                                DNA binding
# 8                                            kinase activity
# 9                           aberrant protein phosphorylation
# 10                            decreased pseudopod retraction
# 11                 decreased prestalk A cell differentiation
# 12                      abolished outer basal disc formation
# 13                                 decreased gene expression
# 14                               secondary metabolic process
# 15                   increased prespore cell differentiation
# 16                                      aberrant culmination
# 17                                  decreased slug migration
# 18                 development arrests at tipped mound stage
# 19                                   aberrant slug migration
# 20                    aberrant prestalk cell differentiation
# 21                                                 autophagy
# 22                                                 wild type
# 23                              precocious spore germination
# 24                                aberrant spore germination
# 25                           Arginine and proline metabolism
#
#                     Ontology       FDR  N in query
# 0   (GO, biological_process)  3.34e-02          25
# 1   (GO, biological_process)  4.04e-02          54
# 2   (GO, molecular_function)  4.30e-02          10
# 3    (Dictybase, Phenotypes)  8.03e-02           7
# 4    (Dictybase, Phenotypes)  8.03e-02           3
# 5           (KEGG, Pathways)  8.03e-02           7
# 6   (GO, biological_process)  8.03e-02          14
# 7   (GO, molecular_function)  8.03e-02          30
# 8   (GO, molecular_function)  1.37e-01          39
# 9    (Dictybase, Phenotypes)  1.48e-01           2
# 10   (Dictybase, Phenotypes)  1.48e-01           2
# 11   (Dictybase, Phenotypes)  1.48e-01           2
# 12   (Dictybase, Phenotypes)  1.48e-01           2
# 13   (Dictybase, Phenotypes)  1.48e-01          14
# 14  (GO, biological_process)  1.48e-01           3
# 15   (Dictybase, Phenotypes)  1.59e-01           3
# 16   (Dictybase, Phenotypes)  1.59e-01          14
# 17   (Dictybase, Phenotypes)  1.59e-01           4
# 18   (Dictybase, Phenotypes)  2.06e-01           4
# 19   (Dictybase, Phenotypes)  2.25e-01          10
# 20   (Dictybase, Phenotypes)  2.25e-01           3
# 21  (GO, biological_process)  2.27e-01           7
# 22   (Dictybase, Phenotypes)  2.43e-01          37
# 23   (Dictybase, Phenotypes)  2.43e-01           2
# 24   (Dictybase, Phenotypes)  2.43e-01           2
# 25          (KEGG, Pathways)  2.43e-01           5

# %% [markdown]
# ### ImpulseDE2
# Milestone genes are selected as those that are at up-level in a stage and at down level at non neighbouring stages (to account for imperfect annotation of up/down). no_agg is not considered a neighbour of stream and vice versa.

# %% [markdown]
# #### ImpulseDE2 all strains

# %%
milestones=pd.read_table(path_impulse+'DEacrossStages_summary_noyem.tsv',index_col=0,sep='\t')
stages=np.array([phenotype for phenotype in PHENOTYPES if phenotype in list(milestones.columns)])
for stage_idx,stage in enumerate(stages):
    
    #Nonneighbouring stages
    neigh_previous=1
    neigh_next=1
    #Assumes phenotypes order
    if stage_idx==1:
        neigh_previous=0
    if stage_idx==0:
        neigh_next=0
    non_neighbours = stages[[(idx <stage_idx-neigh_previous or idx>stage_idx+neigh_next) 
                 for idx in range(len(stages)) ]]
    #print(stage,':',non_neighbours)
    
    #Find genes up at stage and down at nonenighbouring
    query_condition=stage+'=="up"'
    for non_neigh in non_neighbours:
        query_condition=query_condition+' & '+non_neigh+' =="down"'
    #print(query_condition)
    
    query_names=list(milestones.query(query_condition).index)
    enriched=group_diff_enrichment(query_names=query_names,group=stage,min_overlap=2,use_annotated_genes=True)
# Out:
# ***  no_agg selected: 1199 with EID: 1193
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.4
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 344 out of 479 query genes used for enrichment calculation.
#                                           Gene set                  Ontology  \
# 0                                         Ribosome          (KEGG, Pathways)
# 1                                         ribosome  (GO, cellular_component)
# 2               structural constituent of ribosome  (GO, molecular_function)
# 3                     structural molecule activity  (GO, molecular_function)
# 4                                      translation  (GO, biological_process)
# 5                                    mitochondrion  (GO, cellular_component)
# 6                               Metabolic pathways          (KEGG, Pathways)
# 7                          oxidoreductase activity  (GO, molecular_function)
# 8                        Oxidative phosphorylation          (KEGG, Pathways)
# 9                      Biosynthesis of amino acids          (KEGG, Pathways)
# 10           Biosynthesis of secondary metabolites          (KEGG, Pathways)
# 11                        unfolded protein binding  (GO, molecular_function)
# 12                small molecule metabolic process  (GO, biological_process)
# 13           cellular amino acid metabolic process  (GO, biological_process)
# 14                                 protein folding  (GO, biological_process)
# 15                                        lysosome  (GO, cellular_component)
# 16                                         Glycine          (KEGG, Pathways)
# 17              transmembrane transporter activity  (GO, molecular_function)
# 18                            Steroid biosynthesis          (KEGG, Pathways)
# 19  generation of precursor metabolites and energy  (GO, biological_process)
# 20                      cofactor metabolic process  (GO, biological_process)
# 21                       Pentose phosphate pathway          (KEGG, Pathways)
# 22                              peptidase activity  (GO, molecular_function)
# 23                              isomerase activity  (GO, molecular_function)
# 24                           Fatty acid elongation          (KEGG, Pathways)
# 25                           Vitamin B6 metabolism          (KEGG, Pathways)
# 26                             Sulfur relay system          (KEGG, Pathways)
# 27                         beta-Alanine metabolism          (KEGG, Pathways)
# 28                                         vacuole  (GO, cellular_component)
# 29                                       Phagosome          (KEGG, Pathways)
# 30                               Carbon metabolism          (KEGG, Pathways)
# 31                            extracellular region  (GO, cellular_component)
# 32                             Lysine biosynthesis          (KEGG, Pathways)
#
#          FDR  N in query
# 0   7.40e-38          67
# 1   3.54e-30          59
# 2   5.02e-30          56
# 3   4.96e-23          59
# 4   1.78e-20          69
# 5   7.78e-08          60
# 6   6.02e-05         119
# 7   6.02e-05          49
# 8   6.62e-05          20
# 9   2.36e-03          19
# 10  3.87e-03          55
# 11  3.90e-03          11
# 12  9.31e-03          64
# 13  1.44e-02          28
# 14  1.86e-02          12
# 15  2.00e-02          18
# 16  2.23e-02           9
# 17  5.06e-02          30
# 18  5.48e-02           7
# 19  5.97e-02          18
# 20  6.49e-02          17
# 21  6.57e-02           7
# 22  6.57e-02          20
# 23  6.57e-02          13
# 24  1.64e-01           5
# 25  1.64e-01           3
# 26  1.70e-01           4
# 27  1.70e-01           7
# 28  1.70e-01          24
# 29  1.82e-01          12
# 30  1.82e-01          20
# 31  2.00e-01          28
# 32  2.36e-01           3
# ***  stream selected: 956 with EID: 941
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.4
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 270 out of 377 query genes used for enrichment calculation.
#                                                      Gene set  \
# 0                                          aberrant streaming
# 1                                        aberrant cytokinesis
# 2                                                  locomotion
# 3                                               cell division
# 4                                                  Proteasome
# 5                                         signal transduction
# 6                                          mitotic cell cycle
# 7                                   cytoskeleton organization
# 8                                             plasma membrane
# 9                               aberrant F-actin organization
# 10                                                 cell cycle
# 11                                      abolished aggregation
# 12                  decreased activation of adenylate cyclase
# 13                                   aberrant cell morphology
# 14                               aberrant cAMP wave formation
# 15                                               cytoskeleton
# 16                                             Protein export
# 17                                cellular component assembly
# 18                               abolished chemotaxis to cAMP
# 19                Protein processing in endoplasmic reticulum
# 20                  abolished activation of adenylate cyclase
# 21                         development arrests at mound stage
# 22                                       aberrant aggregation
# 23                                   decreased aggregate size
# 24                                      endoplasmic reticulum
# 25                               decreased chemotaxis to cAMP
# 26                                    decreased cell motility
# 27                           anatomical structure development
# 28                                  enzyme regulator activity
# 29                             abolished chemotaxis to folate
# 30                       abolished adenylate cyclase activity
# 31                                         cell morphogenesis
# 32                                        delayed aggregation
# 33                                               reproduction
# 34                                        aberrant chemotaxis
# 35                        decreased protein kinase activation
# 36                                                  wild type
# 37                                  decreased chemotaxis rate
# 38                                      abolished culmination
# 39                                        delayed development
# 40                                   abolished slug migration
# 41                          abolished protein phosphorylation
# 42                              aberrant protein localization
# 43                                                    cytosol
# 44                   aberrant adaptation of signaling pathway
# 45                   aberrant localization to plasma membrane
# 46                        protein-containing complex assembly
# 47                                      aberrant phagocytosis
# 48                         increased intracellular cAMP level
# 49                        decreased growth rate in suspension
# 50                                            GTPase activity
# 51                          decreased cAMP-induced cAMP pulse
# 52                                 decreased macropinocytosis
# 53                                aberrant chemotaxis to cAMP
# 54                                      increased growth rate
# 55                    decreased lateral pseudopod suppression
# 56                               aberrant pseudopod formation
# 57                                 vesicle-mediated transport
# 58                                    aberrant slug migration
# 59                                       aberrant culmination
# 60                                              cell motility
# 61                    increased period of cAMP wave formation
# 62           aberrant chemotaxis to cAMP in response to DIF-2
# 63                                      decreased growth rate
# 64                                    decreased cell polarity
# 65                                        abolished streaming
# 66                                    aberrant slug formation
# 67                                         response to stress
# 68                                          protein targeting
# 69                              abolished cAMP wave formation
# 70                                             enzyme binding
# 71                               decreased myosin II assembly
# 72                              increased basal F-actin level
# 73                                      decreased pinocytosis
# 74                                       aberrant development
# 75                                      N-Glycan biosynthesis
# 76                                       decreased exocytosis
# 77                             decreased chemotaxis to folate
# 78                    abolished activation of GTPase activity
# 79                                 precocious gene expression
# 80                               decreased fruiting body size
# 81                   aberrant adaptation of adenylate cyclase
# 82                    decreased secretion of lysosomal enzyme
# 83                             decreased number of aggregates
# 84                                            kinase activity
# 85     Glycosylphosphatidylinositol (GPI)-anchor biosynthesis
# 86                                  decreased gene expression
# 87                                        homeostatic process
# 88                               aberrant stalk morphogenesis
# 89                                     decreased phagocytosis
# 90                                     precocious aggregation
# 91   abolished positive regulation of chemorepellant activity
# 92                aberrant cell separation during cytokinesis
# 93          aberrant activation of adenylate cyclase activity
# 94                          decreased cAMP-induced cGMP pulse
# 95                                             aberrant taxis
# 96           aberrant cellular response to fluid shear stress
# 97                                    abolished cell polarity
# 98                                      decreased stalk width
# 99                             decreased accumulation of cGMP
# 100         decreased protein localization to plasma membrane
# 101                                    precocious culmination
# 102                                             multiple tips
# 103                             microtubule organizing center
# 104                        transmembrane transporter activity
# 105                     increased lateral pseudopod formation
# 106                                    precocious development
#
#                      Ontology       FDR  N in query
# 0     (Dictybase, Phenotypes)  2.91e-08          27
# 1     (Dictybase, Phenotypes)  2.91e-08          32
# 2    (GO, biological_process)  4.16e-06          43
# 3    (GO, biological_process)  5.19e-06          31
# 4            (KEGG, Pathways)  5.81e-06          16
# 5    (GO, biological_process)  5.81e-06          64
# 6    (GO, biological_process)  5.81e-06          28
# 7    (GO, biological_process)  1.40e-05          42
# 8    (GO, cellular_component)  7.71e-05          50
# 9     (Dictybase, Phenotypes)  1.53e-04          14
# 10   (GO, biological_process)  5.05e-04          34
# 11    (Dictybase, Phenotypes)  1.52e-03          20
# 12    (Dictybase, Phenotypes)  1.52e-03           5
# 13    (Dictybase, Phenotypes)  2.15e-03          13
# 14    (Dictybase, Phenotypes)  2.15e-03          22
# 15   (GO, cellular_component)  3.09e-03          34
# 16           (KEGG, Pathways)  3.09e-03           8
# 17   (GO, biological_process)  3.09e-03          36
# 18    (Dictybase, Phenotypes)  3.17e-03           7
# 19           (KEGG, Pathways)  3.88e-03          20
# 20    (Dictybase, Phenotypes)  7.46e-03           5
# 21    (Dictybase, Phenotypes)  8.09e-03          14
# 22    (Dictybase, Phenotypes)  8.98e-03          15
# 23    (Dictybase, Phenotypes)  1.01e-02          10
# 24   (GO, cellular_component)  1.01e-02          23
# 25    (Dictybase, Phenotypes)  1.07e-02          15
# 26    (Dictybase, Phenotypes)  1.07e-02          17
# 27   (GO, biological_process)  1.07e-02          62
# 28   (GO, molecular_function)  1.19e-02          21
# 29    (Dictybase, Phenotypes)  1.26e-02           3
# 30    (Dictybase, Phenotypes)  1.26e-02           3
# 31   (GO, biological_process)  1.26e-02           8
# 32    (Dictybase, Phenotypes)  1.36e-02          16
# 33   (GO, biological_process)  1.36e-02          17
# 34    (Dictybase, Phenotypes)  1.38e-02           4
# 35    (Dictybase, Phenotypes)  1.61e-02           7
# 36    (Dictybase, Phenotypes)  1.83e-02          49
# 37    (Dictybase, Phenotypes)  1.83e-02          10
# 38    (Dictybase, Phenotypes)  2.00e-02          14
# 39    (Dictybase, Phenotypes)  2.03e-02          15
# 40    (Dictybase, Phenotypes)  2.04e-02          11
# 41    (Dictybase, Phenotypes)  2.41e-02           5
# 42    (Dictybase, Phenotypes)  2.48e-02           9
# 43   (GO, cellular_component)  2.87e-02          32
# 44    (Dictybase, Phenotypes)  3.20e-02           3
# 45    (Dictybase, Phenotypes)  3.20e-02           3
# 46   (GO, biological_process)  3.23e-02          23
# 47    (Dictybase, Phenotypes)  3.86e-02           4
# 48    (Dictybase, Phenotypes)  3.86e-02           4
# 49    (Dictybase, Phenotypes)  3.86e-02           4
# 50   (GO, molecular_function)  4.39e-02          24
# 51    (Dictybase, Phenotypes)  4.61e-02           5
# 52    (Dictybase, Phenotypes)  5.73e-02           6
# 53    (Dictybase, Phenotypes)  5.73e-02           8
# 54    (Dictybase, Phenotypes)  5.73e-02           8
# 55    (Dictybase, Phenotypes)  5.73e-02           4
# 56    (Dictybase, Phenotypes)  5.73e-02           4
# 57   (GO, biological_process)  5.73e-02          34
# 58    (Dictybase, Phenotypes)  5.87e-02          12
# 59    (Dictybase, Phenotypes)  6.30e-02          16
# 60   (GO, biological_process)  6.38e-02          13
# 61    (Dictybase, Phenotypes)  6.60e-02           2
# 62    (Dictybase, Phenotypes)  6.60e-02           2
# 63    (Dictybase, Phenotypes)  7.07e-02          22
# 64    (Dictybase, Phenotypes)  7.37e-02           8
# 65    (Dictybase, Phenotypes)  7.37e-02           8
# 66    (Dictybase, Phenotypes)  7.39e-02           4
# 67   (GO, biological_process)  8.77e-02          47
# 68   (GO, biological_process)  1.01e-01           8
# 69    (Dictybase, Phenotypes)  1.01e-01           4
# 70   (GO, molecular_function)  1.01e-01          18
# 71    (Dictybase, Phenotypes)  1.15e-01           5
# 72    (Dictybase, Phenotypes)  1.15e-01           5
# 73    (Dictybase, Phenotypes)  1.23e-01           7
# 74    (Dictybase, Phenotypes)  1.23e-01          10
# 75           (KEGG, Pathways)  1.23e-01           7
# 76    (Dictybase, Phenotypes)  1.28e-01           4
# 77    (Dictybase, Phenotypes)  1.28e-01           4
# 78    (Dictybase, Phenotypes)  1.31e-01           3
# 79    (Dictybase, Phenotypes)  1.34e-01           5
# 80    (Dictybase, Phenotypes)  1.35e-01          13
# 81    (Dictybase, Phenotypes)  1.39e-01           2
# 82    (Dictybase, Phenotypes)  1.39e-01           2
# 83    (Dictybase, Phenotypes)  1.39e-01           2
# 84   (GO, molecular_function)  1.40e-01          42
# 85           (KEGG, Pathways)  1.56e-01           5
# 86    (Dictybase, Phenotypes)  1.67e-01          14
# 87   (GO, biological_process)  1.67e-01          12
# 88    (Dictybase, Phenotypes)  1.73e-01           3
# 89    (Dictybase, Phenotypes)  1.75e-01          11
# 90    (Dictybase, Phenotypes)  1.82e-01           5
# 91    (Dictybase, Phenotypes)  1.87e-01           4
# 92    (Dictybase, Phenotypes)  1.87e-01           4
# 93    (Dictybase, Phenotypes)  2.09e-01           2
# 94    (Dictybase, Phenotypes)  2.09e-01           3
# 95    (Dictybase, Phenotypes)  2.09e-01           2
# 96    (Dictybase, Phenotypes)  2.09e-01           2
# 97    (Dictybase, Phenotypes)  2.09e-01           3
# 98    (Dictybase, Phenotypes)  2.09e-01           3
# 99    (Dictybase, Phenotypes)  2.09e-01           2
# 100   (Dictybase, Phenotypes)  2.09e-01           2
# 101   (Dictybase, Phenotypes)  2.09e-01           2
# 102   (Dictybase, Phenotypes)  2.09e-01           4
# 103  (GO, cellular_component)  2.09e-01           9
# 104  (GO, molecular_function)  2.09e-01          21
# 105   (Dictybase, Phenotypes)  2.25e-01           5
# 106   (Dictybase, Phenotypes)  2.25e-01           6
# ***  lag selected: 1190 with EID: 1175
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.39
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 332 out of 461 query genes used for enrichment calculation.
#                                                              Gene set  \
# 0                                                 signal transduction
# 1                                                          locomotion
# 2                                                aberrant cytokinesis
# 3                                                  aberrant streaming
# 4                                           cytoskeleton organization
# 5                                                     kinase activity
# 6                                               abolished aggregation
# 7                                       aberrant F-actin organization
# 8                                                      enzyme binding
# 9                                            aberrant cell morphology
# 10                                            decreased cell motility
# 11                        Protein processing in endoplasmic reticulum
# 12                                          decreased chemotaxis rate
# 13                                                    plasma membrane
# 14                                                          wild type
# 15                            decreased lateral pseudopod suppression
# 16                                       decreased chemotaxis to cAMP
# 17                                              increased growth rate
# 18                                              endoplasmic reticulum
# 19                                  decreased cAMP-induced cAMP pulse
# 20                                        cellular component assembly
# 21                          abolished activation of adenylate cyclase
# 22                                                delayed development
# 23                                        aberrant chemotaxis to cAMP
# 24                                         decreased macropinocytosis
# 25                                decreased protein kinase activation
# 26                                       aberrant pseudopod formation
# 27                                                       cytoskeleton
# 28                                       decreased myosin II assembly
# 29           abolished positive regulation of chemorepellant activity
# 30                                                     Protein export
# 31                                  decreased cell-substrate adhesion
# 32                                           decreased aggregate size
# 33                                  abolished protein phosphorylation
# 34                                   anatomical structure development
# 35                                          enzyme regulator activity
# 36                                                      cell motility
# 37                                     increased filopodium formation
# 38                                                delayed aggregation
# 39                                               aberrant aggregation
# 40                                   increased F-actin polymerization
# 41                                     abolished chemotaxis to folate
# 42                              decreased lateral pseudopod formation
# 43              decreased 3' 5'-cyclic-AMP phosphodiesterase activity
# 44                                     abolished filopodium formation
# 45                                          decreased gene expression
# 46                                       decreased fruiting body size
# 47                                            increased cell motility
# 48                                                    decreased taxis
# 49                                                aberrant chemotaxis
# 50                          decreased activation of adenylate cyclase
# 51                                                 mitotic cell cycle
# 52                              increased lateral pseudopod formation
# 53                                      aberrant protein localization
# 54                                                         Proteasome
# 55                                protein-containing complex assembly
# 56                                           abolished slug migration
# 57                                       aberrant cAMP wave formation
# 58                                       abolished chemotaxis to cAMP
# 59                                                 cell morphogenesis
# 60                                       cytoskeletal protein binding
# 61                                             aberrant cell motility
# 62                   decreased positive regulation of GTPase activity
# 63                                            increased cell polarity
# 64                   aberrant cellular response to fluid shear stress
# 65                                  increased cAMP-induced cAMP pulse
# 66                                  increased cell-substrate adhesion
# 67                                                            cytosol
# 68                                                      cell division
# 69                                                 response to stress
# 70                                       aberrant stalk morphogenesis
# 71                                 increased intracellular cAMP level
# 72                                decreased growth rate in suspension
# 73                                                       reproduction
# 74                                      increased basal F-actin level
# 75                                      microtubule organizing center
# 76                                                abolished streaming
# 77                            increased period of cAMP wave formation
# 78                                         multiple tips in culminant
# 79                                       aberrant signal transduction
# 80                                      abolished negative chemotaxis
# 81              decreased substrate adhesion-dependent cell spreading
# 82           increased Ras guanyl-nucleotide exchange factor activity
# 83                            decreased activation of GTPase activity
# 84                                               aberrant development
# 85                                  decreased cAMP-induced cGMP pulse
# 86                                              decreased culmination
# 87                                              decreased stalk width
# 88                                              decreased growth rate
# 89                                                    GTPase activity
# 90                                              N-Glycan biosynthesis
# 91                                          abolished gene expression
# 92                                            aberrant slug formation
# 93                           development arrests at loose mound stage
# 94                            increased activation of GTPase activity
# 95                                  decreased protein phosphorylation
# 96                      abolished protein localization to cell cortex
# 97                                              abolished culmination
# 98                                             decreased phagocytosis
# 99                                   decreased F-actin polymerization
# 100                            aberrant activation of GTPase activity
# 101                                     abolished cAMP wave formation
# 102                                          Other glycan degradation
# 103                                              phosphatase activity
# 104                                            increased phagocytosis
# 105                                           aberrant slug migration
# 106                           decreased secretion of lysosomal enzyme
# 107                         aberrant socially cooperative development
# 108                              abolished adenylate cyclase activity
# 109                                    decreased number of aggregates
# 110                aberrant cytokinesis  contractile ring contraction
# 111                                                  aberrant binding
# 112                                aberrant response to cation stress
# 113                                                aberrant autophagy
# 114                          decreased engulfment during phagocytosis
# 115         aberrant production of siRNA involved in RNA interference
# 116                               aberrant sorting to prestalk region
# 117                            Various types of N-glycan biosynthesis
# 118                           abolished activation of GTPase activity
# 119                                              decreased exocytosis
# 120                                    decreased chemotaxis to folate
# 121                                      increased myosin II assembly
# 122                                                 protein targeting
# 123                                            precocious development
# 124                                              aberrant culmination
# 125                                                        cell cycle
# 126                                        aberrant vegetative growth
# 127                                        precocious gene expression
# 128                                          increased aggregate size
# 129                                             aberrant phagocytosis
# 130                          aberrant response to hyperosmotic stress
# 131  increased infection rate by a gram-negative pathogenic bacterium
# 132                               increased protein kinase activation
# 133                                          increased slug migration
# 134                                                     cell adhesion
# 135                                                            growth
# 136                                                        cell death
# 137                 aberrant activation of adenylate cyclase activity
# 138                          aberrant adaptation of signaling pathway
# 139                                      increased fruiting body size
# 140              increased F-actin polymerization at the leading edge
# 141                                  abolished F-actin polymerization
# 142                                       increased membrane ruffling
# 143                                     abolished positive chemotaxis
# 144                                         increased chemotaxis rate
# 145                                 increased cytosolic Ca2+ response
# 146                          aberrant localization to plasma membrane
# 147                                    decreased accumulation of cGMP
# 148                                            precocious culmination
# 149                             abolished transitive RNA interference
# 150                           decreased prespore cell differentiation
# 151                                      abolished catalytic activity
# 152                                            precocious aggregation
# 153                                              cell differentiation
#
#                      Ontology       FDR  N in query
# 0    (GO, biological_process)  2.50e-14          95
# 1    (GO, biological_process)  1.30e-10          58
# 2     (Dictybase, Phenotypes)  1.04e-08          36
# 3     (Dictybase, Phenotypes)  1.25e-06          27
# 4    (GO, biological_process)  2.94e-06          50
# 5    (GO, molecular_function)  9.42e-06          70
# 6     (Dictybase, Phenotypes)  9.43e-06          27
# 7     (Dictybase, Phenotypes)  1.14e-05          17
# 8    (GO, molecular_function)  2.51e-05          32
# 9     (Dictybase, Phenotypes)  5.55e-05          17
# 10    (Dictybase, Phenotypes)  1.19e-04          24
# 11           (KEGG, Pathways)  1.69e-04          26
# 12    (Dictybase, Phenotypes)  1.72e-04          15
# 13   (GO, cellular_component)  1.95e-04          56
# 14    (Dictybase, Phenotypes)  2.70e-04          66
# 15    (Dictybase, Phenotypes)  2.70e-04           7
# 16    (Dictybase, Phenotypes)  4.76e-04          20
# 17    (Dictybase, Phenotypes)  4.76e-04          13
# 18   (GO, cellular_component)  4.76e-04          30
# 19    (Dictybase, Phenotypes)  6.13e-04           8
# 20   (GO, biological_process)  9.54e-04          43
# 21    (Dictybase, Phenotypes)  1.26e-03           6
# 22    (Dictybase, Phenotypes)  1.56e-03          20
# 23    (Dictybase, Phenotypes)  2.04e-03          12
# 24    (Dictybase, Phenotypes)  2.25e-03           9
# 25    (Dictybase, Phenotypes)  2.25e-03           9
# 26    (Dictybase, Phenotypes)  2.78e-03           6
# 27   (GO, cellular_component)  4.96e-03          38
# 28    (Dictybase, Phenotypes)  5.20e-03           8
# 29    (Dictybase, Phenotypes)  7.70e-03           7
# 30           (KEGG, Pathways)  7.87e-03           8
# 31    (Dictybase, Phenotypes)  8.89e-03          10
# 32    (Dictybase, Phenotypes)  9.58e-03          11
# 33    (Dictybase, Phenotypes)  9.58e-03           6
# 34   (GO, biological_process)  9.58e-03          73
# 35   (GO, molecular_function)  1.08e-02          24
# 36   (GO, biological_process)  1.51e-02          17
# 37    (Dictybase, Phenotypes)  1.53e-02           7
# 38    (Dictybase, Phenotypes)  1.53e-02          18
# 39    (Dictybase, Phenotypes)  1.53e-02          16
# 40    (Dictybase, Phenotypes)  1.53e-02           6
# 41    (Dictybase, Phenotypes)  1.73e-02           3
# 42    (Dictybase, Phenotypes)  1.73e-02           3
# 43    (Dictybase, Phenotypes)  1.73e-02           3
# 44    (Dictybase, Phenotypes)  1.73e-02           3
# 45    (Dictybase, Phenotypes)  1.82e-02          20
# 46    (Dictybase, Phenotypes)  2.01e-02          18
# 47    (Dictybase, Phenotypes)  2.01e-02           7
# 48    (Dictybase, Phenotypes)  2.15e-02           4
# 49    (Dictybase, Phenotypes)  2.15e-02           4
# 50    (Dictybase, Phenotypes)  2.15e-02           4
# 51   (GO, biological_process)  2.15e-02          22
# 52    (Dictybase, Phenotypes)  2.20e-02           8
# 53    (Dictybase, Phenotypes)  2.26e-02          10
# 54           (KEGG, Pathways)  2.26e-02          11
# 55   (GO, biological_process)  2.26e-02          27
# 56    (Dictybase, Phenotypes)  2.49e-02          12
# 57    (Dictybase, Phenotypes)  2.50e-02          21
# 58    (Dictybase, Phenotypes)  2.68e-02           6
# 59   (GO, biological_process)  2.68e-02           8
# 60   (GO, molecular_function)  3.52e-02          30
# 61    (Dictybase, Phenotypes)  3.82e-02           4
# 62    (Dictybase, Phenotypes)  4.21e-02           5
# 63    (Dictybase, Phenotypes)  4.23e-02           3
# 64    (Dictybase, Phenotypes)  4.23e-02           3
# 65    (Dictybase, Phenotypes)  4.23e-02           3
# 66    (Dictybase, Phenotypes)  4.23e-02           9
# 67   (GO, cellular_component)  4.40e-02          36
# 68   (GO, biological_process)  4.47e-02          23
# 69   (GO, biological_process)  5.27e-02          57
# 70    (Dictybase, Phenotypes)  5.81e-02           4
# 71    (Dictybase, Phenotypes)  5.81e-02           4
# 72    (Dictybase, Phenotypes)  5.81e-02           4
# 73   (GO, biological_process)  5.81e-02          17
# 74    (Dictybase, Phenotypes)  6.47e-02           6
# 75   (GO, cellular_component)  6.91e-02          12
# 76    (Dictybase, Phenotypes)  7.08e-02           9
# 77    (Dictybase, Phenotypes)  7.83e-02           2
# 78    (Dictybase, Phenotypes)  7.83e-02           3
# 79    (Dictybase, Phenotypes)  7.83e-02           3
# 80    (Dictybase, Phenotypes)  7.83e-02           2
# 81    (Dictybase, Phenotypes)  7.83e-02           2
# 82    (Dictybase, Phenotypes)  7.83e-02           2
# 83    (Dictybase, Phenotypes)  7.83e-02           3
# 84    (Dictybase, Phenotypes)  7.83e-02          12
# 85    (Dictybase, Phenotypes)  7.99e-02           4
# 86    (Dictybase, Phenotypes)  7.99e-02           4
# 87    (Dictybase, Phenotypes)  7.99e-02           4
# 88    (Dictybase, Phenotypes)  8.06e-02          25
# 89   (GO, molecular_function)  8.75e-02          26
# 90           (KEGG, Pathways)  1.01e-01           8
# 91    (Dictybase, Phenotypes)  1.12e-01           7
# 92    (Dictybase, Phenotypes)  1.15e-01           4
# 93    (Dictybase, Phenotypes)  1.19e-01           6
# 94    (Dictybase, Phenotypes)  1.22e-01           3
# 95    (Dictybase, Phenotypes)  1.22e-01           3
# 96    (Dictybase, Phenotypes)  1.22e-01           3
# 97    (Dictybase, Phenotypes)  1.23e-01          13
# 98    (Dictybase, Phenotypes)  1.38e-01          13
# 99    (Dictybase, Phenotypes)  1.47e-01           5
# 100   (Dictybase, Phenotypes)  1.47e-01           4
# 101   (Dictybase, Phenotypes)  1.47e-01           4
# 102          (KEGG, Pathways)  1.47e-01           4
# 103  (GO, molecular_function)  1.47e-01          11
# 104   (Dictybase, Phenotypes)  1.47e-01           7
# 105   (Dictybase, Phenotypes)  1.53e-01          12
# 106   (Dictybase, Phenotypes)  1.56e-01           2
# 107   (Dictybase, Phenotypes)  1.56e-01           2
# 108   (Dictybase, Phenotypes)  1.56e-01           2
# 109   (Dictybase, Phenotypes)  1.56e-01           2
# 110   (Dictybase, Phenotypes)  1.56e-01           2
# 111   (Dictybase, Phenotypes)  1.56e-01           2
# 112   (Dictybase, Phenotypes)  1.56e-01           2
# 113   (Dictybase, Phenotypes)  1.56e-01           2
# 114   (Dictybase, Phenotypes)  1.56e-01           2
# 115   (Dictybase, Phenotypes)  1.56e-01           2
# 116   (Dictybase, Phenotypes)  1.56e-01           2
# 117          (KEGG, Pathways)  1.56e-01           6
# 118   (Dictybase, Phenotypes)  1.59e-01           3
# 119   (Dictybase, Phenotypes)  1.70e-01           4
# 120   (Dictybase, Phenotypes)  1.70e-01           4
# 121   (Dictybase, Phenotypes)  1.70e-01           4
# 122  (GO, biological_process)  1.79e-01           8
# 123   (Dictybase, Phenotypes)  1.79e-01           7
# 124   (Dictybase, Phenotypes)  1.83e-01          16
# 125  (GO, biological_process)  1.87e-01          27
# 126   (Dictybase, Phenotypes)  1.93e-01           9
# 127   (Dictybase, Phenotypes)  1.93e-01           5
# 128   (Dictybase, Phenotypes)  2.02e-01           7
# 129   (Dictybase, Phenotypes)  2.04e-01           3
# 130   (Dictybase, Phenotypes)  2.04e-01           4
# 131   (Dictybase, Phenotypes)  2.04e-01           4
# 132   (Dictybase, Phenotypes)  2.04e-01           4
# 133   (Dictybase, Phenotypes)  2.04e-01           3
# 134  (GO, biological_process)  2.04e-01          15
# 135  (GO, biological_process)  2.04e-01           3
# 136  (GO, biological_process)  2.26e-01           6
# 137   (Dictybase, Phenotypes)  2.27e-01           2
# 138   (Dictybase, Phenotypes)  2.27e-01           2
# 139   (Dictybase, Phenotypes)  2.27e-01           2
# 140   (Dictybase, Phenotypes)  2.27e-01           2
# 141   (Dictybase, Phenotypes)  2.27e-01           2
# 142   (Dictybase, Phenotypes)  2.27e-01           2
# 143   (Dictybase, Phenotypes)  2.27e-01           2
# 144   (Dictybase, Phenotypes)  2.27e-01           2
# 145   (Dictybase, Phenotypes)  2.27e-01           2
# 146   (Dictybase, Phenotypes)  2.27e-01           2
# 147   (Dictybase, Phenotypes)  2.27e-01           2
# 148   (Dictybase, Phenotypes)  2.27e-01           2
# 149   (Dictybase, Phenotypes)  2.27e-01           2
# 150   (Dictybase, Phenotypes)  2.29e-01           4
# 151   (Dictybase, Phenotypes)  2.29e-01           4
# 152   (Dictybase, Phenotypes)  2.40e-01           5
# 153  (GO, biological_process)  2.45e-01          23
# ***  tag selected: 191 with EID: 191
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.4
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 62 out of 76 query genes used for enrichment calculation.
#                          Gene set                  Ontology       FDR  \
# 0                 DNA replication          (KEGG, Pathways)  1.87e-25
# 1                      chromosome  (GO, cellular_component)  1.42e-23
# 2         chromosome organization  (GO, biological_process)  1.98e-14
# 3                 Mismatch repair          (KEGG, Pathways)  8.78e-12
# 4          chromosome segregation  (GO, biological_process)  2.17e-10
# 5      Nucleotide excision repair          (KEGG, Pathways)  7.03e-10
# 6                      cell cycle  (GO, biological_process)  2.28e-09
# 7           DNA metabolic process  (GO, biological_process)  9.25e-09
# 8        mitotic nuclear division  (GO, biological_process)  5.32e-08
# 9            Base excision repair          (KEGG, Pathways)  3.37e-07
# 10             nuclear chromosome  (GO, cellular_component)  4.49e-06
# 11             mitotic cell cycle  (GO, biological_process)  2.21e-05
# 12                ATPase activity  (GO, molecular_function)  1.14e-04
# 13                    DNA binding  (GO, molecular_function)  1.14e-04
# 14                  cell division  (GO, biological_process)  4.27e-04
# 15                    nucleoplasm  (GO, cellular_component)  2.17e-03
# 16              helicase activity  (GO, molecular_function)  1.81e-02
# 17     Non-homologous end-joining          (KEGG, Pathways)  4.24e-02
# 18                histone binding  (GO, molecular_function)  4.24e-02
# 19       Homologous recombination          (KEGG, Pathways)  6.51e-02
# 20               nuclear envelope  (GO, cellular_component)  7.94e-02
# 21          Pyrimidine metabolism          (KEGG, Pathways)  7.94e-02
# 22             response to stress  (GO, biological_process)  7.94e-02
# 23              nuclease activity  (GO, molecular_function)  1.67e-01
# 24                      nucleolus  (GO, cellular_component)  1.82e-01
# 25                   cytoskeleton  (GO, cellular_component)  2.17e-01
# 26  microtubule organizing center  (GO, cellular_component)  2.32e-01
#
#     N in query
# 0           20
# 1           24
# 2           18
# 3           10
# 4            9
# 5           11
# 6           19
# 7           15
# 8            7
# 9            8
# 10           6
# 11          11
# 12          13
# 13          15
# 14          10
# 15           8
# 16           5
# 17           2
# 18           2
# 19           3
# 20           3
# 21           3
# 22          13
# 23           3
# 24           4
# 25           7
# 26           3
# ***  tip selected: 261 with EID: 260
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.38
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 73 out of 99 query genes used for enrichment calculation.
#                                             Gene set  \
# 0                                         chromosome
# 1                                    DNA replication
# 2                            chromosome organization
# 3                                         cell cycle
# 4                                    Mismatch repair
# 5                         Nucleotide excision repair
# 6                             chromosome segregation
# 7                              DNA metabolic process
# 8                                 nuclear chromosome
# 9                                      cell division
# 10                          mitotic nuclear division
# 11                              Base excision repair
# 12                                       DNA binding
# 13                                mitotic cell cycle
# 14                                   ATPase activity
# 15                             Pyrimidine metabolism
# 16                     microtubule organizing center
# 17                                       nucleoplasm
# 18                                      cytoskeleton
# 19                                 cell cycle arrest
# 20                                 helicase activity
# 21                        Non-homologous end-joining
# 22                                   histone binding
# 23                          Homologous recombination
# 24  nucleobase-containing compound catabolic process
#
#                     Ontology       FDR  N in query
# 0   (GO, cellular_component)  1.23e-27          29
# 1           (KEGG, Pathways)  3.97e-23          20
# 2   (GO, biological_process)  2.11e-13          19
# 3   (GO, biological_process)  3.63e-13          26
# 4           (KEGG, Pathways)  2.41e-12          11
# 5           (KEGG, Pathways)  3.38e-11          13
# 6   (GO, biological_process)  2.08e-09           9
# 7   (GO, biological_process)  7.03e-09          17
# 8   (GO, cellular_component)  3.49e-08           8
# 9   (GO, biological_process)  1.91e-07          16
# 10  (GO, biological_process)  3.30e-07           7
# 11          (KEGG, Pathways)  2.67e-06           8
# 12  (GO, molecular_function)  3.36e-06          20
# 13  (GO, biological_process)  7.85e-06          13
# 14  (GO, molecular_function)  2.12e-03          13
# 15          (KEGG, Pathways)  5.40e-03           5
# 16  (GO, cellular_component)  1.07e-02           6
# 17  (GO, cellular_component)  1.32e-02           8
# 18  (GO, cellular_component)  1.41e-02          12
# 19   (Dictybase, Phenotypes)  3.85e-02           2
# 20  (GO, molecular_function)  5.26e-02           5
# 21          (KEGG, Pathways)  6.80e-02           2
# 22  (GO, molecular_function)  6.80e-02           2
# 23          (KEGG, Pathways)  1.16e-01           3
# 24  (GO, biological_process)  1.17e-01           3
# ***  slug selected: 76 with EID: 76
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.28
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 5 out of 21 query genes used for enrichment calculation.
#                 Gene set                  Ontology       FDR  N in query
# 0      cell cycle arrest   (Dictybase, Phenotypes)  1.99e-02           2
# 1  Pyrimidine metabolism          (KEGG, Pathways)  2.17e-01           2
# 2          cell division  (GO, biological_process)  2.17e-01           3
# ***  mhat selected: 8 with EID: 8
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.0
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 0 out of 0 query genes used for enrichment calculation.
# None
# ***  cul selected: 565 with EID: 559
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.28
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 32 out of 156 query genes used for enrichment calculation.
#                                     Gene set                  Ontology  \
# 0                            Golgi apparatus  (GO, cellular_component)
# 1  SNARE interactions in vesicular transport          (KEGG, Pathways)
# 2                    oxidoreductase activity  (GO, molecular_function)
#
#         FDR  N in query
# 0  9.22e-02          11
# 1  1.18e-01           5
# 2  1.18e-01          18
# ***  FB selected: 555 with EID: 546
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.23
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 34 out of 123 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0  anatomical structure formation involved in morphogenesis
# 1                                      extracellular region
# 2                                      cell differentiation
# 3                 SNARE interactions in vesicular transport
# 4                               secondary metabolic process
# 5       Ubiquinone and other terpenoid-quinone biosynthesis
#
#                    Ontology       FDR  N in query
# 0  (GO, biological_process)  5.78e-05          13
# 1  (GO, cellular_component)  2.16e-03          16
# 2  (GO, biological_process)  2.23e-03          15
# 3          (KEGG, Pathways)  2.60e-03           6
# 4  (GO, biological_process)  1.10e-02           3
# 5          (KEGG, Pathways)  9.80e-02           3

# %% [markdown]
# #### ImpulseDE2 WT

# %%
milestones=pd.read_table(path_impulse+'DEacrossStages_summary_WT_noyem_batchrep.tsv',index_col=0,sep='\t')
stages=np.array([phenotype for phenotype in PHENOTYPES if phenotype in list(milestones.columns)])
for stage_idx,stage in enumerate(stages):
    
    #Nonneighbouring stages
    neigh_previous=1
    neigh_next=1
    #Assumes phenotypes order
    if stage_idx==1:
        neigh_previous=0
    if stage_idx==0:
        neigh_next=0
    non_neighbours = stages[[(idx <stage_idx-neigh_previous or idx>stage_idx+neigh_next) 
                 for idx in range(len(stages)) ]]
    #print(stage,':',non_neighbours)
    
    #Find genes up at stage and down at nonenighbouring
    query_condition=stage+'=="up"'
    for non_neigh in non_neighbours:
        query_condition=query_condition+' & '+non_neigh+' =="down"'
    #print(query_condition)
    
    query_names=list(milestones.query(query_condition).index)
    enriched=group_diff_enrichment(query_names=query_names,group=stage,min_overlap=2,use_annotated_genes=True)
# Out:
# ***  no_agg selected: 2330 with EID: 2310
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.4
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 568 out of 925 query genes used for enrichment calculation.
#                                           Gene set                  Ontology  \
# 0                                         Ribosome          (KEGG, Pathways)
# 1                                      translation  (GO, biological_process)
# 2               structural constituent of ribosome  (GO, molecular_function)
# 3                                         ribosome  (GO, cellular_component)
# 4                                    mitochondrion  (GO, cellular_component)
# 5                              ribosome biogenesis  (GO, biological_process)
# 6                                        nucleolus  (GO, cellular_component)
# 7                     structural molecule activity  (GO, molecular_function)
# 8                Ribosome biogenesis in eukaryotes          (KEGG, Pathways)
# 9                           tRNA metabolic process  (GO, biological_process)
# 10                     Aminoacyl-tRNA biosynthesis          (KEGG, Pathways)
# 11                       Oxidative phosphorylation          (KEGG, Pathways)
# 12                                     RNA binding  (GO, molecular_function)
# 13                            Steroid biosynthesis          (KEGG, Pathways)
# 14                                 ligase activity  (GO, molecular_function)
# 15                      methyltransferase activity  (GO, molecular_function)
# 16  generation of precursor metabolites and energy  (GO, biological_process)
# 17           cellular amino acid metabolic process  (GO, biological_process)
# 18                         oxidoreductase activity  (GO, molecular_function)
# 19                      cofactor metabolic process  (GO, biological_process)
# 20                              Metabolic pathways          (KEGG, Pathways)
# 21           Biosynthesis of secondary metabolites          (KEGG, Pathways)
# 22                small molecule metabolic process  (GO, biological_process)
# 23                        unfolded protein binding  (GO, molecular_function)
# 24            Porphyrin and chlorophyll metabolism          (KEGG, Pathways)
# 25                                 protein folding  (GO, biological_process)
# 26                      mitochondrion organization  (GO, biological_process)
# 27                                    rRNA binding  (GO, molecular_function)
# 28                                  RNA polymerase          (KEGG, Pathways)
# 29      increased sensitivity to hydrogen peroxide   (Dictybase, Phenotypes)
# 30                              isomerase activity  (GO, molecular_function)
# 31                           Fatty acid elongation          (KEGG, Pathways)
# 32                            Butanoate metabolism          (KEGG, Pathways)
# 33               sulfur compound metabolic process  (GO, biological_process)
#
#          FDR  N in query
# 0   3.31e-28          76
# 1   6.33e-25         104
# 2   3.06e-23          65
# 3   1.58e-22          68
# 4   1.55e-19         118
# 5   5.12e-17          47
# 6   6.82e-16          51
# 7   3.63e-15          69
# 8   4.93e-14          47
# 9   5.01e-12          45
# 10  9.52e-09          31
# 11  1.87e-08          34
# 12  4.77e-07          72
# 13  4.85e-05          14
# 14  4.92e-05          38
# 15  8.98e-05          29
# 16  1.29e-04          36
# 17  8.80e-04          49
# 18  1.23e-03          73
# 19  3.44e-03          31
# 20  3.83e-03         193
# 21  4.95e-03          91
# 22  5.96e-03         110
# 23  2.10e-02          14
# 24  2.13e-02           9
# 25  3.36e-02          17
# 26  3.90e-02          12
# 27  5.33e-02           8
# 28  8.71e-02          12
# 29  1.74e-01           3
# 30  1.93e-01          19
# 31  2.05e-01           7
# 32  2.05e-01           7
# 33  2.05e-01          14
# ***  stream selected: 409 with EID: 403
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.41
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 131 out of 166 query genes used for enrichment calculation.
#                                                 Gene set  \
# 0                                             Proteasome
# 1            Protein processing in endoplasmic reticulum
# 2                                             locomotion
# 3                                    signal transduction
# 4                                     aberrant streaming
# 5                                      catabolic process
# 6              abolished activation of adenylate cyclase
# 7                                   aberrant aggregation
# 8                               decreased aggregate size
# 9                                decreased cell motility
# 10                                             wild type
# 11                                  aberrant cytokinesis
# 12                         aberrant F-actin organization
# 13                                  decreased exocytosis
# 14              development arrests at loose mound stage
# 15                                   aberrant chemotaxis
# 16                             cytoskeleton organization
# 17                                          reproduction
# 18                                         curly fingers
# 19      aberrant chemotaxis to cAMP in response to DIF-2
# 20                                   abolished streaming
# 21                          aberrant cAMP wave formation
# 22                                  aberrant culmination
# 23                        increased filopodium formation
# 24                          decreased chemotaxis to cAMP
# 25                                 decreased culmination
# 26                         increased basal F-actin level
# 27                        abolished chemotaxis to folate
# 28               decreased secretion of lysosomal enzyme
# 29              decreased engulfment during phagocytosis
# 30                        abolished filopodium formation
# 31                           cellular component assembly
# 32                             enzyme regulator activity
# 33                            precocious gene expression
# 34                                         cell motility
# 35                    aberrant cytoskeleton organisation
# 36                            decreased macropinocytosis
# 37                               aberrant slug formation
# 38                                    response to stress
# 39                                 decreased pinocytosis
# 40                                       plasma membrane
# 41                      anatomical structure development
# 42                              abolished slug migration
# 43                     abolished protein phosphorylation
# 44                                       kinase activity
# 45                      abolished F-actin polymerization
# 46                                precocious culmination
# 47                          decreased fruiting body size
# 48                     decreased cAMP-induced cAMP pulse
# 49              aberrant response to hyperosmotic stress
# 50                            multiple tips in culminant
# 51                                        enzyme binding
# 52                          abolished chemotaxis to cAMP
# 53      nucleobase-containing compound catabolic process
# 54                         aberrant chemotaxis to folate
# 55             decreased activation of adenylate cyclase
# 56                    development arrests at mound stage
# 57                                   delayed development
# 58                                 endoplasmic reticulum
# 59                              aberrant cell morphology
# 60                               aberrant slug migration
# 61                               increased protein level
# 62                                 increased growth rate
# 63                    increased intracellular cAMP level
# 64                   decreased growth rate in suspension
# 65                                    peptidase activity
# 66                   decreased protein kinase activation
# 67                                          cytoskeleton
# 68                                      abolished growth
# 69                                precocious aggregation
# 70                               abolished cell polarity
# 71                                 abolished aggregation
# 72               decreased lateral pseudopod suppression
# 73                          aberrant pseudopod formation
# 74                   protein-containing complex assembly
# 75                                         cell division
# 76                                       ATPase activity
# 77                                    mitotic cell cycle
# 78                                         cell adhesion
# 79                             decreased chemotaxis rate
# 80                             decreased gene expression
# 81                                    cell morphogenesis
# 82  AGE-RAGE signaling pathway in diabetic complications
# 83                              Other glycan degradation
# 84                        decreased chemotaxis to folate
# 85             development arrests at tipped mound stage
# 86                             abolished gene expression
# 87                                 abolished sporulation
# 88                    decreased intracellular cAMP level
# 89                          increased myosin II assembly
# 90                     development arrests at slug stage
# 91                              Homologous recombination
#
#                     Ontology       FDR  N in query
# 0           (KEGG, Pathways)  4.95e-06          12
# 1           (KEGG, Pathways)  4.29e-04          15
# 2   (GO, biological_process)  1.02e-03          22
# 3   (GO, biological_process)  1.21e-03          32
# 4    (Dictybase, Phenotypes)  2.26e-03          12
# 5   (GO, biological_process)  5.06e-03          24
# 6    (Dictybase, Phenotypes)  7.44e-03           4
# 7    (Dictybase, Phenotypes)  7.44e-03          10
# 8    (Dictybase, Phenotypes)  9.03e-03           7
# 9    (Dictybase, Phenotypes)  9.03e-03          11
# 10   (Dictybase, Phenotypes)  9.18e-03          28
# 11   (Dictybase, Phenotypes)  1.78e-02          12
# 12   (Dictybase, Phenotypes)  1.78e-02           7
# 13   (Dictybase, Phenotypes)  2.43e-02           4
# 14   (Dictybase, Phenotypes)  2.43e-02           5
# 15   (Dictybase, Phenotypes)  2.47e-02           3
# 16  (GO, biological_process)  2.47e-02          18
# 17  (GO, biological_process)  2.74e-02          10
# 18   (Dictybase, Phenotypes)  2.77e-02           2
# 19   (Dictybase, Phenotypes)  2.77e-02           2
# 20   (Dictybase, Phenotypes)  3.14e-02           6
# 21   (Dictybase, Phenotypes)  3.14e-02          11
# 22   (Dictybase, Phenotypes)  4.84e-02          10
# 23   (Dictybase, Phenotypes)  4.87e-02           4
# 24   (Dictybase, Phenotypes)  4.89e-02           8
# 25   (Dictybase, Phenotypes)  4.89e-02           3
# 26   (Dictybase, Phenotypes)  4.89e-02           4
# 27   (Dictybase, Phenotypes)  4.89e-02           2
# 28   (Dictybase, Phenotypes)  4.89e-02           2
# 29   (Dictybase, Phenotypes)  4.89e-02           2
# 30   (Dictybase, Phenotypes)  4.89e-02           2
# 31  (GO, biological_process)  4.89e-02          17
# 32  (GO, molecular_function)  4.89e-02          11
# 33   (Dictybase, Phenotypes)  5.39e-02           4
# 34  (GO, biological_process)  5.39e-02           8
# 35   (Dictybase, Phenotypes)  5.92e-02           3
# 36   (Dictybase, Phenotypes)  5.92e-02           4
# 37   (Dictybase, Phenotypes)  5.92e-02           3
# 38  (GO, biological_process)  5.92e-02          25
# 39   (Dictybase, Phenotypes)  5.95e-02           5
# 40  (GO, cellular_component)  6.13e-02          20
# 41  (GO, biological_process)  6.13e-02          29
# 42   (Dictybase, Phenotypes)  6.24e-02           6
# 43   (Dictybase, Phenotypes)  6.59e-02           3
# 44  (GO, molecular_function)  6.59e-02          23
# 45   (Dictybase, Phenotypes)  6.68e-02           2
# 46   (Dictybase, Phenotypes)  6.68e-02           2
# 47   (Dictybase, Phenotypes)  8.37e-02           8
# 48   (Dictybase, Phenotypes)  9.66e-02           3
# 49   (Dictybase, Phenotypes)  9.66e-02           3
# 50   (Dictybase, Phenotypes)  9.98e-02           2
# 51  (GO, molecular_function)  1.00e-01          10
# 52   (Dictybase, Phenotypes)  1.12e-01           3
# 53  (GO, biological_process)  1.28e-01           4
# 54   (Dictybase, Phenotypes)  1.33e-01           2
# 55   (Dictybase, Phenotypes)  1.33e-01           2
# 56   (Dictybase, Phenotypes)  1.33e-01           6
# 57   (Dictybase, Phenotypes)  1.33e-01           7
# 58  (GO, cellular_component)  1.33e-01          10
# 59   (Dictybase, Phenotypes)  1.44e-01           5
# 60   (Dictybase, Phenotypes)  1.47e-01           6
# 61   (Dictybase, Phenotypes)  1.47e-01           2
# 62   (Dictybase, Phenotypes)  1.47e-01           4
# 63   (Dictybase, Phenotypes)  1.47e-01           2
# 64   (Dictybase, Phenotypes)  1.47e-01           2
# 65  (GO, molecular_function)  1.47e-01           8
# 66   (Dictybase, Phenotypes)  1.50e-01           3
# 67  (GO, cellular_component)  1.59e-01          13
# 68   (Dictybase, Phenotypes)  1.62e-01           4
# 69   (Dictybase, Phenotypes)  1.63e-01           3
# 70   (Dictybase, Phenotypes)  1.63e-01           2
# 71   (Dictybase, Phenotypes)  1.63e-01           7
# 72   (Dictybase, Phenotypes)  1.63e-01           2
# 73   (Dictybase, Phenotypes)  1.63e-01           2
# 74  (GO, biological_process)  1.63e-01          10
# 75  (GO, biological_process)  1.63e-01           9
# 76  (GO, molecular_function)  1.63e-01          12
# 77  (GO, biological_process)  1.80e-01           8
# 78  (GO, biological_process)  1.80e-01           7
# 79   (Dictybase, Phenotypes)  1.90e-01           4
# 80   (Dictybase, Phenotypes)  2.06e-01           7
# 81  (GO, biological_process)  2.08e-01           3
# 82          (KEGG, Pathways)  2.12e-01           3
# 83          (KEGG, Pathways)  2.12e-01           2
# 84   (Dictybase, Phenotypes)  2.13e-01           2
# 85   (Dictybase, Phenotypes)  2.13e-01           2
# 86   (Dictybase, Phenotypes)  2.13e-01           3
# 87   (Dictybase, Phenotypes)  2.13e-01           3
# 88   (Dictybase, Phenotypes)  2.13e-01           2
# 89   (Dictybase, Phenotypes)  2.13e-01           2
# 90   (Dictybase, Phenotypes)  2.13e-01           2
# 91          (KEGG, Pathways)  2.13e-01           3
# ***  lag selected: 429 with EID: 423
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.42
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 135 out of 176 query genes used for enrichment calculation.
#                                             Gene set  \
# 0                                         Proteasome
# 1                                signal transduction
# 2                                         locomotion
# 3                               aberrant aggregation
# 4        Protein processing in endoplasmic reticulum
# 5                                 aberrant streaming
# 6                           decreased aggregate size
# 7          abolished activation of adenylate cyclase
# 8                                abolished streaming
# 9                            decreased cell motility
# 10                          abolished slug migration
# 11                                   plasma membrane
# 12                     aberrant F-actin organization
# 13                              aberrant cytokinesis
# 14                              decreased exocytosis
# 15          development arrests at loose mound stage
# 16                               aberrant chemotaxis
# 17                                 catabolic process
# 18                                     curly fingers
# 19  aberrant chemotaxis to cAMP in response to DIF-2
# 20                         cytoskeleton organization
# 21                      aberrant cAMP wave formation
# 22                                         wild type
# 23                                response to stress
# 24                    increased filopodium formation
# 25                     increased basal F-actin level
# 26                    abolished chemotaxis to folate
# 27           decreased secretion of lysosomal enzyme
# 28                              aberrant culmination
# 29          decreased engulfment during phagocytosis
# 30                    abolished filopodium formation
# 31                             decreased culmination
# 32                      decreased chemotaxis to cAMP
# 33                         enzyme regulator activity
# 34                       cellular component assembly
# 35                aberrant cytoskeleton organisation
# 36                        decreased macropinocytosis
# 37                development arrests at mound stage
# 38                             decreased pinocytosis
# 39                            precocious aggregation
# 40                  abolished F-actin polymerization
# 41                 abolished protein phosphorylation
# 42                            precocious culmination
# 43                             endoplasmic reticulum
# 44                 decreased cAMP-induced cAMP pulse
# 45                        multiple tips in culminant
# 46          aberrant response to hyperosmotic stress
# 47                      decreased fruiting body size
# 48                                      cytoskeleton
# 49                  anatomical structure development
# 50                      abolished chemotaxis to cAMP
# 51                                      reproduction
# 52                     aberrant chemotaxis to folate
# 53         decreased activation of adenylate cyclase
# 54                                     cell motility
# 55                          aberrant cell morphology
# 56                           aberrant slug migration
# 57                           delayed gene expression
# 58                           increased protein level
# 59                       aberrant chemotaxis to cAMP
# 60                             increased growth rate
# 61                increased intracellular cAMP level
# 62               decreased growth rate in suspension
# 63                               delayed development
# 64                          increased slug migration
# 65                        precocious gene expression
# 66                                     cell adhesion
# 67               decreased protein kinase activation
# 68                             abolished culmination
# 69                           abolished cell polarity
# 70           decreased lateral pseudopod suppression
# 71                                  abolished growth
# 72                      aberrant pseudopod formation
# 73                                   kinase activity
# 74                                    enzyme binding
# 75                             abolished aggregation
# 76                                           cytosol
# 77                           aberrant slug formation
# 78                                     cell division
# 79                                   ATPase activity
# 80               protein-containing complex assembly
# 81                         decreased chemotaxis rate
# 82                          decreased slug migration
# 83                     abolished cAMP wave formation
# 84                          Other glycan degradation
# 85                                mitotic cell cycle
# 86                         decreased gene expression
# 87                    decreased chemotaxis to folate
# 88         development arrests at tipped mound stage
# 89                decreased intracellular cAMP level
# 90                      increased myosin II assembly
# 91                 development arrests at slug stage
# 92                          Homologous recombination
# 93                               delayed aggregation
#
#                     Ontology       FDR  N in query
# 0           (KEGG, Pathways)  9.91e-06          12
# 1   (GO, biological_process)  5.48e-05          37
# 2   (GO, biological_process)  8.26e-04          23
# 3    (Dictybase, Phenotypes)  9.07e-04          12
# 4           (KEGG, Pathways)  1.73e-03          14
# 5    (Dictybase, Phenotypes)  2.97e-03          12
# 6    (Dictybase, Phenotypes)  2.97e-03           8
# 7    (Dictybase, Phenotypes)  9.46e-03           4
# 8    (Dictybase, Phenotypes)  1.51e-02           7
# 9    (Dictybase, Phenotypes)  1.51e-02          11
# 10   (Dictybase, Phenotypes)  1.51e-02           8
# 11  (GO, cellular_component)  1.86e-02          24
# 12   (Dictybase, Phenotypes)  2.59e-02           7
# 13   (Dictybase, Phenotypes)  2.83e-02          12
# 14   (Dictybase, Phenotypes)  2.85e-02           4
# 15   (Dictybase, Phenotypes)  2.85e-02           5
# 16   (Dictybase, Phenotypes)  2.85e-02           3
# 17  (GO, biological_process)  2.85e-02          22
# 18   (Dictybase, Phenotypes)  3.20e-02           2
# 19   (Dictybase, Phenotypes)  3.20e-02           2
# 20  (GO, biological_process)  3.88e-02          18
# 21   (Dictybase, Phenotypes)  4.90e-02          11
# 22   (Dictybase, Phenotypes)  5.35e-02          26
# 23  (GO, biological_process)  5.65e-02          27
# 24   (Dictybase, Phenotypes)  5.94e-02           4
# 25   (Dictybase, Phenotypes)  6.05e-02           4
# 26   (Dictybase, Phenotypes)  6.05e-02           2
# 27   (Dictybase, Phenotypes)  6.05e-02           2
# 28   (Dictybase, Phenotypes)  6.05e-02          10
# 29   (Dictybase, Phenotypes)  6.05e-02           2
# 30   (Dictybase, Phenotypes)  6.05e-02           2
# 31   (Dictybase, Phenotypes)  6.09e-02           3
# 32   (Dictybase, Phenotypes)  6.27e-02           8
# 33  (GO, molecular_function)  6.31e-02          11
# 34  (GO, biological_process)  7.06e-02          17
# 35   (Dictybase, Phenotypes)  7.48e-02           3
# 36   (Dictybase, Phenotypes)  7.69e-02           4
# 37   (Dictybase, Phenotypes)  8.00e-02           7
# 38   (Dictybase, Phenotypes)  8.00e-02           5
# 39   (Dictybase, Phenotypes)  8.42e-02           4
# 40   (Dictybase, Phenotypes)  8.42e-02           2
# 41   (Dictybase, Phenotypes)  8.42e-02           3
# 42   (Dictybase, Phenotypes)  8.42e-02           2
# 43  (GO, cellular_component)  1.07e-01          11
# 44   (Dictybase, Phenotypes)  1.17e-01           3
# 45   (Dictybase, Phenotypes)  1.17e-01           2
# 46   (Dictybase, Phenotypes)  1.17e-01           3
# 47   (Dictybase, Phenotypes)  1.17e-01           8
# 48  (GO, cellular_component)  1.17e-01          15
# 49  (GO, biological_process)  1.17e-01          29
# 50   (Dictybase, Phenotypes)  1.40e-01           3
# 51  (GO, biological_process)  1.46e-01           8
# 52   (Dictybase, Phenotypes)  1.56e-01           2
# 53   (Dictybase, Phenotypes)  1.56e-01           2
# 54  (GO, biological_process)  1.56e-01           7
# 55   (Dictybase, Phenotypes)  1.68e-01           5
# 56   (Dictybase, Phenotypes)  1.68e-01           6
# 57   (Dictybase, Phenotypes)  1.68e-01           3
# 58   (Dictybase, Phenotypes)  1.68e-01           2
# 59   (Dictybase, Phenotypes)  1.68e-01           4
# 60   (Dictybase, Phenotypes)  1.68e-01           4
# 61   (Dictybase, Phenotypes)  1.68e-01           2
# 62   (Dictybase, Phenotypes)  1.68e-01           2
# 63   (Dictybase, Phenotypes)  1.68e-01           7
# 64   (Dictybase, Phenotypes)  1.68e-01           2
# 65   (Dictybase, Phenotypes)  1.68e-01           3
# 66  (GO, biological_process)  1.68e-01           8
# 67   (Dictybase, Phenotypes)  1.76e-01           3
# 68   (Dictybase, Phenotypes)  1.89e-01           6
# 69   (Dictybase, Phenotypes)  1.89e-01           2
# 70   (Dictybase, Phenotypes)  1.89e-01           2
# 71   (Dictybase, Phenotypes)  1.89e-01           4
# 72   (Dictybase, Phenotypes)  1.89e-01           2
# 73  (GO, molecular_function)  1.89e-01          21
# 74  (GO, molecular_function)  1.89e-01           9
# 75   (Dictybase, Phenotypes)  2.09e-01           7
# 76  (GO, cellular_component)  2.17e-01          14
# 77   (Dictybase, Phenotypes)  2.20e-01           2
# 78  (GO, biological_process)  2.20e-01           9
# 79  (GO, molecular_function)  2.20e-01          12
# 80  (GO, biological_process)  2.22e-01          10
# 81   (Dictybase, Phenotypes)  2.25e-01           4
# 82   (Dictybase, Phenotypes)  2.25e-01           2
# 83   (Dictybase, Phenotypes)  2.25e-01           2
# 84          (KEGG, Pathways)  2.25e-01           2
# 85  (GO, biological_process)  2.25e-01           8
# 86   (Dictybase, Phenotypes)  2.26e-01           7
# 87   (Dictybase, Phenotypes)  2.40e-01           2
# 88   (Dictybase, Phenotypes)  2.40e-01           2
# 89   (Dictybase, Phenotypes)  2.40e-01           2
# 90   (Dictybase, Phenotypes)  2.40e-01           2
# 91   (Dictybase, Phenotypes)  2.40e-01           2
# 92          (KEGG, Pathways)  2.40e-01           3
# 93   (Dictybase, Phenotypes)  2.45e-01           6
# ***  tag selected: 273 with EID: 272
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.35
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 71 out of 95 query genes used for enrichment calculation.
#                           Gene set                  Ontology       FDR  \
# 0                       chromosome  (GO, cellular_component)  1.55e-16
# 1                  DNA replication          (KEGG, Pathways)  1.55e-16
# 2            DNA metabolic process  (GO, biological_process)  3.67e-14
# 3                  Mismatch repair          (KEGG, Pathways)  8.21e-11
# 4          chromosome organization  (GO, biological_process)  1.62e-10
# 5                      DNA binding  (GO, molecular_function)  2.75e-09
# 6                       cell cycle  (GO, biological_process)  1.84e-08
# 7           chromosome segregation  (GO, biological_process)  3.93e-08
# 8             Base excision repair          (KEGG, Pathways)  1.02e-07
# 9       Nucleotide excision repair          (KEGG, Pathways)  1.38e-06
# 10        mitotic nuclear division  (GO, biological_process)  6.58e-06
# 11              nuclear chromosome  (GO, cellular_component)  3.04e-04
# 12                 ATPase activity  (GO, molecular_function)  3.04e-04
# 13                   cell division  (GO, biological_process)  5.91e-04
# 14              mitotic cell cycle  (GO, biological_process)  4.02e-03
# 15              response to stress  (GO, biological_process)  1.20e-02
# 16        Homologous recombination          (KEGG, Pathways)  1.64e-02
# 17      Non-homologous end-joining          (KEGG, Pathways)  6.01e-02
# 18                 histone binding  (GO, molecular_function)  6.01e-02
# 19  Ubiquitin mediated proteolysis          (KEGG, Pathways)  7.71e-02
# 20           Pyrimidine metabolism          (KEGG, Pathways)  1.34e-01
# 21                 GTPase activity  (GO, molecular_function)  2.16e-01
#
#     N in query
# 0           21
# 1           16
# 2           22
# 3           10
# 4           16
# 5           24
# 6           20
# 7            8
# 8            9
# 9            9
# 10           6
# 11           5
# 12          14
# 13          11
# 14           9
# 15          18
# 16           4
# 17           2
# 18           2
# 19           5
# 20           3
# 21           7
# ***  tip selected: 486 with EID: 485
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.34
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 119 out of 166 query genes used for enrichment calculation.
#                                         Gene set                  Ontology  \
# 0                                     chromosome  (GO, cellular_component)
# 1                                DNA replication          (KEGG, Pathways)
# 2                        chromosome organization  (GO, biological_process)
# 3                                     cell cycle  (GO, biological_process)
# 4                                Mismatch repair          (KEGG, Pathways)
# 5                          DNA metabolic process  (GO, biological_process)
# 6                         chromosome segregation  (GO, biological_process)
# 7                       mitotic nuclear division  (GO, biological_process)
# 8                                    DNA binding  (GO, molecular_function)
# 9                           Base excision repair          (KEGG, Pathways)
# 10                                 cell division  (GO, biological_process)
# 11                    Nucleotide excision repair          (KEGG, Pathways)
# 12                            mitotic cell cycle  (GO, biological_process)
# 13                            nuclear chromosome  (GO, cellular_component)
# 14                 microtubule organizing center  (GO, cellular_component)
# 15                               ATPase activity  (GO, molecular_function)
# 16                      Homologous recombination          (KEGG, Pathways)
# 17                                  cytoskeleton  (GO, cellular_component)
# 18                Ubiquitin mediated proteolysis          (KEGG, Pathways)
# 19                   increased cell cycle length   (Dictybase, Phenotypes)
# 20          aberrant centromere complex assembly   (Dictybase, Phenotypes)
# 21                               histone binding  (GO, molecular_function)
# 22                                   nucleoplasm  (GO, cellular_component)
# 23                              aberrant mitosis   (Dictybase, Phenotypes)
# 24              aberrant centrosome localization   (Dictybase, Phenotypes)
# 25                         Pyrimidine metabolism          (KEGG, Pathways)
# 26                            response to stress  (GO, biological_process)
# 27                 aberrant spindle organization   (Dictybase, Phenotypes)
# 28              aberrant centrosome organization   (Dictybase, Phenotypes)
# 29                             cell cycle arrest   (Dictybase, Phenotypes)
# 30                           aberrant cell cycle   (Dictybase, Phenotypes)
# 31                   aberrant nucleus morphology   (Dictybase, Phenotypes)
# 32                             helicase activity  (GO, molecular_function)
# 33                              nuclear envelope  (GO, cellular_component)
# 34                    Non-homologous end-joining          (KEGG, Pathways)
# 35  increased sensitivity to DNA-damaging agents   (Dictybase, Phenotypes)
#
#          FDR  N in query
# 0   1.11e-31          37
# 1   5.66e-27          25
# 2   2.12e-21          30
# 3   3.05e-20          41
# 4   1.26e-16          15
# 5   1.26e-16          30
# 6   1.96e-15          14
# 7   1.27e-11          11
# 8   3.79e-11          35
# 9   2.87e-10          13
# 10  3.64e-10          24
# 11  1.13e-09          14
# 12  3.60e-08          20
# 13  1.68e-06           8
# 14  5.06e-05          11
# 15  5.06e-05          21
# 16  4.34e-03           6
# 17  5.77e-03          18
# 18  7.41e-03           9
# 19  1.33e-02           2
# 20  1.33e-02           2
# 21  1.64e-02           3
# 22  3.12e-02          10
# 23  3.26e-02           2
# 24  3.26e-02           2
# 25  3.98e-02           5
# 26  4.32e-02          25
# 27  5.66e-02           2
# 28  8.03e-02           2
# 29  8.03e-02           2
# 30  8.03e-02           2
# 31  8.03e-02           2
# 32  9.20e-02           6
# 33  1.46e-01           4
# 34  1.46e-01           2
# 35  1.55e-01           2
# ***  slug selected: 117 with EID: 116
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.22
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 13 out of 25 query genes used for enrichment calculation.
#                     Gene set                  Ontology       FDR  N in query
# 0    chromosome organization  (GO, biological_process)  7.73e-03           5
# 1                nucleoplasm  (GO, cellular_component)  1.11e-01           4
# 2                 chromosome  (GO, cellular_component)  1.15e-01           3
# 3             RNA polymerase          (KEGG, Pathways)  1.15e-01           2
# 4                 cell cycle  (GO, biological_process)  1.15e-01           4
# 5      DNA metabolic process  (GO, biological_process)  1.15e-01           3
# 6                 cell death  (GO, biological_process)  1.15e-01           2
# 7  enzyme regulator activity  (GO, molecular_function)  1.15e-01           3
# 8              cell division  (GO, biological_process)  1.23e-01           3
# 9       transferase activity  (GO, molecular_function)  1.39e-01           2
# ***  mhat selected: 28 with EID: 28
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.5
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 9 out of 14 query genes used for enrichment calculation.
#                                           Gene set                  Ontology  \
# 0                    Starch and sucrose metabolism          (KEGG, Pathways)
# 1      Amino sugar and nucleotide sugar metabolism          (KEGG, Pathways)
# 2                   carbohydrate metabolic process  (GO, biological_process)
# 3   generation of precursor metabolites and energy  (GO, biological_process)
# 4                                catabolic process  (GO, biological_process)
# 5                 small molecule metabolic process  (GO, biological_process)
# 6                          oxidoreductase activity  (GO, molecular_function)
# 7                                Carbon metabolism          (KEGG, Pathways)
# 8                               Metabolic pathways          (KEGG, Pathways)
# 9            Biosynthesis of secondary metabolites          (KEGG, Pathways)
# 10                     cellular component assembly  (GO, biological_process)
#
#          FDR  N in query
# 0   7.86e-02           2
# 1   7.86e-02           2
# 2   7.86e-02           3
# 3   7.86e-02           3
# 4   8.11e-02           4
# 5   1.26e-01           4
# 6   1.30e-01           3
# 7   1.68e-01           2
# 8   1.93e-01           5
# 9   1.93e-01           3
# 10  2.35e-01           2
# ***  cul selected: 1412 with EID: 1403
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.31
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 76 out of 431 query genes used for enrichment calculation.
#                                     Gene set                  Ontology  \
# 0  SNARE interactions in vesicular transport          (KEGG, Pathways)
# 1                secondary metabolic process  (GO, biological_process)
# 2                                  autophagy  (GO, biological_process)
# 3                                Endocytosis          (KEGG, Pathways)
# 4                       cell differentiation  (GO, biological_process)
# 5                          Autophagy - other          (KEGG, Pathways)
# 6                  decreased spore viability   (Dictybase, Phenotypes)
#
#         FDR  N in query
# 0  4.17e-03          11
# 1  9.57e-02           4
# 2  9.57e-02          11
# 3  9.93e-02          18
# 4  1.49e-01          28
# 5  2.12e-01           8
# 6  2.31e-01          14
# ***  FB selected: 564 with EID: 560
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.25
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 35 out of 141 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0                                      extracellular region
# 1  anatomical structure formation involved in morphogenesis
# 2                             Starch and sucrose metabolism
# 3                            decreased pseudopod retraction
# 4                 SNARE interactions in vesicular transport
# 5                                      cell differentiation
#
#                    Ontology       FDR  N in query
# 0  (GO, cellular_component)  2.87e-02          16
# 1  (GO, biological_process)  3.00e-02          10
# 2          (KEGG, Pathways)  5.23e-02           6
# 3   (Dictybase, Phenotypes)  5.99e-02           2
# 4          (KEGG, Pathways)  5.99e-02           5
# 5  (GO, biological_process)  2.06e-01          12
