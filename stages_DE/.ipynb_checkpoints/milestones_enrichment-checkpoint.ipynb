# %% [markdown]
# # Enrichment for milestone genes

# %%
import os
import sys
from importlib import reload

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.insert(0,module_path)
    
import warnings

import pandas as pd
from IPython.display import display
pd.set_option('max_colwidth', 70)
pd.set_option('display.max_rows', 500)
import string
import numpy as np
import matplotlib.pyplot as plt

from orangecontrib.bioinformatics.geneset.__init__ import list_all

import jupyter_functions as jf
reload(jf)
import jupyter_functions as jf
from networks.functionsDENet import loadPickle, savePickle
import enrichment_library as enr
reload(enr)
import enrichment_library as enr
from stages_DE.stages_library import PHENOTYPES

# %%
#Path for expression data (mergedGenes_RPKUM.tsv)
dataPath='/home/karin/Documents/timeTrajectories/data/RPKUM/combined/'
path_de='/home/karin/Documents/timeTrajectories/data/deTime/stage_vs_other/'
path_impulse='/home/karin/Documents/timeTrajectories/data/stages/DE_across_stages/'

# %% [markdown]
# ## Gene sets

# %% [markdown]
# Uses gene sets that do not have less than 5 or more than 500 genes. Use all ontologies.

# %%
# Get all gene sets
gene_sets=list(list_all(organism='44689'))
GENE_SETS_ONTOLOGY=enr.get_gene_sets(gene_set_names=gene_sets, go_slims=True,set_sizes=(5,500))

# %%
# Find out max/min gene set sizes and N sets
max_n=0
min_n=np.inf
for k,v in GENE_SETS_ONTOLOGY.items():
    for s in v:
        n=len(s.genes)
        if n<min_n:
            min_n=n
        if n>max_n:
            max_n=n
print('Min size',min_n,'Max size',max_n)  
print('N sets',{k:len(v) for k,v in GENE_SETS_ONTOLOGY.items()})
# Out:
# Min size 5 Max size 440
# N sets {('GO', 'molecular_function'): 35, ('GO', 'biological_process'): 52, ('KEGG', 'Pathways'): 96, ('Dictybase', 'Phenotypes'): 209, ('GO', 'cellular_component'): 24}

# %%
# For conversion of gene names to EID
genes = pd.read_csv(dataPath + 'mergedGenes_RPKUM.tsv', sep='\t', index_col=0)
all_gene_names= genes[(genes != 0).any(axis=1)].index
NAME_EID=enr.name_genes_entrez(gene_names=all_gene_names, key_entrez=False)
ALL_GENE_NAMES_EID=enr.convert_EID(genes=all_gene_names, name_EID=NAME_EID)

# %%
def group_diff_enrichment(query_names,group:str,padj:float=0.25,min_overlap:int=None,
                          use_annotated_genes:bool=False,enrichment_map=False,map_edge_filter=0.1):
    #Displays only gene sets that have overlap with query greater or equal to min_overlap 
    #For p value and padj calculation uses alll that have overlap >=1 } from gene_set_enrichment
    """
    :param use_annotated_genes: if True use for reference and query  only genes that have at 
    least one gene set annotation
    """
    query_EID=enr.convert_EID(genes=query_names, name_EID=NAME_EID)
    print('***  '+group+' selected:',len(query_names),'with EID:',len(query_EID))
    
    reference_gene_eids=ALL_GENE_NAMES_EID.copy()
    query_eids=query_EID.copy()
    
    if use_annotated_genes:
        gene_sets_genes=set()
        for gene_set_name, gene_sets in GENE_SETS_ONTOLOGY.items():
            for gene_set in gene_sets:
                gene_sets_genes.update(gene_set.genes)
        reference_gene_eids=set(reference_gene_eids) & gene_sets_genes
        query_eids=set(query_eids) & gene_sets_genes
        
        query_annotated_reatio='NA'
        if len(query_EID)>0:
            query_annotated_reatio=round(len(query_eids)/len(query_EID),2)
        print('Ratio of genes annotated with a gene set in reference',
              round(len(reference_gene_eids)/len(ALL_GENE_NAMES_EID),2),
             'and query',query_annotated_reatio)
    
    query_in_enriched=set()
    result=None
    fig,ax=None,None
    if len(query_eids) > 0:
        enrichment=enr.gene_set_enrichment(query_eids, reference_EID=reference_gene_eids, 
                                                padj_threshold=padj,min_overlap=min_overlap,
                                                gene_sets_ontology=GENE_SETS_ONTOLOGY)
        if len(enrichment)>0:
            enrichment_display=list()
            enrichment= sorted(enrichment, key=lambda data: data.padj)
            for enriched in enrichment:
                query_in_enriched.update(enriched.gene_set.genes & query_eids)
                enrichment_display.append({'Gene set':enriched.gene_set.name,
                                           'Ontology':enriched.ontology[0]+': '+enriched.ontology[1],
                                           'FDR':"{:.2e}".format(enriched.padj),'N in query':enriched.in_query,
                                           'Set size':len(enriched.gene_set.genes),
                                                          'N in ref.':enriched.in_reference})
            result=pd.DataFrame(enrichment_display)
            if enrichment_map:
                fig,ax=plt.subplots(figsize=(15,15))
                with warnings.catch_warnings(record=True):
                    enr.enrichment_map(enriched=enrichment, ax=ax,query_size=len(query_eids),
                                   fontsize=8,min_overlap=map_edge_filter)
                fig.suptitle('Group '+group+' using '+str(len(query_eids))+' out of '+str(len(query_names))+
                             ' genes for enrichment calculation.')
    print('Enrichment at FDR: '+str(padj)+' and min query - gene set overlap',str(min_overlap))
    print('N query genes in displayed gene sets:',len(query_in_enriched),'out of', len(query_eids),
          'query genes used for enrichment calculation.')
    display(result)
    print('\n')
    if enrichment_map:
        return (result,(fig,ax))
    else:
        return result

# %% [markdown]
# ## Enrichment report
# Enrichment map: Circles show gene sets (as displayed in the report). Size shows the overlap between gene set and query (genes of interest) as ratio of query genes used in enrichemnt calculation (larger is more). Colour denotes padj value (smaller is more yellow), with all values below 10^-10 being assigned the same shade of yellow. Lines show overlap between gene sets as ration of genes from smaller gene set present in the larger one, encoded as line thickness. Overlaps below 0.2 were excludded from plotting. Arrows show that all genes of a samller gene set (arrow start) are contained in the larger gene set.

# %% [markdown]
# ### DESeq2
# Only positive log2 fold changes (lFC) are used to select only overexpressed genes.

# %% [markdown]
# #### DESeq2 all strains

# %% [markdown]
# ##### DESeq2 all strains lFC >= 2 and padj <= 0.01

# %%
milestones=pd.read_table(path_de+'nobatchrep_combined.tsv',index_col=0,sep='\t')
for stage in [phenotype for phenotype in PHENOTYPES if phenotype in list(milestones['Stage'].unique())]:
    query_names=list(milestones.query('log2FoldChange>=2 & padj <= 0.01 & Stage=="'+stage+'"').index)
    enriched=group_diff_enrichment(query_names=query_names,group=stage,min_overlap=2,use_annotated_genes=True)
# Out:
# ***  no_agg selected: 216 with EID: 215
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.38
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 58 out of 82 query genes used for enrichment calculation.
#                                 Gene set                Ontology       FDR  \
# 0                   extracellular region  GO: cellular_component  3.94e-04
# 1                oxidoreductase activity  GO: molecular_function  1.11e-03
# 2                     hydrolase activity  GO: molecular_function  1.24e-02
# 3                    homeostatic process  GO: biological_process  1.77e-02
# 4                               lysosome  GO: cellular_component  6.15e-02
# 5                     response to stress  GO: biological_process  6.15e-02
# 6           cytoskeletal protein binding  GO: molecular_function  9.44e-02
# 7                    Lysine biosynthesis          KEGG: Pathways  9.78e-02
# 8                     peptidase activity  GO: molecular_function  1.59e-01
# 9                      catabolic process  GO: biological_process  1.76e-01
# 10  aberrant cellular response to stress   Dictybase: Phenotypes  2.27e-01
# 11   aberrant cellular metabolic process   Dictybase: Phenotypes  2.27e-01
# 12              increased aggregate size   Dictybase: Phenotypes  2.27e-01
# 13                       plasma membrane  GO: cellular_component  2.27e-01
#
#     N in query  Set size  N in ref.
# 0           14       157        157
# 1           15       210        207
# 2            6        46         45
# 3            7        70         70
# 4            6        69         69
# 5           16       360        358
# 6            9       158        158
# 7            2         6          6
# 8            6        91         91
# 9           11       250        250
# 10           2        11         11
# 11           2        12         12
# 12           3        31         30
# 13          11       268        268
# ***  stream selected: 15 with EID: 15
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.13
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 0 out of 2 query genes used for enrichment calculation.
# None
# ***  lag selected: 17 with EID: 17
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.18
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 0 out of 3 query genes used for enrichment calculation.
# None
# ***  tag selected: 37 with EID: 37
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.11
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 2 out of 4 query genes used for enrichment calculation.
#           Gene set                Ontology       FDR  N in query  Set size  \
# 0  kinase activity  GO: molecular_function  1.11e-01           2       328
#
#    N in ref.
# 0        327
# ***  tip selected: 48 with EID: 48
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.08
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 4 out of 4 query genes used for enrichment calculation.
#                            Gene set                Ontology       FDR  \
# 0              extracellular region  GO: cellular_component  7.10e-02
# 1  small molecule metabolic process  GO: biological_process  9.97e-02
#
#    N in query  Set size  N in ref.
# 0           2       157        157
# 1           2       354        353
# ***  slug selected: 411 with EID: 410
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.18
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 43 out of 73 query genes used for enrichment calculation.
#                                Gene set                Ontology       FDR  \
# 0                  extracellular region  GO: cellular_component  1.06e-14
# 1      external encapsulating structure  GO: cellular_component  2.30e-03
# 2                             cell wall  GO: cellular_component  2.30e-03
# 3      anatomical structure development  GO: biological_process  6.79e-03
# 4  cell wall organization or biogenesis  GO: biological_process  4.77e-02
# 5           aberrant cell-cell adhesion   Dictybase: Phenotypes  5.47e-02
# 6                  extracellular matrix  GO: cellular_component  1.27e-01
# 7        aberrant spore coat morphology   Dictybase: Phenotypes  2.49e-01
# 8             decreased spore viability   Dictybase: Phenotypes  2.49e-01
# 9                       plasma membrane  GO: cellular_component  2.49e-01
#
#    N in query  Set size  N in ref.
# 0          24       157        157
# 1           4        13         13
# 2           4        13         13
# 3          19       440        438
# 4           3        15         15
# 5           2         5          5
# 6           2         8          8
# 7           2        12         12
# 8           4        60         59
# 9          10       268        268
# ***  mhat selected: 527 with EID: 526
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.27
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 89 out of 144 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                       extracellular region
# 1                             aberrant spore coat morphology
# 2                       cell wall organization or biogenesis
# 3   anatomical structure formation involved in morphogenesis
# 4                           external encapsulating structure
# 5                                                  cell wall
# 6                                       cell differentiation
# 7                           anatomical structure development
# 8                              Starch and sucrose metabolism
# 9                                       extracellular matrix
# 10                          abolished cellulose biosynthesis
# 11                                 decreased spore viability
# 12                            carbohydrate metabolic process
# 13                                        hydrolase activity
# 14                                      aberrant culmination
# 15                                       cell-cell signaling
# 16                                                 wild type
# 17                                     abolished culmination
# 18                      abolished stalk cell differentiation
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: cellular_component  1.31e-10          28       157        157
# 1    Dictybase: Phenotypes  1.09e-07           8        12         12
# 2   GO: biological_process  8.60e-07           8        15         15
# 3   GO: biological_process  1.84e-06          15        74         74
# 4   GO: cellular_component  3.40e-06           7        13         13
# 5   GO: cellular_component  3.40e-06           7        13         13
# 6   GO: biological_process  4.86e-06          20       145        145
# 7   GO: biological_process  3.43e-05          36       440        438
# 8           KEGG: Pathways  1.99e-03           7        31         31
# 9   GO: cellular_component  2.01e-03           4         8          8
# 10   Dictybase: Phenotypes  7.72e-03           3         5          5
# 11   Dictybase: Phenotypes  1.65e-02           8        60         59
# 12  GO: biological_process  1.65e-02          10        89         88
# 13  GO: molecular_function  1.65e-02           7        46         45
# 14   Dictybase: Phenotypes  5.57e-02           9        88         88
# 15  GO: biological_process  2.21e-01           3        16         16
# 16   Dictybase: Phenotypes  2.24e-01          20       341        338
# 17   Dictybase: Phenotypes  2.43e-01           6        62         62
# 18   Dictybase: Phenotypes  2.43e-01           2         7          7
# ***  cul selected: 933 with EID: 926
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.21
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 96 out of 192 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                       extracellular region
# 1                                       cell differentiation
# 2                             aberrant spore coat morphology
# 3   anatomical structure formation involved in morphogenesis
# 4                       cell wall organization or biogenesis
# 5                           external encapsulating structure
# 6                                                  cell wall
# 7                           anatomical structure development
# 8                                       extracellular matrix
# 9                                  decreased spore viability
# 10                                        hydrolase activity
# 11                                   oxidoreductase activity
# 12                                 decreased gene expression
# 13                             Starch and sucrose metabolism
# 14                         development arrests at slug stage
# 15                                             cell adhesion
# 16                                  aberrant stalk formation
# 17                               secondary metabolic process
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: cellular_component  8.76e-13          35       157        157
# 1   GO: biological_process  7.31e-06          24       145        145
# 2    Dictybase: Phenotypes  1.85e-05           7        12         12
# 3   GO: biological_process  1.85e-05          16        74         74
# 4   GO: biological_process  1.06e-04           7        15         15
# 5   GO: cellular_component  5.95e-03           5        13         13
# 6   GO: cellular_component  5.95e-03           5        13         13
# 7   GO: biological_process  5.95e-03          38       440        438
# 8   GO: cellular_component  7.10e-03           4         8          8
# 9    Dictybase: Phenotypes  3.81e-02           9        60         59
# 10  GO: molecular_function  8.94e-02           7        46         45
# 11  GO: molecular_function  8.94e-02          19       210        207
# 12   Dictybase: Phenotypes  1.26e-01          10        95         86
# 13          KEGG: Pathways  2.19e-01           5        31         31
# 14   Dictybase: Phenotypes  2.27e-01           3        12         12
# 15  GO: biological_process  2.27e-01           9        84         83
# 16   Dictybase: Phenotypes  2.31e-01           2         5          5
# 17  GO: biological_process  2.31e-01           2         5          5
# ***  FB selected: 709 with EID: 705
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.22
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 65 out of 155 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0                                      extracellular region
# 1                                      cell differentiation
# 2                                   oxidoreductase activity
# 3  anatomical structure formation involved in morphogenesis
# 4                               secondary metabolic process
# 5                                             cell adhesion
#
#                  Ontology       FDR  N in query  Set size  N in ref.
# 0  GO: cellular_component  5.28e-09          27       157        157
# 1  GO: biological_process  3.77e-03          17       145        145
# 2  GO: molecular_function  8.51e-03          20       210        207
# 3  GO: biological_process  2.04e-02          10        74         74
# 4  GO: biological_process  2.04e-02           3         5          5
# 5  GO: biological_process  1.48e-01           9        84         83
# ***  yem selected: 1001 with EID: 995
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.32
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 97 out of 320 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                secondary metabolic process
# 1                                       cell differentiation
# 2   anatomical structure formation involved in morphogenesis
# 3        Ubiquinone and other terpenoid-quinone biosynthesis
# 4                                  decreased gene expression
# 5                         Cysteine and methionine metabolism
# 6                                    Fatty acid biosynthesis
# 7                                    oxidoreductase activity
# 8                                   Phenylalanine metabolism
# 9                           anatomical structure development
# 10                 SNARE interactions in vesicular transport
# 11                                  aberrant gene expression
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: biological_process  9.67e-04           5         5          5
# 1   GO: biological_process  1.38e-03          28       145        145
# 2   GO: biological_process  5.76e-03          17        74         74
# 3           KEGG: Pathways  4.31e-02           5        10         10
# 4    Dictybase: Phenotypes  5.99e-02          16        95         86
# 5           KEGG: Pathways  5.99e-02           8        28         28
# 6           KEGG: Pathways  8.06e-02           4         8          8
# 7   GO: molecular_function  8.06e-02          29       210        207
# 8           KEGG: Pathways  1.88e-01           4        12         10
# 9   GO: biological_process  1.88e-01          50       440        438
# 10          KEGG: Pathways  2.16e-01           6        23         23
# 11   Dictybase: Phenotypes  2.46e-01           6        24         24

# %% [markdown]
# ##### DESeq2 all strains lFC >= 1 and padj <= 0.05

# %%
milestones=pd.read_table(path_de+'nobatchrep_combined.tsv',index_col=0,sep='\t')
for stage in [phenotype for phenotype in PHENOTYPES if phenotype in list(milestones['Stage'].unique())]:
    query_names=list(milestones.query('log2FoldChange>=1 & padj <= 0.05 & Stage=="'+stage+'"').index)
    enriched=group_diff_enrichment(query_names=query_names,group=stage,min_overlap=2,use_annotated_genes=True)
# Out:
# ***  no_agg selected: 1652 with EID: 1643
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.36
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 359 out of 598 query genes used for enrichment calculation.
#                                    Gene set                Ontology       FDR  \
# 0                                  Ribosome          KEGG: Pathways  8.27e-65
# 1                                  ribosome  GO: cellular_component  6.79e-60
# 2        structural constituent of ribosome  GO: molecular_function  4.38e-57
# 3              structural molecule activity  GO: molecular_function  5.89e-44
# 4                               translation  GO: biological_process  8.91e-39
# 5                             mitochondrion  GO: cellular_component  2.15e-09
# 6                      Steroid biosynthesis          KEGG: Pathways  2.11e-07
# 7                              rRNA binding  GO: molecular_function  1.90e-06
# 8                               RNA binding  GO: molecular_function  1.67e-04
# 9     Biosynthesis of secondary metabolites          KEGG: Pathways  7.76e-04
# 10                Oxidative phosphorylation          KEGG: Pathways  1.56e-02
# 11                  oxidoreductase activity  GO: molecular_function  1.56e-02
# 12              Aminoacyl-tRNA biosynthesis          KEGG: Pathways  1.66e-02
# 13               mitochondrion organization  GO: biological_process  2.01e-02
# 14               methyltransferase activity  GO: molecular_function  2.01e-02
# 15                    Fatty acid elongation          KEGG: Pathways  2.37e-02
# 16                     extracellular region  GO: cellular_component  2.85e-02
# 17     Porphyrin and chlorophyll metabolism          KEGG: Pathways  3.66e-02
# 18  Biosynthesis of unsaturated fatty acids          KEGG: Pathways  1.80e-01
# 19                       hydrolase activity  GO: molecular_function  1.90e-01
# 20                       isomerase activity  GO: molecular_function  1.90e-01
# 21                      ribosome biogenesis  GO: biological_process  2.20e-01
#
#     N in query  Set size  N in ref.
# 0           90       105         97
# 1           85        93         93
# 2           79        85         85
# 3           85       117        117
# 4           99       169        169
# 5           73       229        229
# 6           14        18         18
# 7           11        13         13
# 8           48       169        169
# 9           68       289        281
# 10          18        71         54
# 11          49       210        207
# 12          16        64         46
# 13          10        23         23
# 14          18        58         56
# 15           7        13         13
# 16          38       157        157
# 17           7        14         14
# 18           6        15         14
# 19          13        46         45
# 20          14        50         50
# 21          16        61         61
# ***  stream selected: 170 with EID: 167
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.25
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 28 out of 41 query genes used for enrichment calculation.
#                                     Gene set                Ontology  \
# 0                       extracellular region  GO: cellular_component
# 1   development arrests at loose mound stage   Dictybase: Phenotypes
# 2                              cell adhesion  GO: biological_process
# 3                       aberrant aggregation   Dictybase: Phenotypes
# 4                            plasma membrane  GO: cellular_component
# 5                         aberrant streaming   Dictybase: Phenotypes
# 6                        signal transduction  GO: biological_process
# 7                   abolished slug migration   Dictybase: Phenotypes
# 8                       aberrant culmination   Dictybase: Phenotypes
# 9                     precocious aggregation   Dictybase: Phenotypes
# 10              aberrant cAMP wave formation   Dictybase: Phenotypes
# 11                   aberrant slug migration   Dictybase: Phenotypes
# 12                 abolished gene expression   Dictybase: Phenotypes
#
#          FDR  N in query  Set size  N in ref.
# 0   3.40e-05          11       157        157
# 1   2.28e-03           4        20         20
# 2   5.32e-02           5        84         83
# 3   9.01e-02           4        61         61
# 4   1.09e-01           8       268        268
# 5   1.09e-01           4        72         72
# 6   1.27e-01           9       352        350
# 7   1.27e-01           3        43         43
# 8   1.46e-01           4        88         88
# 9   1.69e-01           2        20         20
# 10  1.69e-01           4        96         96
# 11  1.90e-01           3        58         58
# 12  2.19e-01           2        25         25
# ***  lag selected: 193 with EID: 190
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.3
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 43 out of 57 query genes used for enrichment calculation.
#                                                 Gene set  \
# 0                                   extracellular region
# 1                                        plasma membrane
# 2               development arrests at loose mound stage
# 3                                    signal transduction
# 4                               abolished slug migration
# 5                                   aberrant aggregation
# 6                             multiple tips in culminant
# 7                                     response to stress
# 8                                  decreased culmination
# 9                       anatomical structure development
# 10                         abolished cAMP wave formation
# 11                                   abolished streaming
# 12                                 delayed tip formation
# 13                                    aberrant streaming
# 14                                 abolished aggregation
# 15                                multiple tips in mound
# 16                                         cell adhesion
# 17                                precocious aggregation
# 18                                  aberrant development
# 19                                  aberrant culmination
# 20                    development arrests at mound stage
# 21                                 abolished sporulation
# 22                             abolished gene expression
# 23                          aberrant cAMP wave formation
# 24                               aberrant slug migration
# 25  AGE-RAGE signaling pathway in diabetic complications
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: cellular_component  1.38e-03          11       157        157
# 1   GO: cellular_component  5.24e-03          13       268        268
# 2    Dictybase: Phenotypes  6.81e-03           4        20         20
# 3   GO: biological_process  8.56e-03          14       352        350
# 4    Dictybase: Phenotypes  8.56e-03           5        43         43
# 5    Dictybase: Phenotypes  3.61e-02           5        61         61
# 6    Dictybase: Phenotypes  3.62e-02           2         5          5
# 7   GO: biological_process  6.93e-02          12       360        358
# 8    Dictybase: Phenotypes  9.76e-02           2         9          9
# 9   GO: biological_process  1.06e-01          13       440        438
# 10   Dictybase: Phenotypes  1.20e-01           2        11         11
# 11   Dictybase: Phenotypes  1.22e-01           3        33         33
# 12   Dictybase: Phenotypes  1.41e-01           2        13         13
# 13   Dictybase: Phenotypes  1.77e-01           4        72         72
# 14   Dictybase: Phenotypes  2.19e-01           4        82         80
# 15   Dictybase: Phenotypes  2.19e-01           2        18         18
# 16  GO: biological_process  2.32e-01           4        84         83
# 17   Dictybase: Phenotypes  2.33e-01           2        20         20
# 18   Dictybase: Phenotypes  2.37e-01           3        51         51
# 19   Dictybase: Phenotypes  2.37e-01           4        88         88
# 20   Dictybase: Phenotypes  2.47e-01           3        56         54
# 21   Dictybase: Phenotypes  2.47e-01           2        25         25
# 22   Dictybase: Phenotypes  2.47e-01           2        25         25
# 23   Dictybase: Phenotypes  2.47e-01           4        96         96
# 24   Dictybase: Phenotypes  2.47e-01           3        58         58
# 25          KEGG: Pathways  2.47e-01           2        24         24
# ***  tag selected: 384 with EID: 382
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.18
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 44 out of 70 query genes used for enrichment calculation.
#                              Gene set                Ontology       FDR  \
# 0              chromosome segregation  GO: biological_process  1.34e-03
# 1                          cell cycle  GO: biological_process  1.75e-03
# 2            mitotic nuclear division  GO: biological_process  4.38e-03
# 3             chromosome organization  GO: biological_process  7.08e-03
# 4                     DNA replication          KEGG: Pathways  7.08e-03
# 5                  mitotic cell cycle  GO: biological_process  2.73e-02
# 6                          chromosome  GO: cellular_component  2.73e-02
# 7   increased cell-substrate adhesion   Dictybase: Phenotypes  2.73e-02
# 8                       cell division  GO: biological_process  5.37e-02
# 9                extracellular region  GO: cellular_component  7.53e-02
# 10                          cell wall  GO: cellular_component  1.86e-01
# 11   external encapsulating structure  GO: cellular_component  1.86e-01
# 12              delayed tip formation   Dictybase: Phenotypes  1.86e-01
# 13          decreased spore viability   Dictybase: Phenotypes  1.86e-01
# 14                    kinase activity  GO: molecular_function  2.27e-01
#
#     N in query  Set size  N in ref.
# 0            5        18         18
# 1           12       167        167
# 2            4        15         15
# 3            7        74         74
# 4            5        34         33
# 5            7       100        100
# 6            6        70         70
# 7            4        30         30
# 8            7       115        115
# 9            8       157        157
# 10           2        13         13
# 11           2        13         13
# 12           2        13         13
# 13           4        60         59
# 14          11       328        327
# ***  tip selected: 616 with EID: 613
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.26
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 92 out of 157 query genes used for enrichment calculation.
#                                    Gene set                Ontology       FDR  \
# 0                                chromosome  GO: cellular_component  1.17e-12
# 1                           DNA replication          KEGG: Pathways  1.17e-12
# 2                                cell cycle  GO: biological_process  1.08e-08
# 3                    chromosome segregation  GO: biological_process  3.38e-07
# 4                   chromosome organization  GO: biological_process  6.51e-07
# 5                  mitotic nuclear division  GO: biological_process  2.13e-05
# 6                             cell division  GO: biological_process  5.46e-05
# 7                        mitotic cell cycle  GO: biological_process  6.71e-04
# 8                        nuclear chromosome  GO: cellular_component  6.71e-04
# 9                           Mismatch repair          KEGG: Pathways  1.19e-03
# 10                              DNA binding  GO: molecular_function  6.82e-03
# 11               Nucleotide excision repair          KEGG: Pathways  8.11e-03
# 12                     Base excision repair          KEGG: Pathways  9.43e-03
# 13                    DNA metabolic process  GO: biological_process  1.03e-02
# 14                    Pyrimidine metabolism          KEGG: Pathways  1.03e-02
# 15                     extracellular region  GO: cellular_component  1.42e-02
# 16                    delayed tip formation   Dictybase: Phenotypes  1.42e-02
# 17            microtubule organizing center  GO: cellular_component  3.39e-02
# 18           Ubiquitin mediated proteolysis          KEGG: Pathways  9.73e-02
# 19          aberrant myosin II organization   Dictybase: Phenotypes  1.17e-01
# 20               increased macropinocytosis   Dictybase: Phenotypes  1.17e-01
# 21                        cell cycle arrest   Dictybase: Phenotypes  1.17e-01
# 22           increased chemotaxis to folate   Dictybase: Phenotypes  1.17e-01
# 23                   Glutathione metabolism          KEGG: Pathways  1.23e-01
# 24             decreased cell-cell adhesion   Dictybase: Phenotypes  1.46e-01
# 25  decreased prestalk cell differentiation   Dictybase: Phenotypes  1.51e-01
# 26                             cytoskeleton  GO: cellular_component  2.15e-01
# 27               precocious gene expression   Dictybase: Phenotypes  2.15e-01
#
#     N in query  Set size  N in ref.
# 0           22        70         70
# 1           16        34         33
# 2           27       167        167
# 3            9        18         18
# 4           16        74         74
# 5            7        15         15
# 6           17       115        115
# 7           14       100        100
# 8            6        17         17
# 9            6        19         19
# 10          20       221        221
# 11           7        37         37
# 12           6        28         28
# 13          12       105        105
# 14           6        31         29
# 15          15       157        157
# 16           4        13         13
# 17           7        50         50
# 18           7        62         61
# 19           2         5          5
# 20           2         5          5
# 21           2         5          5
# 22           2         5          5
# 23           4        28         25
# 24           3        15         15
# 25           2         6          6
# 26          13       185        185
# 27           3        18         18
# ***  slug selected: 1373 with EID: 1367
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.21
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 166 out of 292 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                       extracellular region
# 1                           anatomical structure development
# 2                             aberrant spore coat morphology
# 3                                                  cell wall
# 4                           external encapsulating structure
# 5                                       cell differentiation
# 6                              Starch and sucrose metabolism
# 7   anatomical structure formation involved in morphogenesis
# 8                       cell wall organization or biogenesis
# 9                                        signal transduction
# 10                                      aberrant culmination
# 11                                 decreased spore viability
# 12                 DNA-binding transcription factor activity
# 13                          abolished cellulose biosynthesis
# 14                                      aberrant thermotaxis
# 15                                           spores inviable
# 16                                               DNA binding
# 17                                       aberrant phototaxis
# 18                   increased prespore cell differentiation
# 19                                    Glutathione metabolism
# 20                         development arrests at slug stage
# 21                         aberrant fruiting body morphology
# 22                                     abolished culmination
# 23                                      extracellular matrix
# 24                                    increased stalk length
# 25                              aberrant cAMP wave formation
# 26                                       cell-cell signaling
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: cellular_component  4.35e-09          38       157        157
# 1   GO: biological_process  1.80e-05          62       440        438
# 2    Dictybase: Phenotypes  2.63e-05           8        12         12
# 3   GO: cellular_component  3.84e-05           8        13         13
# 4   GO: cellular_component  3.84e-05           8        13         13
# 5   GO: biological_process  2.13e-04          27       145        145
# 6           KEGG: Pathways  2.44e-04          11        31         31
# 7   GO: biological_process  5.80e-04          17        74         74
# 8   GO: biological_process  1.21e-03           7        15         15
# 9   GO: biological_process  6.01e-03          44       352        350
# 10   Dictybase: Phenotypes  1.36e-02          16        88         88
# 11   Dictybase: Phenotypes  2.16e-02          12        60         59
# 12  GO: molecular_function  2.23e-02           9        37         37
# 13   Dictybase: Phenotypes  5.23e-02           3         5          5
# 14   Dictybase: Phenotypes  5.23e-02           3         5          5
# 15   Dictybase: Phenotypes  5.23e-02           3         5          5
# 16  GO: molecular_function  5.23e-02          28       221        221
# 17   Dictybase: Phenotypes  8.84e-02           3        14          6
# 18   Dictybase: Phenotypes  8.84e-02           3         6          6
# 19          KEGG: Pathways  1.04e-01           6        28         25
# 20   Dictybase: Phenotypes  1.07e-01           4        12         12
# 21   Dictybase: Phenotypes  1.40e-01          14       101         98
# 22   Dictybase: Phenotypes  1.58e-01          10        62         62
# 23  GO: cellular_component  1.68e-01           3         8          8
# 24   Dictybase: Phenotypes  1.68e-01           3         8          8
# 25   Dictybase: Phenotypes  2.25e-01          13        96         96
# 26  GO: biological_process  2.41e-01           4        16         16
# ***  mhat selected: 1871 with EID: 1864
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.3
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 340 out of 567 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                           anatomical structure development
# 1   anatomical structure formation involved in morphogenesis
# 2                             aberrant spore coat morphology
# 3                                       cell differentiation
# 4                                       extracellular region
# 5                                                  cell wall
# 6                           external encapsulating structure
# 7                              Starch and sucrose metabolism
# 8                                  decreased spore viability
# 9                                        signal transduction
# 10                                           kinase activity
# 11                   increased prespore cell differentiation
# 12                 DNA-binding transcription factor activity
# 13                      cell wall organization or biogenesis
# 14                                      aberrant culmination
# 15                 development arrests at tipped mound stage
# 16                          abolished cellulose biosynthesis
# 17                                           spores inviable
# 18                                 aberrant spore morphology
# 19                         aberrant fruiting body morphology
# 20                                   aberrant slug migration
# 21                                       aberrant phototaxis
# 22                                     abolished culmination
# 23                                                 wild type
# 24                                               DNA binding
# 25                                      Galactose metabolism
# 26                                 increased gene expression
# 27                            carbohydrate metabolic process
# 28                                          ABC transporters
# 29                                  abolished slug migration
# 30                                     decreased sporulation
# 31                                      extracellular matrix
# 32                                    increased stalk length
# 33                                 decreased gene expression
# 34                                       cell-cell signaling
# 35                        decreased intracellular cAMP level
# 36                                 abolished gene expression
# 37                            aberrant autophagic cell death
# 38                 abolished protein localization to nucleus
# 39                                increased macropinocytosis
# 40                                      aberrant thermotaxis
# 41                                    precocious sporulation
# 42                                         translucent sorus
# 43                                      Histidine metabolism
# 44               Amino sugar and nucleotide sugar metabolism
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: biological_process  7.80e-07         107       440        438
# 1   GO: biological_process  1.87e-05          29        74         74
# 2    Dictybase: Phenotypes  2.08e-05          10        12         12
# 3   GO: biological_process  3.65e-05          44       145        145
# 4   GO: cellular_component  1.28e-04          45       157        157
# 5   GO: cellular_component  5.17e-04           9        13         13
# 6   GO: cellular_component  5.17e-04           9        13         13
# 7           KEGG: Pathways  1.52e-03          14        31         31
# 8    Dictybase: Phenotypes  4.67e-03          20        60         59
# 9   GO: biological_process  7.14e-03          74       352        350
# 10  GO: molecular_function  7.14e-03          70       328        327
# 11   Dictybase: Phenotypes  9.25e-03           5         6          6
# 12  GO: molecular_function  9.34e-03          14        37         37
# 13  GO: biological_process  1.02e-02           8        15         15
# 14   Dictybase: Phenotypes  1.02e-02          25        88         88
# 15   Dictybase: Phenotypes  1.10e-02           7        12         12
# 16   Dictybase: Phenotypes  3.60e-02           4         5          5
# 17   Dictybase: Phenotypes  3.60e-02           4         5          5
# 18   Dictybase: Phenotypes  4.03e-02           5         8          8
# 19   Dictybase: Phenotypes  4.03e-02          25       101         98
# 20   Dictybase: Phenotypes  4.03e-02          17        58         58
# 21   Dictybase: Phenotypes  7.83e-02           4        14          6
# 22   Dictybase: Phenotypes  7.88e-02          17        62         62
# 23   Dictybase: Phenotypes  9.53e-02          65       341        338
# 24  GO: molecular_function  1.13e-01          45       221        221
# 25          KEGG: Pathways  1.23e-01           6        15         14
# 26   Dictybase: Phenotypes  1.36e-01          13        46         46
# 27  GO: biological_process  1.42e-01          21        89         88
# 28          KEGG: Pathways  1.62e-01           6        15         15
# 29   Dictybase: Phenotypes  1.71e-01          12        43         43
# 30   Dictybase: Phenotypes  1.71e-01          14        53         53
# 31  GO: cellular_component  1.86e-01           4         8          8
# 32   Dictybase: Phenotypes  1.86e-01           4         8          8
# 33   Dictybase: Phenotypes  1.86e-01          20        95         86
# 34  GO: biological_process  1.87e-01           6        16         16
# 35   Dictybase: Phenotypes  1.87e-01           5        12         12
# 36   Dictybase: Phenotypes  1.87e-01           8        25         25
# 37   Dictybase: Phenotypes  1.93e-01           3         5          5
# 38   Dictybase: Phenotypes  1.93e-01           3         5          5
# 39   Dictybase: Phenotypes  1.93e-01           3         5          5
# 40   Dictybase: Phenotypes  1.93e-01           3         5          5
# 41   Dictybase: Phenotypes  1.93e-01           3         5          5
# 42   Dictybase: Phenotypes  2.30e-01           4         9          9
# 43          KEGG: Pathways  2.30e-01           5        16         13
# 44          KEGG: Pathways  2.42e-01           8        27         27
# ***  cul selected: 2344 with EID: 2328
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.27
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 344 out of 629 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0   anatomical structure formation involved in morphogenesis
# 1                                       cell differentiation
# 2                                       extracellular region
# 3                           anatomical structure development
# 4                             aberrant spore coat morphology
# 5                                                  cell wall
# 6                           external encapsulating structure
# 7                              Starch and sucrose metabolism
# 8                                  decreased spore viability
# 9                                       aberrant culmination
# 10                   increased prespore cell differentiation
# 11                      cell wall organization or biogenesis
# 12                 development arrests at tipped mound stage
# 13                               secondary metabolic process
# 14                                   aberrant slug migration
# 15                                           spores inviable
# 16                 DNA-binding transcription factor activity
# 17                                 aberrant spore morphology
# 18                                     abolished culmination
# 19                 SNARE interactions in vesicular transport
# 20                                           kinase activity
# 21                    abolished autophagic vacuole formation
# 22                           abolished autophagic cell death
# 23                                 increased gene expression
# 24                                           Golgi apparatus
# 25       Ubiquinone and other terpenoid-quinone biosynthesis
# 26                                 decreased gene expression
# 27                    aberrant prestalk cell differentiation
# 28                                     decreased sporulation
# 29                                      Galactose metabolism
# 30                         aberrant fruiting body morphology
# 31                                               DNA binding
# 32                                       signal transduction
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: biological_process  1.03e-11          40        74         74
# 1   GO: biological_process  5.49e-11          59       145        145
# 2   GO: cellular_component  6.85e-09          58       157        157
# 3   GO: biological_process  1.95e-05         109       440        438
# 4    Dictybase: Phenotypes  3.45e-05          10        12         12
# 5   GO: cellular_component  1.09e-03           9        13         13
# 6   GO: cellular_component  1.09e-03           9        13         13
# 7           KEGG: Pathways  1.09e-03          15        31         31
# 8    Dictybase: Phenotypes  6.61e-03          21        60         59
# 9    Dictybase: Phenotypes  1.29e-02          27        88         88
# 10   Dictybase: Phenotypes  1.68e-02           5         6          6
# 11  GO: biological_process  2.60e-02           8        15         15
# 12   Dictybase: Phenotypes  2.60e-02           7        12         12
# 13  GO: biological_process  6.48e-02           4         5          5
# 14   Dictybase: Phenotypes  6.48e-02          18        58         58
# 15   Dictybase: Phenotypes  6.48e-02           4         5          5
# 16  GO: molecular_function  6.87e-02          13        37         37
# 17   Dictybase: Phenotypes  7.23e-02           5         8          8
# 18   Dictybase: Phenotypes  1.09e-01          18        62         62
# 19          KEGG: Pathways  1.09e-01           9        23         23
# 20  GO: molecular_function  1.09e-01          69       328        327
# 21   Dictybase: Phenotypes  1.11e-01           4         6          6
# 22   Dictybase: Phenotypes  1.11e-01           4         6          6
# 23   Dictybase: Phenotypes  1.46e-01          14        46         46
# 24  GO: cellular_component  1.70e-01          22        85         85
# 25          KEGG: Pathways  1.70e-01           5        10         10
# 26   Dictybase: Phenotypes  1.80e-01          22        95         86
# 27   Dictybase: Phenotypes  1.84e-01           4         7          7
# 28   Dictybase: Phenotypes  1.84e-01          15        53         53
# 29          KEGG: Pathways  1.84e-01           6        15         14
# 30   Dictybase: Phenotypes  2.02e-01          24       101         98
# 31  GO: molecular_function  2.19e-01          47       221        221
# 32  GO: biological_process  2.26e-01          70       352        350
# ***  FB selected: 1970 with EID: 1958
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.25
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 277 out of 494 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                       cell differentiation
# 1                                       extracellular region
# 2   anatomical structure formation involved in morphogenesis
# 3                           anatomical structure development
# 4                              Starch and sucrose metabolism
# 5                                       aberrant culmination
# 6                                secondary metabolic process
# 7                                                  wild type
# 8                                            spores inviable
# 9                  SNARE interactions in vesicular transport
# 10                 development arrests at tipped mound stage
# 11                                 decreased spore viability
# 12                            aberrant spore coat morphology
# 13                   decreased prestalk cell differentiation
# 14                   increased prespore cell differentiation
# 15                                     abolished culmination
# 16       Ubiquinone and other terpenoid-quinone biosynthesis
# 17                                           Golgi apparatus
# 18                                           kinase activity
# 19                                 decreased gene expression
# 20                                      extracellular matrix
# 21                                       signal transduction
# 22                 DNA-binding transcription factor activity
# 23                        development arrests at mound stage
# 24                            aberrant autophagic cell death
# 25                          abolished cellulose biosynthesis
# 26                                       delayed culmination
# 27                                   delayed gene expression
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: biological_process  1.61e-06          44       145        145
# 1   GO: cellular_component  1.61e-06          46       157        157
# 2   GO: biological_process  2.33e-06          28        74         74
# 3   GO: biological_process  4.24e-04          86       440        438
# 4           KEGG: Pathways  4.64e-04          14        31         31
# 5    Dictybase: Phenotypes  2.01e-02          23        88         88
# 6   GO: biological_process  3.82e-02           4         5          5
# 7    Dictybase: Phenotypes  3.82e-02          62       341        338
# 8    Dictybase: Phenotypes  3.82e-02           4         5          5
# 9           KEGG: Pathways  3.82e-02           9        23         23
# 10   Dictybase: Phenotypes  4.72e-02           6        12         12
# 11   Dictybase: Phenotypes  4.72e-02          16        60         59
# 12   Dictybase: Phenotypes  4.72e-02           6        12         12
# 13   Dictybase: Phenotypes  6.57e-02           4         6          6
# 14   Dictybase: Phenotypes  6.57e-02           4         6          6
# 15   Dictybase: Phenotypes  6.67e-02          16        62         62
# 16          KEGG: Pathways  8.70e-02           5        10         10
# 17  GO: cellular_component  1.35e-01          19        85         85
# 18  GO: molecular_function  1.35e-01          56       328        327
# 19   Dictybase: Phenotypes  1.46e-01          19        95         86
# 20  GO: cellular_component  1.78e-01           4         8          8
# 21  GO: biological_process  1.90e-01          58       352        350
# 22  GO: molecular_function  1.90e-01          10        37         37
# 23   Dictybase: Phenotypes  1.92e-01          13        56         54
# 24   Dictybase: Phenotypes  2.05e-01           3         5          5
# 25   Dictybase: Phenotypes  2.05e-01           3         5          5
# 26   Dictybase: Phenotypes  2.20e-01           8        28         28
# 27   Dictybase: Phenotypes  2.20e-01           6        19         18
# ***  yem selected: 2231 with EID: 2218
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.34
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 69 out of 760 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0                               secondary metabolic process
# 1  anatomical structure formation involved in morphogenesis
# 2                                   Glycerolipid metabolism
# 3                 DNA-binding transcription factor activity
# 4                                      cell differentiation
#
#                  Ontology       FDR  N in query  Set size  N in ref.
# 0  GO: biological_process  9.98e-02           5         5          5
# 1  GO: biological_process  1.09e-01          26        74         74
# 2          KEGG: Pathways  1.09e-01          10        20         19
# 3  GO: molecular_function  1.09e-01          16        37         37
# 4  GO: biological_process  2.13e-01          42       145        145

# %% [markdown]
# #### DESeq2 WT

# %% [markdown]
# ##### DESeq2 WT lFC >= 2 and padj <= 0.01

# %%
milestones=pd.read_table(path_de+'WT_batchrep_combined.tsv',index_col=0,sep='\t')
for stage in [phenotype for phenotype in PHENOTYPES if phenotype in list(milestones['Stage'].unique())]:
    query_names=list(milestones.query('log2FoldChange>=2 & padj <= 0.01 & Stage=="'+stage+'"').index)
    enriched=group_diff_enrichment(query_names=query_names,group=stage,min_overlap=2,use_annotated_genes=True)
# Out:
# ***  no_agg selected: 878 with EID: 873
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.39
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 248 out of 337 query genes used for enrichment calculation.
#                                   Gene set                Ontology       FDR  \
# 0                                 Ribosome          KEGG: Pathways  2.46e-19
# 1       structural constituent of ribosome  GO: molecular_function  1.98e-15
# 2                              translation  GO: biological_process  4.23e-15
# 3                                 ribosome  GO: cellular_component  4.23e-15
# 4             structural molecule activity  GO: molecular_function  9.32e-11
# 5                            mitochondrion  GO: cellular_component  1.66e-06
# 6                     Steroid biosynthesis          KEGG: Pathways  1.75e-04
# 7        Ribosome biogenesis in eukaryotes          KEGG: Pathways  1.06e-03
# 8                  oxidoreductase activity  GO: molecular_function  1.29e-03
# 9    Biosynthesis of secondary metabolites          KEGG: Pathways  1.89e-03
# 10                 lipid metabolic process  GO: biological_process  3.00e-03
# 11                               nucleolus  GO: cellular_component  5.32e-03
# 12    Porphyrin and chlorophyll metabolism          KEGG: Pathways  1.09e-02
# 13                      hydrolase activity  GO: molecular_function  1.77e-02
# 14             Aminoacyl-tRNA biosynthesis          KEGG: Pathways  2.01e-02
# 15              methyltransferase activity  GO: molecular_function  3.18e-02
# 16                   Fatty acid elongation          KEGG: Pathways  4.04e-02
# 17                                 Glycine          KEGG: Pathways  4.04e-02
# 18   cellular amino acid metabolic process  GO: biological_process  4.57e-02
# 19                             RNA binding  GO: molecular_function  4.87e-02
# 20                     ribosome biogenesis  GO: biological_process  5.09e-02
# 21                  tRNA metabolic process  GO: biological_process  5.09e-02
# 22                   Vitamin B6 metabolism          KEGG: Pathways  5.34e-02
# 23                     Lysine biosynthesis          KEGG: Pathways  9.59e-02
# 24                    extracellular region  GO: cellular_component  1.22e-01
# 25             Biosynthesis of amino acids          KEGG: Pathways  1.28e-01
# 26                         ligase activity  GO: molecular_function  1.43e-01
# 27                    Butanoate metabolism          KEGG: Pathways  1.63e-01
# 28                      isomerase activity  GO: molecular_function  1.87e-01
# 29  protein-macromolecule adaptor activity  GO: molecular_function  1.89e-01
# 30                                lysosome  GO: cellular_component  2.25e-01
# 31                   Fatty acid metabolism          KEGG: Pathways  2.33e-01
# 32        small molecule metabolic process  GO: biological_process  2.48e-01
#
#     N in query  Set size  N in ref.
# 0           43       105         97
# 1           36        85         85
# 2           51       169        169
# 3           37        93         93
# 4           36       117        117
# 5           45       229        229
# 6            9        18         18
# 7           17        72         68
# 8           35       210        207
# 9           43       289        281
# 10          28       159        159
# 11          16        72         72
# 12           6        14         14
# 13          11        46         45
# 14          11        64         46
# 15          12        58         56
# 16           5        13         13
# 17           7        27         24
# 18          20       125        124
# 19          25       169        169
# 20          12        61         61
# 21          13        69         69
# 22           3         5          5
# 23           3         6          6
# 24          22       157        157
# 25          11        63         62
# 26          13        80         80
# 27           4        13         13
# 28           9        50         50
# 29           3         8          8
# 30          11        69         69
# 31           6        30         29
# 32          40       354        353
# ***  stream selected: 87 with EID: 86
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.17
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 6 out of 15 query genes used for enrichment calculation.
#                                    Gene set                Ontology       FDR  \
# 0                             cell adhesion  GO: biological_process  6.88e-02
# 1                    precocious aggregation   Dictybase: Phenotypes  6.88e-02
# 2  development arrests at loose mound stage   Dictybase: Phenotypes  6.88e-02
# 3                           plasma membrane  GO: cellular_component  1.56e-01
# 4                     decreased sporulation   Dictybase: Phenotypes  1.56e-01
# 5              decreased fruiting body size   Dictybase: Phenotypes  1.56e-01
# 6                   decreased cell motility   Dictybase: Phenotypes  1.56e-01
#
#    N in query  Set size  N in ref.
# 0           3        84         83
# 1           2        20         20
# 2           2        20         20
# 3           4       268        268
# 4           2        53         53
# 5           2        76         75
# 6           2        76         76
# ***  lag selected: 70 with EID: 69
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.22
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 9 out of 15 query genes used for enrichment calculation.
#                        Gene set                Ontology       FDR  N in query  \
# 0      abolished slug migration   Dictybase: Phenotypes  2.69e-02           3
# 1               plasma membrane  GO: cellular_component  3.20e-02           5
# 2            aberrant streaming   Dictybase: Phenotypes  3.20e-02           3
# 3          aberrant aggregation   Dictybase: Phenotypes  3.20e-02           3
# 4          aberrant culmination   Dictybase: Phenotypes  4.31e-02           3
# 5  aberrant cAMP wave formation   Dictybase: Phenotypes  4.59e-02           3
# 6       aberrant slug migration   Dictybase: Phenotypes  1.17e-01           2
# 7               GTPase activity  GO: molecular_function  1.17e-01           3
# 8                  reproduction  GO: biological_process  1.34e-01           2
# 9                 cell adhesion  GO: biological_process  1.37e-01           2
#
#    Set size  N in ref.
# 0        43         43
# 1       268        268
# 2        72         72
# 3        61         61
# 4        88         88
# 5        96         96
# 6        58         58
# 7       145        145
# 8        79         79
# 9        84         83
# ***  tag selected: 24 with EID: 24
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.17
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 4 out of 4 query genes used for enrichment calculation.
#                                 Gene set                Ontology       FDR  \
# 0       small molecule metabolic process  GO: biological_process  9.15e-02
# 1  Biosynthesis of secondary metabolites          KEGG: Pathways  9.15e-02
# 2                        kinase activity  GO: molecular_function  9.15e-02
#
#    N in query  Set size  N in ref.
# 0           2       354        353
# 1           2       289        281
# 2           2       328        327
# ***  tip selected: 60 with EID: 60
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.37
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 21 out of 22 query genes used for enrichment calculation.
#                             Gene set                Ontology       FDR  \
# 0                         cell cycle  GO: biological_process  1.36e-08
# 1                         chromosome  GO: cellular_component  4.33e-08
# 2            chromosome organization  GO: biological_process  4.55e-08
# 3           mitotic nuclear division  GO: biological_process  1.20e-07
# 4             chromosome segregation  GO: biological_process  2.58e-07
# 5                 mitotic cell cycle  GO: biological_process  2.58e-07
# 6                    DNA replication          KEGG: Pathways  5.07e-06
# 7                  cell cycle arrest   Dictybase: Phenotypes  1.81e-03
# 8                      cell division  GO: biological_process  1.89e-03
# 9              Pyrimidine metabolism          KEGG: Pathways  2.48e-03
# 10                   ATPase activity  GO: molecular_function  8.72e-03
# 11     microtubule organizing center  GO: cellular_component  1.03e-02
# 12                   Mismatch repair          KEGG: Pathways  1.82e-02
# 13                      cytoskeleton  GO: cellular_component  5.83e-02
# 14        Nucleotide excision repair          KEGG: Pathways  5.83e-02
# 15             DNA metabolic process  GO: biological_process  6.04e-02
# 16                       DNA binding  GO: molecular_function  7.54e-02
# 17                 helicase activity  GO: molecular_function  7.54e-02
# 18  small molecule metabolic process  GO: biological_process  2.47e-01
#
#     N in query  Set size  N in ref.
# 0           11       167        167
# 1            8        70         70
# 2            8        74         74
# 3            5        15         15
# 4            5        18         18
# 5            8       100        100
# 6            5        34         33
# 7            2         5          5
# 8            5       115        115
# 9            3        31         29
# 10           5       169        168
# 11           3        50         50
# 12           2        19         19
# 13           4       185        185
# 14           2        37         37
# 15           3       105        105
# 16           4       221        221
# 17           2        51         51
# 18           4       354        353
# ***  slug selected: 148 with EID: 148
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.14
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 11 out of 21 query genes used for enrichment calculation.
#                            Gene set                Ontology       FDR  \
# 0              extracellular region  GO: cellular_component  3.83e-05
# 1                         cell wall  GO: cellular_component  3.69e-02
# 2  external encapsulating structure  GO: cellular_component  3.69e-02
# 3            Glutathione metabolism          KEGG: Pathways  1.02e-01
#
#    N in query  Set size  N in ref.
# 0           8       157        157
# 1           2        13         13
# 2           2        13         13
# 3           2        28         25
# ***  mhat selected: 545 with EID: 544
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.24
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 63 out of 132 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                       extracellular region
# 1                             aberrant spore coat morphology
# 2                                                  cell wall
# 3                           external encapsulating structure
# 4                       cell wall organization or biogenesis
# 5                                       extracellular matrix
# 6   anatomical structure formation involved in morphogenesis
# 7                           anatomical structure development
# 8                                  decreased spore viability
# 9                                       cell differentiation
# 10                             Starch and sucrose metabolism
# 11                                                 wild type
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: cellular_component  1.61e-07          23       157        157
# 1    Dictybase: Phenotypes  2.25e-06           7        12         12
# 2   GO: cellular_component  7.21e-05           6        13         13
# 3   GO: cellular_component  7.21e-05           6        13         13
# 4   GO: biological_process  1.59e-04           6        15         15
# 5   GO: cellular_component  2.03e-03           4         8          8
# 6   GO: biological_process  3.40e-03          10        74         74
# 7   GO: biological_process  9.52e-03          28       440        438
# 8    Dictybase: Phenotypes  1.21e-02           8        60         59
# 9   GO: biological_process  1.59e-02          13       145        145
# 10          KEGG: Pathways  4.82e-02           5        31         31
# 11   Dictybase: Phenotypes  1.09e-01          20       341        338
# ***  cul selected: 944 with EID: 936
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.23
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 94 out of 211 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                       extracellular region
# 1   anatomical structure formation involved in morphogenesis
# 2                                       cell differentiation
# 3                             aberrant spore coat morphology
# 4                       cell wall organization or biogenesis
# 5                                       extracellular matrix
# 6                           anatomical structure development
# 7                              Starch and sucrose metabolism
# 8                                secondary metabolic process
# 9                                                  wild type
# 10                                        hydrolase activity
# 11                                 decreased spore viability
# 12       Ubiquinone and other terpenoid-quinone biosynthesis
# 13                                 decreased gene expression
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: cellular_component  6.59e-10          33       157        157
# 1   GO: biological_process  1.25e-04          16        74         74
# 2   GO: biological_process  1.30e-04          23       145        145
# 3    Dictybase: Phenotypes  8.64e-04           6        12         12
# 4   GO: biological_process  3.27e-03           6        15         15
# 5   GO: cellular_component  1.75e-02           4         8          8
# 6   GO: biological_process  2.48e-02          39       440        438
# 7           KEGG: Pathways  2.79e-02           7        31         31
# 8   GO: biological_process  3.44e-02           3         5          5
# 9    Dictybase: Phenotypes  3.99e-02          31       341        338
# 10  GO: molecular_function  4.65e-02           8        46         45
# 11   Dictybase: Phenotypes  2.30e-01           8        60         59
# 12          KEGG: Pathways  2.34e-01           3        10         10
# 13   Dictybase: Phenotypes  2.49e-01          10        95         86
# ***  FB selected: 307 with EID: 303
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.23
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 21 out of 69 query genes used for enrichment calculation.
#                                    Gene set                Ontology       FDR  \
# 0                      extracellular region  GO: cellular_component  8.87e-02
# 1                   oxidoreductase activity  GO: molecular_function  8.87e-02
# 2           Fructose and mannose metabolism          KEGG: Pathways  1.30e-01
# 3  Pentose and glucuronate interconversions          KEGG: Pathways  1.30e-01
#
#    N in query  Set size  N in ref.
# 0           9       157        157
# 1          11       210        207
# 2           3        19         19
# 3           2         6          6

# %% [markdown]
# ##### DESeq2 WT lFC >= 1 and padj <= 0.05

# %%
# %matplotlib agg
milestones=pd.read_table(path_de+'WT_batchrep_combined.tsv',index_col=0,sep='\t')
figs=[]
for stage in [phenotype for phenotype in PHENOTYPES if phenotype in list(milestones['Stage'].unique())]:
    query_names=list(milestones.query('log2FoldChange>=1 & padj <= 0.05 & Stage=="'+stage+'"').index)
    enriched=group_diff_enrichment(query_names=query_names,group=stage,min_overlap=2,
                                   use_annotated_genes=True,enrichment_map=True,map_edge_filter=0.2)
    figs.append(enriched[1])
# Out:
# ***  no_agg selected: 2578 with EID: 2560
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.38
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 596 out of 966 query genes used for enrichment calculation.
#                                           Gene set                Ontology  \
# 0                                         Ribosome          KEGG: Pathways
# 1                                         ribosome  GO: cellular_component
# 2               structural constituent of ribosome  GO: molecular_function
# 3                                      translation  GO: biological_process
# 4                     structural molecule activity  GO: molecular_function
# 5                                    mitochondrion  GO: cellular_component
# 6                              ribosome biogenesis  GO: biological_process
# 7                                        nucleolus  GO: cellular_component
# 8                Ribosome biogenesis in eukaryotes          KEGG: Pathways
# 9                                      RNA binding  GO: molecular_function
# 10                          tRNA metabolic process  GO: biological_process
# 11                     Aminoacyl-tRNA biosynthesis          KEGG: Pathways
# 12                       Oxidative phosphorylation          KEGG: Pathways
# 13                                    rRNA binding  GO: molecular_function
# 14                      methyltransferase activity  GO: molecular_function
# 15                            Steroid biosynthesis          KEGG: Pathways
# 16                                 ligase activity  GO: molecular_function
# 17                small molecule metabolic process  GO: biological_process
# 18           cellular amino acid metabolic process  GO: biological_process
# 19           Biosynthesis of secondary metabolites          KEGG: Pathways
# 20  generation of precursor metabolites and energy  GO: biological_process
# 21                         oxidoreductase activity  GO: molecular_function
# 22                      cofactor metabolic process  GO: biological_process
# 23                      mitochondrion organization  GO: biological_process
# 24            Porphyrin and chlorophyll metabolism          KEGG: Pathways
# 25                        unfolded protein binding  GO: molecular_function
# 26                              isomerase activity  GO: molecular_function
# 27                           Pyrimidine metabolism          KEGG: Pathways
# 28                           Fatty acid elongation          KEGG: Pathways
# 29                             Sulfur relay system          KEGG: Pathways
# 30                                 protein folding  GO: biological_process
# 31                               Purine metabolism          KEGG: Pathways
# 32              transmembrane transporter activity  GO: molecular_function
#
#          FDR  N in query  Set size  N in ref.
# 0   3.19e-52          94       105         97
# 1   2.38e-46          88        93         93
# 2   3.46e-45          82        85         85
# 3   8.01e-37         120       169        169
# 4   8.99e-31          89       117        117
# 5   4.62e-22         125       229        229
# 6   1.32e-19          50        61         61
# 7   1.26e-12          48        72         72
# 8   1.10e-11          45        72         68
# 9   3.89e-09          79       169        169
# 10  1.57e-08          41        69         69
# 11  2.26e-08          31        64         46
# 12  2.49e-07          33        71         54
# 13  1.04e-05          12        13         13
# 14  5.40e-05          30        58         56
# 15  5.88e-05          14        18         18
# 16  1.08e-04          38        80         80
# 17  1.97e-04         121       354        353
# 18  1.97e-04          52       125        124
# 19  3.41e-04          99       289        281
# 20  1.04e-02          32        77         77
# 21  1.15e-02          71       210        207
# 22  1.31e-02          30        72         72
# 23  1.32e-02          13        23         23
# 24  2.33e-02           9        14         14
# 25  2.40e-02          14        27         27
# 26  5.39e-02          21        50         50
# 27  5.39e-02          14        31         29
# 28  5.39e-02           8        13         13
# 29  9.50e-02           6         9          9
# 30  9.69e-02          16        37         37
# 31  1.09e-01          20        52         50
# 32  1.85e-01          48       150        149
# ***  stream selected: 557 with EID: 553
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.35
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 86 out of 193 query genes used for enrichment calculation.
#                                       Gene set                Ontology  \
# 0                                   Proteasome          KEGG: Pathways
# 1                           peptidase activity  GO: molecular_function
# 2                            catabolic process  GO: biological_process
# 3  Protein processing in endoplasmic reticulum          KEGG: Pathways
# 4                        endoplasmic reticulum  GO: cellular_component
# 5       Various types of N-glycan biosynthesis          KEGG: Pathways
# 6                               Protein export          KEGG: Pathways
# 7     development arrests at loose mound stage   Dictybase: Phenotypes
# 8                           aberrant streaming   Dictybase: Phenotypes
# 9                        N-Glycan biosynthesis          KEGG: Pathways
#
#         FDR  N in query  Set size  N in ref.
# 0  2.36e-40          34        39         37
# 1  2.55e-09          23        91         91
# 2  4.49e-07          35       250        250
# 3  7.57e-06          18        91         88
# 4  2.65e-05          20       117        117
# 5  1.73e-02           6        22         22
# 6  4.07e-02           5        19         18
# 7  5.55e-02           5        20         20
# 8  5.55e-02          10        72         72
# 9  5.93e-02           6        31         30
# ***  lag selected: 509 with EID: 505
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.36
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 136 out of 182 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0                                                Proteasome
# 1                                        peptidase activity
# 2                                           plasma membrane
# 3                                        aberrant streaming
# 4                                  decreased aggregate size
# 5                                         catabolic process
# 6                              cytoskeletal protein binding
# 7                                 cytoskeleton organization
# 8                                                locomotion
# 9                                       signal transduction
# 10                   Various types of N-glycan biosynthesis
# 11                 development arrests at loose mound stage
# 12                                     aberrant cytokinesis
# 13                                 aberrant cell morphology
# 14                                    endoplasmic reticulum
# 15                                       cell morphogenesis
# 16                  aberrant contractile vacuole morphology
# 17                             aberrant cAMP wave formation
# 18                                             cytoskeleton
# 19                         anatomical structure development
# 20                                     extracellular region
# 21                                    decreased culmination
# 22                                                wild type
# 23                            increased basal F-actin level
# 24                                            cell motility
# 25                                    decreased pinocytosis
# 26                                 Other glycan degradation
# 27                                            cell adhesion
# 28                                      delayed development
# 29              Protein processing in endoplasmic reticulum
# 30                               multiple tips in culminant
# 31                                     aberrant culmination
# 32  aberrant positive regulation of chemorepellant activity
# 33                                     aberrant aggregation
# 34                             decreased fruiting body size
# 35                                    decreased growth rate
# 36                                   decreased phagocytosis
# 37                            aberrant F-actin organization
# 38                                         ABC transporters
# 39                       development arrests at mound stage
# 40                                       mitotic cell cycle
# 41                                    N-Glycan biosynthesis
# 42                                 increased slug migration
# 43                abolished activation of adenylate cyclase
# 44                                  increased protein level
# 45                                 abolished slug migration
# 46                                enzyme regulator activity
# 47                                    increased growth rate
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0           KEGG: Pathways  9.73e-22          24        39         37
# 1   GO: molecular_function  5.64e-03          14        91         91
# 2   GO: cellular_component  5.64e-03          27       268        268
# 3    Dictybase: Phenotypes  2.17e-02          11        72         72
# 4    Dictybase: Phenotypes  2.25e-02           7        32         32
# 5   GO: biological_process  3.71e-02          23       250        250
# 6   GO: molecular_function  4.09e-02          16       158        158
# 7   GO: biological_process  4.09e-02          19       197        196
# 8   GO: biological_process  4.09e-02          18       191        189
# 9   GO: biological_process  4.09e-02          28       352        350
# 10          KEGG: Pathways  4.09e-02           5        22         22
# 11   Dictybase: Phenotypes  4.09e-02           5        20         20
# 12   Dictybase: Phenotypes  4.09e-02          12        98         98
# 13   Dictybase: Phenotypes  4.09e-02           7        42         41
# 14  GO: cellular_component  4.09e-02          13       117        117
# 15  GO: biological_process  4.72e-02           5        23         23
# 16   Dictybase: Phenotypes  5.49e-02           3         8          8
# 17   Dictybase: Phenotypes  5.49e-02          11        96         96
# 18  GO: cellular_component  5.49e-02          17       185        185
# 19  GO: biological_process  5.72e-02          32       440        438
# 20  GO: cellular_component  5.76e-02          15       157        157
# 21   Dictybase: Phenotypes  6.12e-02           3         9          9
# 22   Dictybase: Phenotypes  6.12e-02          26       341        338
# 23   Dictybase: Phenotypes  6.12e-02           4        18         17
# 24  GO: biological_process  9.16e-02           8        67         66
# 25   Dictybase: Phenotypes  9.46e-02           5        30         30
# 26          KEGG: Pathways  9.97e-02           3        11         11
# 27  GO: biological_process  1.04e-01           9        84         83
# 28   Dictybase: Phenotypes  1.04e-01           8        69         69
# 29          KEGG: Pathways  1.30e-01           9        91         88
# 30   Dictybase: Phenotypes  1.30e-01           2         5          5
# 31   Dictybase: Phenotypes  1.30e-01           9        88         88
# 32   Dictybase: Phenotypes  1.30e-01           2         5          5
# 33   Dictybase: Phenotypes  1.35e-01           7        61         61
# 34   Dictybase: Phenotypes  1.35e-01           8        76         75
# 35   Dictybase: Phenotypes  1.44e-01          12       146        137
# 36   Dictybase: Phenotypes  1.49e-01           7        63         63
# 37   Dictybase: Phenotypes  1.53e-01           5        37         37
# 38          KEGG: Pathways  1.66e-01           3        15         15
# 39   Dictybase: Phenotypes  2.04e-01           6        56         54
# 40  GO: biological_process  2.17e-01           9       100        100
# 41          KEGG: Pathways  2.38e-01           4        31         30
# 42   Dictybase: Phenotypes  2.38e-01           2         8          8
# 43   Dictybase: Phenotypes  2.38e-01           2         8          8
# 44   Dictybase: Phenotypes  2.38e-01           2         9          8
# 45   Dictybase: Phenotypes  2.38e-01           5        43         43
# 46  GO: molecular_function  2.42e-01           9       105        105
# 47   Dictybase: Phenotypes  2.42e-01           4        32         31
# ***  tag selected: 305 with EID: 305
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.36
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 93 out of 109 query genes used for enrichment calculation.
#                           Gene set                Ontology       FDR  \
# 0                  DNA replication          KEGG: Pathways  1.17e-29
# 1                       chromosome  GO: cellular_component  1.41e-26
# 2                       cell cycle  GO: biological_process  5.62e-19
# 3          chromosome organization  GO: biological_process  2.22e-16
# 4            DNA metabolic process  GO: biological_process  2.88e-16
# 5                  Mismatch repair          KEGG: Pathways  1.35e-15
# 6           chromosome segregation  GO: biological_process  3.19e-14
# 7       Nucleotide excision repair          KEGG: Pathways  8.77e-11
# 8                    cell division  GO: biological_process  2.31e-10
# 9         mitotic nuclear division  GO: biological_process  3.74e-10
# 10            Base excision repair          KEGG: Pathways  7.28e-10
# 11                     DNA binding  GO: molecular_function  6.50e-09
# 12              mitotic cell cycle  GO: biological_process  5.66e-07
# 13              nuclear chromosome  GO: cellular_component  1.42e-06
# 14                 ATPase activity  GO: molecular_function  3.87e-04
# 15   microtubule organizing center  GO: cellular_component  4.24e-04
# 16  Ubiquitin mediated proteolysis          KEGG: Pathways  1.70e-03
# 17        Homologous recombination          KEGG: Pathways  3.49e-03
# 18              response to stress  GO: biological_process  4.21e-03
# 19                    cytoskeleton  GO: cellular_component  9.81e-03
# 20               cell cycle arrest   Dictybase: Phenotypes  4.23e-02
# 21           Pyrimidine metabolism          KEGG: Pathways  4.36e-02
# 22               helicase activity  GO: molecular_function  6.82e-02
# 23                 histone binding  GO: molecular_function  7.19e-02
# 24      Non-homologous end-joining          KEGG: Pathways  7.19e-02
# 25    increased cell-cell adhesion   Dictybase: Phenotypes  2.30e-01
#
#     N in query  Set size  N in ref.
# 0           24        34         33
# 1           29        70         70
# 2           33       167        167
# 3           22        74         74
# 4           25       105        105
# 5           13        19         19
# 6           12        18         18
# 7           13        37         37
# 8           20       115        115
# 9            9        15         15
# 10          11        28         28
# 11          25       221        221
# 12          15       100        100
# 13           7        17         17
# 14          15       169        168
# 15           8        50         50
# 16           8        62         61
# 17           5        26         25
# 18          21       360        358
# 19          13       185        185
# 20           2         5          5
# 21           4        31         29
# 22           5        51         51
# 23           2         7          7
# 24           2         7          7
# 25           2        13         13
# ***  tip selected: 309 with EID: 308
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.39
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 101 out of 119 query genes used for enrichment calculation.
#                           Gene set                Ontology       FDR  \
# 0                       chromosome  GO: cellular_component  7.23e-33
# 1                  DNA replication          KEGG: Pathways  5.00e-29
# 2          chromosome organization  GO: biological_process  2.42e-23
# 3                       cell cycle  GO: biological_process  4.97e-21
# 4            DNA metabolic process  GO: biological_process  8.78e-19
# 5           chromosome segregation  GO: biological_process  1.18e-17
# 6                  Mismatch repair          KEGG: Pathways  3.16e-15
# 7         mitotic nuclear division  GO: biological_process  1.94e-13
# 8                      DNA binding  GO: molecular_function  1.25e-12
# 9                    cell division  GO: biological_process  1.30e-12
# 10      Nucleotide excision repair          KEGG: Pathways  7.95e-12
# 11            Base excision repair          KEGG: Pathways  5.85e-11
# 12              mitotic cell cycle  GO: biological_process  3.07e-08
# 13              nuclear chromosome  GO: cellular_component  7.88e-08
# 14   microtubule organizing center  GO: cellular_component  1.11e-05
# 15  Ubiquitin mediated proteolysis          KEGG: Pathways  4.64e-04
# 16                 ATPase activity  GO: molecular_function  7.93e-04
# 17           Pyrimidine metabolism          KEGG: Pathways  1.03e-03
# 18                    cytoskeleton  GO: cellular_component  2.07e-03
# 19        Homologous recombination          KEGG: Pathways  3.90e-03
# 20                 histone binding  GO: molecular_function  4.21e-03
# 21                     nucleoplasm  GO: cellular_component  2.69e-02
# 22     aberrant nucleus morphology   Dictybase: Phenotypes  3.64e-02
# 23               cell cycle arrest   Dictybase: Phenotypes  3.64e-02
# 24      Non-homologous end-joining          KEGG: Pathways  7.05e-02
# 25               helicase activity  GO: molecular_function  7.10e-02
# 26              response to stress  GO: biological_process  7.85e-02
# 27                nuclear envelope  GO: cellular_component  2.03e-01
#
#     N in query  Set size  N in ref.
# 0           34        70         70
# 1           24        34         33
# 2           28        74         74
# 3           36       167        167
# 4           28       105        105
# 5           14        18         18
# 6           13        19         19
# 7           11        15         15
# 8           31       221        221
# 9           23       115        115
# 10          14        37         37
# 11          12        28         28
# 12          17       100        100
# 13           8        17         17
# 14          10        50         50
# 15           9        62         61
# 16          15       169        168
# 17           6        31         29
# 18          15       185        185
# 19           5        26         25
# 20           3         7          7
# 21           8        91         91
# 22           2         5          5
# 23           2         5          5
# 24           2         7          7
# 25           5        51         51
# 26          18       360        358
# 27           3        29         29
# ***  slug selected: 757 with EID: 753
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.24
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 105 out of 182 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                     chromosome segregation
# 1                                            DNA replication
# 2                                                  cell wall
# 3                           external encapsulating structure
# 4                                                 chromosome
# 5                                    chromosome organization
# 6                                                 cell cycle
# 7                                   mitotic nuclear division
# 8                                     Glutathione metabolism
# 9                                         nuclear chromosome
# 10                                 decreased spore viability
# 11                            aberrant spore coat morphology
# 12                                           ATPase activity
# 13                                          ABC transporters
# 14                 DNA-binding transcription factor activity
# 15                                               DNA binding
# 16                                             cell division
# 17  anatomical structure formation involved in morphogenesis
# 18                                        mitotic cell cycle
# 19                                      extracellular region
# 20                        transmembrane transporter activity
# 21                                      Base excision repair
# 22                                     Pyrimidine metabolism
# 23                                      cell differentiation
# 24                                   transmembrane transport
# 25                           aberrant myosin II organization
# 26                                         cell cycle arrest
# 27                 increased prestalk 0 cell differentiation
# 28                      increased sorting to prestalk region
# 29                                increased macropinocytosis
# 30                                Nucleotide excision repair
# 31                             microtubule organizing center
# 32                   increased prespore cell differentiation
# 33                      cell wall organization or biogenesis
# 34                                           histone binding
# 35                                       extracellular space
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: biological_process  1.13e-04           8        18         18
# 1           KEGG: Pathways  5.77e-04           9        34         33
# 2   GO: cellular_component  5.77e-04           6        13         13
# 3   GO: cellular_component  5.77e-04           6        13         13
# 4   GO: cellular_component  5.77e-04          13        70         70
# 5   GO: biological_process  9.01e-04          13        74         74
# 6   GO: biological_process  2.00e-03          20       167        167
# 7   GO: biological_process  1.09e-02           5        15         15
# 8           KEGG: Pathways  1.67e-02           6        28         25
# 9   GO: cellular_component  1.67e-02           5        17         17
# 10   Dictybase: Phenotypes  2.60e-02           9        60         59
# 11   Dictybase: Phenotypes  2.89e-02           4        12         12
# 12  GO: molecular_function  6.49e-02          16       169        168
# 13          KEGG: Pathways  6.49e-02           4        15         15
# 14  GO: molecular_function  6.92e-02           6        37         37
# 15  GO: molecular_function  6.92e-02          19       221        221
# 16  GO: biological_process  6.92e-02          12       115        115
# 17  GO: biological_process  6.92e-02           9        74         74
# 18  GO: biological_process  6.92e-02          11       100        100
# 19  GO: cellular_component  6.92e-02          15       157        157
# 20  GO: molecular_function  8.02e-02          14       150        149
# 21          KEGG: Pathways  8.02e-02           5        28         28
# 22          KEGG: Pathways  8.87e-02           5        31         29
# 23  GO: biological_process  1.37e-01          13       145        145
# 24  GO: biological_process  1.37e-01          14       165        164
# 25   Dictybase: Phenotypes  1.37e-01           2         5          5
# 26   Dictybase: Phenotypes  1.37e-01           2         5          5
# 27   Dictybase: Phenotypes  1.37e-01           2         5          5
# 28   Dictybase: Phenotypes  1.37e-01           2         5          5
# 29   Dictybase: Phenotypes  1.37e-01           2         5          5
# 30          KEGG: Pathways  1.75e-01           5        37         37
# 31  GO: cellular_component  1.75e-01           6        50         50
# 32   Dictybase: Phenotypes  1.81e-01           2         6          6
# 33  GO: biological_process  1.83e-01           3        15         15
# 34  GO: molecular_function  2.25e-01           2         7          7
# 35  GO: cellular_component  2.25e-01           2         7          7
# ***  mhat selected: 1615 with EID: 1609
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.29
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 224 out of 468 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                             aberrant spore coat morphology
# 1   anatomical structure formation involved in morphogenesis
# 2                                       cell differentiation
# 3                                       extracellular region
# 4                           anatomical structure development
# 5                                  decreased spore viability
# 6                              Starch and sucrose metabolism
# 7                                            Golgi apparatus
# 8                       cell wall organization or biogenesis
# 9                           abolished cellulose biosynthesis
# 10                   increased prespore cell differentiation
# 11                                                 cell wall
# 12                          external encapsulating structure
# 13                                      Galactose metabolism
# 14                                                   Alanine
# 15                                  Phenylalanine metabolism
# 16                            carbohydrate metabolic process
# 17                                 aberrant spore morphology
# 18                                      extracellular matrix
# 19                                       signal transduction
# 20                                       Tyrosine metabolism
# 21                        Taurine and hypotaurine metabolism
# 22                                      aberrant thermotaxis
# 23                                  aberrant stalk formation
# 24                                      aberrant culmination
# 25                                           spores inviable
# 26                                                 wild type
# 27                                       delayed culmination
# 28                                   aberrant slug migration
# 29                              abolished catalytic activity
# 30       Ubiquinone and other terpenoid-quinone biosynthesis
# 31                           Arginine and proline metabolism
# 32                  Pentose and glucuronate interconversions
# 33                                       aberrant phototaxis
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0    Dictybase: Phenotypes  2.36e-04           9        12         12
# 1   GO: biological_process  2.99e-03          22        74         74
# 2   GO: biological_process  2.99e-03          35       145        145
# 3   GO: cellular_component  4.57e-03          36       157        157
# 4   GO: biological_process  5.23e-03          78       440        438
# 5    Dictybase: Phenotypes  5.58e-03          18        60         59
# 6           KEGG: Pathways  5.62e-03          12        31         31
# 7   GO: cellular_component  1.10e-02          22        85         85
# 8   GO: biological_process  3.00e-02           7        15         15
# 9    Dictybase: Phenotypes  3.00e-02           4         5          5
# 10   Dictybase: Phenotypes  6.27e-02           4         6          6
# 11  GO: cellular_component  6.27e-02           6        13         13
# 12  GO: cellular_component  6.27e-02           6        13         13
# 13          KEGG: Pathways  7.63e-02           6        15         14
# 14          KEGG: Pathways  7.63e-02           8        23         23
# 15          KEGG: Pathways  7.63e-02           5        12         10
# 16  GO: biological_process  1.26e-01          19        89         88
# 17   Dictybase: Phenotypes  1.64e-01           4         8          8
# 18  GO: cellular_component  1.64e-01           4         8          8
# 19  GO: biological_process  1.66e-01          56       352        350
# 20          KEGG: Pathways  1.66e-01           5        15         13
# 21          KEGG: Pathways  1.66e-01           3         6          5
# 22   Dictybase: Phenotypes  1.66e-01           3         5          5
# 23   Dictybase: Phenotypes  1.66e-01           3         5          5
# 24   Dictybase: Phenotypes  1.66e-01          18        88         88
# 25   Dictybase: Phenotypes  1.66e-01           3         5          5
# 26   Dictybase: Phenotypes  1.66e-01          54       341        338
# 27   Dictybase: Phenotypes  1.66e-01           8        28         28
# 28   Dictybase: Phenotypes  1.90e-01          13        58         58
# 29   Dictybase: Phenotypes  2.08e-01           5        14         14
# 30          KEGG: Pathways  2.49e-01           4        10         10
# 31          KEGG: Pathways  2.49e-01           6        23         20
# 32          KEGG: Pathways  2.49e-01           3         6          6
# 33   Dictybase: Phenotypes  2.49e-01           3        14          6
# ***  cul selected: 2289 with EID: 2274
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.28
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 373 out of 631 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0   anatomical structure formation involved in morphogenesis
# 1                                       cell differentiation
# 2                           anatomical structure development
# 3                              Starch and sucrose metabolism
# 4                             aberrant spore coat morphology
# 5                                       extracellular region
# 6                  DNA-binding transcription factor activity
# 7                                       aberrant culmination
# 8                    increased prespore cell differentiation
# 9                                  decreased gene expression
# 10                      cell wall organization or biogenesis
# 11                                           kinase activity
# 12                 SNARE interactions in vesicular transport
# 13                                       signal transduction
# 14                               secondary metabolic process
# 15                                      Galactose metabolism
# 16                                   aberrant slug migration
# 17                          abolished cellulose biosynthesis
# 18                                           Golgi apparatus
# 19                                 decreased spore viability
# 20                                 aberrant spore morphology
# 21                                 increased gene expression
# 22                  Pentose and glucuronate interconversions
# 23                                       aberrant phototaxis
# 24                           abolished autophagic cell death
# 25                 development arrests at tipped mound stage
# 26                    abolished autophagic vacuole formation
# 27                                       delayed culmination
# 28                                                 wild type
# 29                                                 cell wall
# 30                          external encapsulating structure
# 31       Ubiquinone and other terpenoid-quinone biosynthesis
# 32                                  Phenylalanine metabolism
# 33                                                 autophagy
# 34                                     abolished culmination
# 35                    aberrant prestalk cell differentiation
# 36                                   delayed gene expression
# 37                         aberrant fruiting body morphology
# 38                             aberrant protein localization
# 39                                               DNA binding
# 40                                       cell-cell signaling
# 41                           Arginine and proline metabolism
# 42                                       Nitrogen metabolism
# 43                            aberrant autophagic cell death
# 44                                      aberrant thermotaxis
# 45                                  aberrant gene expression
# 46                                  aberrant stalk formation
# 47                                           spores inviable
# 48                                    precocious sporulation
# 49                                      extracellular matrix
# 50                                  abolished slug migration
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: biological_process  4.19e-08          35        74         74
# 1   GO: biological_process  4.19e-08          54       145        145
# 2   GO: biological_process  1.28e-05         110       440        438
# 3           KEGG: Pathways  1.28e-05          18        31         31
# 4    Dictybase: Phenotypes  3.80e-05          10        12         12
# 5   GO: cellular_component  9.08e-04          46       157        157
# 6   GO: molecular_function  1.58e-02          15        37         37
# 7    Dictybase: Phenotypes  1.81e-02          27        88         88
# 8    Dictybase: Phenotypes  2.23e-02           5         6          6
# 9    Dictybase: Phenotypes  2.38e-02          26        95         86
# 10  GO: biological_process  3.16e-02           8        15         15
# 11  GO: molecular_function  3.68e-02          73       328        327
# 12          KEGG: Pathways  4.65e-02          10        23         23
# 13  GO: biological_process  5.69e-02          76       352        350
# 14  GO: biological_process  6.25e-02           4         5          5
# 15          KEGG: Pathways  6.25e-02           7        15         14
# 16   Dictybase: Phenotypes  6.25e-02          18        58         58
# 17   Dictybase: Phenotypes  6.25e-02           4         5          5
# 18  GO: cellular_component  6.25e-02          24        85         85
# 19   Dictybase: Phenotypes  6.69e-02          18        60         59
# 20   Dictybase: Phenotypes  6.69e-02           5         8          8
# 21   Dictybase: Phenotypes  6.69e-02          15        46         46
# 22          KEGG: Pathways  1.02e-01           4         6          6
# 23   Dictybase: Phenotypes  1.02e-01           4        14          6
# 24   Dictybase: Phenotypes  1.02e-01           4         6          6
# 25   Dictybase: Phenotypes  1.02e-01           6        12         12
# 26   Dictybase: Phenotypes  1.02e-01           4         6          6
# 27   Dictybase: Phenotypes  1.16e-01          10        28         28
# 28   Dictybase: Phenotypes  1.26e-01          70       341        338
# 29  GO: cellular_component  1.26e-01           6        13         13
# 30  GO: cellular_component  1.26e-01           6        13         13
# 31          KEGG: Pathways  1.45e-01           5        10         10
# 32          KEGG: Pathways  1.45e-01           5        12         10
# 33  GO: biological_process  1.50e-01          11        34         34
# 34   Dictybase: Phenotypes  1.56e-01          17        62         62
# 35   Dictybase: Phenotypes  1.56e-01           4         7          7
# 36   Dictybase: Phenotypes  1.66e-01           7        19         18
# 37   Dictybase: Phenotypes  1.83e-01          24       101         98
# 38   Dictybase: Phenotypes  2.24e-01          10        32         32
# 39  GO: molecular_function  2.37e-01          46       221        221
# 40  GO: biological_process  2.37e-01           6        16         16
# 41          KEGG: Pathways  2.37e-01           7        23         20
# 42          KEGG: Pathways  2.37e-01           4         8          8
# 43   Dictybase: Phenotypes  2.37e-01           3         5          5
# 44   Dictybase: Phenotypes  2.37e-01           3         5          5
# 45   Dictybase: Phenotypes  2.37e-01           8        24         24
# 46   Dictybase: Phenotypes  2.37e-01           3         5          5
# 47   Dictybase: Phenotypes  2.37e-01           3         5          5
# 48   Dictybase: Phenotypes  2.37e-01           3         5          5
# 49  GO: cellular_component  2.37e-01           4         8          8
# 50   Dictybase: Phenotypes  2.42e-01          12        43         43
# ***  FB selected: 1096 with EID: 1085
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.28
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 129 out of 304 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                       cell differentiation
# 1                           anatomical structure development
# 2                  DNA-binding transcription factor activity
# 3                                                DNA binding
# 4   anatomical structure formation involved in morphogenesis
# 5                  SNARE interactions in vesicular transport
# 6                                   aberrant gene expression
# 7                                            kinase activity
# 8                                secondary metabolic process
# 9                                  decreased gene expression
# 10                                  decreased slug migration
# 11                                      aberrant culmination
# 12                   increased prespore cell differentiation
# 13                 development arrests at tipped mound stage
# 14                                   aberrant slug migration
# 15                    aberrant prestalk cell differentiation
# 16                                                 autophagy
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: biological_process  2.73e-02          25       145        145
# 1   GO: biological_process  3.35e-02          54       440        438
# 2   GO: molecular_function  3.48e-02          10        37         37
# 3   GO: molecular_function  7.07e-02          30       221        221
# 4   GO: biological_process  7.07e-02          14        74         74
# 5           KEGG: Pathways  7.07e-02           7        23         23
# 6    Dictybase: Phenotypes  7.23e-02           7        24         24
# 7   GO: molecular_function  1.27e-01          39       328        327
# 8   GO: biological_process  1.35e-01           3         5          5
# 9    Dictybase: Phenotypes  1.68e-01          14        95         86
# 10   Dictybase: Phenotypes  1.77e-01           4        11         11
# 11   Dictybase: Phenotypes  1.77e-01          14        88         88
# 12   Dictybase: Phenotypes  1.77e-01           3         6          6
# 13   Dictybase: Phenotypes  2.25e-01           4        12         12
# 14   Dictybase: Phenotypes  2.37e-01          10        58         58
# 15   Dictybase: Phenotypes  2.37e-01           3         7          7
# 16  GO: biological_process  2.37e-01           7        34         34

# %% [markdown]
# ###### Enrichment map for DESeq2 WT lFC >= 1 and padj <= 0.05

# %%
for fig,ax in figs:
    display(fig)

# %% [markdown]
# ### ImpulseDE2
# Milestone genes are selected as those that are at up-level in a stage and at down level at non neighbouring stages (to account for imperfect annotation of up/down). no_agg is not considered a neighbour of stream and vice versa.

# %% [markdown]
# #### ImpulseDE2 all strains

# %%
milestones=pd.read_table(path_impulse+'DEacrossStages_summary_noyem.tsv',index_col=0,sep='\t')
stages=np.array([phenotype for phenotype in PHENOTYPES if phenotype in list(milestones.columns)])
for stage_idx,stage in enumerate(stages):
    
    #Nonneighbouring stages
    neigh_previous=1
    neigh_next=1
    #Assumes phenotypes order
    if stage_idx==1:
        neigh_previous=0
    if stage_idx==0:
        neigh_next=0
    non_neighbours = stages[[(idx <stage_idx-neigh_previous or idx>stage_idx+neigh_next) 
                 for idx in range(len(stages)) ]]
    #print(stage,':',non_neighbours)
    
    #Find genes up at stage and down at nonenighbouring
    query_condition=stage+'=="up"'
    for non_neigh in non_neighbours:
        query_condition=query_condition+' & '+non_neigh+' =="down"'
    #print(query_condition)
    
    query_names=list(milestones.query(query_condition).index)
    enriched=group_diff_enrichment(query_names=query_names,group=stage,min_overlap=2,use_annotated_genes=True)
# Out:
# ***  no_agg selected: 1199 with EID: 1193
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.4
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 328 out of 479 query genes used for enrichment calculation.
#                                           Gene set                Ontology  \
# 0                                         Ribosome          KEGG: Pathways
# 1                                         ribosome  GO: cellular_component
# 2               structural constituent of ribosome  GO: molecular_function
# 3                     structural molecule activity  GO: molecular_function
# 4                                      translation  GO: biological_process
# 5                                    mitochondrion  GO: cellular_component
# 6                          oxidoreductase activity  GO: molecular_function
# 7                        Oxidative phosphorylation          KEGG: Pathways
# 8                      Biosynthesis of amino acids          KEGG: Pathways
# 9            Biosynthesis of secondary metabolites          KEGG: Pathways
# 10                        unfolded protein binding  GO: molecular_function
# 11                small molecule metabolic process  GO: biological_process
# 12           cellular amino acid metabolic process  GO: biological_process
# 13                                 protein folding  GO: biological_process
# 14                                        lysosome  GO: cellular_component
# 15                                         Glycine          KEGG: Pathways
# 16              transmembrane transporter activity  GO: molecular_function
# 17                            Steroid biosynthesis          KEGG: Pathways
# 18  generation of precursor metabolites and energy  GO: biological_process
# 19                      cofactor metabolic process  GO: biological_process
# 20                       Pentose phosphate pathway          KEGG: Pathways
# 21                              peptidase activity  GO: molecular_function
# 22                              isomerase activity  GO: molecular_function
# 23                           Vitamin B6 metabolism          KEGG: Pathways
# 24                           Fatty acid elongation          KEGG: Pathways
# 25                             Sulfur relay system          KEGG: Pathways
# 26                         beta-Alanine metabolism          KEGG: Pathways
# 27                                         vacuole  GO: cellular_component
# 28                               Carbon metabolism          KEGG: Pathways
# 29                                       Phagosome          KEGG: Pathways
# 30                            extracellular region  GO: cellular_component
# 31                             Lysine biosynthesis          KEGG: Pathways
#
#          FDR  N in query  Set size  N in ref.
# 0   7.00e-38          67       105         97
# 1   3.31e-30          59        93         93
# 2   4.68e-30          56        85         85
# 3   4.62e-23          59       117        117
# 4   1.67e-20          69       169        169
# 5   7.13e-08          60       229        229
# 6   6.22e-05          49       210        207
# 7   6.62e-05          20        71         54
# 8   2.32e-03          19        63         62
# 9   3.75e-03          55       289        281
# 10  3.75e-03          11        27         27
# 11  9.10e-03          64       354        353
# 12  1.37e-02          28       125        124
# 13  1.75e-02          12        37         37
# 14  1.88e-02          18        69         69
# 15  2.08e-02           9        27         24
# 16  4.76e-02          30       150        149
# 17  5.08e-02           7        18         18
# 18  5.55e-02          18        77         77
# 19  6.01e-02          17        72         72
# 20  6.06e-02           7        21         19
# 21  6.06e-02          20        91         91
# 22  6.06e-02          13        50         50
# 23  1.50e-01           3         5          5
# 24  1.50e-01           5        13         13
# 25  1.54e-01           4         9          9
# 26  1.54e-01           7        23         23
# 27  1.56e-01          24       127        127
# 28  1.66e-01          20       104        102
# 29  1.66e-01          12        53         52
# 30  1.83e-01          28       157        157
# 31  2.13e-01           3         6          6
# ***  stream selected: 956 with EID: 941
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.4
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 276 out of 377 query genes used for enrichment calculation.
#                                                              Gene set  \
# 0                                                  aberrant streaming
# 1                                                aberrant cytokinesis
# 2                                                          locomotion
# 3                                                       cell division
# 4                                                 signal transduction
# 5                                                  mitotic cell cycle
# 6                                                          Proteasome
# 7                                           cytoskeleton organization
# 8                                                     plasma membrane
# 9                                       aberrant F-actin organization
# 10                                                         cell cycle
# 11                          decreased activation of adenylate cyclase
# 12                                              abolished aggregation
# 13                                       aberrant cAMP wave formation
# 14                                           aberrant cell morphology
# 15                                        cellular component assembly
# 16                                                       cytoskeleton
# 17                                                     Protein export
# 18                                       abolished chemotaxis to cAMP
# 19                        Protein processing in endoplasmic reticulum
# 20                          abolished activation of adenylate cyclase
# 21                                 development arrests at mound stage
# 22                                               aberrant aggregation
# 23                                              endoplasmic reticulum
# 24                                           decreased aggregate size
# 25                                   anatomical structure development
# 26                                       decreased chemotaxis to cAMP
# 27                                            decreased cell motility
# 28                                          enzyme regulator activity
# 29                                                 cell morphogenesis
# 30                                                       reproduction
# 31                                                delayed aggregation
# 32                                                aberrant chemotaxis
# 33                                decreased protein kinase activation
# 34                                          decreased chemotaxis rate
# 35                                                          wild type
# 36                                              abolished culmination
# 37                                                delayed development
# 38                                           abolished slug migration
# 39                                  abolished protein phosphorylation
# 40                                      aberrant protein localization
# 41                                                            cytosol
# 42                                protein-containing complex assembly
# 43                                decreased growth rate in suspension
# 44                                 increased intracellular cAMP level
# 45                                              aberrant phagocytosis
# 46                                                    GTPase activity
# 47                                  decreased cAMP-induced cAMP pulse
# 48                                         decreased macropinocytosis
# 49                                        aberrant chemotaxis to cAMP
# 50                                       aberrant pseudopod formation
# 51                            decreased lateral pseudopod suppression
# 52                                              increased growth rate
# 53                                         vesicle-mediated transport
# 54                                            aberrant slug migration
# 55                                               aberrant culmination
# 56                                                      cell motility
# 57                                              decreased growth rate
# 58                                                abolished streaming
# 59                                            decreased cell polarity
# 60                                            aberrant slug formation
# 61                                                 response to stress
# 62                                                  protein targeting
# 63                                      abolished cAMP wave formation
# 64                                                     enzyme binding
# 65                                      increased basal F-actin level
# 66                                       decreased myosin II assembly
# 67                                               aberrant development
# 68                                              decreased pinocytosis
# 69                                              N-Glycan biosynthesis
# 70                                               decreased exocytosis
# 71                                     decreased chemotaxis to folate
# 72                            abolished activation of GTPase activity
# 73                                         precocious gene expression
# 74                                       decreased fruiting body size
# 75                                                    kinase activity
# 76             Glycosylphosphatidylinositol (GPI)-anchor biosynthesis
# 77                                                homeostatic process
# 78                                          decreased gene expression
# 79                                       aberrant stalk morphogenesis
# 80                                             decreased phagocytosis
# 81                                             precocious aggregation
# 82           abolished positive regulation of chemorepellant activity
# 83                        aberrant cell separation during cytokinesis
# 84                                 transmembrane transporter activity
# 85                                      microtubule organizing center
# 86                                              decreased stalk width
# 87                                  decreased cAMP-induced cGMP pulse
# 88                                            abolished cell polarity
# 89                                                      multiple tips
# 90                              increased lateral pseudopod formation
# 91                                             precocious development
# 92                                 aberrant cytoskeleton organisation
# 93                                      decreased basal F-actin level
# 94                                      aberrant cellular homeostasis
# 95                             Nicotinate and nicotinamide metabolism
# 96                                            transmembrane transport
# 97                                      cell population proliferation
# 98                                                cytoplasmic vesicle
# 99                                          aberrant macropinocytosis
# 100                                   aberrant myosin II organization
# 101                         abolished protein localization to nucleus
# 102  decreased infection rate by a gram-negative pathogenic bacterium
# 103                                          aberrant gene expression
# 104                                     aberrant filopodium formation
# 105                 aberrant cortical actin cytoskeleton organization
# 106                               abolished protein kinase activation
# 107                                      aberrant signal transduction
# 108                 abolished protein localization to plasma membrane
# 109                                      cytoskeletal protein binding
# 110                                 aberrant fruiting body morphology
# 111                                           decreased protein level
#
#                    Ontology       FDR  N in query  Set size  N in ref.
# 0     Dictybase: Phenotypes  2.13e-08          27        72         72
# 1     Dictybase: Phenotypes  2.13e-08          32        98         98
# 2    GO: biological_process  3.06e-06          43       191        189
# 3    GO: biological_process  3.79e-06          31       115        115
# 4    GO: biological_process  4.33e-06          64       352        350
# 5    GO: biological_process  4.33e-06          28       100        100
# 6            KEGG: Pathways  4.33e-06          16        39         37
# 7    GO: biological_process  1.03e-05          42       197        196
# 8    GO: cellular_component  5.68e-05          50       268        268
# 9     Dictybase: Phenotypes  1.10e-04          14        37         37
# 10   GO: biological_process  3.68e-04          34       167        167
# 11    Dictybase: Phenotypes  1.09e-03           5         6          6
# 12    Dictybase: Phenotypes  1.09e-03          20        82         80
# 13    Dictybase: Phenotypes  1.55e-03          22        96         96
# 14    Dictybase: Phenotypes  1.55e-03          13        42         41
# 15   GO: biological_process  2.25e-03          36       202        201
# 16   GO: cellular_component  2.25e-03          34       185        185
# 17           KEGG: Pathways  2.25e-03           8        19         18
# 18    Dictybase: Phenotypes  2.27e-03           7        14         14
# 19           KEGG: Pathways  2.80e-03          20        91         88
# 20    Dictybase: Phenotypes  5.32e-03           5         8          8
# 21    Dictybase: Phenotypes  5.81e-03          14        56         54
# 22    Dictybase: Phenotypes  6.46e-03          15        61         61
# 23   GO: cellular_component  7.28e-03          23       117        117
# 24    Dictybase: Phenotypes  7.28e-03          10        32         32
# 25   GO: biological_process  7.87e-03          62       440        438
# 26    Dictybase: Phenotypes  7.87e-03          15        63         63
# 27    Dictybase: Phenotypes  7.87e-03          17        76         76
# 28   GO: molecular_function  8.56e-03          21       105        105
# 29   GO: biological_process  9.61e-03           8        23         23
# 30   GO: biological_process  1.04e-02          17        79         79
# 31    Dictybase: Phenotypes  1.04e-02          16        72         72
# 32    Dictybase: Phenotypes  1.04e-02           4         6          6
# 33    Dictybase: Phenotypes  1.22e-02           7        19         19
# 34    Dictybase: Phenotypes  1.40e-02          10        36         36
# 35    Dictybase: Phenotypes  1.40e-02          49       341        338
# 36    Dictybase: Phenotypes  1.52e-02          14        62         62
# 37    Dictybase: Phenotypes  1.54e-02          15        69         69
# 38    Dictybase: Phenotypes  1.54e-02          11        43         43
# 39    Dictybase: Phenotypes  1.81e-02           5        11         11
# 40    Dictybase: Phenotypes  1.86e-02           9        32         32
# 41   GO: cellular_component  2.18e-02          32       203        203
# 42   GO: biological_process  2.55e-02          23       134        133
# 43    Dictybase: Phenotypes  2.99e-02           4         8          8
# 44    Dictybase: Phenotypes  2.99e-02           4         8          8
# 45    Dictybase: Phenotypes  2.99e-02           4         8          8
# 46   GO: molecular_function  3.43e-02          24       145        145
# 47    Dictybase: Phenotypes  3.56e-02           5        14         13
# 48    Dictybase: Phenotypes  4.42e-02           6        19         19
# 49    Dictybase: Phenotypes  4.42e-02           8        31         31
# 50    Dictybase: Phenotypes  4.42e-02           4         9          9
# 51    Dictybase: Phenotypes  4.42e-02           4         9          9
# 52    Dictybase: Phenotypes  4.42e-02           8        32         31
# 53   GO: biological_process  4.45e-02          34       233        233
# 54    Dictybase: Phenotypes  4.51e-02          12        58         58
# 55    Dictybase: Phenotypes  4.85e-02          16        88         88
# 56   GO: biological_process  4.89e-02          13        67         66
# 57    Dictybase: Phenotypes  5.61e-02          22       146        137
# 58    Dictybase: Phenotypes  5.78e-02           8        33         33
# 59    Dictybase: Phenotypes  5.78e-02           8        34         33
# 60    Dictybase: Phenotypes  5.78e-02           4        10         10
# 61   GO: biological_process  6.97e-02          47       360        358
# 62   GO: biological_process  7.89e-02           8        35         35
# 63    Dictybase: Phenotypes  7.89e-02           4        11         11
# 64   GO: molecular_function  7.89e-02          18       110        110
# 65    Dictybase: Phenotypes  8.91e-02           5        18         17
# 66    Dictybase: Phenotypes  8.91e-02           5        17         17
# 67    Dictybase: Phenotypes  9.57e-02          10        51         51
# 68    Dictybase: Phenotypes  9.57e-02           7        30         30
# 69           KEGG: Pathways  9.57e-02           7        31         30
# 70    Dictybase: Phenotypes  9.89e-02           4        12         12
# 71    Dictybase: Phenotypes  9.89e-02           4        12         12
# 72    Dictybase: Phenotypes  1.01e-01           3         7          7
# 73    Dictybase: Phenotypes  1.03e-01           5        18         18
# 74    Dictybase: Phenotypes  1.04e-01          13        76         75
# 75   GO: molecular_function  1.13e-01          42       328        327
# 76           KEGG: Pathways  1.24e-01           5        20         19
# 77   GO: biological_process  1.33e-01          12        70         70
# 78    Dictybase: Phenotypes  1.33e-01          14        95         86
# 79    Dictybase: Phenotypes  1.37e-01           3         8          8
# 80    Dictybase: Phenotypes  1.39e-01          11        63         63
# 81    Dictybase: Phenotypes  1.44e-01           5        20         20
# 82    Dictybase: Phenotypes  1.47e-01           4        14         14
# 83    Dictybase: Phenotypes  1.47e-01           4        14         14
# 84   GO: molecular_function  1.69e-01          21       150        149
# 85   GO: cellular_component  1.70e-01           9        50         50
# 86    Dictybase: Phenotypes  1.72e-01           3         9          9
# 87    Dictybase: Phenotypes  1.72e-01           3        10          9
# 88    Dictybase: Phenotypes  1.72e-01           3         9          9
# 89    Dictybase: Phenotypes  1.74e-01           4        15         15
# 90    Dictybase: Phenotypes  1.86e-01           5        22         22
# 91    Dictybase: Phenotypes  1.86e-01           6        30         29
# 92    Dictybase: Phenotypes  2.12e-01           3        10         10
# 93    Dictybase: Phenotypes  2.12e-01           3        10         10
# 94    Dictybase: Phenotypes  2.12e-01           3        10         10
# 95           KEGG: Pathways  2.12e-01           3        10         10
# 96   GO: biological_process  2.12e-01          22       165        164
# 97   GO: biological_process  2.21e-01           2         5          5
# 98   GO: cellular_component  2.21e-01          27       211        211
# 99    Dictybase: Phenotypes  2.21e-01           2         5          5
# 100   Dictybase: Phenotypes  2.21e-01           2         5          5
# 101   Dictybase: Phenotypes  2.21e-01           2         5          5
# 102   Dictybase: Phenotypes  2.21e-01           2         5          5
# 103   Dictybase: Phenotypes  2.21e-01           5        24         24
# 104   Dictybase: Phenotypes  2.21e-01           2         5          5
# 105   Dictybase: Phenotypes  2.21e-01           2         5          5
# 106   Dictybase: Phenotypes  2.21e-01           2         5          5
# 107   Dictybase: Phenotypes  2.21e-01           2         5          5
# 108   Dictybase: Phenotypes  2.21e-01           2         5          5
# 109  GO: molecular_function  2.21e-01          21       158        158
# 110   Dictybase: Phenotypes  2.39e-01          14       101         98
# 111   Dictybase: Phenotypes  2.49e-01           4        18         18
# ***  lag selected: 1190 with EID: 1175
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.39
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 335 out of 461 query genes used for enrichment calculation.
#                                                              Gene set  \
# 0                                                 signal transduction
# 1                                                          locomotion
# 2                                                aberrant cytokinesis
# 3                                                  aberrant streaming
# 4                                           cytoskeleton organization
# 5                                               abolished aggregation
# 6                                                     kinase activity
# 7                                       aberrant F-actin organization
# 8                                                      enzyme binding
# 9                                            aberrant cell morphology
# 10                                            decreased cell motility
# 11                        Protein processing in endoplasmic reticulum
# 12                                          decreased chemotaxis rate
# 13                                                    plasma membrane
# 14                            decreased lateral pseudopod suppression
# 15                                                          wild type
# 16                                              endoplasmic reticulum
# 17                                       decreased chemotaxis to cAMP
# 18                                              increased growth rate
# 19                                  decreased cAMP-induced cAMP pulse
# 20                                        cellular component assembly
# 21                          abolished activation of adenylate cyclase
# 22                                                delayed development
# 23                                        aberrant chemotaxis to cAMP
# 24                                decreased protein kinase activation
# 25                                         decreased macropinocytosis
# 26                                       aberrant pseudopod formation
# 27                                                       cytoskeleton
# 28                                       decreased myosin II assembly
# 29           abolished positive regulation of chemorepellant activity
# 30                                                     Protein export
# 31                                  decreased cell-substrate adhesion
# 32                                   anatomical structure development
# 33                                           decreased aggregate size
# 34                                  abolished protein phosphorylation
# 35                                          enzyme regulator activity
# 36                                                      cell motility
# 37                                                delayed aggregation
# 38                                     increased filopodium formation
# 39                                               aberrant aggregation
# 40                                   increased F-actin polymerization
# 41                                          decreased gene expression
# 42                                       decreased fruiting body size
# 43                                            increased cell motility
# 44                                                 mitotic cell cycle
# 45                          decreased activation of adenylate cyclase
# 46                                                aberrant chemotaxis
# 47                                                    decreased taxis
# 48                              increased lateral pseudopod formation
# 49                                protein-containing complex assembly
# 50                                      aberrant protein localization
# 51                                                         Proteasome
# 52                                           abolished slug migration
# 53                                       aberrant cAMP wave formation
# 54                                                 cell morphogenesis
# 55                                       abolished chemotaxis to cAMP
# 56                                       cytoskeletal protein binding
# 57                                             aberrant cell motility
# 58                   decreased positive regulation of GTPase activity
# 59                                  increased cell-substrate adhesion
# 60                                                            cytosol
# 61                                                      cell division
# 62                                                 response to stress
# 63                                                       reproduction
# 64                                       aberrant stalk morphogenesis
# 65                                decreased growth rate in suspension
# 66                                 increased intracellular cAMP level
# 67                                      increased basal F-actin level
# 68                                      microtubule organizing center
# 69                                                abolished streaming
# 70                                               aberrant development
# 71                                         multiple tips in culminant
# 72                                       aberrant signal transduction
# 73                            decreased activation of GTPase activity
# 74                                              decreased culmination
# 75                                              decreased stalk width
# 76                                  decreased cAMP-induced cGMP pulse
# 77                                              decreased growth rate
# 78                                                    GTPase activity
# 79                                              N-Glycan biosynthesis
# 80                                          abolished gene expression
# 81                                            aberrant slug formation
# 82                           development arrests at loose mound stage
# 83                                  decreased protein phosphorylation
# 84                            increased activation of GTPase activity
# 85                      abolished protein localization to cell cortex
# 86                                              abolished culmination
# 87                                             decreased phagocytosis
# 88                             aberrant activation of GTPase activity
# 89                                      abolished cAMP wave formation
# 90                                   decreased F-actin polymerization
# 91                                           Other glycan degradation
# 92                                               phosphatase activity
# 93                                             increased phagocytosis
# 94                                            aberrant slug migration
# 95                             Various types of N-glycan biosynthesis
# 96                            abolished activation of GTPase activity
# 97                                               decreased exocytosis
# 98                                     decreased chemotaxis to folate
# 99                                       increased myosin II assembly
# 100                                                 protein targeting
# 101                                            precocious development
# 102                                              aberrant culmination
# 103                                                        cell cycle
# 104                                        precocious gene expression
# 105                                        aberrant vegetative growth
# 106                                                            growth
# 107                                                     cell adhesion
# 108                                          increased aggregate size
# 109                                          increased slug migration
# 110                          aberrant response to hyperosmotic stress
# 111  increased infection rate by a gram-negative pathogenic bacterium
# 112                                             aberrant phagocytosis
# 113                               increased protein kinase activation
# 114                                                        cell death
# 115                                      increased fruiting body size
# 116                                     abolished positive chemotaxis
# 117                                      abolished catalytic activity
# 118                           decreased prespore cell differentiation
# 119                                            precocious aggregation
# 120                                              cell differentiation
# 121                                         mRNA surveillance pathway
# 122                                           decreased cell polarity
# 123                                             decreased sporulation
#
#                    Ontology       FDR  N in query  Set size  N in ref.
# 0    GO: biological_process  1.91e-14          95       352        350
# 1    GO: biological_process  9.65e-11          58       191        189
# 2     Dictybase: Phenotypes  7.58e-09          36        98         98
# 3     Dictybase: Phenotypes  9.03e-07          27        72         72
# 4    GO: biological_process  2.15e-06          50       197        196
# 5     Dictybase: Phenotypes  6.79e-06          27        82         80
# 6    GO: molecular_function  6.79e-06          70       328        327
# 7     Dictybase: Phenotypes  8.16e-06          17        37         37
# 8    GO: molecular_function  1.82e-05          32       110        110
# 9     Dictybase: Phenotypes  3.96e-05          17        42         41
# 10    Dictybase: Phenotypes  8.51e-05          24        76         76
# 11           KEGG: Pathways  1.21e-04          26        91         88
# 12    Dictybase: Phenotypes  1.23e-04          15        36         36
# 13   GO: cellular_component  1.42e-04          56       268        268
# 14    Dictybase: Phenotypes  1.94e-04           7         9          9
# 15    Dictybase: Phenotypes  1.97e-04          66       341        338
# 16   GO: cellular_component  3.38e-04          30       117        117
# 17    Dictybase: Phenotypes  3.38e-04          20        63         63
# 18    Dictybase: Phenotypes  3.38e-04          13        32         31
# 19    Dictybase: Phenotypes  4.34e-04           8        14         13
# 20   GO: biological_process  6.90e-04          43       202        201
# 21    Dictybase: Phenotypes  8.91e-04           6         8          8
# 22    Dictybase: Phenotypes  1.11e-03          20        69         69
# 23    Dictybase: Phenotypes  1.45e-03          12        31         31
# 24    Dictybase: Phenotypes  1.60e-03           9        19         19
# 25    Dictybase: Phenotypes  1.60e-03           9        19         19
# 26    Dictybase: Phenotypes  1.96e-03           6         9          9
# 27   GO: cellular_component  3.57e-03          38       185        185
# 28    Dictybase: Phenotypes  3.68e-03           8        17         17
# 29    Dictybase: Phenotypes  5.44e-03           7        14         14
# 30           KEGG: Pathways  5.57e-03           8        19         18
# 31    Dictybase: Phenotypes  6.30e-03          10        28         27
# 32   GO: biological_process  6.81e-03          73       440        438
# 33    Dictybase: Phenotypes  6.81e-03          11        32         32
# 34    Dictybase: Phenotypes  6.81e-03           6        11         11
# 35   GO: molecular_function  7.74e-03          24       105        105
# 36   GO: biological_process  1.07e-02          17        67         66
# 37    Dictybase: Phenotypes  1.09e-02          18        72         72
# 38    Dictybase: Phenotypes  1.09e-02           7        16         16
# 39    Dictybase: Phenotypes  1.09e-02          16        61         61
# 40    Dictybase: Phenotypes  1.09e-02           6        12         12
# 41    Dictybase: Phenotypes  1.42e-02          20        95         86
# 42    Dictybase: Phenotypes  1.56e-02          18        76         75
# 43    Dictybase: Phenotypes  1.56e-02           7        17         17
# 44   GO: biological_process  1.64e-02          22       100        100
# 45    Dictybase: Phenotypes  1.64e-02           4         6          6
# 46    Dictybase: Phenotypes  1.64e-02           4         6          6
# 47    Dictybase: Phenotypes  1.64e-02           4         6          6
# 48    Dictybase: Phenotypes  1.68e-02           8        22         22
# 49   GO: biological_process  1.72e-02          27       134        133
# 50    Dictybase: Phenotypes  1.72e-02          10        32         32
# 51           KEGG: Pathways  1.72e-02          11        39         37
# 52    Dictybase: Phenotypes  1.90e-02          12        43         43
# 53    Dictybase: Phenotypes  1.92e-02          21        96         96
# 54   GO: biological_process  2.03e-02           8        23         23
# 55    Dictybase: Phenotypes  2.03e-02           6        14         14
# 56   GO: molecular_function  2.69e-02          30       158        158
# 57    Dictybase: Phenotypes  2.88e-02           4         7          7
# 58    Dictybase: Phenotypes  3.17e-02           5        11         11
# 59    Dictybase: Phenotypes  3.28e-02           9        30         30
# 60   GO: cellular_component  3.51e-02          36       203        203
# 61   GO: biological_process  3.54e-02          23       115        115
# 62   GO: biological_process  4.22e-02          57       360        358
# 63   GO: biological_process  4.52e-02          17        79         79
# 64    Dictybase: Phenotypes  4.52e-02           4         8          8
# 65    Dictybase: Phenotypes  4.52e-02           4         8          8
# 66    Dictybase: Phenotypes  4.52e-02           4         8          8
# 67    Dictybase: Phenotypes  5.03e-02           6        18         17
# 68   GO: cellular_component  5.39e-02          12        50         50
# 69    Dictybase: Phenotypes  5.51e-02           9        33         33
# 70    Dictybase: Phenotypes  6.15e-02          12        51         51
# 71    Dictybase: Phenotypes  6.16e-02           3         5          5
# 72    Dictybase: Phenotypes  6.16e-02           3         5          5
# 73    Dictybase: Phenotypes  6.16e-02           3         5          5
# 74    Dictybase: Phenotypes  6.43e-02           4         9          9
# 75    Dictybase: Phenotypes  6.43e-02           4         9          9
# 76    Dictybase: Phenotypes  6.43e-02           4        10          9
# 77    Dictybase: Phenotypes  6.55e-02          25       146        137
# 78   GO: molecular_function  7.10e-02          26       145        145
# 79           KEGG: Pathways  8.11e-02           8        31         30
# 80    Dictybase: Phenotypes  8.96e-02           7        25         25
# 81    Dictybase: Phenotypes  9.15e-02           4        10         10
# 82    Dictybase: Phenotypes  9.52e-02           6        20         20
# 83    Dictybase: Phenotypes  9.69e-02           3         6          6
# 84    Dictybase: Phenotypes  9.69e-02           3         6          6
# 85    Dictybase: Phenotypes  9.69e-02           3         6          6
# 86    Dictybase: Phenotypes  9.82e-02          13        62         62
# 87    Dictybase: Phenotypes  1.10e-01          13        63         63
# 88    Dictybase: Phenotypes  1.16e-01           4        11         11
# 89    Dictybase: Phenotypes  1.16e-01           4        11         11
# 90    Dictybase: Phenotypes  1.16e-01           5        16         16
# 91           KEGG: Pathways  1.16e-01           4        11         11
# 92   GO: molecular_function  1.16e-01          11        51         51
# 93    Dictybase: Phenotypes  1.16e-01           7        27         27
# 94    Dictybase: Phenotypes  1.21e-01          12        58         58
# 95           KEGG: Pathways  1.30e-01           6        22         22
# 96    Dictybase: Phenotypes  1.37e-01           3         7          7
# 97    Dictybase: Phenotypes  1.46e-01           4        12         12
# 98    Dictybase: Phenotypes  1.46e-01           4        12         12
# 99    Dictybase: Phenotypes  1.46e-01           4        12         12
# 100  GO: biological_process  1.53e-01           8        35         35
# 101   Dictybase: Phenotypes  1.53e-01           7        30         29
# 102   Dictybase: Phenotypes  1.57e-01          16        88         88
# 103  GO: biological_process  1.61e-01          27       167        167
# 104   Dictybase: Phenotypes  1.64e-01           5        18         18
# 105   Dictybase: Phenotypes  1.64e-01           9        42         42
# 106  GO: biological_process  1.71e-01           3         8          8
# 107  GO: biological_process  1.71e-01          15        84         83
# 108   Dictybase: Phenotypes  1.71e-01           7        31         30
# 109   Dictybase: Phenotypes  1.71e-01           3         8          8
# 110   Dictybase: Phenotypes  1.71e-01           4        13         13
# 111   Dictybase: Phenotypes  1.71e-01           4        21         13
# 112   Dictybase: Phenotypes  1.71e-01           3         8          8
# 113   Dictybase: Phenotypes  1.71e-01           4        13         13
# 114  GO: biological_process  1.90e-01           6        25         25
# 115   Dictybase: Phenotypes  2.04e-01           2         5          4
# 116   Dictybase: Phenotypes  2.04e-01           2         5          4
# 117   Dictybase: Phenotypes  2.06e-01           4        14         14
# 118   Dictybase: Phenotypes  2.06e-01           4        14         14
# 119   Dictybase: Phenotypes  2.16e-01           5        20         20
# 120  GO: biological_process  2.21e-01          23       145        145
# 121          KEGG: Pathways  2.31e-01           9        46         46
# 122   Dictybase: Phenotypes  2.32e-01           7        34         33
# 123   Dictybase: Phenotypes  2.34e-01          10        53         53
# ***  tag selected: 191 with EID: 191
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.4
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 61 out of 76 query genes used for enrichment calculation.
#                       Gene set                Ontology       FDR  N in query  \
# 0              DNA replication          KEGG: Pathways  1.78e-25          20
# 1                   chromosome  GO: cellular_component  1.36e-23          24
# 2      chromosome organization  GO: biological_process  1.88e-14          18
# 3              Mismatch repair          KEGG: Pathways  8.25e-12          10
# 4       chromosome segregation  GO: biological_process  2.03e-10           9
# 5   Nucleotide excision repair          KEGG: Pathways  6.61e-10          11
# 6                   cell cycle  GO: biological_process  2.16e-09          19
# 7        DNA metabolic process  GO: biological_process  8.73e-09          15
# 8     mitotic nuclear division  GO: biological_process  4.98e-08           7
# 9         Base excision repair          KEGG: Pathways  3.16e-07           8
# 10          nuclear chromosome  GO: cellular_component  4.20e-06           6
# 11          mitotic cell cycle  GO: biological_process  2.07e-05          11
# 12                 DNA binding  GO: molecular_function  1.07e-04          15
# 13             ATPase activity  GO: molecular_function  1.07e-04          13
# 14               cell division  GO: biological_process  4.01e-04          10
# 15                 nucleoplasm  GO: cellular_component  2.03e-03           8
# 16           helicase activity  GO: molecular_function  1.68e-02           5
# 17  Non-homologous end-joining          KEGG: Pathways  3.95e-02           2
# 18             histone binding  GO: molecular_function  3.95e-02           2
# 19    Homologous recombination          KEGG: Pathways  6.06e-02           3
# 20          response to stress  GO: biological_process  8.19e-02          13
# 21            nuclear envelope  GO: cellular_component  8.19e-02           3
# 22       Pyrimidine metabolism          KEGG: Pathways  8.19e-02           3
# 23           nuclease activity  GO: molecular_function  1.88e-01           3
# 24                   nucleolus  GO: cellular_component  2.04e-01           4
#
#     Set size  N in ref.
# 0         34         33
# 1         70         70
# 2         74         74
# 3         19         19
# 4         18         18
# 5         37         37
# 6        167        167
# 7        105        105
# 8         15         15
# 9         28         28
# 10        17         17
# 11       100        100
# 12       221        221
# 13       169        168
# 14       115        115
# 15        91         91
# 16        51         51
# 17         7          7
# 18         7          7
# 19        26         25
# 20       360        358
# 21        29         29
# 22        31         29
# 23        41         41
# 24        72         72
# ***  tip selected: 261 with EID: 260
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.38
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 73 out of 99 query genes used for enrichment calculation.
#                                             Gene set                Ontology  \
# 0                                         chromosome  GO: cellular_component
# 1                                    DNA replication          KEGG: Pathways
# 2                            chromosome organization  GO: biological_process
# 3                                         cell cycle  GO: biological_process
# 4                                    Mismatch repair          KEGG: Pathways
# 5                         Nucleotide excision repair          KEGG: Pathways
# 6                             chromosome segregation  GO: biological_process
# 7                              DNA metabolic process  GO: biological_process
# 8                                 nuclear chromosome  GO: cellular_component
# 9                                      cell division  GO: biological_process
# 10                          mitotic nuclear division  GO: biological_process
# 11                              Base excision repair          KEGG: Pathways
# 12                                       DNA binding  GO: molecular_function
# 13                                mitotic cell cycle  GO: biological_process
# 14                                   ATPase activity  GO: molecular_function
# 15                             Pyrimidine metabolism          KEGG: Pathways
# 16                     microtubule organizing center  GO: cellular_component
# 17                                       nucleoplasm  GO: cellular_component
# 18                                      cytoskeleton  GO: cellular_component
# 19                                 cell cycle arrest   Dictybase: Phenotypes
# 20                                 helicase activity  GO: molecular_function
# 21                        Non-homologous end-joining          KEGG: Pathways
# 22                                   histone binding  GO: molecular_function
# 23                          Homologous recombination          KEGG: Pathways
# 24  nucleobase-containing compound catabolic process  GO: biological_process
#
#          FDR  N in query  Set size  N in ref.
# 0   1.17e-27          29        70         70
# 1   3.75e-23          20        34         33
# 2   1.99e-13          19        74         74
# 3   3.45e-13          26       167        167
# 4   2.25e-12          11        19         19
# 5   3.17e-11          13        37         37
# 6   1.94e-09           9        18         18
# 7   6.61e-09          17       105        105
# 8   3.26e-08           8        17         17
# 9   1.79e-07          16       115        115
# 10  3.07e-07           7        15         15
# 11  2.48e-06           8        28         28
# 12  3.16e-06          20       221        221
# 13  7.35e-06          13       100        100
# 14  1.98e-03          13       169        168
# 15  5.01e-03           5        31         29
# 16  9.96e-03           6        50         50
# 17  1.22e-02           8        91         91
# 18  1.31e-02          12       185        185
# 19  3.56e-02           2         5          5
# 20  4.88e-02           5        51         51
# 21  6.29e-02           2         7          7
# 22  6.29e-02           2         7          7
# 23  1.18e-01           3        26         25
# 24  1.26e-01           3        26         26
# ***  slug selected: 76 with EID: 76
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.28
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 2 out of 21 query genes used for enrichment calculation.
#             Gene set               Ontology       FDR  N in query  Set size  \
# 0  cell cycle arrest  Dictybase: Phenotypes  1.91e-02           2         5
#
#    N in ref.
# 0          5
# ***  mhat selected: 8 with EID: 8
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.0
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 0 out of 0 query genes used for enrichment calculation.
# None
# ***  cul selected: 565 with EID: 559
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.28
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 32 out of 156 query genes used for enrichment calculation.
#                                     Gene set                Ontology  \
# 0                            Golgi apparatus  GO: cellular_component
# 1  SNARE interactions in vesicular transport          KEGG: Pathways
# 2                    oxidoreductase activity  GO: molecular_function
#
#         FDR  N in query  Set size  N in ref.
# 0  8.59e-02          11        85         85
# 1  1.10e-01           5        23         23
# 2  1.10e-01          18       210        207
# ***  FB selected: 555 with EID: 546
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.23
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 36 out of 123 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0  anatomical structure formation involved in morphogenesis
# 1                                      extracellular region
# 2                                      cell differentiation
# 3                 SNARE interactions in vesicular transport
# 4                               secondary metabolic process
# 5       Ubiquinone and other terpenoid-quinone biosynthesis
# 6                                 decreased spore viability
#
#                  Ontology       FDR  N in query  Set size  N in ref.
# 0  GO: biological_process  5.29e-05          13        74         74
# 1  GO: cellular_component  1.98e-03          16       157        157
# 2  GO: biological_process  2.04e-03          15       145        145
# 3          KEGG: Pathways  2.36e-03           6        23         23
# 4  GO: biological_process  9.95e-03           3         5          5
# 5          KEGG: Pathways  8.86e-02           3        10         10
# 6   Dictybase: Phenotypes  2.40e-01           6        60         59

# %% [markdown]
# #### ImpulseDE2 WT

# %%
milestones=pd.read_table(path_impulse+'DEacrossStages_summary_WT_noyem_batchrep.tsv',index_col=0,sep='\t')
stages=np.array([phenotype for phenotype in PHENOTYPES if phenotype in list(milestones.columns)])
for stage_idx,stage in enumerate(stages):
    
    #Nonneighbouring stages
    neigh_previous=1
    neigh_next=1
    #Assumes phenotypes order
    if stage_idx==1:
        neigh_previous=0
    if stage_idx==0:
        neigh_next=0
    non_neighbours = stages[[(idx <stage_idx-neigh_previous or idx>stage_idx+neigh_next) 
                 for idx in range(len(stages)) ]]
    #print(stage,':',non_neighbours)
    
    #Find genes up at stage and down at nonenighbouring
    query_condition=stage+'=="up"'
    for non_neigh in non_neighbours:
        query_condition=query_condition+' & '+non_neigh+' =="down"'
    #print(query_condition)
    
    query_names=list(milestones.query(query_condition).index)
    enriched=group_diff_enrichment(query_names=query_names,group=stage,min_overlap=2,use_annotated_genes=True)
# Out:
# ***  no_agg selected: 2330 with EID: 2310
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.4
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 539 out of 923 query genes used for enrichment calculation.
#                                           Gene set                Ontology  \
# 0                                         Ribosome          KEGG: Pathways
# 1                                      translation  GO: biological_process
# 2               structural constituent of ribosome  GO: molecular_function
# 3                                         ribosome  GO: cellular_component
# 4                                    mitochondrion  GO: cellular_component
# 5                              ribosome biogenesis  GO: biological_process
# 6                                        nucleolus  GO: cellular_component
# 7                     structural molecule activity  GO: molecular_function
# 8                Ribosome biogenesis in eukaryotes          KEGG: Pathways
# 9                           tRNA metabolic process  GO: biological_process
# 10                     Aminoacyl-tRNA biosynthesis          KEGG: Pathways
# 11                       Oxidative phosphorylation          KEGG: Pathways
# 12                                     RNA binding  GO: molecular_function
# 13                            Steroid biosynthesis          KEGG: Pathways
# 14                                 ligase activity  GO: molecular_function
# 15                      methyltransferase activity  GO: molecular_function
# 16  generation of precursor metabolites and energy  GO: biological_process
# 17           cellular amino acid metabolic process  GO: biological_process
# 18                         oxidoreductase activity  GO: molecular_function
# 19                      cofactor metabolic process  GO: biological_process
# 20           Biosynthesis of secondary metabolites          KEGG: Pathways
# 21                small molecule metabolic process  GO: biological_process
# 22                        unfolded protein binding  GO: molecular_function
# 23            Porphyrin and chlorophyll metabolism          KEGG: Pathways
# 24                                 protein folding  GO: biological_process
# 25                      mitochondrion organization  GO: biological_process
# 26                                    rRNA binding  GO: molecular_function
# 27                                  RNA polymerase          KEGG: Pathways
# 28                              isomerase activity  GO: molecular_function
# 29               sulfur compound metabolic process  GO: biological_process
# 30                            Butanoate metabolism          KEGG: Pathways
# 31                           Fatty acid elongation          KEGG: Pathways
#
#          FDR  N in query  Set size  N in ref.
# 0   2.53e-28          76       105         97
# 1   4.76e-25         104       169        169
# 2   2.37e-23          65        85         85
# 3   1.22e-22          68        93         93
# 4   1.17e-19         118       229        229
# 5   4.03e-17          47        61         61
# 6   5.36e-16          51        72         72
# 7   2.82e-15          69       117        117
# 8   3.89e-14          47        72         68
# 9   3.96e-12          45        69         69
# 10  7.61e-09          31        64         46
# 11  1.49e-08          34        71         54
# 12  3.75e-07          72       169        169
# 13  3.93e-05          14        18         18
# 14  3.94e-05          38        80         80
# 15  7.22e-05          29        58         56
# 16  1.03e-04          36        77         77
# 17  7.03e-04          49       125        124
# 18  9.76e-04          73       210        207
# 19  2.77e-03          31        72         72
# 20  4.11e-03          91       289        281
# 21  4.91e-03         110       354        353
# 22  1.78e-02          14        27         27
# 23  1.81e-02           9        14         14
# 24  2.84e-02          17        37         37
# 25  3.29e-02          12        23         23
# 26  4.50e-02           8        13         13
# 27  7.34e-02          12        26         25
# 28  1.68e-01          19        50         50
# 29  1.77e-01          14        34         34
# 30  1.77e-01           7        13         13
# 31  1.77e-01           7        13         13
# ***  stream selected: 409 with EID: 403
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.41
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 127 out of 166 query genes used for enrichment calculation.
#                                             Gene set                Ontology  \
# 0                                         Proteasome          KEGG: Pathways
# 1        Protein processing in endoplasmic reticulum          KEGG: Pathways
# 2                                         locomotion  GO: biological_process
# 3                                signal transduction  GO: biological_process
# 4                                 aberrant streaming   Dictybase: Phenotypes
# 5                                  catabolic process  GO: biological_process
# 6                               aberrant aggregation   Dictybase: Phenotypes
# 7          abolished activation of adenylate cyclase   Dictybase: Phenotypes
# 8                           decreased aggregate size   Dictybase: Phenotypes
# 9                            decreased cell motility   Dictybase: Phenotypes
# 10                                         wild type   Dictybase: Phenotypes
# 11                     aberrant F-actin organization   Dictybase: Phenotypes
# 12                              aberrant cytokinesis   Dictybase: Phenotypes
# 13                              decreased exocytosis   Dictybase: Phenotypes
# 14          development arrests at loose mound stage   Dictybase: Phenotypes
# 15                         cytoskeleton organization  GO: biological_process
# 16                               aberrant chemotaxis   Dictybase: Phenotypes
# 17                                      reproduction  GO: biological_process
# 18                               abolished streaming   Dictybase: Phenotypes
# 19                      aberrant cAMP wave formation   Dictybase: Phenotypes
# 20                    increased filopodium formation   Dictybase: Phenotypes
# 21                              aberrant culmination   Dictybase: Phenotypes
# 22                       cellular component assembly  GO: biological_process
# 23                         enzyme regulator activity  GO: molecular_function
# 24                      decreased chemotaxis to cAMP   Dictybase: Phenotypes
# 25                     increased basal F-actin level   Dictybase: Phenotypes
# 26                             decreased culmination   Dictybase: Phenotypes
# 27                                     cell motility  GO: biological_process
# 28                        precocious gene expression   Dictybase: Phenotypes
# 29                                response to stress  GO: biological_process
# 30                        decreased macropinocytosis   Dictybase: Phenotypes
# 31                             decreased pinocytosis   Dictybase: Phenotypes
# 32                aberrant cytoskeleton organisation   Dictybase: Phenotypes
# 33                           aberrant slug formation   Dictybase: Phenotypes
# 34                  anatomical structure development  GO: biological_process
# 35                                   plasma membrane  GO: cellular_component
# 36                          abolished slug migration   Dictybase: Phenotypes
# 37                 abolished protein phosphorylation   Dictybase: Phenotypes
# 38                                   kinase activity  GO: molecular_function
# 39                      decreased fruiting body size   Dictybase: Phenotypes
# 40                 decreased cAMP-induced cAMP pulse   Dictybase: Phenotypes
# 41          aberrant response to hyperosmotic stress   Dictybase: Phenotypes
# 42                        multiple tips in culminant   Dictybase: Phenotypes
# 43                                    enzyme binding  GO: molecular_function
# 44                      abolished chemotaxis to cAMP   Dictybase: Phenotypes
# 45  nucleobase-containing compound catabolic process  GO: biological_process
# 46                             endoplasmic reticulum  GO: cellular_component
# 47                     aberrant chemotaxis to folate   Dictybase: Phenotypes
# 48         decreased activation of adenylate cyclase   Dictybase: Phenotypes
# 49                               delayed development   Dictybase: Phenotypes
# 50                development arrests at mound stage   Dictybase: Phenotypes
# 51                          aberrant cell morphology   Dictybase: Phenotypes
# 52                           aberrant slug migration   Dictybase: Phenotypes
# 53                                peptidase activity  GO: molecular_function
# 54                             increased growth rate   Dictybase: Phenotypes
# 55               decreased growth rate in suspension   Dictybase: Phenotypes
# 56                           increased protein level   Dictybase: Phenotypes
# 57                increased intracellular cAMP level   Dictybase: Phenotypes
# 58               decreased protein kinase activation   Dictybase: Phenotypes
# 59               protein-containing complex assembly  GO: biological_process
# 60                                     cell division  GO: biological_process
# 61                                      cytoskeleton  GO: cellular_component
# 62                             abolished aggregation   Dictybase: Phenotypes
# 63                            precocious aggregation   Dictybase: Phenotypes
# 64                           abolished cell polarity   Dictybase: Phenotypes
# 65                      aberrant pseudopod formation   Dictybase: Phenotypes
# 66                                  abolished growth   Dictybase: Phenotypes
# 67           decreased lateral pseudopod suppression   Dictybase: Phenotypes
# 68                                   ATPase activity  GO: molecular_function
# 69                                     cell adhesion  GO: biological_process
# 70                                mitotic cell cycle  GO: biological_process
# 71                         decreased chemotaxis rate   Dictybase: Phenotypes
# 72                         decreased gene expression   Dictybase: Phenotypes
# 73                                cell morphogenesis  GO: biological_process
#
#          FDR  N in query  Set size  N in ref.
# 0   4.00e-06          12        39         37
# 1   3.47e-04          15        91         88
# 2   8.30e-04          22       191        189
# 3   9.86e-04          32       352        350
# 4   1.82e-03          12        72         72
# 5   4.11e-03          24       250        250
# 6   5.98e-03          10        61         61
# 7   5.98e-03           4         8          8
# 8   7.24e-03           7        32         32
# 9   7.24e-03          11        76         76
# 10  7.46e-03          28       341        338
# 11  1.43e-02           7        37         37
# 12  1.43e-02          12        98         98
# 13  1.94e-02           4        12         12
# 14  1.94e-02           5        20         20
# 15  1.97e-02          18       197        196
# 16  1.97e-02           3         6          6
# 17  2.20e-02          10        79         79
# 18  2.77e-02           6        33         33
# 19  2.77e-02          11        96         96
# 20  4.24e-02           4        16         16
# 21  4.24e-02          10        88         88
# 22  4.50e-02          17       202        201
# 23  4.50e-02          11       105        105
# 24  4.54e-02           8        63         63
# 25  4.54e-02           4        18         17
# 26  4.75e-02           3         9          9
# 27  5.21e-02           8        67         66
# 28  5.21e-02           4        18         18
# 29  5.60e-02          25       360        358
# 30  5.60e-02           4        19         19
# 31  5.60e-02           5        30         30
# 32  5.60e-02           3        10         10
# 33  5.60e-02           3        10         10
# 34  5.79e-02          29       440        438
# 35  5.79e-02          20       268        268
# 36  5.81e-02           6        43         43
# 37  6.07e-02           3        11         11
# 38  6.07e-02          23       328        327
# 39  8.05e-02           8        76         75
# 40  9.18e-02           3        14         13
# 41  9.18e-02           3        13         13
# 42  9.44e-02           2         5          5
# 43  9.51e-02          10       110        110
# 44  1.06e-01           3        14         14
# 45  1.20e-01           4        26         26
# 46  1.23e-01          10       117        117
# 47  1.23e-01           2         6          6
# 48  1.23e-01           2         6          6
# 49  1.23e-01           7        69         69
# 50  1.23e-01           6        56         54
# 51  1.33e-01           5        42         41
# 52  1.60e-01           6        58         58
# 53  1.70e-01           8        91         91
# 54  1.80e-01           4        32         31
# 55  1.80e-01           2         8          8
# 56  1.80e-01           2         9          8
# 57  1.80e-01           2         8          8
# 58  1.84e-01           3        19         19
# 59  1.91e-01          10       134        133
# 60  1.91e-01           9       115        115
# 61  1.91e-01          13       185        185
# 62  1.91e-01           7        82         80
# 63  1.91e-01           3        20         20
# 64  1.91e-01           2         9          9
# 65  1.91e-01           2         9          9
# 66  1.91e-01           4        34         33
# 67  1.91e-01           2         9          9
# 68  1.91e-01          12       169        168
# 69  2.09e-01           7        84         83
# 70  2.09e-01           8       100        100
# 71  2.19e-01           4        36         36
# 72  2.37e-01           7        95         86
# 73  2.37e-01           3        23         23
# ***  lag selected: 429 with EID: 423
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.42
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 125 out of 176 query genes used for enrichment calculation.
#                                        Gene set                Ontology  \
# 0                                    Proteasome          KEGG: Pathways
# 1                           signal transduction  GO: biological_process
# 2                                    locomotion  GO: biological_process
# 3                          aberrant aggregation   Dictybase: Phenotypes
# 4   Protein processing in endoplasmic reticulum          KEGG: Pathways
# 5                      decreased aggregate size   Dictybase: Phenotypes
# 6                            aberrant streaming   Dictybase: Phenotypes
# 7     abolished activation of adenylate cyclase   Dictybase: Phenotypes
# 8                           abolished streaming   Dictybase: Phenotypes
# 9                      abolished slug migration   Dictybase: Phenotypes
# 10                      decreased cell motility   Dictybase: Phenotypes
# 11                              plasma membrane  GO: cellular_component
# 12                aberrant F-actin organization   Dictybase: Phenotypes
# 13                            catabolic process  GO: biological_process
# 14                          aberrant chemotaxis   Dictybase: Phenotypes
# 15                         decreased exocytosis   Dictybase: Phenotypes
# 16     development arrests at loose mound stage   Dictybase: Phenotypes
# 17                         aberrant cytokinesis   Dictybase: Phenotypes
# 18                    cytoskeleton organization  GO: biological_process
# 19                 aberrant cAMP wave formation   Dictybase: Phenotypes
# 20                                    wild type   Dictybase: Phenotypes
# 21                           response to stress  GO: biological_process
# 22               increased filopodium formation   Dictybase: Phenotypes
# 23                         aberrant culmination   Dictybase: Phenotypes
# 24                        decreased culmination   Dictybase: Phenotypes
# 25                increased basal F-actin level   Dictybase: Phenotypes
# 26                 decreased chemotaxis to cAMP   Dictybase: Phenotypes
# 27                    enzyme regulator activity  GO: molecular_function
# 28                  cellular component assembly  GO: biological_process
# 29           aberrant cytoskeleton organisation   Dictybase: Phenotypes
# 30                   decreased macropinocytosis   Dictybase: Phenotypes
# 31                        decreased pinocytosis   Dictybase: Phenotypes
# 32           development arrests at mound stage   Dictybase: Phenotypes
# 33                       precocious aggregation   Dictybase: Phenotypes
# 34            abolished protein phosphorylation   Dictybase: Phenotypes
# 35                        endoplasmic reticulum  GO: cellular_component
# 36             anatomical structure development  GO: biological_process
# 37                                 cytoskeleton  GO: cellular_component
# 38            decreased cAMP-induced cAMP pulse   Dictybase: Phenotypes
# 39                   multiple tips in culminant   Dictybase: Phenotypes
# 40                 decreased fruiting body size   Dictybase: Phenotypes
# 41     aberrant response to hyperosmotic stress   Dictybase: Phenotypes
# 42                 abolished chemotaxis to cAMP   Dictybase: Phenotypes
# 43                                 reproduction  GO: biological_process
# 44                                cell motility  GO: biological_process
# 45                aberrant chemotaxis to folate   Dictybase: Phenotypes
# 46    decreased activation of adenylate cyclase   Dictybase: Phenotypes
# 47                                cell adhesion  GO: biological_process
# 48                          delayed development   Dictybase: Phenotypes
# 49                     aberrant cell morphology   Dictybase: Phenotypes
# 50                  aberrant chemotaxis to cAMP   Dictybase: Phenotypes
# 51                      delayed gene expression   Dictybase: Phenotypes
# 52          decreased growth rate in suspension   Dictybase: Phenotypes
# 53                      increased protein level   Dictybase: Phenotypes
# 54                     increased slug migration   Dictybase: Phenotypes
# 55                   precocious gene expression   Dictybase: Phenotypes
# 56           increased intracellular cAMP level   Dictybase: Phenotypes
# 57                      aberrant slug migration   Dictybase: Phenotypes
# 58                        increased growth rate   Dictybase: Phenotypes
# 59          decreased protein kinase activation   Dictybase: Phenotypes
# 60                        abolished culmination   Dictybase: Phenotypes
# 61                      abolished cell polarity   Dictybase: Phenotypes
# 62                 aberrant pseudopod formation   Dictybase: Phenotypes
# 63                             abolished growth   Dictybase: Phenotypes
# 64      decreased lateral pseudopod suppression   Dictybase: Phenotypes
# 65                              kinase activity  GO: molecular_function
# 66                               enzyme binding  GO: molecular_function
# 67                        abolished aggregation   Dictybase: Phenotypes
#
#          FDR  N in query  Set size  N in ref.
# 0   7.99e-06          12        39         37
# 1   4.50e-05          37       352        350
# 2   6.71e-04          23       191        189
# 3   7.30e-04          12        61         61
# 4   1.40e-03          14        91         88
# 5   2.39e-03           8        32         32
# 6   2.39e-03          12        72         72
# 7   7.56e-03           4         8          8
# 8   1.21e-02           7        33         33
# 9   1.21e-02           8        43         43
# 10  1.21e-02          11        76         76
# 11  1.51e-02          24       268        268
# 12  2.08e-02           7        37         37
# 13  2.27e-02          22       250        250
# 14  2.27e-02           3         6          6
# 15  2.27e-02           4        12         12
# 16  2.27e-02           5        20         20
# 17  2.27e-02          12        98         98
# 18  3.45e-02          18       197        196
# 19  4.32e-02          11        96         96
# 20  4.74e-02          26       341        338
# 21  4.99e-02          27       360        358
# 22  5.16e-02           4        16         16
# 23  5.81e-02          10        88         88
# 24  5.98e-02           3         9          9
# 25  5.98e-02           4        18         17
# 26  6.14e-02           8        63         63
# 27  6.15e-02          11       105        105
# 28  6.85e-02          17       202        201
# 29  7.16e-02           3        10         10
# 30  7.33e-02           4        19         19
# 31  7.56e-02           5        30         30
# 32  7.56e-02           7        56         54
# 33  8.07e-02           4        20         20
# 34  8.17e-02           3        11         11
# 35  1.05e-01          11       117        117
# 36  1.12e-01          29       440        438
# 37  1.12e-01          15       185        185
# 38  1.12e-01           3        14         13
# 39  1.12e-01           2         5          5
# 40  1.12e-01           8        76         75
# 41  1.12e-01           3        13         13
# 42  1.33e-01           3        14         14
# 43  1.39e-01           8        79         79
# 44  1.46e-01           7        67         66
# 45  1.46e-01           2         6          6
# 46  1.46e-01           2         6          6
# 47  1.65e-01           8        84         83
# 48  1.74e-01           7        69         69
# 49  1.77e-01           5        42         41
# 50  2.07e-01           4        31         31
# 51  2.07e-01           3        19         18
# 52  2.07e-01           2         8          8
# 53  2.07e-01           2         9          8
# 54  2.07e-01           2         8          8
# 55  2.07e-01           3        18         18
# 56  2.07e-01           2         8          8
# 57  2.07e-01           6        58         58
# 58  2.07e-01           4        32         31
# 59  2.15e-01           3        19         19
# 60  2.23e-01           6        62         62
# 61  2.23e-01           2         9          9
# 62  2.23e-01           2         9          9
# 63  2.23e-01           4        34         33
# 64  2.23e-01           2         9          9
# 65  2.23e-01          21       328        327
# 66  2.23e-01           9       110        110
# 67  2.46e-01           7        82         80
# ***  tag selected: 273 with EID: 272
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.35
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 65 out of 95 query genes used for enrichment calculation.
#                           Gene set                Ontology       FDR  \
# 0                       chromosome  GO: cellular_component  1.44e-16
# 1                  DNA replication          KEGG: Pathways  1.44e-16
# 2            DNA metabolic process  GO: biological_process  3.43e-14
# 3                  Mismatch repair          KEGG: Pathways  7.58e-11
# 4          chromosome organization  GO: biological_process  1.50e-10
# 5                      DNA binding  GO: molecular_function  2.58e-09
# 6                       cell cycle  GO: biological_process  1.72e-08
# 7           chromosome segregation  GO: biological_process  3.62e-08
# 8             Base excision repair          KEGG: Pathways  9.40e-08
# 9       Nucleotide excision repair          KEGG: Pathways  1.27e-06
# 10        mitotic nuclear division  GO: biological_process  6.05e-06
# 11              nuclear chromosome  GO: cellular_component  2.81e-04
# 12                 ATPase activity  GO: molecular_function  2.81e-04
# 13                   cell division  GO: biological_process  5.45e-04
# 14              mitotic cell cycle  GO: biological_process  3.70e-03
# 15              response to stress  GO: biological_process  1.11e-02
# 16        Homologous recombination          KEGG: Pathways  1.50e-02
# 17      Non-homologous end-joining          KEGG: Pathways  5.49e-02
# 18                 histone binding  GO: molecular_function  5.49e-02
# 19  Ubiquitin mediated proteolysis          KEGG: Pathways  7.06e-02
# 20           Pyrimidine metabolism          KEGG: Pathways  1.41e-01
#
#     N in query  Set size  N in ref.
# 0           21        70         70
# 1           16        34         33
# 2           22       105        105
# 3           10        19         19
# 4           16        74         74
# 5           24       221        221
# 6           20       167        167
# 7            8        18         18
# 8            9        28         28
# 9            9        37         37
# 10           6        15         15
# 11           5        17         17
# 12          14       169        168
# 13          11       115        115
# 14           9       100        100
# 15          18       360        358
# 16           4        26         25
# 17           2         7          7
# 18           2         7          7
# 19           5        62         61
# 20           3        31         29
# ***  tip selected: 486 with EID: 485
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.34
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 119 out of 166 query genes used for enrichment calculation.
#                                         Gene set                Ontology  \
# 0                                     chromosome  GO: cellular_component
# 1                                DNA replication          KEGG: Pathways
# 2                        chromosome organization  GO: biological_process
# 3                                     cell cycle  GO: biological_process
# 4                          DNA metabolic process  GO: biological_process
# 5                                Mismatch repair          KEGG: Pathways
# 6                         chromosome segregation  GO: biological_process
# 7                       mitotic nuclear division  GO: biological_process
# 8                                    DNA binding  GO: molecular_function
# 9                           Base excision repair          KEGG: Pathways
# 10                                 cell division  GO: biological_process
# 11                    Nucleotide excision repair          KEGG: Pathways
# 12                            mitotic cell cycle  GO: biological_process
# 13                            nuclear chromosome  GO: cellular_component
# 14                 microtubule organizing center  GO: cellular_component
# 15                               ATPase activity  GO: molecular_function
# 16                      Homologous recombination          KEGG: Pathways
# 17                                  cytoskeleton  GO: cellular_component
# 18                Ubiquitin mediated proteolysis          KEGG: Pathways
# 19                               histone binding  GO: molecular_function
# 20                                   nucleoplasm  GO: cellular_component
# 21                         Pyrimidine metabolism          KEGG: Pathways
# 22                            response to stress  GO: biological_process
# 23              aberrant centrosome organization   Dictybase: Phenotypes
# 24                   aberrant nucleus morphology   Dictybase: Phenotypes
# 25                             cell cycle arrest   Dictybase: Phenotypes
# 26                           aberrant cell cycle   Dictybase: Phenotypes
# 27                             helicase activity  GO: molecular_function
# 28                              nuclear envelope  GO: cellular_component
# 29                    Non-homologous end-joining          KEGG: Pathways
# 30  increased sensitivity to DNA-damaging agents   Dictybase: Phenotypes
#
#          FDR  N in query  Set size  N in ref.
# 0   1.00e-31          37        70         70
# 1   5.03e-27          25        34         33
# 2   1.89e-21          30        74         74
# 3   2.75e-20          41       167        167
# 4   1.13e-16          30       105        105
# 5   1.13e-16          15        19         19
# 6   1.72e-15          14        18         18
# 7   1.10e-11          11        15         15
# 8   3.39e-11          35       221        221
# 9   2.51e-10          13        28         28
# 10  3.22e-10          24       115        115
# 11  9.92e-10          14        37         37
# 12  3.17e-08          20       100        100
# 13  1.46e-06           8        17         17
# 14  4.43e-05          11        50         50
# 15  4.45e-05          21       169        168
# 16  3.76e-03           6        26         25
# 17  5.04e-03          18       185        185
# 18  6.44e-03           9        62         61
# 19  1.55e-02           3         7          7
# 20  2.97e-02          10        91         91
# 21  4.08e-02           5        31         29
# 22  4.43e-02          25       360        358
# 23  8.21e-02           2         5          5
# 24  8.21e-02           2         5          5
# 25  8.21e-02           2         5          5
# 26  8.21e-02           2         5          5
# 27  9.39e-02           6        51         51
# 28  1.47e-01           4        29         29
# 29  1.47e-01           2         7          7
# 30  1.84e-01           2         8          8
# ***  slug selected: 117 with EID: 116
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.22
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 13 out of 25 query genes used for enrichment calculation.
#                     Gene set                Ontology       FDR  N in query  \
# 0    chromosome organization  GO: biological_process  6.87e-03           5
# 1                nucleoplasm  GO: cellular_component  9.85e-02           4
# 2                 cell cycle  GO: biological_process  1.76e-01           4
# 3                 cell death  GO: biological_process  1.76e-01           2
# 4      DNA metabolic process  GO: biological_process  1.76e-01           3
# 5                 chromosome  GO: cellular_component  1.76e-01           3
# 6             RNA polymerase          KEGG: Pathways  1.76e-01           2
# 7  enzyme regulator activity  GO: molecular_function  1.76e-01           3
# 8              cell division  GO: biological_process  1.85e-01           3
# 9       transferase activity  GO: molecular_function  2.02e-01           2
#
#    Set size  N in ref.
# 0        74         74
# 1        91         91
# 2       167        167
# 3        25         25
# 4       105        105
# 5        70         70
# 6        26         25
# 7       105        105
# 8       115        115
# 9        51         51
# ***  mhat selected: 28 with EID: 28
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.5
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 7 out of 14 query genes used for enrichment calculation.
#                                          Gene set                Ontology  \
# 0  generation of precursor metabolites and energy  GO: biological_process
# 1                  carbohydrate metabolic process  GO: biological_process
# 2                   Starch and sucrose metabolism          KEGG: Pathways
# 3     Amino sugar and nucleotide sugar metabolism          KEGG: Pathways
# 4                               catabolic process  GO: biological_process
# 5                small molecule metabolic process  GO: biological_process
# 6                         oxidoreductase activity  GO: molecular_function
# 7                               Carbon metabolism          KEGG: Pathways
# 8           Biosynthesis of secondary metabolites          KEGG: Pathways
# 9                     cellular component assembly  GO: biological_process
#
#         FDR  N in query  Set size  N in ref.
# 0  7.36e-02           3        77         77
# 1  7.36e-02           3        89         88
# 2  7.36e-02           2        31         31
# 3  7.36e-02           2        27         27
# 4  1.01e-01           4       250        250
# 5  1.47e-01           4       354        353
# 6  1.49e-01           3       210        207
# 7  1.88e-01           2       104        102
# 8  2.19e-01           3       289        281
# 9  2.44e-01           2       202        201
# ***  cul selected: 1412 with EID: 1403
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.31
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 112 out of 431 query genes used for enrichment calculation.
#                                     Gene set                Ontology  \
# 0  SNARE interactions in vesicular transport          KEGG: Pathways
# 1                secondary metabolic process  GO: biological_process
# 2                                  autophagy  GO: biological_process
# 3                                Endocytosis          KEGG: Pathways
# 4                       cell differentiation  GO: biological_process
# 5                          Autophagy - other          KEGG: Pathways
# 6                  decreased spore viability   Dictybase: Phenotypes
# 7                                  wild type   Dictybase: Phenotypes
#
#         FDR  N in query  Set size  N in ref.
# 0  3.24e-03          11        23         23
# 1  7.41e-02           4         5          5
# 2  7.41e-02          11        34         34
# 3  7.73e-02          18        77         75
# 4  1.17e-01          28       145        145
# 5  1.64e-01           8        25         24
# 6  1.79e-01          14        60         59
# 7  2.39e-01          52       341        338
# ***  FB selected: 564 with EID: 560
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.25
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 33 out of 141 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0                                      extracellular region
# 1  anatomical structure formation involved in morphogenesis
# 2                             Starch and sucrose metabolism
# 3                 SNARE interactions in vesicular transport
# 4                                      cell differentiation
#
#                  Ontology       FDR  N in query  Set size  N in ref.
# 0  GO: cellular_component  2.45e-02          16       157        157
# 1  GO: biological_process  2.56e-02          10        74         74
# 2          KEGG: Pathways  4.44e-02           6        31         31
# 3          KEGG: Pathways  5.47e-02           5        23         23
# 4  GO: biological_process  2.11e-01          12       145        145
