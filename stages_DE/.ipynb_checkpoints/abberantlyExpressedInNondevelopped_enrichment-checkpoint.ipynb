# %%
import os
import sys
from importlib import reload

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.insert(0,module_path)

import pandas as pd
from IPython.display import display
pd.set_option('max_colwidth', 70)
pd.set_option('display.max_rows', 500)
import string
import numpy as np

from orangecontrib.bioinformatics.geneset.__init__ import list_all

import jupyter_functions as jf
reload(jf)
import jupyter_functions as jf
from networks.functionsDENet import loadPickle, savePickle
import enrichment_library as enr
reload(enr)
import enrichment_library as enr
from stages_DE.stages_library import PHENOTYPES

# %%
#Path for expression data (mergedGenes_RPKUM.tsv)
dataPath='/home/karin/Documents/timeTrajectories/data/RPKUM/combined/'
path_abberant='/home/karin/Documents/timeTrajectories/data/regulons/selected_genes/'

# %%
# For conversion of gene names to EID
genes = pd.read_csv(dataPath + 'mergedGenes_RPKUM.tsv', sep='\t', index_col=0)
all_gene_names= genes[(genes != 0).any(axis=1)].index
NAME_EID=enr.name_genes_entrez(gene_names=all_gene_names, key_entrez=False)
ALL_GENE_NAMES_EID=enr.convert_EID(genes=all_gene_names, name_EID=NAME_EID)

# %%
def group_diff_enrichment(query_names,group:str,padj:float=0.25,min_overlap:int=None,
                          use_annotated_genes:bool=False):
    #Displays only gene sets that have overlap with query greater or equal to min_overlap 
    #For p value and padj calculation uses alll that have overlap >=1 } from gene_set_enrichment
    """
    :param use_annotated_genes: if True use for reference and query  only genes that have at 
    least one gene set annotation
    """
    query_EID=enr.convert_EID(genes=query_names, name_EID=NAME_EID)
    print('***  '+group+' selected:',len(query_names),'with EID:',len(query_EID))
    
    reference_gene_eids=ALL_GENE_NAMES_EID.copy()
    query_eids=query_EID.copy()
    
    if use_annotated_genes:
        gene_sets_genes=set()
        for gene_set_name, gene_sets in GENE_SETS_ONTOLOGY.items():
            for gene_set in gene_sets:
                gene_sets_genes.update(gene_set.genes)
        reference_gene_eids=set(reference_gene_eids) & gene_sets_genes
        query_eids=set(query_eids) & gene_sets_genes
        
        query_annotated_reatio='NA'
        if len(query_EID)>0:
            query_annotated_reatio=round(len(query_eids)/len(query_EID),2)
        print('Ratio of genes annotated with a gene set in reference',
              round(len(reference_gene_eids)/len(ALL_GENE_NAMES_EID),2),
             'and query',query_annotated_reatio)
    
    query_in_enriched=set()
    result=None
    if len(query_eids) > 0:
        enrichment=enr.gene_set_enrichment(query_eids, reference_EID=reference_gene_eids, 
                                                padj_threshold=padj,min_overlap=min_overlap,
                                                gene_sets_ontology=GENE_SETS_ONTOLOGY)
        if len(enrichment)>0:
            enrichment_display=list()
            enrichment= sorted(enrichment, key=lambda data: data.padj)
            for enriched in enrichment:
                query_in_enriched.update(enriched.gene_set.genes & query_eids)
                enrichment_display.append({'Gene set':enriched.gene_set.name,
                                           'Ontology':enriched.ontology[0]+': '+enriched.ontology[1],
                                           'FDR':"{:.2e}".format(enriched.padj),'N in query':enriched.in_query,
                                          'Set size':len(enriched.gene_set.genes),
                                                          'N in ref.':enriched.in_reference})
            result=pd.DataFrame(enrichment_display)
    print('Enrichment at FDR: '+str(padj)+' and min query - gene set overlap',str(min_overlap))
    print('N query genes in displayed gene sets:',len(query_in_enriched),'out of', len(query_eids),
          'query genes used for enrichment calculation.')
    display(result)
    print('\n')
    return result

# %%
comparison_order=('agg-','dis','tag','cud')

# %% [markdown]
# ## Enrichment report

# %% [markdown]
# Filter results based on FDR (<=0.05) and Difference between group means (>=0.3).

# %%
abberant=pd.read_table(
    path_abberant+'comparisonsAvgSimsSingle2STDAny0.2_lessComparisons2_AX4basedNeigh_u-less_newGenes_noAll-removeZeroRep_simsDict_scalemean0std1_logTrue_kN11_splitStrain.tsv',
                       index_col=0,sep='\t')
abberant=abberant[(abberant['Difference mean']>=0.3) & (abberant['FDR']<=0.05)]

# %% [markdown]
# ### KEGG, DictyPhenotypes, GO slims

# %%
# Get all gene sets
gene_sets=list(list_all(organism='44689'))
GENE_SETS_ONTOLOGY=enr.get_gene_sets(gene_set_names=gene_sets, go_slims=True,set_sizes=(5,500))

# %%
# Find out max/min gene set sizes and N sets
max_n=0
min_n=np.inf
for k,v in GENE_SETS_ONTOLOGY.items():
    for s in v:
        n=len(s.genes)
        if n<min_n:
            min_n=n
        if n>max_n:
            max_n=n
print('Min size',min_n,'Max size',max_n)  
print('N sets',{k:len(v) for k,v in GENE_SETS_ONTOLOGY.items()})
# Out:
# Min size 5 Max size 440
# N sets {('Dictybase', 'Phenotypes'): 209, ('GO', 'molecular_function'): 35, ('GO', 'biological_process'): 52, ('KEGG', 'Pathways'): 96, ('GO', 'cellular_component'): 24}

# %%
for comparison in comparison_order:
    query_names=list(abberant.query('Comparison == "'+comparison+'"').index)
    enriched=group_diff_enrichment(query_names=query_names,group=comparison,min_overlap=2,use_annotated_genes=True)
# Out:
# ***  agg- selected: 162 with EID: 160
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.28
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 22 out of 45 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                       cell differentiation
# 1                           anatomical structure development
# 2   anatomical structure formation involved in morphogenesis
# 3                             aberrant spore coat morphology
# 4                                                  cell wall
# 5                           external encapsulating structure
# 6                       cell wall organization or biogenesis
# 7                                 multiple tips in culminant
# 8                               aberrant stalk morphogenesis
# 9                                  decreased spore viability
# 10                              mislocalized gene expression
# 11                                     decreased sporulation
# 12                                 cytoskeleton organization
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: biological_process  5.05e-05          11       145        145
# 1   GO: biological_process  3.60e-03          15       440        438
# 2   GO: biological_process  6.83e-03           6        74         74
# 3    Dictybase: Phenotypes  7.66e-03           3        12         12
# 4   GO: cellular_component  7.66e-03           3        13         13
# 5   GO: cellular_component  7.66e-03           3        13         13
# 6   GO: biological_process  1.03e-02           3        15         15
# 7    Dictybase: Phenotypes  1.94e-02           2         5          5
# 8    Dictybase: Phenotypes  4.73e-02           2         8          8
# 9    Dictybase: Phenotypes  5.35e-02           4        60         59
# 10   Dictybase: Phenotypes  8.87e-02           2        12         12
# 11   Dictybase: Phenotypes  2.18e-01           3        53         53
# 12  GO: biological_process  2.18e-01           6       197        196
# ***  dis selected: 550 with EID: 549
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.26
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 52 out of 142 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0                                      extracellular region
# 1                                                 cell wall
# 2                          external encapsulating structure
# 3                          anatomical structure development
# 4  anatomical structure formation involved in morphogenesis
# 5                             Starch and sucrose metabolism
# 6                            aberrant spore coat morphology
# 7                                     abolished sporulation
#
#                  Ontology       FDR  N in query  Set size  N in ref.
# 0  GO: cellular_component  7.51e-07          23       157        157
# 1  GO: cellular_component  5.04e-02           4        13         13
# 2  GO: cellular_component  5.04e-02           4        13         13
# 3  GO: biological_process  6.68e-02          28       440        438
# 4  GO: biological_process  1.33e-01           8        74         74
# 5          KEGG: Pathways  1.33e-01           5        31         31
# 6   Dictybase: Phenotypes  1.91e-01           3        12         12
# 7   Dictybase: Phenotypes  2.39e-01           4        25         25
# ***  tag selected: 39 with EID: 39
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.21
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 3 out of 8 query genes used for enrichment calculation.
#                Gene set                Ontology       FDR  N in query  \
# 0  extracellular region  GO: cellular_component  5.44e-02           3
#
#    Set size  N in ref.
# 0       157        157
# ***  cud selected: 517 with EID: 510
# Ratio of genes annotated with a gene set in reference 0.32 and query 0.21
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 39 out of 109 query genes used for enrichment calculation.
#                                                    Gene set  \
# 0                                      extracellular region
# 1  anatomical structure formation involved in morphogenesis
# 2                                      cell differentiation
# 3                                 decreased spore viability
# 4                   decreased prespore cell differentiation
# 5                                        hydrolase activity
# 6                               secondary metabolic process
# 7                                             cell adhesion
#
#                  Ontology       FDR  N in query  Set size  N in ref.
# 0  GO: cellular_component  2.50e-05          18       157        157
# 1  GO: biological_process  2.96e-04          11        74         74
# 2  GO: biological_process  1.64e-03          14       145        145
# 3   Dictybase: Phenotypes  1.30e-01           6        60         59
# 4   Dictybase: Phenotypes  1.30e-01           3        14         14
# 5  GO: molecular_function  1.30e-01           5        46         45
# 6  GO: biological_process  1.30e-01           2         5          5
# 7  GO: biological_process  1.30e-01           7        84         83

# %% [markdown]
# ### KEGG, DictyPhenotypes, GO

# %%
# Get all gene sets
gene_sets=list(list_all(organism='44689'))
GENE_SETS_ONTOLOGY=enr.get_gene_sets(gene_set_names=gene_sets, go_slims=False,set_sizes=(5,500))

# %%
# Find out max/min gene set sizes and N sets
max_n=0
min_n=np.inf
for k,v in GENE_SETS_ONTOLOGY.items():
    for s in v:
        n=len(s.genes)
        if n<min_n:
            min_n=n
        if n>max_n:
            max_n=n
print('Min size',min_n,'Max size',max_n)  
print('N sets',{k:len(v) for k,v in GENE_SETS_ONTOLOGY.items()})
# Out:
# Min size 5 Max size 481
# N sets {('Dictybase', 'Phenotypes'): 209, ('GO', 'molecular_function'): 424, ('GO', 'biological_process'): 1379, ('KEGG', 'Pathways'): 96, ('GO', 'cellular_component'): 305}

# %%
# Genes sets, not including only slims
gene_sets=list(list_all(organism='44689'))
GENE_SETS_ONTOLOGY=enr.get_gene_sets(gene_set_names=gene_sets, go_slims=False,set_sizes=(5,500))
for comparison in comparison_order:
    query_names=list(abberant.query('Comparison == "'+comparison+'"').index)
    enriched=group_diff_enrichment(query_names=query_names,group=comparison,min_overlap=2,use_annotated_genes=True)
# Out:
# ***  agg- selected: 162 with EID: 160
# Ratio of genes annotated with a gene set in reference 0.33 and query 0.31
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 40 out of 50 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                             cellular developmental process
# 1                                       cell differentiation
# 2                                       cell wall biogenesis
# 3              external encapsulating structure organization
# 4                                     cell wall organization
# 5                                        spore wall assembly
# 6                                         cell wall assembly
# 7                           cellular component morphogenesis
# 8                                      developmental process
# 9      cellular component assembly involved in morphogenesis
# 10                                     spore wall biogenesis
# 11                          anatomical structure development
# 12                                               sporulation
# 13         slug development involved in sorocarp development
# 14    sporulation resulting in formation of a cellular spore
# 15  anatomical structure formation involved in morphogenesis
# 16                                                spore wall
# 17                            aberrant spore coat morphology
# 18                        anatomical structure morphogenesis
# 19                                                 cell wall
# 20                          external encapsulating structure
# 21                      cell wall organization or biogenesis
# 22                intraspecies interaction between organisms
# 23                                      sorocarp development
# 24                non-reproductive fruiting body development
# 25                          socially cooperative development
# 26                                multiple tips in culminant
# 27                                  protein depolymerization
# 28                                              cell surface
# 29                    intrinsic component of plasma membrane
# 30                          external side of plasma membrane
# 31                              aberrant stalk morphogenesis
# 32                      cellular protein complex disassembly
# 33                                 decreased spore viability
# 34                            cellular component disassembly
# 35                    regulation of protein depolymerization
# 36                    protein-containing complex disassembly
# 37                             guanyl ribonucleotide binding
# 38                                 guanyl nucleotide binding
# 39                              mislocalized gene expression
# 40      regulation of protein-containing complex disassembly
# 41                                          sterol transport
# 42                        organic hydroxy compound transport
# 43                       sorocarp spore cell differentiation
# 44                                          side of membrane
# 45                        multicellular organism development
# 46                   regulation of cytoskeleton organization
# 47                          multicellular organismal process
# 48                                sorocarp stalk development
# 49                                sorocarp sorus development
# 50                                 protein dephosphorylation
# 51             regulation of cellular component organization
# 52                               signaling receptor activity
# 53                 transmembrane signaling receptor activity
# 54            signal transduction by protein phosphorylation
# 55                                         cellulose binding
# 56                             molecular transducer activity
# 57                           actin filament depolymerization
# 58                      regulation of organelle organization
# 59                         supramolecular fiber organization
# 60                                            cell periphery
# 61                                               GTP binding
# 62                                        nucleoside binding
# 63                             purine ribonucleoside binding
# 64                                    ribonucleoside binding
# 65                                 purine nucleoside binding
# 66              culmination involved in sorocarp development
# 67                                     decreased sporulation
# 68                                        catalytic activity
# 69                     integral component of plasma membrane
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: biological_process  2.61e-04          11       145        145
# 1   GO: biological_process  2.61e-04          11       145        145
# 2   GO: biological_process  5.19e-03           3         8          8
# 3   GO: biological_process  5.19e-03           3         8          8
# 4   GO: biological_process  5.19e-03           3         8          8
# 5   GO: biological_process  5.19e-03           3         8          8
# 6   GO: biological_process  5.19e-03           3         8          8
# 7   GO: biological_process  5.19e-03           3         8          8
# 8   GO: biological_process  5.19e-03          16       449        447
# 9   GO: biological_process  5.19e-03           3         8          8
# 10  GO: biological_process  5.19e-03           3         8          8
# 11  GO: biological_process  7.13e-03          15       440        438
# 12  GO: biological_process  9.65e-03           6        75         75
# 13  GO: biological_process  9.65e-03           3        11         11
# 14  GO: biological_process  9.65e-03           6        74         74
# 15  GO: biological_process  9.65e-03           6        74         74
# 16  GO: cellular_component  9.65e-03           3        11         11
# 17   Dictybase: Phenotypes  1.20e-02           3        12         12
# 18  GO: biological_process  1.21e-02           8       149        149
# 19  GO: cellular_component  1.33e-02           3        13         13
# 20  GO: cellular_component  1.33e-02           3        13         13
# 21  GO: biological_process  1.99e-02           3        15         15
# 22  GO: biological_process  2.51e-02          12       365        363
# 23  GO: biological_process  2.51e-02          12       365        363
# 24  GO: biological_process  2.51e-02          12       365        363
# 25  GO: biological_process  2.51e-02          12       365        363
# 26   Dictybase: Phenotypes  3.21e-02           2         5          5
# 27  GO: biological_process  3.21e-02           3        19         19
# 28  GO: cellular_component  4.18e-02           3        21         21
# 29  GO: cellular_component  5.30e-02           3        23         23
# 30  GO: cellular_component  5.93e-02           2         7          7
# 31   Dictybase: Phenotypes  7.61e-02           2         8          8
# 32  GO: biological_process  7.68e-02           3        27         27
# 33   Dictybase: Phenotypes  9.97e-02           4        60         59
# 34  GO: biological_process  1.04e-01           3        31         31
# 35  GO: biological_process  1.04e-01           2        10         10
# 36  GO: biological_process  1.04e-01           3        31         31
# 37  GO: molecular_function  1.13e-01           7       187        187
# 38  GO: molecular_function  1.14e-01           7       188        188
# 39   Dictybase: Phenotypes  1.29e-01           2        12         12
# 40  GO: biological_process  1.29e-01           2        12         12
# 41  GO: biological_process  1.29e-01           2        12         12
# 42  GO: biological_process  1.29e-01           2        12         12
# 43  GO: biological_process  1.30e-01           3        36         36
# 44  GO: cellular_component  1.45e-01           2        13         13
# 45  GO: biological_process  1.48e-01           4        72         72
# 46  GO: biological_process  1.60e-01           4        75         74
# 47  GO: biological_process  1.68e-01           4        76         76
# 48  GO: biological_process  1.68e-01           3        41         41
# 49  GO: biological_process  1.69e-01           3        42         42
# 50  GO: biological_process  1.69e-01           3        42         42
# 51  GO: biological_process  1.69e-01           5       120        119
# 52  GO: molecular_function  1.70e-01           3        43         43
# 53  GO: molecular_function  1.70e-01           3        43         43
# 54  GO: biological_process  1.70e-01           3        44         43
# 55  GO: molecular_function  1.75e-01           2        16         16
# 56  GO: molecular_function  1.85e-01           3        45         45
# 57  GO: biological_process  1.90e-01           2        17         17
# 58  GO: biological_process  2.05e-01           4        87         86
# 59  GO: biological_process  2.05e-01           5       131        130
# 60  GO: cellular_component  2.05e-01           9       340        340
# 61  GO: molecular_function  2.05e-01           6       182        182
# 62  GO: molecular_function  2.05e-01           6       182        182
# 63  GO: molecular_function  2.05e-01           6       182        182
# 64  GO: molecular_function  2.05e-01           6       182        182
# 65  GO: molecular_function  2.05e-01           6       182        182
# 66  GO: biological_process  2.05e-01           5       132        131
# 67   Dictybase: Phenotypes  2.36e-01           3        53         53
# 68  GO: molecular_function  2.36e-01          11       481        479
# 69  GO: cellular_component  2.36e-01           2        21         21
# ***  dis selected: 550 with EID: 549
# Ratio of genes annotated with a gene set in reference 0.33 and query 0.28
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 38 out of 151 query genes used for enrichment calculation.
#                                   Gene set                Ontology       FDR  \
# 0                     extracellular region  GO: cellular_component  5.67e-06
# 1  cell surface receptor signaling pathway  GO: biological_process  2.73e-02
# 2       multicellular organism development  GO: biological_process  1.92e-01
# 3                                cell wall  GO: cellular_component  1.92e-01
# 4         external encapsulating structure  GO: cellular_component  1.92e-01
# 5         multicellular organismal process  GO: biological_process  2.36e-01
#
#    N in query  Set size  N in ref.
# 0          23       157        157
# 1           8        39         39
# 2           9        72         72
# 3           4        13         13
# 4           4        13         13
# 5           9        76         76
# ***  tag selected: 39 with EID: 39
# Ratio of genes annotated with a gene set in reference 0.33 and query 0.21
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 3 out of 8 query genes used for enrichment calculation.
#                  Gene set                Ontology       FDR  N in query  \
# 0  polysaccharide binding  GO: molecular_function  6.91e-02           2
# 1    extracellular region  GO: cellular_component  1.03e-01           3
# 2    carbohydrate binding  GO: molecular_function  1.33e-01           2
#
#    Set size  N in ref.
# 0        24         24
# 1       157        157
# 2        58         58
# ***  cud selected: 517 with EID: 510
# Ratio of genes annotated with a gene set in reference 0.33 and query 0.23
# Enrichment at FDR: 0.25 and min query - gene set overlap 2
# N query genes in displayed gene sets: 39 out of 116 query genes used for enrichment calculation.
#                                                     Gene set  \
# 0                                       carbohydrate binding
# 1                                     polysaccharide binding
# 2                                       extracellular region
# 3                                          cellulose binding
# 4                                                sporulation
# 5     sporulation resulting in formation of a cellular spore
# 6   anatomical structure formation involved in morphogenesis
# 7                                          spore germination
# 8                             cellular developmental process
# 9                                       cell differentiation
# 10                        anatomical structure morphogenesis
# 11                            anchored component of membrane
#
#                   Ontology       FDR  N in query  Set size  N in ref.
# 0   GO: molecular_function  1.63e-08          15        58         58
# 1   GO: molecular_function  5.22e-05           8        24         24
# 2   GO: cellular_component  5.54e-05          18       157        157
# 3   GO: molecular_function  4.62e-04           6        16         16
# 4   GO: biological_process  5.63e-04          11        75         75
# 5   GO: biological_process  5.63e-04          11        74         74
# 6   GO: biological_process  5.63e-04          11        74         74
# 7   GO: biological_process  9.07e-04           5        12         12
# 8   GO: biological_process  2.96e-03          14       145        145
# 9   GO: biological_process  2.96e-03          14       145        145
# 10  GO: biological_process  3.64e-03          14       149        149
# 11  GO: cellular_component  1.92e-01           4        23         23
